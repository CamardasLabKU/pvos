# %%
#### Cell 0: Imports and Setup

# 1. Problem Selection and Configuration
#According to Table 2 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
problem_name = "ZDT1"
n_var = 30  # Custom number of decision variables 
n_obj = 2  # Custom number of objectives

# 2. Population Settings
# -----------------------
pop_size = 100
generations = 200

# 3. Operator-specific parameters
#According to Table 1 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
crossover_probability = 0.9
mutation_sigma = 0.5           
distribution_index_n_c = 15    # For simulated binary crossover
distribution_index_n_m = 20    # For polynomial mutation
blend_alpha = 0.5              # for blend crossover
swap_prob = 0.5                # For uniform crossover 


# 4. Select Crossover and Mutation Operators
# List all desired crossover operators to be applied in parallel.
selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    "single_point_crossover_batch",
    "blend_crossover_batch",
    "uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# Cell 1:


import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  

# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"
    return "unknown"

def get_problem_dynamic(name: str, n_var=None, n_obj=None):
    fam = _family(name)

    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for build in attempts:
        try:
            return build()
        except Exception as e:
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )








# Cell 2: Configuration Parameters

# =============================================================================
#                            PVOS-4C Configuration
# =============================================================================



problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 







# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1 


#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


#  Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices, F_start):

    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, F_start: F_start + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))


def select_parents_batch(population, rank, cd, population_size):
    """
    Perform binary tournament selection in a vectorized manner to select parents.
    """
    total_individuals = population.shape[0]
    
    # First set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents1 = np.where(better, parent1_idx, parent2_idx)

    # Second set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents2 = np.where(better, parent1_idx, parent2_idx)

    return selected_parents1, selected_parents2

#cell 4




import numpy as np

def _sbx_core_batch(parents_dec_1, parents_dec_2, xl, xu,
                    eta_arr, prob_var_arr, prob_bin_arr,
                    eps=1e-14):
    """
    Core SBX operator matching pymoo.cross_sbx, but using
    parents_dec_1, parents_dec_2 instead of X.

    parents_dec_1, parents_dec_2 : (N, D)
    eta_arr, prob_var_arr, prob_bin_arr : (N, 1)

    Returns:
        Q : (2, N, D)  # two children per mating
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    xl = np.asarray(xl, dtype=float)
    xu = np.asarray(xu, dtype=float)

    N, D = parents_dec_1.shape
    X = np.stack([parents_dec_1, parents_dec_2], axis=0)  # (2, N, D)

    # probability of crossover for each variable
    prob_var_2d = np.repeat(prob_var_arr, D, axis=1)      # (N, D)
    cross = np.random.rand(N, D) < prob_var_2d

    # when solutions are too close -> do not apply sbx crossover
    too_close = np.abs(X[0] - X[1]) <= eps
    cross[too_close] = False

    # disable crossover when lower and upper bound are identical
    cross[:, xl == xu] = False

    # if no variable crosses at all, just clamp bounds and return
    if not np.any(cross):
        Q = X.copy()
        Q[0] = np.clip(Q[0], xl, xu)
        Q[1] = np.clip(Q[1], xl, xu)
        return Q

    # flatten the crossed positions
    p1 = X[0][cross]  # (n_cross,)
    p2 = X[1][cross]

    # orientation: y1 = smaller, y2 = larger
    sm = p1 < p2
    y1 = np.where(sm, p1, p2)
    y2 = np.where(sm, p2, p1)

    # bounds repeated and masked
    _xl = np.repeat(xl[None, :], N, axis=0)[cross]
    _xu = np.repeat(xu[None, :], N, axis=0)[cross]

    # eta, prob_bin expanded to (N, D) then masked
    eta_flat = np.repeat(eta_arr, D, axis=1)[cross]       # (n_cross,)
    prob_bin_flat = np.repeat(prob_bin_arr, D, axis=1)[cross]

    # shared random for both c1 and c2 (same as pymoo)
    rand = np.random.rand(len(eta_flat))

    def calc_betaq(beta):
        alpha = 2.0 - np.power(beta, -(eta_flat + 1.0))
        mask = rand <= (1.0 / alpha)
        mask_not = ~mask

        betaq = np.zeros_like(beta)
        if np.any(mask):
            betaq[mask] = np.power(rand[mask] * alpha[mask],
                                   1.0 / (eta_flat[mask] + 1.0))
        if np.any(mask_not):
            betaq[mask_not] = np.power(
                1.0 / (2.0 - rand[mask_not] * alpha[mask_not]),
                1.0 / (eta_flat[mask_not] + 1.0)
            )
        return betaq

    # difference between parents
    delta = (y2 - y1)

    # c1
    beta = 1.0 + (2.0 * (y1 - _xl) / delta)
    betaq = calc_betaq(beta)
    c1 = 0.5 * ((y1 + y2) - betaq * delta)

    # c2
    beta = 1.0 + (2.0 * (_xu - y2) / delta)
    betaq = calc_betaq(beta)
    c2 = 0.5 * ((y1 + y2) + betaq * delta)

    # children based on parent orientation
    child1 = np.where(sm, c1, c2)  # child aligned with parent 1
    child2 = np.where(sm, c2, c1)  # child aligned with parent 2

    # exchange children with probability prob_bin_flat and orientation
    b = np.bitwise_xor(
        np.random.rand(len(prob_bin_flat)) < prob_bin_flat,
        X[0][cross] > X[1][cross]
    )
    child1_final = np.where(b, child2, child1)
    child2_final = np.where(b, child1, child2)

    # assemble Q
    Q = X.copy()
    Q[0][cross] = child1_final
    Q[1][cross] = child2_final

    # clamp to bounds
    Q[0] = np.clip(Q[0], xl, xu)
    Q[1] = np.clip(Q[1], xl, xu)
    return Q


def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     prob, eta, min_values, max_values,
                                     n_offsprings=1,
                                     prob_exch=1.0,
                                     prob_bin=0.5,
                                     eps=1e-14):
    """
    Simulated Binary Crossover (SBX) matching pymoo.SBX(prob=..., eta=..., n_offsprings=...)

    Parameters
    ----------
    parents_dec_1 : (N, D)
    parents_dec_2 : (N, D)
    prob          : float
        Per-variable crossover probability (SBX 'prob' / 'prob_var').
    eta           : float
        Distribution index.
    min_values    : (D,)  lower bounds (xl)
    max_values    : (D,)  upper bounds (xu)
    n_offsprings  : 1 or 2
    prob_exch     : float, default 1.0
        Exchange probability (SBX prob_exch).
    prob_bin      : float, default 0.5
        Per-gene child swap probability (SBX prob_bin).
    eps           : float
        Threshold for "too close" parents.

    Returns
    -------
    offspring_dec :
        if n_offsprings == 1 : shape (N, D)
        if n_offsprings == 2 : shape (2*N, D)  [first N rows child1, next N rows child2]
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    min_values = np.asarray(min_values, dtype=float)
    max_values = np.asarray(max_values, dtype=float)

    N, D = parents_dec_1.shape

    # parameter arrays (N, 1) – same idea as pymoo's get(...)
    eta_arr = np.full((N, 1), eta, dtype=float)
    prob_var_arr = np.full((N, 1), prob, dtype=float)
    prob_exch_arr = np.full((N, 1), prob_exch, dtype=float)
    prob_bin_arr = np.full((N, 1), prob_bin, dtype=float)

    # apply prob_exch: zero out prob_bin if no exchange for that mating
    rand = np.random.rand(N, 1)
    prob_bin_arr[rand > prob_exch_arr] = 0.0

    # core SBX – returns two children per mating: Q shape (2, N, D)
    Q = _sbx_core_batch(parents_dec_1, parents_dec_2,
                        min_values, max_values,
                        eta_arr, prob_var_arr, prob_bin_arr,
                        eps=eps)

    if n_offsprings == 1:
        # randomly pick one of the two offspring per mating (same as SBX.n_offsprings=2)
        child = Q[0].copy()           # (N, D)
        pick_second = np.random.rand(N) < 0.5
        child[pick_second] = Q[1, pick_second]
        return child

    elif n_offsprings == 2:
        # stack to (2*N, D): [child1_0..child1_{N-1}, child2_0..child2_{N-1}]
        return Q.reshape(2 * N, D)

    else:
        raise ValueError("n_offsprings must be 1 or 2")





def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        
    """

    num_offspring, num_decision_variables = parents_dec_1.shape

    # Start with child1 as a copy of parent 1
    child1 = parents_dec_1.copy()

    # Decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # --- NEW: handle no-crossover pairs without bias ---
    no_cross_indices = np.where(~crossover_mask)[0]
    if no_cross_indices.size > 0:
        # For each no-crossover pair, flip a coin: 0 -> keep parent 1, 1 -> copy parent 2
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        # Overwrite those children with parent 2
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # --- Existing crossover logic for the pairs that do crossover ---
    crossover_indices = np.where(crossover_mask)[0]
    if crossover_indices.size > 0:
        # One crossover point per selected pair
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        for idx, cp in zip(crossover_indices, crossover_points):
            # NEW: randomly choose orientation to remove positional bias
            if np.random.rand() < 0.5:
                # suffix from parent2
                child1[idx, cp:] = parents_dec_2[idx, cp:]
            else:
                # prefix from parent2
                child1[idx, :cp] = parents_dec_2[idx, :cp]

    # Clip to bounds and return
    child1 = np.clip(child1, min_values, max_values)
    return child1




import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):

    N, D = parents_dec_1.shape

    child1 = parents_dec_1.copy()

    do_cross = np.random.rand(N) < crossover_probability

    # Handle pairs that do NOT crossover without bias
    no_cross_idx = np.where(~do_cross)[0]
    if no_cross_idx.size > 0:
        use_parent2 = np.random.rand(no_cross_idx.size) < 0.5
        idx_parent2 = no_cross_idx[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    cross_idx = np.where(do_cross)[0]
    if cross_idx.size > 0:
        p1 = parents_dec_1[cross_idx, :]
        p2 = parents_dec_2[cross_idx, :]

        y1 = np.minimum(p1, p2)
        y2 = np.maximum(p1, p2)
        d = y2 - y1

        # Full extended range — NO clamping to bounds here
        lower_bound = y1 - alpha_blend * d
        upper_bound = y2 + alpha_blend * d

        # Sample uniformly in the extended range
        rand1 = np.random.rand(p1.shape[0], D)
        c1 = lower_bound + rand1 * (upper_bound - lower_bound)

        child1[cross_idx, :] = c1

    # Clip AFTER sampling — this creates the boundary bias that helps ZDT convergence
    child1 = np.clip(child1, min_values, max_values)
    return child1


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # Handle pairs that do NOT crossover without bias:
    # for those indices, randomly choose between parent 1 and parent 2.
    no_cross_indices = np.where(~do_cross)[0]
    if no_cross_indices.size > 0:
        # Flip a coin for each no-crossover pair:
        # True -> use parent 2, False -> keep parent 1.
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # If no pairs are selected for crossover, we are done.
    if not np.any(do_cross):
        child1 = np.clip(child1, min_values, max_values)
        return child1

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]

    # Assign the offspring genes back to the full child array.
    child1[do_cross, :] = offspring1

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)

    # Return the generated offspring decision variables.
    return child1





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec



# Cell 5: Complete PVOS-4C Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual

class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval, record_history=False):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    # objective slice in your population array [X | F] (or [X | F | CV])
    F_start = num_decision_variables
    F_end   = num_decision_variables + num_objectives

    def _eval_F_and_CV(X):
        """Evaluate F (and CV if you use it) with the same shape handling you already do."""
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(X, return_values_of=['F', 'G'])
            CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, CV
        else:
            eval_result = problem.evaluate(X)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, None
    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]
    K = len(crossover_ops)
    crossover_names = [co.__name__ for co in crossover_ops]

    def enxea_probabilities(beta):
        """
        EnXEA probability update.
        Using the quadratic rule from Sharma et al.:
            p_k ∝ beta_k^2
        """
        beta = np.asarray(beta, dtype=float)
        weights = beta ** 2
        total = np.sum(weights)

        # Safety fallback for the undefined all-zero case
        if total <= 0.0 or not np.isfinite(total):
            return np.full(K, 1.0 / K, dtype=float)

        return weights / total
    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    metrics_history = []
    front_history = []
    true_pf_history = []
    gen_history = []
    
    true_pf_static = problem.pareto_front() if hasattr(problem, "pareto_front") else None
    
    # EnXEA, Algorithm 1, Line 3: initialize all crossover success rates equally
    beta = np.full(K, 1.0 / K, dtype=float)
    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator, each crossover produced one child.
        if co == simulated_binary_crossover_batch:
            sbx = SBX(prob=crossover_probability,
                      eta=distribution_index_n_c,
                      n_offsprings=1)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            matings = [[Individual(X=p1), Individual(X=p2)]
                       for p1, p2 in zip(parents_dec_1, parents_dec_2)]
        
            # single call → (N, D) offspring
            child_dec = sbx.do(_prob, matings).get("X")      
               


        elif co == single_point_crossover_batch:
            
            child_dec= single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
  

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child_dec = polynomial_mutation_batch(
                child_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )

        elif selected_mutation_operator == gaussian_mutation_batch:
            child_dec = gaussian_mutation_batch(
                child_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )

        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        offspring_dec = child_dec                         
        
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(offspring_dec, return_values_of=['F', 'G'])
            CV   = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F, CV])
        else:
            eval_result = problem.evaluate(offspring_dec)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F])
        
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx, F_start)

        # =========================
        # EnXEA adaptive mating
        # =========================
        pair_cnt = population_size   # all your current crossover operators create 1 child per mating
        p_crossover = enxea_probabilities(beta)

        p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
        parents1_all = population[p1_idx, :num_decision_variables]
        parents2_all = population[p2_idx, :num_decision_variables]

        # Sample one crossover operator for each mating from p_k
        chosen_k = np.random.choice(K, size=pair_cnt, p=p_crossover)

        # Bookkeeping for Algorithm 1: every offspring carries the id of the operator that created it
        generated_counts = np.bincount(chosen_k, minlength=K)
        combined_offspring = np.empty((pair_cnt, population.shape[1]), dtype=float)
        offspring_operator_ids = np.empty(pair_cnt, dtype=object)

        for k, op in enumerate(crossover_ops):
            idx_k = np.where(chosen_k == k)[0]
            if idx_k.size == 0:
                continue

            res = apply_crossover_and_mutation(
                op,
                parents1_all[idx_k],
                parents2_all[idx_k],
                selected_mutation_operator,
                mutation_probability,
                distribution_index_n_c,
                distribution_index_n_m,
                mutation_sigma,
                blend_alpha,
                swap_prob,
                min_values,
                max_values,
                crossover_probability
            )

            combined_offspring[idx_k, :] = res["offspring"]
            offspring_operator_ids[idx_k] = crossover_names[k]

        # Keep parent count so we can implement P(t) \ P(t-1) exactly after survival
        n_parents = population.shape[0]

        
        # Now combine the populations
        combined_pop = np.vstack([population, combined_offspring])
        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))

        for r in range(1, rank_combined.max()+1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx, F_start)


        # Environmental selection
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted([(i, crowding_combined[i]) for i in front_idx], 
                                    key=lambda x: -x[1])
                survivors.extend([i for i, _ in sorted_front[:population_size-len(survivors)]])
            current_rank += 1

        survivor_array = np.asarray(survivors, dtype=int)

        # EnXEA update:
        # beta_k = (# surviving offspring created by operator k) / (# offspring created by operator k)
        # Important: count only offspring that enter the next population, not surviving parents.
        survived_offspring_mask = survivor_array >= n_parents
        survived_offspring_local_idx = survivor_array[survived_offspring_mask] - n_parents
        survived_offspring_ids = offspring_operator_ids[survived_offspring_local_idx]

        survived_counts = np.array(
            [np.sum(survived_offspring_ids == name) for name in crossover_names],
            dtype=float
        )

        # Practical guard for the zero-denominator case:
        # if an operator received no matings this generation, keep its previous beta.
        beta_next = beta.copy()
        used_mask = generated_counts > 0
        beta_next[used_mask] = survived_counts[used_mask] / generated_counts[used_mask]
        beta = beta_next

        population = combined_pop[survivors]

        survival_stats = {
            name: int(cnt) for name, cnt in zip(crossover_names, survived_counts)
        }
        probability_stats = {
            name: float(prob) for name, prob in zip(crossover_names, p_crossover)
        }

        print("EnXEA probabilities:", {k: round(v, 4) for k, v in probability_stats.items()})
        print("EnXEA offspring survivors:", survival_stats)

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]
        if record_history:
            front_history.append(non_dominated_front.copy())
            true_pf_history.append(true_pf_static.copy() if true_pf_static is not None else None)
            gen_history.append(generation)

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["crossover_probabilities"] = probability_stats
            metrics_results["beta"] = {name: float(b) for name, b in zip(crossover_names, beta)}
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time
            metrics_results["pair_cnt"] = pair_cnt
            #metrics_results["pm_used"] = [mut_prob_eff] * len(crossover_ops)
            #metrics_results["eta_m_used"] = [eta_m_eff] * len(crossover_ops)

            # how many offspring were evaluated this generation
            metrics_results["offspring_evals"] = combined_offspring.shape[0]

            # evaluations used for change detection sampling each gen
            #metrics_results["sample_evals"] = n_samples

            # evaluations used when you re-evaluate the whole population after a change
           # metrics_results["parent_reeval_evals"] = population_size if change_detected else 0

            #metrics_results["total_evals_this_gen"] = (
            #    combined_offspring.shape[0] 
            #)
            # ----------------------------------------------------------------------            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    history = None
    if record_history:
        history = {
            "front": front_history,
            "true_pf": true_pf_history,
            "generation": gen_history
        }
    
    return population, problem.pareto_front(), metrics_history, history




#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts (using Pymoo data for the analytical solution)
    
    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib



# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    


    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,  
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points,
        'history': history

    }

# Run NSGA-II in parallel for seeds 1 to 30 (or 31 if you prefer 1 to 31) in series 
seeds = range(1, 2)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    


    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],

            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)

        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.25, 'single_point_crossover_batch': 0.25, 'blend_crossover_batch': 0.25, 'uniform_crossover_batch': 0.25}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 17}
# Gen 1: hypervolume=0.0000, igd=1.9284, gd=2.6843, gd_plus=2.6843, igd_plus=1.9284, spacing=0.3907, generation=1.0000, generation_time=0.0072, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1666, 'single_point_crossover_batch': 0.3868, 'blend_crossover_batch': 0.2176, 'uniform_crossover_batch': 0.229}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 18}
# Gen 2: hypervolume=0.0000, igd=1.9284, gd=2.5933, gd_plus=2.5933, igd_plus=1.9284, spacing=0.3475, generation=2.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3456, 'single_point_crossover_batch': 0.2212, 'blend_crossover_batch': 0.126, 'uniform_crossover_batch': 0.3072}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 16}
# Gen 3: hypervolume=0.0000, igd=1.8643, gd=2.4626, gd_plus=2.4626, igd_plus=1.8643, spacing=0.0960, generation=3.0000, generation_time=0.0062, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.26, 'single_point_crossover_batch': 0.3146, 'blend_crossover_batch': 0.224, 'uniform_crossover_batch': 0.2014}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 13}
# Gen 4: hypervolume=0.0000, igd=1.7093, gd=2.1291, gd_plus=2.1291, igd_plus=1.7093, spacing=0.1096, generation=4.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2741, 'single_point_crossover_batch': 0.2741, 'blend_crossover_batch': 0.1869, 'uniform_crossover_batch': 0.2649}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 15}
# Gen 5: hypervolume=0.0000, igd=1.2447, gd=1.5639, gd_plus=1.5639, igd_plus=1.2446, spacing=0.3500, generation=5.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3083, 'single_point_crossover_batch': 0.2325, 'blend_crossover_batch': 0.2524, 'uniform_crossover_batch': 0.2068}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 9}
# Gen 6: hypervolume=0.0000, igd=1.2408, gd=1.5602, gd_plus=1.5602, igd_plus=1.2408, spacing=0.1404, generation=6.0000, generation_time=0.0068, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.267, 'single_point_crossover_batch': 0.2784, 'blend_crossover_batch': 0.2058, 'uniform_crossover_batch': 0.2488}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 13}
# Gen 7: hypervolume=0.0000, igd=1.1254, gd=1.3162, gd_plus=1.3162, igd_plus=1.1254, spacing=0.0917, generation=7.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2716, 'single_point_crossover_batch': 0.1807, 'blend_crossover_batch': 0.2423, 'uniform_crossover_batch': 0.3054}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 15}
# Gen 8: hypervolume=0.0000, igd=0.9705, gd=1.1914, gd_plus=1.1914, igd_plus=0.9689, spacing=0.1836, generation=8.0000, generation_time=0.0063, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2202, 'single_point_crossover_batch': 0.2802, 'blend_crossover_batch': 0.2105, 'uniform_crossover_batch': 0.2891}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 17}
# Gen 9: hypervolume=0.0000, igd=0.9703, gd=1.0422, gd_plus=1.0422, igd_plus=0.9687, spacing=0.1068, generation=9.0000, generation_time=0.0076, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1426, 'single_point_crossover_batch': 0.2599, 'blend_crossover_batch': 0.3494, 'uniform_crossover_batch': 0.2481}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 8}
# Gen 10: hypervolume=0.0310, igd=0.7927, gd=0.8720, gd_plus=0.8720, igd_plus=0.7924, spacing=0.0996, generation=10.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2509, 'single_point_crossover_batch': 0.2432, 'blend_crossover_batch': 0.3829, 'uniform_crossover_batch': 0.123}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 10}
# Gen 11: hypervolume=0.0357, igd=0.7920, gd=0.8422, gd_plus=0.8422, igd_plus=0.7917, spacing=0.0309, generation=11.0000, generation_time=0.0084, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3103, 'single_point_crossover_batch': 0.2866, 'blend_crossover_batch': 0.2164, 'uniform_crossover_batch': 0.1867}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 14}
# Gen 12: hypervolume=0.0458, igd=0.7628, gd=0.7711, gd_plus=0.7711, igd_plus=0.7628, spacing=0.0737, generation=12.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3219, 'single_point_crossover_batch': 0.1392, 'blend_crossover_batch': 0.3021, 'uniform_crossover_batch': 0.2368}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 17}
# Gen 13: hypervolume=0.0740, igd=0.6998, gd=0.6393, gd_plus=0.6393, igd_plus=0.6994, spacing=0.0601, generation=13.0000, generation_time=0.0082, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2261, 'single_point_crossover_batch': 0.2154, 'blend_crossover_batch': 0.2488, 'uniform_crossover_batch': 0.3096}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 17}
# Gen 14: hypervolume=0.1256, igd=0.5909, gd=0.5932, gd_plus=0.5932, igd_plus=0.5909, spacing=0.0621, generation=14.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3188, 'single_point_crossover_batch': 0.1621, 'blend_crossover_batch': 0.3014, 'uniform_crossover_batch': 0.2177}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 17}
# Gen 15: hypervolume=0.2194, igd=0.4921, gd=0.5807, gd_plus=0.5807, igd_plus=0.4921, spacing=0.0611, generation=15.0000, generation_time=0.0085, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3521, 'single_point_crossover_batch': 0.1346, 'blend_crossover_batch': 0.1244, 'uniform_crossover_batch': 0.3889}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 23}
# Gen 16: hypervolume=0.2440, igd=0.4512, gd=0.4773, gd_plus=0.4773, igd_plus=0.4506, spacing=0.0649, generation=16.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1768, 'single_point_crossover_batch': 0.2745, 'blend_crossover_batch': 0.3389, 'uniform_crossover_batch': 0.2098}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 17}
# Gen 17: hypervolume=0.2956, igd=0.3962, gd=0.4300, gd_plus=0.4300, igd_plus=0.3954, spacing=0.0413, generation=17.0000, generation_time=0.0080, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1938, 'single_point_crossover_batch': 0.2081, 'blend_crossover_batch': 0.2712, 'uniform_crossover_batch': 0.3269}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 17}
# Gen 18: hypervolume=0.3181, igd=0.3814, gd=0.4136, gd_plus=0.4136, igd_plus=0.3814, spacing=0.0384, generation=18.0000, generation_time=0.0082, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1832, 'single_point_crossover_batch': 0.4121, 'blend_crossover_batch': 0.2216, 'uniform_crossover_batch': 0.1832}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 27, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 12}
# Gen 19: hypervolume=0.3469, igd=0.3623, gd=0.3911, gd_plus=0.3911, igd_plus=0.3623, spacing=0.0357, generation=19.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2748, 'single_point_crossover_batch': 0.2322, 'blend_crossover_batch': 0.1425, 'uniform_crossover_batch': 0.3505}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 19}
# Gen 20: hypervolume=0.3743, igd=0.3458, gd=0.3679, gd_plus=0.3679, igd_plus=0.3458, spacing=0.0310, generation=20.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2157, 'single_point_crossover_batch': 0.2624, 'blend_crossover_batch': 0.334, 'uniform_crossover_batch': 0.1879}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 11}
# Gen 21: hypervolume=0.4144, igd=0.2981, gd=0.3385, gd_plus=0.3385, igd_plus=0.2981, spacing=0.0484, generation=21.0000, generation_time=0.0083, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2782, 'single_point_crossover_batch': 0.3182, 'blend_crossover_batch': 0.2247, 'uniform_crossover_batch': 0.179}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 5}
# Gen 22: hypervolume=0.4307, igd=0.2932, gd=0.3109, gd_plus=0.3109, igd_plus=0.2932, spacing=0.0469, generation=22.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2018, 'single_point_crossover_batch': 0.32, 'blend_crossover_batch': 0.32, 'uniform_crossover_batch': 0.1582}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 7}
# Gen 23: hypervolume=0.4594, igd=0.2637, gd=0.2901, gd_plus=0.2901, igd_plus=0.2637, spacing=0.0389, generation=23.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3664, 'single_point_crossover_batch': 0.0871, 'blend_crossover_batch': 0.2386, 'uniform_crossover_batch': 0.3079}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 21}
# Gen 24: hypervolume=0.4813, igd=0.2515, gd=0.2737, gd_plus=0.2737, igd_plus=0.2515, spacing=0.0368, generation=24.0000, generation_time=0.0071, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2678, 'single_point_crossover_batch': 0.1424, 'blend_crossover_batch': 0.2805, 'uniform_crossover_batch': 0.3093}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 15}
# Gen 25: hypervolume=0.5067, igd=0.2307, gd=0.2416, gd_plus=0.2416, igd_plus=0.2307, spacing=0.0293, generation=25.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4454, 'single_point_crossover_batch': 0.2655, 'blend_crossover_batch': 0.1301, 'uniform_crossover_batch': 0.1591}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 8}
# Gen 26: hypervolume=0.5249, igd=0.2204, gd=0.2276, gd_plus=0.2275, igd_plus=0.2204, spacing=0.0293, generation=26.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2184, 'single_point_crossover_batch': 0.3237, 'blend_crossover_batch': 0.2853, 'uniform_crossover_batch': 0.1726}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 6}
# Gen 27: hypervolume=0.5614, igd=0.1986, gd=0.2037, gd_plus=0.2036, igd_plus=0.1985, spacing=0.0225, generation=27.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3806, 'single_point_crossover_batch': 0.2315, 'blend_crossover_batch': 0.2483, 'uniform_crossover_batch': 0.1397}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 26, 'uniform_crossover_batch': 3}
# Gen 28: hypervolume=0.5836, igd=0.1858, gd=0.1765, gd_plus=0.1764, igd_plus=0.1858, spacing=0.0250, generation=28.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4076, 'single_point_crossover_batch': 0.1567, 'blend_crossover_batch': 0.3269, 'uniform_crossover_batch': 0.1088}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 7}
# Gen 29: hypervolume=0.6012, igd=0.1737, gd=0.1680, gd_plus=0.1678, igd_plus=0.1737, spacing=0.0238, generation=29.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.273, 'single_point_crossover_batch': 0.1947, 'blend_crossover_batch': 0.2673, 'uniform_crossover_batch': 0.265}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 13}
# Gen 30: hypervolume=0.6209, igd=0.1585, gd=0.1579, gd_plus=0.1578, igd_plus=0.1585, spacing=0.0277, generation=30.0000, generation_time=0.0071, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2614, 'single_point_crossover_batch': 0.1929, 'blend_crossover_batch': 0.2075, 'uniform_crossover_batch': 0.3382}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 15}
# Gen 31: hypervolume=0.6550, igd=0.1336, gd=0.1360, gd_plus=0.1359, igd_plus=0.1335, spacing=0.0242, generation=31.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2751, 'single_point_crossover_batch': 0.2864, 'blend_crossover_batch': 0.1868, 'uniform_crossover_batch': 0.2517}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 11}
# Gen 32: hypervolume=0.6723, igd=0.1217, gd=0.1306, gd_plus=0.1303, igd_plus=0.1216, spacing=0.0266, generation=32.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3733, 'single_point_crossover_batch': 0.2591, 'blend_crossover_batch': 0.2327, 'uniform_crossover_batch': 0.1349}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 6}
# Gen 33: hypervolume=0.6787, igd=0.1186, gd=0.1231, gd_plus=0.1230, igd_plus=0.1185, spacing=0.0252, generation=33.0000, generation_time=0.0092, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2315, 'single_point_crossover_batch': 0.2155, 'blend_crossover_batch': 0.1836, 'uniform_crossover_batch': 0.3693}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 12}
# Gen 34: hypervolume=0.6973, igd=0.1060, gd=0.1111, gd_plus=0.1107, igd_plus=0.1057, spacing=0.0324, generation=34.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2123, 'single_point_crossover_batch': 0.3317, 'blend_crossover_batch': 0.2437, 'uniform_crossover_batch': 0.2123}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 13}
# Gen 35: hypervolume=0.7041, igd=0.1024, gd=0.1064, gd_plus=0.1061, igd_plus=0.1022, spacing=0.0291, generation=35.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1874, 'single_point_crossover_batch': 0.248, 'blend_crossover_batch': 0.1355, 'uniform_crossover_batch': 0.4291}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 26}
# Gen 36: hypervolume=0.7160, igd=0.0947, gd=0.0924, gd_plus=0.0920, igd_plus=0.0946, spacing=0.0229, generation=36.0000, generation_time=0.0128, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3152, 'single_point_crossover_batch': 0.1897, 'blend_crossover_batch': 0.2686, 'uniform_crossover_batch': 0.2266}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 6}
# Gen 37: hypervolume=0.7273, igd=0.0894, gd=0.0901, gd_plus=0.0895, igd_plus=0.0894, spacing=0.0197, generation=37.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.295, 'single_point_crossover_batch': 0.2503, 'blend_crossover_batch': 0.3139, 'uniform_crossover_batch': 0.1408}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 6}
# Gen 38: hypervolume=0.7392, igd=0.0822, gd=0.0829, gd_plus=0.0823, igd_plus=0.0822, spacing=0.0174, generation=38.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1933, 'single_point_crossover_batch': 0.3863, 'blend_crossover_batch': 0.1536, 'uniform_crossover_batch': 0.2668}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 13}
# Gen 39: hypervolume=0.7456, igd=0.0775, gd=0.0798, gd_plus=0.0792, igd_plus=0.0775, spacing=0.0186, generation=39.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.105, 'single_point_crossover_batch': 0.2234, 'blend_crossover_batch': 0.4201, 'uniform_crossover_batch': 0.2515}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 15}
# Gen 40: hypervolume=0.7553, igd=0.0713, gd=0.0734, gd_plus=0.0728, igd_plus=0.0713, spacing=0.0163, generation=40.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1355, 'single_point_crossover_batch': 0.2306, 'blend_crossover_batch': 0.3658, 'uniform_crossover_batch': 0.268}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 11}
# Gen 41: hypervolume=0.7622, igd=0.0684, gd=0.0706, gd_plus=0.0698, igd_plus=0.0684, spacing=0.0134, generation=41.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1976, 'single_point_crossover_batch': 0.3139, 'blend_crossover_batch': 0.221, 'uniform_crossover_batch': 0.2675}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 11}
# Gen 42: hypervolume=0.7703, igd=0.0641, gd=0.0663, gd_plus=0.0661, igd_plus=0.0641, spacing=0.0101, generation=42.0000, generation_time=0.0083, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2509, 'single_point_crossover_batch': 0.163, 'blend_crossover_batch': 0.3979, 'uniform_crossover_batch': 0.1881}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 7}
# Gen 43: hypervolume=0.7760, igd=0.0602, gd=0.0600, gd_plus=0.0599, igd_plus=0.0601, spacing=0.0148, generation=43.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1476, 'single_point_crossover_batch': 0.1552, 'blend_crossover_batch': 0.2873, 'uniform_crossover_batch': 0.4099}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 23}
# Gen 44: hypervolume=0.7846, igd=0.0541, gd=0.0550, gd_plus=0.0548, igd_plus=0.0540, spacing=0.0142, generation=44.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1922, 'single_point_crossover_batch': 0.2834, 'blend_crossover_batch': 0.1677, 'uniform_crossover_batch': 0.3567}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 24}
# Gen 45: hypervolume=0.7954, igd=0.0475, gd=0.0498, gd_plus=0.0497, igd_plus=0.0473, spacing=0.0158, generation=45.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3195, 'single_point_crossover_batch': 0.195, 'blend_crossover_batch': 0.1797, 'uniform_crossover_batch': 0.3058}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 15}
# Gen 46: hypervolume=0.7990, igd=0.0452, gd=0.0461, gd_plus=0.0457, igd_plus=0.0450, spacing=0.0155, generation=46.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3195, 'single_point_crossover_batch': 0.1855, 'blend_crossover_batch': 0.1502, 'uniform_crossover_batch': 0.3449}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 14}
# Gen 47: hypervolume=0.8056, igd=0.0412, gd=0.0421, gd_plus=0.0417, igd_plus=0.0411, spacing=0.0143, generation=47.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3551, 'single_point_crossover_batch': 0.2007, 'blend_crossover_batch': 0.2541, 'uniform_crossover_batch': 0.19}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 3}
# Gen 48: hypervolume=0.8113, igd=0.0375, gd=0.0394, gd_plus=0.0391, igd_plus=0.0373, spacing=0.0132, generation=48.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3976, 'single_point_crossover_batch': 0.3314, 'blend_crossover_batch': 0.2331, 'uniform_crossover_batch': 0.0379}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 49: hypervolume=0.8160, igd=0.0348, gd=0.0380, gd_plus=0.0371, igd_plus=0.0345, spacing=0.0112, generation=49.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4191, 'single_point_crossover_batch': 0.3179, 'blend_crossover_batch': 0.2631, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Gen 50: hypervolume=0.8188, igd=0.0338, gd=0.0356, gd_plus=0.0347, igd_plus=0.0335, spacing=0.0110, generation=50.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1212, 'single_point_crossover_batch': 0.2374, 'blend_crossover_batch': 0.6415, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 0}
# Gen 51: hypervolume=0.8254, igd=0.0300, gd=0.0310, gd_plus=0.0302, igd_plus=0.0298, spacing=0.0107, generation=51.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.346, 'single_point_crossover_batch': 0.49, 'blend_crossover_batch': 0.164, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 22, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 52: hypervolume=0.8288, igd=0.0278, gd=0.0288, gd_plus=0.0280, igd_plus=0.0276, spacing=0.0106, generation=52.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3606, 'single_point_crossover_batch': 0.3564, 'blend_crossover_batch': 0.2829, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 53: hypervolume=0.8322, igd=0.0264, gd=0.0278, gd_plus=0.0268, igd_plus=0.0260, spacing=0.0098, generation=53.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3083, 'single_point_crossover_batch': 0.1457, 'blend_crossover_batch': 0.5459, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 26, 'uniform_crossover_batch': 0}
# Gen 54: hypervolume=0.8363, igd=0.0237, gd=0.0253, gd_plus=0.0240, igd_plus=0.0233, spacing=0.0077, generation=54.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3533, 'single_point_crossover_batch': 0.3052, 'blend_crossover_batch': 0.3414, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 55: hypervolume=0.8390, igd=0.0220, gd=0.0234, gd_plus=0.0222, igd_plus=0.0217, spacing=0.0072, generation=55.0000, generation_time=0.0079, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3922, 'single_point_crossover_batch': 0.3717, 'blend_crossover_batch': 0.2361, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Gen 56: hypervolume=0.8414, igd=0.0205, gd=0.0221, gd_plus=0.0208, igd_plus=0.0202, spacing=0.0082, generation=56.0000, generation_time=0.0071, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2403, 'single_point_crossover_batch': 0.4785, 'blend_crossover_batch': 0.2812, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 0}
# Gen 57: hypervolume=0.8427, igd=0.0196, gd=0.0211, gd_plus=0.0199, igd_plus=0.0194, spacing=0.0075, generation=57.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.205, 'single_point_crossover_batch': 0.1414, 'blend_crossover_batch': 0.6536, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 28, 'uniform_crossover_batch': 0}
# Gen 58: hypervolume=0.8445, igd=0.0184, gd=0.0201, gd_plus=0.0189, igd_plus=0.0182, spacing=0.0071, generation=58.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.341, 'single_point_crossover_batch': 0.184, 'blend_crossover_batch': 0.475, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Gen 59: hypervolume=0.8459, igd=0.0176, gd=0.0190, gd_plus=0.0178, igd_plus=0.0174, spacing=0.0056, generation=59.0000, generation_time=0.0080, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4277, 'single_point_crossover_batch': 0.3501, 'blend_crossover_batch': 0.2222, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 60: hypervolume=0.8467, igd=0.0171, gd=0.0187, gd_plus=0.0173, igd_plus=0.0169, spacing=0.0056, generation=60.0000, generation_time=0.0066, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.39, 'single_point_crossover_batch': 0.3428, 'blend_crossover_batch': 0.2671, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 0}
# Gen 61: hypervolume=0.8480, igd=0.0162, gd=0.0177, gd_plus=0.0161, igd_plus=0.0161, spacing=0.0063, generation=61.0000, generation_time=0.0076, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.468, 'single_point_crossover_batch': 0.2348, 'blend_crossover_batch': 0.2972, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 62: hypervolume=0.8491, igd=0.0154, gd=0.0170, gd_plus=0.0155, igd_plus=0.0154, spacing=0.0060, generation=62.0000, generation_time=0.0075, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.257, 'single_point_crossover_batch': 0.3139, 'blend_crossover_batch': 0.4291, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 63: hypervolume=0.8498, igd=0.0150, gd=0.0164, gd_plus=0.0149, igd_plus=0.0150, spacing=0.0062, generation=63.0000, generation_time=0.0075, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4374, 'single_point_crossover_batch': 0.3243, 'blend_crossover_batch': 0.2383, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# Gen 64: hypervolume=0.8506, igd=0.0146, gd=0.0159, gd_plus=0.0147, igd_plus=0.0145, spacing=0.0067, generation=64.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4583, 'single_point_crossover_batch': 0.3661, 'blend_crossover_batch': 0.1756, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 0}
# Gen 65: hypervolume=0.8513, igd=0.0141, gd=0.0155, gd_plus=0.0143, igd_plus=0.0141, spacing=0.0067, generation=65.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.629, 'single_point_crossover_batch': 0.1701, 'blend_crossover_batch': 0.2009, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 0}
# Gen 66: hypervolume=0.8521, igd=0.0138, gd=0.0148, gd_plus=0.0136, igd_plus=0.0137, spacing=0.0062, generation=66.0000, generation_time=0.0069, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3846, 'single_point_crossover_batch': 0.1729, 'blend_crossover_batch': 0.4426, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 0}
# Gen 67: hypervolume=0.8534, igd=0.0130, gd=0.0141, gd_plus=0.0129, igd_plus=0.0129, spacing=0.0049, generation=67.0000, generation_time=0.0074, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.159, 'single_point_crossover_batch': 0.6062, 'blend_crossover_batch': 0.2347, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 0}
# Gen 68: hypervolume=0.8543, igd=0.0126, gd=0.0134, gd_plus=0.0125, igd_plus=0.0125, spacing=0.0063, generation=68.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1187, 'single_point_crossover_batch': 0.54, 'blend_crossover_batch': 0.3413, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 0}
# Gen 69: hypervolume=0.8551, igd=0.0121, gd=0.0131, gd_plus=0.0122, igd_plus=0.0120, spacing=0.0057, generation=69.0000, generation_time=0.0043, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4268, 'single_point_crossover_batch': 0.1291, 'blend_crossover_batch': 0.4441, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 70: hypervolume=0.8553, igd=0.0119, gd=0.0130, gd_plus=0.0114, igd_plus=0.0118, spacing=0.0063, generation=70.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2152, 'single_point_crossover_batch': 0.4842, 'blend_crossover_batch': 0.3006, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 0}
# Gen 71: hypervolume=0.8559, igd=0.0116, gd=0.0126, gd_plus=0.0113, igd_plus=0.0114, spacing=0.0066, generation=71.0000, generation_time=0.0044, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4567, 'single_point_crossover_batch': 0.2107, 'blend_crossover_batch': 0.3326, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 72: hypervolume=0.8566, igd=0.0112, gd=0.0120, gd_plus=0.0108, igd_plus=0.0110, spacing=0.0062, generation=72.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2357, 'single_point_crossover_batch': 0.3753, 'blend_crossover_batch': 0.3891, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 0}
# Gen 73: hypervolume=0.8571, igd=0.0109, gd=0.0116, gd_plus=0.0103, igd_plus=0.0107, spacing=0.0069, generation=73.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3555, 'single_point_crossover_batch': 0.1236, 'blend_crossover_batch': 0.5209, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 0}
# Gen 74: hypervolume=0.8575, igd=0.0107, gd=0.0115, gd_plus=0.0101, igd_plus=0.0105, spacing=0.0058, generation=74.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2446, 'single_point_crossover_batch': 0.3822, 'blend_crossover_batch': 0.3732, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 75: hypervolume=0.8577, igd=0.0106, gd=0.0115, gd_plus=0.0102, igd_plus=0.0104, spacing=0.0067, generation=75.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4569, 'single_point_crossover_batch': 0.2082, 'blend_crossover_batch': 0.3349, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 76: hypervolume=0.8580, igd=0.0106, gd=0.0114, gd_plus=0.0101, igd_plus=0.0104, spacing=0.0059, generation=76.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3595, 'single_point_crossover_batch': 0.0841, 'blend_crossover_batch': 0.5565, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 77: hypervolume=0.8587, igd=0.0102, gd=0.0109, gd_plus=0.0097, igd_plus=0.0100, spacing=0.0067, generation=77.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5242, 'single_point_crossover_batch': 0.1985, 'blend_crossover_batch': 0.2773, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 78: hypervolume=0.8597, igd=0.0096, gd=0.0107, gd_plus=0.0092, igd_plus=0.0093, spacing=0.0081, generation=78.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3065, 'single_point_crossover_batch': 0.3119, 'blend_crossover_batch': 0.3816, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Gen 79: hypervolume=0.8599, igd=0.0095, gd=0.0101, gd_plus=0.0090, igd_plus=0.0092, spacing=0.0072, generation=79.0000, generation_time=0.0047, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4872, 'single_point_crossover_batch': 0.304, 'blend_crossover_batch': 0.2087, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 0}
# Gen 80: hypervolume=0.8606, igd=0.0091, gd=0.0099, gd_plus=0.0087, igd_plus=0.0088, spacing=0.0064, generation=80.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0967, 'single_point_crossover_batch': 0.355, 'blend_crossover_batch': 0.5483, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Gen 81: hypervolume=0.8605, igd=0.0091, gd=0.0099, gd_plus=0.0087, igd_plus=0.0089, spacing=0.0066, generation=81.0000, generation_time=0.0042, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4576, 'single_point_crossover_batch': 0.2175, 'blend_crossover_batch': 0.3249, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 82: hypervolume=0.8610, igd=0.0087, gd=0.0094, gd_plus=0.0082, igd_plus=0.0085, spacing=0.0068, generation=82.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4486, 'single_point_crossover_batch': 0.2289, 'blend_crossover_batch': 0.3225, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 83: hypervolume=0.8616, igd=0.0082, gd=0.0090, gd_plus=0.0078, igd_plus=0.0080, spacing=0.0060, generation=83.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1328, 'single_point_crossover_batch': 0.5091, 'blend_crossover_batch': 0.3581, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 84: hypervolume=0.8621, igd=0.0080, gd=0.0087, gd_plus=0.0075, igd_plus=0.0078, spacing=0.0063, generation=84.0000, generation_time=0.0024, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4397, 'single_point_crossover_batch': 0.3204, 'blend_crossover_batch': 0.2399, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 0}
# Gen 85: hypervolume=0.8619, igd=0.0082, gd=0.0087, gd_plus=0.0073, igd_plus=0.0079, spacing=0.0072, generation=85.0000, generation_time=0.0038, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3625, 'single_point_crossover_batch': 0.3625, 'blend_crossover_batch': 0.275, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 0}
# Gen 86: hypervolume=0.8624, igd=0.0079, gd=0.0086, gd_plus=0.0071, igd_plus=0.0076, spacing=0.0071, generation=86.0000, generation_time=0.0026, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.242, 'single_point_crossover_batch': 0.343, 'blend_crossover_batch': 0.415, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 87: hypervolume=0.8629, igd=0.0078, gd=0.0086, gd_plus=0.0070, igd_plus=0.0074, spacing=0.0070, generation=87.0000, generation_time=0.0031, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4198, 'single_point_crossover_batch': 0.2113, 'blend_crossover_batch': 0.3689, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 88: hypervolume=0.8625, igd=0.0079, gd=0.0086, gd_plus=0.0068, igd_plus=0.0076, spacing=0.0077, generation=88.0000, generation_time=0.0043, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1711, 'single_point_crossover_batch': 0.3089, 'blend_crossover_batch': 0.52, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Gen 89: hypervolume=0.8627, igd=0.0078, gd=0.0084, gd_plus=0.0067, igd_plus=0.0075, spacing=0.0079, generation=89.0000, generation_time=0.0073, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2404, 'single_point_crossover_batch': 0.3621, 'blend_crossover_batch': 0.3974, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 0}
# Gen 90: hypervolume=0.8632, igd=0.0075, gd=0.0086, gd_plus=0.0065, igd_plus=0.0072, spacing=0.0065, generation=90.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4376, 'single_point_crossover_batch': 0.2204, 'blend_crossover_batch': 0.3421, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 91: hypervolume=0.8635, igd=0.0074, gd=0.0085, gd_plus=0.0064, igd_plus=0.0071, spacing=0.0066, generation=91.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4725, 'single_point_crossover_batch': 0.2997, 'blend_crossover_batch': 0.2278, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# ...
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 170: hypervolume=0.8680, igd=0.0054, gd=0.0059, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0073, generation=170.0000, generation_time=0.0088, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6605, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3395, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 171: hypervolume=0.8681, igd=0.0054, gd=0.0057, gd_plus=0.0040, igd_plus=0.0046, spacing=0.0077, generation=171.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3428, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6572, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 172: hypervolume=0.8680, igd=0.0053, gd=0.0057, gd_plus=0.0040, igd_plus=0.0045, spacing=0.0075, generation=172.0000, generation_time=0.0085, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4507, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5493, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 173: hypervolume=0.8680, igd=0.0054, gd=0.0057, gd_plus=0.0040, igd_plus=0.0045, spacing=0.0074, generation=173.0000, generation_time=0.0090, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.639, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.361, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 0}
# Gen 174: hypervolume=0.8681, igd=0.0052, gd=0.0056, gd_plus=0.0039, igd_plus=0.0043, spacing=0.0066, generation=174.0000, generation_time=0.0062, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.401, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.599, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 0}
# Gen 175: hypervolume=0.8680, igd=0.0053, gd=0.0057, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0067, generation=175.0000, generation_time=0.0076, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5078, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4922, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 176: hypervolume=0.8684, igd=0.0051, gd=0.0055, gd_plus=0.0039, igd_plus=0.0042, spacing=0.0071, generation=176.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5795, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4205, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 177: hypervolume=0.8684, igd=0.0052, gd=0.0059, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0065, generation=177.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4601, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5399, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 0}
# Gen 178: hypervolume=0.8682, igd=0.0055, gd=0.0063, gd_plus=0.0038, igd_plus=0.0045, spacing=0.0072, generation=178.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.416, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.584, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 0}
# Gen 179: hypervolume=0.8682, igd=0.0053, gd=0.0060, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0083, generation=179.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3495, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6505, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 0}
# Gen 180: hypervolume=0.8687, igd=0.0053, gd=0.0058, gd_plus=0.0036, igd_plus=0.0042, spacing=0.0062, generation=180.0000, generation_time=0.0044, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6677, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3323, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Gen 181: hypervolume=0.8688, igd=0.0050, gd=0.0058, gd_plus=0.0035, igd_plus=0.0040, spacing=0.0058, generation=181.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.527, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.473, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 182: hypervolume=0.8687, igd=0.0050, gd=0.0059, gd_plus=0.0037, igd_plus=0.0041, spacing=0.0058, generation=182.0000, generation_time=0.0062, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5315, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4685, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 0}
# Gen 183: hypervolume=0.8687, igd=0.0051, gd=0.0061, gd_plus=0.0039, igd_plus=0.0042, spacing=0.0067, generation=183.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.593, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.407, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 184: hypervolume=0.8689, igd=0.0049, gd=0.0062, gd_plus=0.0037, igd_plus=0.0041, spacing=0.0063, generation=184.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5948, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4052, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 185: hypervolume=0.8690, igd=0.0049, gd=0.0058, gd_plus=0.0037, igd_plus=0.0041, spacing=0.0064, generation=185.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.7229, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2771, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Gen 186: hypervolume=0.8687, igd=0.0053, gd=0.0063, gd_plus=0.0037, igd_plus=0.0043, spacing=0.0072, generation=186.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6648, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3352, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Gen 187: hypervolume=0.8688, igd=0.0051, gd=0.0057, gd_plus=0.0036, igd_plus=0.0042, spacing=0.0067, generation=187.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4114, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5886, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 0}
# Gen 188: hypervolume=0.8687, igd=0.0053, gd=0.0060, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0066, generation=188.0000, generation_time=0.0047, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6778, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3222, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 189: hypervolume=0.8684, igd=0.0054, gd=0.0061, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0071, generation=189.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3593, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6407, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 190: hypervolume=0.8687, igd=0.0053, gd=0.0058, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0069, generation=190.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.7722, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2278, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 0}
# Gen 191: hypervolume=0.8688, igd=0.0052, gd=0.0056, gd_plus=0.0035, igd_plus=0.0041, spacing=0.0068, generation=191.0000, generation_time=0.0078, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2761, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.7239, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 28, 'uniform_crossover_batch': 0}
# Gen 192: hypervolume=0.8692, igd=0.0050, gd=0.0057, gd_plus=0.0036, igd_plus=0.0041, spacing=0.0063, generation=192.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2241, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.7759, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 0}
# Gen 193: hypervolume=0.8693, igd=0.0047, gd=0.0055, gd_plus=0.0034, igd_plus=0.0039, spacing=0.0063, generation=193.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6656, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3344, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 0}
# Gen 194: hypervolume=0.8690, igd=0.0049, gd=0.0057, gd_plus=0.0035, igd_plus=0.0040, spacing=0.0068, generation=194.0000, generation_time=0.0074, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Gen 195: hypervolume=0.8687, igd=0.0049, gd=0.0052, gd_plus=0.0034, igd_plus=0.0040, spacing=0.0071, generation=195.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.8626, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1374, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 0}
# Gen 196: hypervolume=0.8689, igd=0.0051, gd=0.0054, gd_plus=0.0034, igd_plus=0.0040, spacing=0.0075, generation=196.0000, generation_time=0.0067, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3209, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6791, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Gen 197: hypervolume=0.8687, igd=0.0051, gd=0.0053, gd_plus=0.0033, igd_plus=0.0040, spacing=0.0070, generation=197.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6853, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3147, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Gen 198: hypervolume=0.8687, igd=0.0051, gd=0.0053, gd_plus=0.0033, igd_plus=0.0040, spacing=0.0070, generation=198.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3274, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6726, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 0}
# Gen 199: hypervolume=0.8687, igd=0.0052, gd=0.0054, gd_plus=0.0035, igd_plus=0.0041, spacing=0.0081, generation=199.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4175, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5825, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Gen 200: hypervolume=0.8687, igd=0.0051, gd=0.0058, gd_plus=0.0034, igd_plus=0.0040, spacing=0.0070, generation=200.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100

# %% [markdown]
# ### Cell 8: Save Combined Metrics History to Excel
# import pandas as pd
# import re
#
# # Convert the all_metrics list to DataFrame
# df_metrics = pd.DataFrame(all_metrics)
#
# # Sanitize problem name for filename
# problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()
#
#
# # Define a mapping from the full crossover operator names to shortcuts
# crossover_shortcuts = {
#     "simulated_binary_crossover_batch": "sbx",
#     "blend_crossover_batch": "blx",
#     "single_point_crossover_batch": "spx",
#     "uniform_crossover_batch": "ux"
# }
#
# # Convert selected crossover operator names to their shortcut representation
# selected_crossover_shortcut_names = [
#     crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
# ]
#
# # Join the shortcuts into a single string (e.g., "sbx-blx")
# crossover_str = "-".join(selected_crossover_shortcut_names)
#
# # Create valid filename
# excel_filename = (
#     f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross 1 poly "
#     f"{pop_size}pop {generations}gen EnXEA.xlsx"
# )
#
# #{crossover_str}
#
# # Save to Excel
# df_metrics.to_excel(excel_filename, index=False)
# print(f"Metrics saved to '{excel_filename}'")

# %%
# =========================
# New Cell: Run all Table 2 problems exactly as manual (no wrappers)
# =========================

import os
import re
import numpy as np
import pandas as pd
from pathlib import Path
from joblib import Parallel, delayed

# Recompute so this cell is self-contained
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None

# -------------------------------------------------
# 1) Table 2 benchmark list
# -------------------------------------------------
TABLE2_PROBLEMS = (
    [{"name": f"zdt{i}",   "n_var": 30, "n_obj": 2, "generations": 200}  for i in [1, 2, 3]] +
    [{"name": f"zdt{i}",   "n_var": 10, "n_obj": 2, "generations": 400}  for i in [4, 6]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 1000} for i in [1, 3]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 200}  for i in [2, 5, 7]] +
    [{"name": "dtlz4",     "n_var": 12, "n_obj": 3, "generations": 500}] +
    [{"name": "dtlz6",     "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": f"wfg{i}",   "n_var": 6,  "n_obj": 3, "generations": 200}  for i in range(1, 10)] +
    [{"name": "c1dtlz1",   "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "c2dtlz2",   "n_var": 12, "n_obj": 3, "generations": 200}] +
    [{"name": "c3dtlz4",   "n_var": 7,  "n_obj": 3, "generations": 500}] +
    [{"name": "dc1dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc1dtlz3",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc3dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}]
)

SEEDS = range(1, 2)
OUTPUT_DIR = Path("EnXEA results time")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

CROSSOVER_SHORTCUTS = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}
MUTATION_SHORTCUTS = {
    "polynomial_mutation_batch": "poly",
    "gaussian_mutation_batch": "gauss"
}


def build_excel_name(problem_name, generations):
    problem_name_clean = re.sub(r"[^a-zA-Z0-9_]", "", problem_name).lower()
    crossover_str = "-".join(
        CROSSOVER_SHORTCUTS.get(name, name)
        for name in selected_crossover_operator_names
    )
    mutation_str = MUTATION_SHORTCUTS.get(selected_mutation_operator_name, selected_mutation_operator_name)
    return (
        f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} "
        f"cross 1 {mutation_str} {pop_size}pop {generations}gen En.xlsx"
    )


def flatten_columns(columns):
    out = []
    for col in columns:
        if isinstance(col, tuple):
            out.append("_".join([str(x) for x in col if str(x) != ""]).rstrip("_"))
        else:
            out.append(str(col))
    return out


# -------------------------------------------------
# 2) Per-seed runner — identical to manual Cell 7
#    Uses the ORIGINAL get_problem_dynamic from Cell 1
#    NO make_problem_safe wrapper
# -------------------------------------------------
def run_seed_manual(problem_cfg, seed):
    """
    Runs exactly like the manual code:
      - Uses get_problem_dynamic from Cell 1 (family-aware, no safety wrapper)
      - Calls run_nsga2 with the same arguments as Cell 7
      - Post-processes with fast_non_dominated_sort just like Cell 7
    """
    # Build problem exactly as manual code does (Cell 1 get_problem_dynamic, no wrapper)
    problem = get_problem_dynamic(
        problem_cfg["name"],
        n_var=problem_cfg["n_var"],
        n_obj=problem_cfg["n_obj"]
    )

    D_local = problem.n_var
    M_local = problem.n_obj
    mutation_probability_local = 1.0 / D_local

    print(f"\n=== Running NSGA-II with seed {seed} ===")

    # Call run_nsga2 with the exact same signature as Cell 7
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,
        population_size=pop_size,
        generations=problem_cfg["generations"],
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability_local,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=False,
        metrics_interval=metrics_interval_value,
        record_history=False
    )

    # Add seed info to metrics — same as Cell 7
    for metric in metrics_history:
        metric["seed"] = seed

    # Identify non-dominated solutions — same as Cell 7
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)
    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D_local:D_local + M_local]

    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")

    return {
        "seed": seed,
        "final_population": final_population,
        "true_pareto": true_pareto,
        "metrics_history": metrics_history,
        "pareto_points": pareto_points,
    }


# -------------------------------------------------
# 3) Run all problems, each with 30 seeds in parallel
# -------------------------------------------------
all_final_tables = []
failures = []

for idx, problem_cfg in enumerate(TABLE2_PROBLEMS, start=1):
    prob_name = problem_cfg["name"].upper()
    print(f"\n{'='*60}")
    print(f"[{idx}/{len(TABLE2_PROBLEMS)}] {prob_name} | "
          f"D={problem_cfg['n_var']}, M={problem_cfg['n_obj']}, G={problem_cfg['generations']}")
    print(f"{'='*60}")

    try:
        # Run 30 seeds in parallel — same as Cell 7 uses Parallel
        seed_results = Parallel(n_jobs=1)(
            delayed(run_seed_manual)(problem_cfg, seed) for seed in SEEDS
        )

        # Collect metrics and final rows — same post-processing as Cell 7
        all_metrics = []
        final_rows = []

        for result in seed_results:
            seed = result["seed"]
            all_metrics.extend(result["metrics_history"])

            # Build final row from last generation metrics
            final_row = {
                "problem": problem_cfg["name"],
                "seed": seed,
                "n_var": problem_cfg["n_var"],
                "n_obj": problem_cfg["n_obj"],
                "configured_generations": problem_cfg["generations"],
                "population_size": pop_size,
                "pareto_size": int(result["pareto_points"].shape[0]),
            }
            if result["metrics_history"]:
                final_row.update(result["metrics_history"][-1])
            final_rows.append(final_row)

        df_metrics = pd.DataFrame(all_metrics)
        df_final = pd.DataFrame(final_rows).sort_values("seed").reset_index(drop=True)

        if not df_metrics.empty:
            if "crossover_survival" in df_metrics.columns:
                df_metrics["crossover_survival"] = df_metrics["crossover_survival"].astype(str)
            if "crossover_probabilities" in df_metrics.columns:
                df_metrics["crossover_probabilities"] = df_metrics["crossover_probabilities"].astype(str)
            if "beta" in df_metrics.columns:
                df_metrics["beta"] = df_metrics["beta"].astype(str)
            df_metrics = df_metrics.sort_values(["seed", "generation"]).reset_index(drop=True)

        # Summary stats
        numeric_cols = [
            c for c in [
                "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
                "spacing", "generation_time", "offspring_evals", "pareto_size"
            ]
            if c in df_final.columns
        ]

        summary_rows = []
        for col in numeric_cols:
            s = pd.to_numeric(df_final[col], errors="coerce").dropna()
            if not s.empty:
                summary_rows.append({
                    "metric": col,
                    "mean": s.mean(),
                    "std": s.std(),
                    "min": s.min(),
                    "max": s.max()
                })
        df_summary = pd.DataFrame(summary_rows)

        # Save per-problem Excel
        excel_path = OUTPUT_DIR / build_excel_name(problem_cfg["name"], problem_cfg["generations"])
        with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
            df_metrics.to_excel(writer, sheet_name="all_metrics", index=False)
            df_final.to_excel(writer, sheet_name="final_gen_by_seed", index=False)
            df_summary.to_excel(writer, sheet_name="summary", index=False)

        print(f"Saved: {excel_path}")
        all_final_tables.append(df_final)

    except Exception as e:
        print(f"FAILED: {problem_cfg['name']} -> {e}")
        failures.append({
            "problem": problem_cfg["name"],
            "n_var": problem_cfg["n_var"],
            "n_obj": problem_cfg["n_obj"],
            "generations": problem_cfg["generations"],
            "error": str(e)
        })

# -------------------------------------------------
# 4) Master summary across all problems
# -------------------------------------------------
df_all_final = pd.concat(all_final_tables, ignore_index=True) if all_final_tables else pd.DataFrame()
df_failures = pd.DataFrame(failures)
df_problem_table = pd.DataFrame(TABLE2_PROBLEMS)

if not df_all_final.empty:
    metric_cols = [
        c for c in [
            "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
            "spacing", "generation_time", "offspring_evals", "pareto_size"
        ]
        if c in df_all_final.columns
    ]
    if metric_cols:
        agg_dict = {col: ["mean", "std"] for col in metric_cols}
        df_problem_summary = (
            df_all_final
            .groupby(["problem", "n_var", "n_obj", "configured_generations"], dropna=False)
            .agg(agg_dict)
            .reset_index()
        )
        df_problem_summary.columns = flatten_columns(df_problem_summary.columns)
        df_problem_summary = df_problem_summary.sort_values("problem").reset_index(drop=True)
    else:
        df_problem_summary = pd.DataFrame()
else:
    df_problem_summary = pd.DataFrame()

summary_path = OUTPUT_DIR / "ALL_PROBLEMS_SUMMARY.xlsx"
with pd.ExcelWriter(summary_path, engine="openpyxl") as writer:
    df_problem_table.to_excel(writer, sheet_name="benchmark_table", index=False)
    df_all_final.to_excel(writer, sheet_name="final_gen_all_seeds", index=False)
    df_problem_summary.to_excel(writer, sheet_name="problem_summary", index=False)
    df_failures.to_excel(writer, sheet_name="failures", index=False)

print(f"\nMaster summary saved: {summary_path}")
if failures:
    print(f"\n{len(failures)} problem(s) failed:")
    for f in failures:
        print(f"  {f['problem']}: {f['error']}")

df_problem_summary
# Out:
# ============================================================
# [1/27] ZDT1 | D=30, M=2, G=200
# ============================================================
#
# === Running NSGA-II with seed 1 ===
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.25, 'single_point_crossover_batch': 0.25, 'blend_crossover_batch': 0.25, 'uniform_crossover_batch': 0.25}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 18}
# Gen 1: hypervolume=0.0000, igd=1.9284, gd=2.7145, gd_plus=2.7145, igd_plus=1.9284, spacing=0.3741, generation=1.0000, generation_time=0.0075, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1446, 'single_point_crossover_batch': 0.3571, 'blend_crossover_batch': 0.2286, 'uniform_crossover_batch': 0.2697}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 17}
# Gen 2: hypervolume=0.0000, igd=1.9284, gd=2.0665, gd_plus=2.0665, igd_plus=1.9284, spacing=0.1320, generation=2.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.167, 'single_point_crossover_batch': 0.2431, 'blend_crossover_batch': 0.3798, 'uniform_crossover_batch': 0.2101}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 19}
# Gen 3: hypervolume=0.0000, igd=1.9282, gd=2.2236, gd_plus=2.2236, igd_plus=1.9282, spacing=0.1106, generation=3.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2953, 'single_point_crossover_batch': 0.2721, 'blend_crossover_batch': 0.1661, 'uniform_crossover_batch': 0.2665}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 13}
# Gen 4: hypervolume=0.0000, igd=1.6095, gd=1.9067, gd_plus=1.9067, igd_plus=1.6090, spacing=0.0890, generation=4.0000, generation_time=0.0062, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2992, 'single_point_crossover_batch': 0.3408, 'blend_crossover_batch': 0.1515, 'uniform_crossover_batch': 0.2086}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 16}
# Gen 5: hypervolume=0.0000, igd=1.4260, gd=1.8849, gd_plus=1.8849, igd_plus=1.4260, spacing=0.1099, generation=5.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3749, 'single_point_crossover_batch': 0.2934, 'blend_crossover_batch': 0.1021, 'uniform_crossover_batch': 0.2296}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 14}
# Gen 6: hypervolume=0.0000, igd=1.4191, gd=1.6951, gd_plus=1.6951, igd_plus=1.4191, spacing=0.1127, generation=6.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2492, 'single_point_crossover_batch': 0.2341, 'blend_crossover_batch': 0.3127, 'uniform_crossover_batch': 0.204}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 13}
# Gen 7: hypervolume=0.0000, igd=1.2324, gd=1.5521, gd_plus=1.5521, igd_plus=1.2300, spacing=0.2686, generation=7.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1774, 'single_point_crossover_batch': 0.2772, 'blend_crossover_batch': 0.2456, 'uniform_crossover_batch': 0.2998}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 17}
# Gen 8: hypervolume=0.0000, igd=1.1807, gd=1.3119, gd_plus=1.3119, igd_plus=1.1807, spacing=0.1139, generation=8.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1479, 'single_point_crossover_batch': 0.2273, 'blend_crossover_batch': 0.411, 'uniform_crossover_batch': 0.2138}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 26, 'uniform_crossover_batch': 8}
# Gen 9: hypervolume=0.0000, igd=1.0985, gd=1.2540, gd_plus=1.2540, igd_plus=1.0985, spacing=0.0447, generation=9.0000, generation_time=0.0059, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3166, 'single_point_crossover_batch': 0.2824, 'blend_crossover_batch': 0.2604, 'uniform_crossover_batch': 0.1407}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 11}
# Gen 10: hypervolume=0.0000, igd=0.9785, gd=1.1111, gd_plus=1.1111, igd_plus=0.9785, spacing=0.0381, generation=10.0000, generation_time=0.0064, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2529, 'single_point_crossover_batch': 0.198, 'blend_crossover_batch': 0.1666, 'uniform_crossover_batch': 0.3825}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 25}
# Gen 11: hypervolume=0.0000, igd=0.9562, gd=0.9620, gd_plus=0.9620, igd_plus=0.9562, spacing=0.0592, generation=11.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3691, 'single_point_crossover_batch': 0.2386, 'blend_crossover_batch': 0.1517, 'uniform_crossover_batch': 0.2406}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 15}
# Gen 12: hypervolume=0.0199, igd=0.7822, gd=0.8982, gd_plus=0.8982, igd_plus=0.7821, spacing=0.1015, generation=12.0000, generation_time=0.0093, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2661, 'single_point_crossover_batch': 0.2837, 'blend_crossover_batch': 0.1897, 'uniform_crossover_batch': 0.2605}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 19}
# Gen 13: hypervolume=0.0611, igd=0.7112, gd=0.8324, gd_plus=0.8324, igd_plus=0.7111, spacing=0.1049, generation=13.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3049, 'single_point_crossover_batch': 0.2212, 'blend_crossover_batch': 0.2212, 'uniform_crossover_batch': 0.2527}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 12}
# Gen 14: hypervolume=0.0806, igd=0.6760, gd=0.7410, gd_plus=0.7410, igd_plus=0.6760, spacing=0.0816, generation=14.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2966, 'single_point_crossover_batch': 0.2966, 'blend_crossover_batch': 0.1825, 'uniform_crossover_batch': 0.2243}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 17}
# Gen 15: hypervolume=0.1474, igd=0.5761, gd=0.6085, gd_plus=0.6085, igd_plus=0.5761, spacing=0.1280, generation=15.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3542, 'single_point_crossover_batch': 0.2287, 'blend_crossover_batch': 0.1464, 'uniform_crossover_batch': 0.2707}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 16}
# Gen 16: hypervolume=0.2050, igd=0.4725, gd=0.5489, gd_plus=0.5489, igd_plus=0.4720, spacing=0.0736, generation=16.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3399, 'single_point_crossover_batch': 0.1434, 'blend_crossover_batch': 0.3061, 'uniform_crossover_batch': 0.2107}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 10}
# Gen 17: hypervolume=0.2541, igd=0.4310, gd=0.4804, gd_plus=0.4804, igd_plus=0.4308, spacing=0.0802, generation=17.0000, generation_time=0.0067, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2532, 'single_point_crossover_batch': 0.2157, 'blend_crossover_batch': 0.273, 'uniform_crossover_batch': 0.2581}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 12}
# Gen 18: hypervolume=0.2847, igd=0.3995, gd=0.4613, gd_plus=0.4613, igd_plus=0.3989, spacing=0.0610, generation=18.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2771, 'single_point_crossover_batch': 0.2438, 'blend_crossover_batch': 0.3017, 'uniform_crossover_batch': 0.1774}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 12}
# Gen 19: hypervolume=0.3309, igd=0.3732, gd=0.4003, gd_plus=0.4003, igd_plus=0.3732, spacing=0.0498, generation=19.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2693, 'single_point_crossover_batch': 0.0812, 'blend_crossover_batch': 0.2386, 'uniform_crossover_batch': 0.411}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 19}
# Gen 20: hypervolume=0.3628, igd=0.3475, gd=0.4069, gd_plus=0.4069, igd_plus=0.3474, spacing=0.0461, generation=20.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4093, 'single_point_crossover_batch': 0.0676, 'blend_crossover_batch': 0.3216, 'uniform_crossover_batch': 0.2015}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 11}
# Gen 21: hypervolume=0.4036, igd=0.3102, gd=0.3679, gd_plus=0.3679, igd_plus=0.3102, spacing=0.0601, generation=21.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3447, 'single_point_crossover_batch': 0.0271, 'blend_crossover_batch': 0.22, 'uniform_crossover_batch': 0.4082}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 20}
# Gen 22: hypervolume=0.4300, igd=0.2907, gd=0.3069, gd_plus=0.3069, igd_plus=0.2907, spacing=0.0331, generation=22.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2654, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4492, 'uniform_crossover_batch': 0.2854}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 17}
# Gen 23: hypervolume=0.4659, igd=0.2717, gd=0.2721, gd_plus=0.2721, igd_plus=0.2716, spacing=0.0264, generation=23.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4154, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2432, 'uniform_crossover_batch': 0.3414}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 16}
# Gen 24: hypervolume=0.4983, igd=0.2406, gd=0.2649, gd_plus=0.2649, igd_plus=0.2406, spacing=0.0213, generation=24.0000, generation_time=0.0062, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3481, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4114, 'uniform_crossover_batch': 0.2406}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 10}
# Gen 25: hypervolume=0.5281, igd=0.2145, gd=0.2336, gd_plus=0.2336, igd_plus=0.2141, spacing=0.0278, generation=25.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3416, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3485, 'uniform_crossover_batch': 0.3099}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 22}
# Gen 26: hypervolume=0.5579, igd=0.1965, gd=0.1992, gd_plus=0.1992, igd_plus=0.1964, spacing=0.0331, generation=26.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.292, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3875, 'uniform_crossover_batch': 0.3205}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 13}
# Gen 27: hypervolume=0.5855, igd=0.1793, gd=0.1908, gd_plus=0.1906, igd_plus=0.1792, spacing=0.0243, generation=27.0000, generation_time=0.0026, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4838, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2974, 'uniform_crossover_batch': 0.2187}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 14}
# Gen 28: hypervolume=0.6222, igd=0.1495, gd=0.1721, gd_plus=0.1718, igd_plus=0.1495, spacing=0.0273, generation=28.0000, generation_time=0.0026, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2609, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2935, 'uniform_crossover_batch': 0.4455}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 27}
# Gen 29: hypervolume=0.6410, igd=0.1409, gd=0.1514, gd_plus=0.1513, igd_plus=0.1409, spacing=0.0191, generation=29.0000, generation_time=0.0024, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.305, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.403, 'uniform_crossover_batch': 0.2919}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 13}
# Gen 30: hypervolume=0.6667, igd=0.1229, gd=0.1333, gd_plus=0.1332, igd_plus=0.1229, spacing=0.0203, generation=30.0000, generation_time=0.0030, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3697, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3425, 'uniform_crossover_batch': 0.2878}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 17}
# Gen 31: hypervolume=0.6821, igd=0.1134, gd=0.1205, gd_plus=0.1204, igd_plus=0.1134, spacing=0.0227, generation=31.0000, generation_time=0.0073, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4553, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2034, 'uniform_crossover_batch': 0.3413}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 14}
# Gen 32: hypervolume=0.6909, igd=0.1090, gd=0.1121, gd_plus=0.1116, igd_plus=0.1090, spacing=0.0247, generation=32.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3486, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4553, 'uniform_crossover_batch': 0.1961}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 13}
# Gen 33: hypervolume=0.7049, igd=0.1023, gd=0.1021, gd_plus=0.1016, igd_plus=0.1023, spacing=0.0213, generation=33.0000, generation_time=0.0061, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2399, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3997, 'uniform_crossover_batch': 0.3604}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 25}
# Gen 34: hypervolume=0.7201, igd=0.0919, gd=0.0941, gd_plus=0.0936, igd_plus=0.0918, spacing=0.0199, generation=34.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2201, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2112, 'uniform_crossover_batch': 0.5686}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 32}
# Gen 35: hypervolume=0.7315, igd=0.0846, gd=0.0899, gd_plus=0.0898, igd_plus=0.0846, spacing=0.0207, generation=35.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3165, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2877, 'uniform_crossover_batch': 0.3958}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 13}
# Gen 36: hypervolume=0.7391, igd=0.0797, gd=0.0845, gd_plus=0.0843, igd_plus=0.0796, spacing=0.0158, generation=36.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3975, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2207, 'uniform_crossover_batch': 0.3819}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 14}
# Gen 37: hypervolume=0.7530, igd=0.0715, gd=0.0757, gd_plus=0.0757, igd_plus=0.0715, spacing=0.0159, generation=37.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3443, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3922, 'uniform_crossover_batch': 0.2636}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 11}
# Gen 38: hypervolume=0.7614, igd=0.0677, gd=0.0733, gd_plus=0.0730, igd_plus=0.0676, spacing=0.0190, generation=38.0000, generation_time=0.0090, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3979, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2877, 'uniform_crossover_batch': 0.3144}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 16}
# Gen 39: hypervolume=0.7704, igd=0.0624, gd=0.0653, gd_plus=0.0649, igd_plus=0.0624, spacing=0.0158, generation=39.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3121, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2418, 'uniform_crossover_batch': 0.446}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 26}
# Gen 40: hypervolume=0.7779, igd=0.0578, gd=0.0598, gd_plus=0.0594, igd_plus=0.0578, spacing=0.0166, generation=40.0000, generation_time=0.0064, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.358, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.105, 'uniform_crossover_batch': 0.5369}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 21}
# Gen 41: hypervolume=0.7849, igd=0.0526, gd=0.0549, gd_plus=0.0542, igd_plus=0.0526, spacing=0.0188, generation=41.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4662, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.0462, 'uniform_crossover_batch': 0.4876}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 21}
# Gen 42: hypervolume=0.7927, igd=0.0482, gd=0.0490, gd_plus=0.0489, igd_plus=0.0481, spacing=0.0194, generation=42.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5306, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.0617, 'uniform_crossover_batch': 0.4077}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 12}
# Gen 43: hypervolume=0.7998, igd=0.0442, gd=0.0449, gd_plus=0.0447, igd_plus=0.0442, spacing=0.0133, generation=43.0000, generation_time=0.0093, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4704, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3492, 'uniform_crossover_batch': 0.1804}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 9}
# Gen 44: hypervolume=0.8062, igd=0.0404, gd=0.0407, gd_plus=0.0397, igd_plus=0.0403, spacing=0.0112, generation=44.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2374, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4965, 'uniform_crossover_batch': 0.2661}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 13}
# Gen 45: hypervolume=0.8148, igd=0.0363, gd=0.0385, gd_plus=0.0373, igd_plus=0.0363, spacing=0.0124, generation=45.0000, generation_time=0.0082, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3051, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3706, 'uniform_crossover_batch': 0.3243}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 13}
# Gen 46: hypervolume=0.8187, igd=0.0340, gd=0.0354, gd_plus=0.0343, igd_plus=0.0339, spacing=0.0099, generation=46.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2695, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3817, 'uniform_crossover_batch': 0.3488}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 12}
# Gen 47: hypervolume=0.8237, igd=0.0308, gd=0.0323, gd_plus=0.0312, igd_plus=0.0307, spacing=0.0101, generation=47.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3857, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.371, 'uniform_crossover_batch': 0.2432}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 7}
# Gen 48: hypervolume=0.8277, igd=0.0284, gd=0.0302, gd_plus=0.0294, igd_plus=0.0284, spacing=0.0080, generation=48.0000, generation_time=0.0105, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1728, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5154, 'uniform_crossover_batch': 0.3118}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 9}
# Gen 49: hypervolume=0.8314, igd=0.0266, gd=0.0281, gd_plus=0.0270, igd_plus=0.0265, spacing=0.0077, generation=49.0000, generation_time=0.0071, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4804, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3336, 'uniform_crossover_batch': 0.1859}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 10}
# Gen 50: hypervolume=0.8342, igd=0.0246, gd=0.0265, gd_plus=0.0255, igd_plus=0.0246, spacing=0.0062, generation=50.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2526, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2969, 'uniform_crossover_batch': 0.4505}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 12}
# Gen 51: hypervolume=0.8367, igd=0.0233, gd=0.0243, gd_plus=0.0239, igd_plus=0.0232, spacing=0.0066, generation=51.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.204, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4589, 'uniform_crossover_batch': 0.3371}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 11}
# Gen 52: hypervolume=0.8387, igd=0.0218, gd=0.0231, gd_plus=0.0227, igd_plus=0.0218, spacing=0.0069, generation=52.0000, generation_time=0.0121, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2174, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4695, 'uniform_crossover_batch': 0.3131}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 9}
# Gen 53: hypervolume=0.8405, igd=0.0208, gd=0.0217, gd_plus=0.0212, igd_plus=0.0207, spacing=0.0060, generation=53.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1541, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4992, 'uniform_crossover_batch': 0.3467}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 10}
# Gen 54: hypervolume=0.8418, igd=0.0202, gd=0.0209, gd_plus=0.0203, igd_plus=0.0202, spacing=0.0065, generation=54.0000, generation_time=0.0068, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5397, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2254, 'uniform_crossover_batch': 0.2349}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 8}
# Gen 55: hypervolume=0.8431, igd=0.0193, gd=0.0204, gd_plus=0.0195, igd_plus=0.0192, spacing=0.0063, generation=55.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5076, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1347, 'uniform_crossover_batch': 0.3577}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 9}
# Gen 56: hypervolume=0.8441, igd=0.0187, gd=0.0198, gd_plus=0.0190, igd_plus=0.0186, spacing=0.0063, generation=56.0000, generation_time=0.0066, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3492, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3789, 'uniform_crossover_batch': 0.2719}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 7}
# Gen 57: hypervolume=0.8451, igd=0.0182, gd=0.0193, gd_plus=0.0183, igd_plus=0.0181, spacing=0.0046, generation=57.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2154, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5711, 'uniform_crossover_batch': 0.2135}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 7}
# Gen 58: hypervolume=0.8460, igd=0.0175, gd=0.0189, gd_plus=0.0178, igd_plus=0.0175, spacing=0.0050, generation=58.0000, generation_time=0.0043, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3495, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2651, 'uniform_crossover_batch': 0.3853}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 8}
# Gen 59: hypervolume=0.8469, igd=0.0170, gd=0.0183, gd_plus=0.0172, igd_plus=0.0169, spacing=0.0052, generation=59.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2429, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5398, 'uniform_crossover_batch': 0.2173}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 13}
# Gen 60: hypervolume=0.8478, igd=0.0164, gd=0.0177, gd_plus=0.0166, igd_plus=0.0163, spacing=0.0059, generation=60.0000, generation_time=0.0071, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2018, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1402, 'uniform_crossover_batch': 0.658}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 21}
# Gen 61: hypervolume=0.8493, igd=0.0155, gd=0.0167, gd_plus=0.0155, igd_plus=0.0154, spacing=0.0050, generation=61.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2755, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4898, 'uniform_crossover_batch': 0.2347}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 4}
# Gen 62: hypervolume=0.8500, igd=0.0150, gd=0.0162, gd_plus=0.0151, igd_plus=0.0149, spacing=0.0050, generation=62.0000, generation_time=0.0063, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2679, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4352, 'uniform_crossover_batch': 0.2969}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 9}
# Gen 63: hypervolume=0.8507, igd=0.0146, gd=0.0155, gd_plus=0.0147, igd_plus=0.0146, spacing=0.0058, generation=63.0000, generation_time=0.0080, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1862, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4546, 'uniform_crossover_batch': 0.3592}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 15}
# Gen 64: hypervolume=0.8514, igd=0.0141, gd=0.0147, gd_plus=0.0139, igd_plus=0.0140, spacing=0.0064, generation=64.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3744, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1914, 'uniform_crossover_batch': 0.4342}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 15}
# Gen 65: hypervolume=0.8527, igd=0.0134, gd=0.0142, gd_plus=0.0133, igd_plus=0.0134, spacing=0.0067, generation=65.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4377, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1245, 'uniform_crossover_batch': 0.4377}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 11}
# Gen 66: hypervolume=0.8536, igd=0.0131, gd=0.0138, gd_plus=0.0126, igd_plus=0.0130, spacing=0.0061, generation=66.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2547, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4608, 'uniform_crossover_batch': 0.2845}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 11}
# Gen 67: hypervolume=0.8545, igd=0.0125, gd=0.0132, gd_plus=0.0120, igd_plus=0.0124, spacing=0.0067, generation=67.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6447, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1274, 'uniform_crossover_batch': 0.2279}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 8}
# Gen 68: hypervolume=0.8554, igd=0.0121, gd=0.0129, gd_plus=0.0115, igd_plus=0.0120, spacing=0.0066, generation=68.0000, generation_time=0.0065, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1224, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.7235, 'uniform_crossover_batch': 0.1541}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 2}
# Gen 69: hypervolume=0.8557, igd=0.0118, gd=0.0129, gd_plus=0.0112, igd_plus=0.0117, spacing=0.0060, generation=69.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2158, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4812, 'uniform_crossover_batch': 0.3031}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 10}
# Gen 70: hypervolume=0.8563, igd=0.0115, gd=0.0126, gd_plus=0.0109, igd_plus=0.0114, spacing=0.0054, generation=70.0000, generation_time=0.0060, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1547, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3893, 'uniform_crossover_batch': 0.456}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 14}
# Gen 71: hypervolume=0.8569, igd=0.0111, gd=0.0117, gd_plus=0.0106, igd_plus=0.0110, spacing=0.0063, generation=71.0000, generation_time=0.0044, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4368, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2573, 'uniform_crossover_batch': 0.306}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 7}
# Gen 72: hypervolume=0.8578, igd=0.0105, gd=0.0114, gd_plus=0.0102, igd_plus=0.0105, spacing=0.0052, generation=72.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3841, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.334, 'uniform_crossover_batch': 0.2819}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 9}
# Gen 73: hypervolume=0.8579, igd=0.0104, gd=0.0112, gd_plus=0.0097, igd_plus=0.0103, spacing=0.0062, generation=73.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1749, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.4793, 'uniform_crossover_batch': 0.3459}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 9}
# Gen 74: hypervolume=0.8584, igd=0.0101, gd=0.0110, gd_plus=0.0093, igd_plus=0.0100, spacing=0.0063, generation=74.0000, generation_time=0.0059, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6181, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1226, 'uniform_crossover_batch': 0.2593}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 9}
# Gen 75: hypervolume=0.8589, igd=0.0098, gd=0.0110, gd_plus=0.0093, igd_plus=0.0097, spacing=0.0056, generation=75.0000, generation_time=0.0057, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1692, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2109, 'uniform_crossover_batch': 0.6199}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 24}
# Gen 76: hypervolume=0.8592, igd=0.0095, gd=0.0106, gd_plus=0.0089, igd_plus=0.0094, spacing=0.0059, generation=76.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2922, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3977, 'uniform_crossover_batch': 0.3101}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 13}
# Gen 77: hypervolume=0.8598, igd=0.0094, gd=0.0104, gd_plus=0.0087, igd_plus=0.0092, spacing=0.0070, generation=77.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3754, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2874, 'uniform_crossover_batch': 0.3373}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 8}
# Gen 78: hypervolume=0.8601, igd=0.0092, gd=0.0101, gd_plus=0.0084, igd_plus=0.0090, spacing=0.0066, generation=78.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3326, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3728, 'uniform_crossover_batch': 0.2946}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 10}
# Gen 79: hypervolume=0.8603, igd=0.0090, gd=0.0093, gd_plus=0.0083, igd_plus=0.0088, spacing=0.0071, generation=79.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1371, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.501, 'uniform_crossover_batch': 0.362}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 13}
# Gen 80: hypervolume=0.8607, igd=0.0089, gd=0.0092, gd_plus=0.0082, igd_plus=0.0087, spacing=0.0069, generation=80.0000, generation_time=0.0044, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5415, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2555, 'uniform_crossover_batch': 0.203}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 10}
# Gen 81: hypervolume=0.8608, igd=0.0089, gd=0.0094, gd_plus=0.0079, igd_plus=0.0086, spacing=0.0075, generation=81.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3908, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2541, 'uniform_crossover_batch': 0.3552}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 9}
# Gen 82: hypervolume=0.8613, igd=0.0086, gd=0.0093, gd_plus=0.0078, igd_plus=0.0084, spacing=0.0068, generation=82.0000, generation_time=0.0053, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.6416, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1554, 'uniform_crossover_batch': 0.203}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 83: hypervolume=0.8615, igd=0.0085, gd=0.0090, gd_plus=0.0075, igd_plus=0.0082, spacing=0.0069, generation=83.0000, generation_time=0.0056, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.4359, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.3668, 'uniform_crossover_batch': 0.1973}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 9}
# Gen 84: hypervolume=0.8618, igd=0.0082, gd=0.0087, gd_plus=0.0073, igd_plus=0.0079, spacing=0.0063, generation=84.0000, generation_time=0.0050, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1921, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2283, 'uniform_crossover_batch': 0.5796}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 17}
# Gen 85: hypervolume=0.8623, igd=0.0079, gd=0.0082, gd_plus=0.0070, igd_plus=0.0077, spacing=0.0065, generation=85.0000, generation_time=0.0059, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.1869, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.473, 'uniform_crossover_batch': 0.3402}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 9}
# Gen 86: hypervolume=0.8626, igd=0.0077, gd=0.0082, gd_plus=0.0067, igd_plus=0.0074, spacing=0.0073, generation=86.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5083, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.2058, 'uniform_crossover_batch': 0.2859}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Gen 87: hypervolume=0.8631, igd=0.0074, gd=0.0079, gd_plus=0.0064, igd_plus=0.0071, spacing=0.0080, generation=87.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2415, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.0479, 'uniform_crossover_batch': 0.7106}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 20}
# Gen 88: hypervolume=0.8636, igd=0.0071, gd=0.0077, gd_plus=0.0062, igd_plus=0.0068, spacing=0.0069, generation=88.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.5409, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.1539, 'uniform_crossover_batch': 0.3052}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 9}
# Gen 89: hypervolume=0.8639, igd=0.0070, gd=0.0074, gd_plus=0.0061, igd_plus=0.0067, spacing=0.0068, generation=89.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2733, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5054, 'uniform_crossover_batch': 0.2213}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 5}
# Gen 90: hypervolume=0.8641, igd=0.0067, gd=0.0073, gd_plus=0.0060, igd_plus=0.0064, spacing=0.0060, generation=90.0000, generation_time=0.0058, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.2299, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.5839, 'uniform_crossover_batch': 0.1862}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 1}
# Gen 91: hypervolume=0.8640, igd=0.0070, gd=0.0078, gd_plus=0.0061, igd_plus=0.0066, spacing=0.0062, generation=91.0000, generation_time=0.0046, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.3108, 'single_point_crossover_batch': 0.0, 'blend_crossover_batch': 0.6312, 'uniform_crossover_batch': 0.058}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 1}
# ...
# Gen 988: hypervolume=0.0857, igd=0.1157, gd=0.1041, gd_plus=0.1041, igd_plus=0.1152, spacing=0.0149, generation=988.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 989: hypervolume=0.0857, igd=0.1157, gd=0.1040, gd_plus=0.1040, igd_plus=0.1152, spacing=0.0147, generation=989.0000, generation_time=0.0054, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 990: hypervolume=0.0856, igd=0.1163, gd=0.1052, gd_plus=0.1052, igd_plus=0.1157, spacing=0.0133, generation=990.0000, generation_time=0.0047, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 991: hypervolume=0.0861, igd=0.1157, gd=0.1040, gd_plus=0.1040, igd_plus=0.1153, spacing=0.0135, generation=991.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 992: hypervolume=0.0856, igd=0.1160, gd=0.1039, gd_plus=0.1039, igd_plus=0.1155, spacing=0.0127, generation=992.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 22, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 993: hypervolume=0.0869, igd=0.1148, gd=0.1037, gd_plus=0.1037, igd_plus=0.1145, spacing=0.0152, generation=993.0000, generation_time=0.0048, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 994: hypervolume=0.0862, igd=0.1154, gd=0.1034, gd_plus=0.1034, igd_plus=0.1149, spacing=0.0133, generation=994.0000, generation_time=0.0049, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 995: hypervolume=0.0863, igd=0.1153, gd=0.1037, gd_plus=0.1037, igd_plus=0.1149, spacing=0.0163, generation=995.0000, generation_time=0.0051, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 996: hypervolume=0.0860, igd=0.1161, gd=0.1043, gd_plus=0.1043, igd_plus=0.1156, spacing=0.0157, generation=996.0000, generation_time=0.0052, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 23, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 997: hypervolume=0.0868, igd=0.1153, gd=0.1036, gd_plus=0.1036, igd_plus=0.1149, spacing=0.0187, generation=997.0000, generation_time=0.0026, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 998: hypervolume=0.0872, igd=0.1147, gd=0.1042, gd_plus=0.1042, igd_plus=0.1143, spacing=0.0189, generation=998.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 999: hypervolume=0.0871, igd=0.1147, gd=0.1050, gd_plus=0.1050, igd_plus=0.1144, spacing=0.0189, generation=999.0000, generation_time=0.0055, pair_cnt=100.0000, offspring_evals=100.0000
# EnXEA probabilities: {'simulated_binary_crossover_batch': 0.0, 'single_point_crossover_batch': 1.0, 'blend_crossover_batch': 0.0, 'uniform_crossover_batch': 0.0}
# EnXEA offspring survivors: {'simulated_binary_crossover_batch': 0, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Gen 1000: hypervolume=0.0866, igd=0.1154, gd=0.1038, gd_plus=0.1038, igd_plus=0.1150, spacing=0.0159, generation=1000.0000, generation_time=0.0068, pair_cnt=100.0000, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100
# Saved: EnXEA results time\dc3dtlz1 4 sbx-spx-blx-ux cross 1 poly 100pop 1000gen En.xlsx
#
# Master summary saved: EnXEA results time\ALL_PROBLEMS_SUMMARY.xlsx
#      problem  n_var  n_obj  configured_generations  hypervolume_mean  \
# 0    c1dtlz1     12      3                    1000          0.135981
# 1    c2dtlz2     12      3                     200          0.660370
# 2    c3dtlz4      7      3                     500          8.135895
# 3   dc1dtlz1     12      3                    1000          0.117653
# 4   dc1dtlz3     12      3                    1000          0.656843
# 5   dc3dtlz1     12      3                    1000          0.086596
# 6      dtlz1     12      3                    1000          0.136450
# 7      dtlz2     12      3                     200          0.706456
# 8      dtlz3     12      3                    1000          0.708991
# 9      dtlz4     12      3                     500          0.704781
# 10     dtlz5     12      3                     200          0.132165
# 11     dtlz6     12      3                    1000          0.132478
# 12     dtlz7     12      3                     200          1.583611
# 13      wfg1      6      3                     200         40.818406
# 14      wfg2      6      3                     200         58.998980
# 15      wfg3      6      3                     200          5.672732
# 16      wfg4      6      3                     200         32.791230
# 17      wfg5      6      3                     200         29.403796
# 18      wfg6      6      3                     200         34.231695
# 19      wfg7      6      3                     200         33.985810
# 20      wfg8      6      3                     200         31.364733
# 21      wfg9      6      3                     200         32.023350
# 22      zdt1     30      2                     200          0.869929
# 23      zdt2     30      2                     200          0.534887
# 24      zdt3     30      2                     200          1.021542
# 25      zdt4     10      2                     400          0.867139
# 26      zdt6     10      2                     400          0.431442
#
#     hypervolume_std  igd_mean  igd_std   gd_mean  gd_std  ...  igd_plus_mean  \
# 0               NaN  0.027111      NaN  0.016428     NaN  ...       0.019209
# 1               NaN  0.056337      NaN  0.053643     NaN  ...       0.020296
# 2               NaN  0.128662      NaN  0.089824     NaN  ...       0.090821
# 3               NaN  0.061008      NaN  0.015463     NaN  ...       0.042194
# 4               NaN  0.127614      NaN  0.042079     NaN  ...       0.057208
# 5               NaN  0.115351      NaN  0.103780     NaN  ...       0.115004
# 6               NaN  0.029916      NaN  0.016717     NaN  ...       0.020809
# 7               NaN  0.071123      NaN  0.047209     NaN  ...       0.037202
# 8               NaN  0.077506      NaN  1.969350     NaN  ...       0.036547
# 9               NaN  0.073334      NaN  0.051582     NaN  ...       0.037424
# 10              NaN  0.005589      NaN  0.004112     NaN  ...       0.003248
# 11              NaN  0.006512      NaN  0.003682     NaN  ...       0.003022
# 12              NaN  0.082049      NaN  0.021938     NaN  ...       0.044740
# 13              NaN  0.695838      NaN  0.683782     NaN  ...       0.685398
# 14              NaN  0.227402      NaN  0.235458     NaN  ...       0.060224
# 15              NaN  0.044359      NaN  0.493267     NaN  ...       0.023679
# 16              NaN  0.221076      NaN  0.221104     NaN  ...       0.116361
# 17              NaN  0.275779      NaN  0.213816     NaN  ...       0.167114
# 18              NaN  0.254691      NaN  0.178848     NaN  ...       0.109055
# 19              NaN  0.253287      NaN  0.215020     NaN  ...       0.118862
# 20              NaN  0.335738      NaN  0.241065     NaN  ...       0.178936
# 21              NaN  0.282533      NaN  0.191873     NaN  ...       0.167748
# 22              NaN  0.004477      NaN  0.005241     NaN  ...       0.003328
# 23              NaN  0.005281      NaN  0.004786     NaN  ...       0.004147
# 24              NaN  0.004919      NaN  0.005399     NaN  ...       0.002023
# 25              NaN  0.005532      NaN  0.006155     NaN  ...       0.004907
# 26              NaN  0.004621      NaN  0.003117     NaN  ...       0.003201
#
#     igd_plus_std  spacing_mean  spacing_std  generation_time_mean  \
# 0            NaN      0.018794          NaN              0.006448
# 1            NaN      0.047144          NaN              0.006614
# 2            NaN      0.108305          NaN              0.009069
# 3            NaN      0.009903          NaN              0.006405
# 4            NaN      0.032781          NaN              0.004371
# 5            NaN      0.015913          NaN              0.006845
# 6            NaN      0.023616          NaN              0.003721
# 7            NaN      0.062386          NaN              0.005476
# 8            NaN     19.100152          NaN              0.003927
# 9            NaN      0.056310          NaN              0.004025
# 10           NaN      0.008186          NaN              0.006414
# 11           NaN      0.011990          NaN              0.006126
# 12           NaN      0.089282          NaN              0.005489
# 13           NaN      0.148093          NaN              0.006952
# 14           NaN      0.215401          NaN              0.007392
# 15           NaN      0.133278          NaN              0.003725
# 16           NaN      0.237180          NaN              0.004172
# 17           NaN      0.198841          NaN              0.007131
# 18           NaN      0.223534          NaN              0.003675
# 19           NaN      0.237038          NaN              0.005213
# 20           NaN      0.235975          NaN              0.006145
# 21           NaN      0.167201          NaN              0.007570
# 22           NaN      0.005618          NaN              0.005877
# 23           NaN      0.006318          NaN              0.003437
# 24           NaN      0.008799          NaN              0.006162
# 25           NaN      0.007533          NaN              0.006156
# 26           NaN      0.008372          NaN              0.004777
#
#     generation_time_std  offspring_evals_mean  offspring_evals_std  \
# 0                   NaN                 100.0                  NaN
# 1                   NaN                 100.0                  NaN
# 2                   NaN                 100.0                  NaN
# 3                   NaN                 100.0                  NaN
# 4                   NaN                 100.0                  NaN
# 5                   NaN                 100.0                  NaN
# 6                   NaN                 100.0                  NaN
# 7                   NaN                 100.0                  NaN
# 8                   NaN                 100.0                  NaN
# 9                   NaN                 100.0                  NaN
# 10                  NaN                 100.0                  NaN
# 11                  NaN                 100.0                  NaN
# 12                  NaN                 100.0                  NaN
# 13                  NaN                 100.0                  NaN
# 14                  NaN                 100.0                  NaN
# 15                  NaN                 100.0                  NaN
# 16                  NaN                 100.0                  NaN
# 17                  NaN                 100.0                  NaN
# 18                  NaN                 100.0                  NaN
# 19                  NaN                 100.0                  NaN
# 20                  NaN                 100.0                  NaN
# 21                  NaN                 100.0                  NaN
# 22                  NaN                 100.0                  NaN
# 23                  NaN                 100.0                  NaN
# 24                  NaN                 100.0                  NaN
# 25                  NaN                 100.0                  NaN
# 26                  NaN                 100.0                  NaN
#
#     pareto_size_mean  pareto_size_std
# 0              100.0              NaN
# 1              100.0              NaN
# 2              100.0              NaN
# 3              100.0              NaN
# 4              100.0              NaN
# 5              100.0              NaN
# 6              100.0              NaN
# 7              100.0              NaN
# 8              100.0              NaN
# 9              100.0              NaN
# 10             100.0              NaN
# 11             100.0              NaN
# 12             100.0              NaN
# 13             100.0              NaN
# 14             100.0              NaN
# 15             100.0              NaN
# 16             100.0              NaN
# 17             100.0              NaN
# 18             100.0              NaN
# 19             100.0              NaN
# 20             100.0              NaN
# 21             100.0              NaN
# 22             100.0              NaN
# 23             100.0              NaN
# 24             100.0              NaN
# 25             100.0              NaN
# 26             100.0              NaN
#
# [27 rows x 22 columns]
