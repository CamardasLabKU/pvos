# %%
#### Cell 0: Imports and Setup

# 1. Problem Selection and Configuration
#According to Table 2 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
problem_name = "ZDT1"
n_var = 30  # Custom number of decision variables 
n_obj = 2  # Custom number of objectives

# 2. Population Settings
# -----------------------
pop_size = 100
generations = 200

# 3. Operator-specific parameters
#According to Table 1 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
crossover_probability = 0.9
mutation_sigma = 0.5           
distribution_index_n_c = 15    # For simulated binary crossover
distribution_index_n_m = 20    # For polynomial mutation
blend_alpha = 0.5              # for blend crossover
swap_prob = 0.5                # For uniform crossover 


# 4. Select Crossover and Mutation Operators
# List all desired crossover operators to be applied in parallel.
selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    "single_point_crossover_batch",
    "blend_crossover_batch",
    "uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# Cell 1:


import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  

# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"  # e.g. c1dtlz1
    return "unknown"

def get_problem_dynamic(name: str, n_var: int | None = None, n_obj: int | None = None):
    """
    Robustly instantiate a Pymoo problem without you having to remember the exact signature.
    Tries the 'right' order per family, then falls back gracefully.
    """
    fam = _family(name)

    # preferred try-orders per family
    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),  # many constrained DTLZ variants expose fixed dims
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for a in attempts:
        try:
            return a()
        except TypeError as e:    # signature mismatch
            last_err = e
        except Exception as e:    # other errors (invalid name, etc.)
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )







# Cell 2: Configuration Parameters

# =============================================================================
#                            PVOS-4C Configuration
# =============================================================================



problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 

hnsga_alpha = 0.2   # Algorithm 2 in Mashwani et al.





# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1 


#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


#  Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices, F_start):

    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, F_start: F_start + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))




#cell 4




import numpy as np

def _sbx_core_batch(parents_dec_1, parents_dec_2, xl, xu,
                    eta_arr, prob_var_arr, prob_bin_arr,
                    eps=1e-14):
    """
    Core SBX operator matching pymoo.cross_sbx, but using
    parents_dec_1, parents_dec_2 instead of X.

    parents_dec_1, parents_dec_2 : (N, D)
    eta_arr, prob_var_arr, prob_bin_arr : (N, 1)

    Returns:
        Q : (2, N, D)  # two children per mating
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    xl = np.asarray(xl, dtype=float)
    xu = np.asarray(xu, dtype=float)

    N, D = parents_dec_1.shape
    X = np.stack([parents_dec_1, parents_dec_2], axis=0)  # (2, N, D)

    # probability of crossover for each variable
    prob_var_2d = np.repeat(prob_var_arr, D, axis=1)      # (N, D)
    cross = np.random.rand(N, D) < prob_var_2d

    # when solutions are too close -> do not apply sbx crossover
    too_close = np.abs(X[0] - X[1]) <= eps
    cross[too_close] = False

    # disable crossover when lower and upper bound are identical
    cross[:, xl == xu] = False

    # if no variable crosses at all, just clamp bounds and return
    if not np.any(cross):
        Q = X.copy()
        Q[0] = np.clip(Q[0], xl, xu)
        Q[1] = np.clip(Q[1], xl, xu)
        return Q

    # flatten the crossed positions
    p1 = X[0][cross]  # (n_cross,)
    p2 = X[1][cross]

    # orientation: y1 = smaller, y2 = larger
    sm = p1 < p2
    y1 = np.where(sm, p1, p2)
    y2 = np.where(sm, p2, p1)

    # bounds repeated and masked
    _xl = np.repeat(xl[None, :], N, axis=0)[cross]
    _xu = np.repeat(xu[None, :], N, axis=0)[cross]

    # eta, prob_bin expanded to (N, D) then masked
    eta_flat = np.repeat(eta_arr, D, axis=1)[cross]       # (n_cross,)
    prob_bin_flat = np.repeat(prob_bin_arr, D, axis=1)[cross]

    # shared random for both c1 and c2 (same as pymoo)
    rand = np.random.rand(len(eta_flat))

    def calc_betaq(beta):
        alpha = 2.0 - np.power(beta, -(eta_flat + 1.0))
        mask = rand <= (1.0 / alpha)
        mask_not = ~mask

        betaq = np.zeros_like(beta)
        if np.any(mask):
            betaq[mask] = np.power(rand[mask] * alpha[mask],
                                   1.0 / (eta_flat[mask] + 1.0))
        if np.any(mask_not):
            betaq[mask_not] = np.power(
                1.0 / (2.0 - rand[mask_not] * alpha[mask_not]),
                1.0 / (eta_flat[mask_not] + 1.0)
            )
        return betaq

    # difference between parents
    delta = (y2 - y1)

    # c1
    beta = 1.0 + (2.0 * (y1 - _xl) / delta)
    betaq = calc_betaq(beta)
    c1 = 0.5 * ((y1 + y2) - betaq * delta)

    # c2
    beta = 1.0 + (2.0 * (_xu - y2) / delta)
    betaq = calc_betaq(beta)
    c2 = 0.5 * ((y1 + y2) + betaq * delta)

    # children based on parent orientation
    child1 = np.where(sm, c1, c2)  # child aligned with parent 1
    child2 = np.where(sm, c2, c1)  # child aligned with parent 2

    # exchange children with probability prob_bin_flat and orientation
    b = np.bitwise_xor(
        np.random.rand(len(prob_bin_flat)) < prob_bin_flat,
        X[0][cross] > X[1][cross]
    )
    child1_final = np.where(b, child2, child1)
    child2_final = np.where(b, child1, child2)

    # assemble Q
    Q = X.copy()
    Q[0][cross] = child1_final
    Q[1][cross] = child2_final

    # clamp to bounds
    Q[0] = np.clip(Q[0], xl, xu)
    Q[1] = np.clip(Q[1], xl, xu)
    return Q


def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     prob, eta, min_values, max_values,
                                     n_offsprings=1,
                                     prob_exch=1.0,
                                     prob_bin=0.5,
                                     eps=1e-14):
    """
    Simulated Binary Crossover (SBX) matching pymoo.SBX(prob=..., eta=..., n_offsprings=...)

    Parameters
    ----------
    parents_dec_1 : (N, D)
    parents_dec_2 : (N, D)
    prob          : float
        Per-variable crossover probability (SBX 'prob' / 'prob_var').
    eta           : float
        Distribution index.
    min_values    : (D,)  lower bounds (xl)
    max_values    : (D,)  upper bounds (xu)
    n_offsprings  : 1 or 2
    prob_exch     : float, default 1.0
        Exchange probability (SBX prob_exch).
    prob_bin      : float, default 0.5
        Per-gene child swap probability (SBX prob_bin).
    eps           : float
        Threshold for "too close" parents.

    Returns
    -------
    offspring_dec :
        if n_offsprings == 1 : shape (N, D)
        if n_offsprings == 2 : shape (2*N, D)  [first N rows child1, next N rows child2]
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    min_values = np.asarray(min_values, dtype=float)
    max_values = np.asarray(max_values, dtype=float)

    N, D = parents_dec_1.shape

    # parameter arrays (N, 1) – same idea as pymoo's get(...)
    eta_arr = np.full((N, 1), eta, dtype=float)
    prob_var_arr = np.full((N, 1), prob, dtype=float)
    prob_exch_arr = np.full((N, 1), prob_exch, dtype=float)
    prob_bin_arr = np.full((N, 1), prob_bin, dtype=float)

    # apply prob_exch: zero out prob_bin if no exchange for that mating
    rand = np.random.rand(N, 1)
    prob_bin_arr[rand > prob_exch_arr] = 0.0

    # core SBX – returns two children per mating: Q shape (2, N, D)
    Q = _sbx_core_batch(parents_dec_1, parents_dec_2,
                        min_values, max_values,
                        eta_arr, prob_var_arr, prob_bin_arr,
                        eps=eps)

    if n_offsprings == 1:
        # randomly pick one of the two offspring per mating (same as SBX.n_offsprings=2)
        child = Q[0].copy()           # (N, D)
        pick_second = np.random.rand(N) < 0.5
        child[pick_second] = Q[1, pick_second]
        return child

    elif n_offsprings == 2:
        # stack to (2*N, D): [child1_0..child1_{N-1}, child2_0..child2_{N-1}]
        return Q.reshape(2 * N, D)

    else:
        raise ValueError("n_offsprings must be 1 or 2")





def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        
    """

    num_offspring, num_decision_variables = parents_dec_1.shape

    # Start with child1 as a copy of parent 1
    child1 = parents_dec_1.copy()

    # Decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # --- NEW: handle no-crossover pairs without bias ---
    no_cross_indices = np.where(~crossover_mask)[0]
    if no_cross_indices.size > 0:
        # For each no-crossover pair, flip a coin: 0 -> keep parent 1, 1 -> copy parent 2
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        # Overwrite those children with parent 2
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # --- Existing crossover logic for the pairs that do crossover ---
    crossover_indices = np.where(crossover_mask)[0]
    if crossover_indices.size > 0:
        # One crossover point per selected pair
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        for idx, cp in zip(crossover_indices, crossover_points):
            # NEW: randomly choose orientation to remove positional bias
            if np.random.rand() < 0.5:
                # suffix from parent2
                child1[idx, cp:] = parents_dec_2[idx, cp:]
            else:
                # prefix from parent2
                child1[idx, :cp] = parents_dec_2[idx, :cp]

    # Clip to bounds and return
    child1 = np.clip(child1, min_values, max_values)
    return child1




import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):

    N, D = parents_dec_1.shape

    child1 = parents_dec_1.copy()

    do_cross = np.random.rand(N) < crossover_probability

    # Handle pairs that do NOT crossover without bias
    no_cross_idx = np.where(~do_cross)[0]
    if no_cross_idx.size > 0:
        use_parent2 = np.random.rand(no_cross_idx.size) < 0.5
        idx_parent2 = no_cross_idx[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    cross_idx = np.where(do_cross)[0]
    if cross_idx.size > 0:
        p1 = parents_dec_1[cross_idx, :]
        p2 = parents_dec_2[cross_idx, :]

        y1 = np.minimum(p1, p2)
        y2 = np.maximum(p1, p2)
        d = y2 - y1

        # Full extended range — NO clamping to bounds here
        lower_bound = y1 - alpha_blend * d
        upper_bound = y2 + alpha_blend * d

        # Sample uniformly in the extended range
        rand1 = np.random.rand(p1.shape[0], D)
        c1 = lower_bound + rand1 * (upper_bound - lower_bound)

        child1[cross_idx, :] = c1

    # Clip AFTER sampling — this creates the boundary bias that helps ZDT convergence
    child1 = np.clip(child1, min_values, max_values)
    return child1


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # Handle pairs that do NOT crossover without bias:
    # for those indices, randomly choose between parent 1 and parent 2.
    no_cross_indices = np.where(~do_cross)[0]
    if no_cross_indices.size > 0:
        # Flip a coin for each no-crossover pair:
        # True -> use parent 2, False -> keep parent 1.
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # If no pairs are selected for crossover, we are done.
    if not np.any(do_cross):
        child1 = np.clip(child1, min_values, max_values)
        return child1

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]

    # Assign the offspring genes back to the full child array.
    child1[do_cross, :] = offspring1

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)

    # Return the generated offspring decision variables.
    return child1





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec



# Cell 5: Complete PVOS-4C Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual
def _integer_resource_allocation(raw_alloc, total, min_count=1):
    """
    Convert real-valued operator budgets into integers that sum to `total`.
    Keeps at least `min_count` individuals per operator so no operator vanishes
    due to rounding alone.
    """
    raw_alloc = np.asarray(raw_alloc, dtype=float)
    q = len(raw_alloc)

    if total < q * min_count:
        raise ValueError(f"population_size={total} is too small for q={q} and min_count={min_count}")

    if raw_alloc.sum() <= 0:
        raw_alloc = np.ones(q, dtype=float)

    # Normalize in case of tiny numerical drift
    raw_alloc = raw_alloc * (total / raw_alloc.sum())

    alloc = np.floor(raw_alloc).astype(int)
    remainder = int(total - alloc.sum())

    if remainder > 0:
        frac = raw_alloc - alloc
        order = np.argsort(-frac)
        alloc[order[:remainder]] += 1

    # Enforce minimum count by borrowing from the largest allocations
    while np.any(alloc < min_count):
        need_idx = np.where(alloc < min_count)[0]
        for idx in need_idx:
            donor_order = np.argsort(-alloc)
            moved = False
            for donor in donor_order:
                if donor != idx and alloc[donor] > min_count:
                    alloc[donor] -= 1
                    alloc[idx] += 1
                    moved = True
                    break
            if not moved:
                raise RuntimeError("Cannot satisfy min_count in operator allocation.")

    return alloc


def select_group_targets_and_mates(group_idx):
    """
    HNSGA-style reproduction inside one operator subpopulation:
    each individual in the group produces one offspring, using itself
    plus a random distinct mate from the same group.
    """
    group_idx = np.asarray(group_idx, dtype=int)
    n = len(group_idx)

    p1_idx = group_idx.copy()

    # Fallback when an operator currently has only one assigned individual.
    if n == 1:
        p2_idx = group_idx.copy()
        return p1_idx, p2_idx

    p2_idx = np.random.choice(group_idx, size=n, replace=True)
    same = (p1_idx == p2_idx)

    while np.any(same):
        p2_idx[same] = np.random.choice(group_idx, size=same.sum(), replace=True)
        same = (p1_idx == p2_idx)

    return p1_idx, p2_idx


def reassign_operator_labels(survivor_lineage_ids, target_counts):
    """
    After environmental selection, re-partition the new population into
    operator subpopulations whose sizes match target_counts.

    Preference is given to keeping survivors with their previous operator label.
    Any remaining shortages are filled randomly from the unassigned survivors.
    """
    survivor_lineage_ids = np.asarray(survivor_lineage_ids, dtype=int)
    target_counts = np.asarray(target_counts, dtype=int)

    N = len(survivor_lineage_ids)
    q = len(target_counts)

    if target_counts.sum() != N:
        raise ValueError("target_counts must sum to the population size.")

    next_labels = np.full(N, -1, dtype=int)
    taken = np.zeros(N, dtype=bool)

    # Keep as many lineage-consistent assignments as possible
    for k in range(q):
        idx = np.where(survivor_lineage_ids == k)[0]
        take = min(len(idx), int(target_counts[k]))
        if take > 0:
            chosen = np.random.choice(idx, size=take, replace=False)
            next_labels[chosen] = k
            taken[chosen] = True

    remaining_idx = np.where(~taken)[0]

    assigned_counts = np.bincount(next_labels[next_labels >= 0], minlength=q)
    remaining_labels = []
    for k in range(q):
        remaining_labels.extend([k] * int(target_counts[k] - assigned_counts[k]))
    remaining_labels = np.asarray(remaining_labels, dtype=int)

    if len(remaining_idx) != len(remaining_labels):
        raise RuntimeError("Mismatch while reassigning operator labels.")

    if len(remaining_idx) > 0:
        np.random.shuffle(remaining_idx)
        np.random.shuffle(remaining_labels)
        next_labels[remaining_idx] = remaining_labels

    return next_labels
class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval, record_history=False):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    # objective slice in your population array [X | F] (or [X | F | CV])
    F_start = num_decision_variables
    F_end   = num_decision_variables + num_objectives

    def _eval_F_and_CV(X):
        """Evaluate F (and CV if you use it) with the same shape handling you already do."""
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(X, return_values_of=['F', 'G'])
            CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, CV
        else:
            eval_result = problem.evaluate(X)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, None
    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]

    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    metrics_history = []
    front_history = []
    true_pf_history = []
    gen_history = []
    
    true_pf_static = problem.pareto_front() if hasattr(problem, "pareto_front") else None
    
    # ---------------- HNSGA operator-allocation state ----------------
    q = len(crossover_ops)
    operator_names = [op.__name__ for op in crossover_ops]

    # Generation 1: equal allocation across operators, randomized over individuals
    operator_alloc = _integer_resource_allocation(
        np.full(q, population_size / q, dtype=float),
        population_size,
        min_count=1
    )

    population_operator_ids = np.concatenate([
        np.full(operator_alloc[k], k, dtype=int) for k in range(q)
    ])
    np.random.shuffle(population_operator_ids)
    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator, each crossover produced one child.
        if co == simulated_binary_crossover_batch:
            sbx = SBX(prob=crossover_probability,
                      eta=distribution_index_n_c,
                      n_offsprings=1)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            matings = [[Individual(X=p1), Individual(X=p2)]
                       for p1, p2 in zip(parents_dec_1, parents_dec_2)]
        
            # single call → (N, D) offspring
            child_dec = sbx.do(_prob, matings).get("X")      
               


        elif co == single_point_crossover_batch:
            
            child_dec= single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
  

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child_dec = polynomial_mutation_batch(
                child_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )

        elif selected_mutation_operator == gaussian_mutation_batch:
            child_dec = gaussian_mutation_batch(
                child_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )

        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        offspring_dec = child_dec                         
        
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(offspring_dec, return_values_of=['F', 'G'])
            CV   = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F, CV])
        else:
            eval_result = problem.evaluate(offspring_dec)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F])
        
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx, F_start)


        # ================= HNSGA adaptive operator allocation =================
        current_alloc = np.bincount(population_operator_ids, minlength=q)

        # Each operator only acts on its own assigned subpopulation
        jobs = []
        for op_id, op in enumerate(crossover_ops):
            group_idx = np.where(population_operator_ids == op_id)[0]
            if group_idx.size == 0:
                continue

            # One offspring per assigned individual, with mates chosen inside the same subpopulation
            p1_idx, p2_idx = select_group_targets_and_mates(group_idx)
            parents1 = population[p1_idx, :num_decision_variables]
            parents2 = population[p2_idx, :num_decision_variables]

            jobs.append((op_id, op, parents1, parents2))

        results = Parallel(n_jobs=1)(#len(jobs))(
            delayed(apply_crossover_and_mutation)(
                op, parents1, parents2,
                selected_mutation_operator,
                mutation_probability,
                distribution_index_n_c,
                distribution_index_n_m,
                mutation_sigma,
                blend_alpha,
                swap_prob,
                min_values,
                max_values,
                crossover_probability
            )
            for op_id, op, parents1, parents2 in jobs
        )

        offspring_list = []
        offspring_operator_ids = []

        for (op_id, op, parents1, parents2), res in zip(jobs, results):
            offspring_list.append(res["offspring"])
            offspring_operator_ids.append(
                np.full(res["offspring"].shape[0], op_id, dtype=int)
            )

        combined_offspring = np.vstack(offspring_list)
        offspring_operator_ids = np.concatenate(offspring_operator_ids)

        # Parent and offspring lineages are both tracked by operator id
        combined_pop = np.vstack([population, combined_offspring])
        combined_lineage_ids = np.concatenate([population_operator_ids, offspring_operator_ids])

        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))
        for r in range(1, rank_combined.max() + 1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx, F_start)

        # Environmental selection, same as NSGA-II
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted(
                    [(i, crowding_combined[i]) for i in front_idx],
                    key=lambda x: -x[1]
                )
                survivors.extend([i for i, _ in sorted_front[:population_size - len(survivors)]])
            current_rank += 1

        survivors = np.asarray(survivors, dtype=int)

        population = combined_pop[survivors]
        survivor_lineage_ids = combined_lineage_ids[survivors]

        # HNSGA credit assignment:
        # count ONLY offspring that survived into the new population
        successful_offspring_mask = survivors >= population_size
        successful_operator_ids = survivor_lineage_ids[successful_offspring_mask]
        success_counts = np.bincount(successful_operator_ids, minlength=q)

        # Algorithm 2 update:
        # P_{t+1}(k) = alpha * P_t(k) + (1-alpha) * phi_k * N
        # where phi_k = I_k / sum(I_k)
        if success_counts.sum() == 0:
            next_raw_alloc = current_alloc.astype(float)
        else:
            phi = success_counts / success_counts.sum()
            next_raw_alloc = (
                hnsga_alpha * current_alloc
                + (1.0 - hnsga_alpha) * (phi * population_size)
            )

        operator_alloc = _integer_resource_allocation(
            next_raw_alloc,
            population_size,
            min_count=1
        )

        population_operator_ids = reassign_operator_labels(
            survivor_lineage_ids,
            operator_alloc
        )

        survival_stats = {
            operator_names[k]: int(success_counts[k]) for k in range(q)
        }
        allocation_stats = {
            operator_names[k]: int(operator_alloc[k]) for k in range(q)
        }

        print("Successful offspring by operator:", survival_stats)
        print("Next-generation operator allocation:", allocation_stats)

        # Identify the non-dominated front in the NEW population
        non_dominated_indices = np.where(rank_combined[survivors] == 1)[0]
        non_dominated_front = population[
            non_dominated_indices,
            problem.n_var: problem.n_var + num_objectives
        ]

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]
        if record_history:
            front_history.append(non_dominated_front.copy())
            true_pf_history.append(true_pf_static.copy() if true_pf_static is not None else None)
            gen_history.append(generation)

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["operator_allocation"] = allocation_stats
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time

            #metrics_results["pm_used"] = [mut_prob_eff] * len(crossover_ops)
            #metrics_results["eta_m_used"] = [eta_m_eff] * len(crossover_ops)

            # how many offspring were evaluated this generation
            metrics_results["offspring_evals"] = combined_offspring.shape[0]

            # evaluations used for change detection sampling each gen
            #metrics_results["sample_evals"] = n_samples

            # evaluations used when you re-evaluate the whole population after a change
           # metrics_results["parent_reeval_evals"] = population_size if change_detected else 0

            #metrics_results["total_evals_this_gen"] = (
            #    combined_offspring.shape[0] 
            #)
            # ----------------------------------------------------------------------            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    history = None
    if record_history:
        history = {
            "front": front_history,
            "true_pf": true_pf_history,
            "generation": gen_history
        }
    
    return population, problem.pareto_front(), metrics_history, history




#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts (using Pymoo data for the analytical solution)
    
    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib



# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    


    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,  
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points,
        'history': history

    }

# Run NSGA-II in parallel for seeds 1 to 30 (or 31 if you prefer 1 to 31) in series 
seeds = range(1, 2)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    


    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],

            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)

        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 7}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 29, 'blend_crossover_batch': 25, 'uniform_crossover_batch': 16}
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.5351, gd_plus=2.5351, igd_plus=1.9687, spacing=0.1273, generation=1.0000, generation_time=0.0075, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 7}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 35, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 14}
# Gen 2: hypervolume=0.0000, igd=1.9688, gd=2.7377, gd_plus=2.7377, igd_plus=1.9687, spacing=0.1457, generation=2.0000, generation_time=0.0076, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 6}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 38, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 12}
# Gen 3: hypervolume=0.0000, igd=1.9114, gd=2.5181, gd_plus=2.5181, igd_plus=1.9114, spacing=0.1886, generation=3.0000, generation_time=0.0092, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 41, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 9}
# Gen 4: hypervolume=0.0000, igd=1.6366, gd=2.2635, gd_plus=2.2635, igd_plus=1.6366, spacing=0.1326, generation=4.0000, generation_time=0.0081, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 34, 'blend_crossover_batch': 23, 'uniform_crossover_batch': 3}
# Gen 5: hypervolume=0.0000, igd=1.3366, gd=1.8880, gd_plus=1.8880, igd_plus=1.3366, spacing=0.1027, generation=5.0000, generation_time=0.0106, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 45, 'single_point_crossover_batch': 28, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 3}
# Gen 6: hypervolume=0.0000, igd=1.3366, gd=1.8321, gd_plus=1.8321, igd_plus=1.3366, spacing=0.0744, generation=6.0000, generation_time=0.0106, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 51, 'single_point_crossover_batch': 27, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 2}
# Gen 7: hypervolume=0.0000, igd=1.3366, gd=1.7293, gd_plus=1.7293, igd_plus=1.3366, spacing=0.0824, generation=7.0000, generation_time=0.0116, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 51, 'single_point_crossover_batch': 26, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 1}
# Gen 8: hypervolume=0.0000, igd=1.2985, gd=1.5852, gd_plus=1.5852, igd_plus=1.2985, spacing=0.0634, generation=8.0000, generation_time=0.0073, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 52, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 27, 'uniform_crossover_batch': 1}
# Gen 9: hypervolume=0.0000, igd=1.2659, gd=1.5077, gd_plus=1.5077, igd_plus=1.2659, spacing=0.0695, generation=9.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 56, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 2}
# Gen 10: hypervolume=0.0000, igd=1.1722, gd=1.3771, gd_plus=1.3771, igd_plus=1.1722, spacing=0.1112, generation=10.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 53, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 26, 'uniform_crossover_batch': 4}
# Gen 11: hypervolume=0.0000, igd=1.0439, gd=1.2292, gd_plus=1.2292, igd_plus=1.0438, spacing=0.0966, generation=11.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 55, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 6}
# Gen 12: hypervolume=0.0000, igd=1.0334, gd=1.2913, gd_plus=1.2913, igd_plus=1.0333, spacing=0.0634, generation=12.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 61, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 3}
# Gen 13: hypervolume=0.0000, igd=1.0322, gd=1.2950, gd_plus=1.2950, igd_plus=1.0322, spacing=0.0469, generation=13.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 64, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 4}
# Gen 14: hypervolume=0.0000, igd=0.9997, gd=1.1284, gd_plus=1.1284, igd_plus=0.9996, spacing=0.0535, generation=14.0000, generation_time=0.0080, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 64, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 4}
# Gen 15: hypervolume=0.0043, igd=0.9242, gd=1.0254, gd_plus=1.0254, igd_plus=0.9241, spacing=0.0776, generation=15.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 58, 'single_point_crossover_batch': 21, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 5}
# Gen 16: hypervolume=0.0097, igd=0.8744, gd=1.0220, gd_plus=1.0220, igd_plus=0.8744, spacing=0.0834, generation=16.0000, generation_time=0.0088, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 59, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 2}
# Gen 17: hypervolume=0.0495, igd=0.7497, gd=0.9994, gd_plus=0.9994, igd_plus=0.7497, spacing=0.1001, generation=17.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 58, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 2}
# Gen 18: hypervolume=0.0948, igd=0.5944, gd=0.9111, gd_plus=0.9111, igd_plus=0.5943, spacing=0.0967, generation=18.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 55, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 25, 'uniform_crossover_batch': 1}
# Gen 19: hypervolume=0.0948, igd=0.5908, gd=0.7737, gd_plus=0.7737, igd_plus=0.5907, spacing=0.0842, generation=19.0000, generation_time=0.0078, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 55, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 25, 'uniform_crossover_batch': 1}
# Gen 20: hypervolume=0.1105, igd=0.5747, gd=0.7771, gd_plus=0.7771, igd_plus=0.5745, spacing=0.0675, generation=20.0000, generation_time=0.0087, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 66, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 2}
# Gen 21: hypervolume=0.1369, igd=0.5610, gd=0.7447, gd_plus=0.7447, igd_plus=0.5609, spacing=0.0699, generation=21.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 61, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 4}
# Gen 22: hypervolume=0.1513, igd=0.5485, gd=0.6736, gd_plus=0.6736, igd_plus=0.5483, spacing=0.0669, generation=22.0000, generation_time=0.0071, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 32, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 68, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 4}
# Gen 23: hypervolume=0.1729, igd=0.5341, gd=0.6160, gd_plus=0.6160, igd_plus=0.5339, spacing=0.0453, generation=23.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 32, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 68, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 4}
# Gen 24: hypervolume=0.1881, igd=0.5201, gd=0.6005, gd_plus=0.6005, igd_plus=0.5200, spacing=0.0513, generation=24.0000, generation_time=0.0101, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 75, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 1}
# Gen 25: hypervolume=0.2208, igd=0.4817, gd=0.5538, gd_plus=0.5538, igd_plus=0.4799, spacing=0.0470, generation=25.0000, generation_time=0.0100, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 2}
# Gen 26: hypervolume=0.2531, igd=0.4476, gd=0.5074, gd_plus=0.5074, igd_plus=0.4457, spacing=0.0556, generation=26.0000, generation_time=0.0078, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 68, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 1}
# Gen 27: hypervolume=0.2719, igd=0.4285, gd=0.4852, gd_plus=0.4852, igd_plus=0.4263, spacing=0.0444, generation=27.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 71, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 2}
# Gen 28: hypervolume=0.3177, igd=0.3895, gd=0.4363, gd_plus=0.4363, igd_plus=0.3871, spacing=0.0450, generation=28.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 2}
# Gen 29: hypervolume=0.3255, igd=0.3820, gd=0.4425, gd_plus=0.4425, igd_plus=0.3795, spacing=0.0345, generation=29.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 38, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 1}
# Gen 30: hypervolume=0.3356, igd=0.3757, gd=0.3872, gd_plus=0.3872, igd_plus=0.3733, spacing=0.0313, generation=30.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Gen 31: hypervolume=0.3582, igd=0.3626, gd=0.3935, gd_plus=0.3935, igd_plus=0.3601, spacing=0.0354, generation=31.0000, generation_time=0.0085, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 80, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 32: hypervolume=0.3807, igd=0.3471, gd=0.3657, gd_plus=0.3657, igd_plus=0.3446, spacing=0.0352, generation=32.0000, generation_time=0.0084, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 13, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 4}
# Gen 33: hypervolume=0.4000, igd=0.3323, gd=0.3692, gd_plus=0.3691, igd_plus=0.3294, spacing=0.0326, generation=33.0000, generation_time=0.0074, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 34: hypervolume=0.4386, igd=0.2933, gd=0.3270, gd_plus=0.3269, igd_plus=0.2902, spacing=0.0399, generation=34.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 35: hypervolume=0.4514, igd=0.2857, gd=0.3112, gd_plus=0.3111, igd_plus=0.2827, spacing=0.0353, generation=35.0000, generation_time=0.0105, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 8}
# Gen 36: hypervolume=0.4614, igd=0.2822, gd=0.2781, gd_plus=0.2781, igd_plus=0.2792, spacing=0.0345, generation=36.0000, generation_time=0.0090, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 37: hypervolume=0.4762, igd=0.2717, gd=0.2696, gd_plus=0.2696, igd_plus=0.2686, spacing=0.0309, generation=37.0000, generation_time=0.0093, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 38: hypervolume=0.5111, igd=0.2390, gd=0.2422, gd_plus=0.2422, igd_plus=0.2384, spacing=0.0285, generation=38.0000, generation_time=0.0080, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 47, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 39: hypervolume=0.5259, igd=0.2321, gd=0.2273, gd_plus=0.2272, igd_plus=0.2257, spacing=0.0248, generation=39.0000, generation_time=0.0075, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 52, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 5}
# Gen 40: hypervolume=0.5385, igd=0.2205, gd=0.2042, gd_plus=0.2041, igd_plus=0.2162, spacing=0.0199, generation=40.0000, generation_time=0.0085, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 45, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 41: hypervolume=0.5572, igd=0.2067, gd=0.1982, gd_plus=0.1982, igd_plus=0.2060, spacing=0.0306, generation=41.0000, generation_time=0.0071, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 42: hypervolume=0.5959, igd=0.1733, gd=0.1885, gd_plus=0.1885, igd_plus=0.1723, spacing=0.0416, generation=42.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 43: hypervolume=0.6067, igd=0.1692, gd=0.1748, gd_plus=0.1747, igd_plus=0.1682, spacing=0.0290, generation=43.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 5}
# Gen 44: hypervolume=0.6155, igd=0.1651, gd=0.1794, gd_plus=0.1793, igd_plus=0.1641, spacing=0.0331, generation=44.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 45: hypervolume=0.6279, igd=0.1564, gd=0.1650, gd_plus=0.1649, igd_plus=0.1554, spacing=0.0282, generation=45.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 5}
# Gen 46: hypervolume=0.6380, igd=0.1508, gd=0.1660, gd_plus=0.1657, igd_plus=0.1497, spacing=0.0188, generation=46.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 7}
# Gen 47: hypervolume=0.6500, igd=0.1443, gd=0.1618, gd_plus=0.1615, igd_plus=0.1432, spacing=0.0183, generation=47.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Gen 48: hypervolume=0.6599, igd=0.1360, gd=0.1486, gd_plus=0.1482, igd_plus=0.1349, spacing=0.0189, generation=48.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 48, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 49: hypervolume=0.6702, igd=0.1277, gd=0.1360, gd_plus=0.1355, igd_plus=0.1265, spacing=0.0164, generation=49.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 96, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 50: hypervolume=0.6812, igd=0.1196, gd=0.1307, gd_plus=0.1303, igd_plus=0.1187, spacing=0.0194, generation=50.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Gen 51: hypervolume=0.6861, igd=0.1178, gd=0.1281, gd_plus=0.1277, igd_plus=0.1169, spacing=0.0167, generation=51.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 52: hypervolume=0.6988, igd=0.1078, gd=0.1188, gd_plus=0.1183, igd_plus=0.1077, spacing=0.0203, generation=52.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 3}
# Gen 53: hypervolume=0.7043, igd=0.1051, gd=0.1144, gd_plus=0.1140, igd_plus=0.1051, spacing=0.0188, generation=53.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 5}
# Gen 54: hypervolume=0.7094, igd=0.1017, gd=0.1069, gd_plus=0.1063, igd_plus=0.1014, spacing=0.0182, generation=54.0000, generation_time=0.0037, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 5}
# Gen 55: hypervolume=0.7195, igd=0.0940, gd=0.1038, gd_plus=0.1032, igd_plus=0.0938, spacing=0.0178, generation=55.0000, generation_time=0.0045, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 5}
# Gen 56: hypervolume=0.7265, igd=0.0902, gd=0.1004, gd_plus=0.0998, igd_plus=0.0902, spacing=0.0180, generation=56.0000, generation_time=0.0047, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 5}
# Gen 57: hypervolume=0.7328, igd=0.0859, gd=0.0933, gd_plus=0.0928, igd_plus=0.0858, spacing=0.0188, generation=57.0000, generation_time=0.0034, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 58: hypervolume=0.7369, igd=0.0842, gd=0.0885, gd_plus=0.0881, igd_plus=0.0841, spacing=0.0156, generation=58.0000, generation_time=0.0034, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 59: hypervolume=0.7401, igd=0.0823, gd=0.0862, gd_plus=0.0857, igd_plus=0.0822, spacing=0.0161, generation=59.0000, generation_time=0.0032, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 3}
# Gen 60: hypervolume=0.7437, igd=0.0803, gd=0.0841, gd_plus=0.0837, igd_plus=0.0802, spacing=0.0153, generation=60.0000, generation_time=0.0041, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 61: hypervolume=0.7477, igd=0.0772, gd=0.0827, gd_plus=0.0820, igd_plus=0.0772, spacing=0.0163, generation=61.0000, generation_time=0.0039, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 62: hypervolume=0.7534, igd=0.0728, gd=0.0811, gd_plus=0.0804, igd_plus=0.0727, spacing=0.0144, generation=62.0000, generation_time=0.0055, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 32, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 63: hypervolume=0.7587, igd=0.0699, gd=0.0762, gd_plus=0.0757, igd_plus=0.0698, spacing=0.0159, generation=63.0000, generation_time=0.0110, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 5}
# Gen 64: hypervolume=0.7646, igd=0.0665, gd=0.0727, gd_plus=0.0716, igd_plus=0.0663, spacing=0.0130, generation=64.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 84, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 7}
# Gen 65: hypervolume=0.7697, igd=0.0632, gd=0.0696, gd_plus=0.0692, igd_plus=0.0630, spacing=0.0137, generation=65.0000, generation_time=0.0074, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 8}
# Gen 66: hypervolume=0.7741, igd=0.0613, gd=0.0620, gd_plus=0.0615, igd_plus=0.0607, spacing=0.0121, generation=66.0000, generation_time=0.0080, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 6}
# Gen 67: hypervolume=0.7776, igd=0.0592, gd=0.0596, gd_plus=0.0592, igd_plus=0.0587, spacing=0.0108, generation=67.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 19, 'uniform_crossover_batch': 3}
# Gen 68: hypervolume=0.7806, igd=0.0574, gd=0.0581, gd_plus=0.0576, igd_plus=0.0568, spacing=0.0089, generation=68.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 2}
# Gen 69: hypervolume=0.7844, igd=0.0552, gd=0.0567, gd_plus=0.0562, igd_plus=0.0550, spacing=0.0083, generation=69.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 4}
# Gen 70: hypervolume=0.7884, igd=0.0527, gd=0.0516, gd_plus=0.0504, igd_plus=0.0525, spacing=0.0101, generation=70.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 82, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 7}
# Gen 71: hypervolume=0.7913, igd=0.0505, gd=0.0507, gd_plus=0.0494, igd_plus=0.0502, spacing=0.0103, generation=71.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 84, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 8}
# Gen 72: hypervolume=0.7941, igd=0.0485, gd=0.0497, gd_plus=0.0489, igd_plus=0.0483, spacing=0.0110, generation=72.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 88, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 73: hypervolume=0.7988, igd=0.0467, gd=0.0475, gd_plus=0.0468, igd_plus=0.0466, spacing=0.0104, generation=73.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 5}
# Gen 74: hypervolume=0.8028, igd=0.0437, gd=0.0444, gd_plus=0.0436, igd_plus=0.0436, spacing=0.0120, generation=74.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 3}
# Gen 75: hypervolume=0.8055, igd=0.0422, gd=0.0444, gd_plus=0.0435, igd_plus=0.0420, spacing=0.0119, generation=75.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 5}
# Gen 76: hypervolume=0.8079, igd=0.0407, gd=0.0427, gd_plus=0.0419, igd_plus=0.0405, spacing=0.0106, generation=76.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 5}
# Gen 77: hypervolume=0.8104, igd=0.0392, gd=0.0408, gd_plus=0.0399, igd_plus=0.0390, spacing=0.0103, generation=77.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 5}
# Gen 78: hypervolume=0.8132, igd=0.0372, gd=0.0398, gd_plus=0.0387, igd_plus=0.0371, spacing=0.0105, generation=78.0000, generation_time=0.0083, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 79: hypervolume=0.8154, igd=0.0358, gd=0.0366, gd_plus=0.0359, igd_plus=0.0357, spacing=0.0115, generation=79.0000, generation_time=0.0098, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Gen 80: hypervolume=0.8182, igd=0.0346, gd=0.0354, gd_plus=0.0346, igd_plus=0.0346, spacing=0.0083, generation=80.0000, generation_time=0.0092, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 81: hypervolume=0.8205, igd=0.0330, gd=0.0348, gd_plus=0.0341, igd_plus=0.0329, spacing=0.0078, generation=81.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 82: hypervolume=0.8231, igd=0.0311, gd=0.0315, gd_plus=0.0309, igd_plus=0.0311, spacing=0.0101, generation=82.0000, generation_time=0.0071, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 83: hypervolume=0.8250, igd=0.0299, gd=0.0304, gd_plus=0.0295, igd_plus=0.0298, spacing=0.0088, generation=83.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 84: hypervolume=0.8271, igd=0.0290, gd=0.0299, gd_plus=0.0290, igd_plus=0.0290, spacing=0.0089, generation=84.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Gen 85: hypervolume=0.8310, igd=0.0270, gd=0.0285, gd_plus=0.0275, igd_plus=0.0269, spacing=0.0095, generation=85.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Gen 86: hypervolume=0.8329, igd=0.0257, gd=0.0273, gd_plus=0.0267, igd_plus=0.0256, spacing=0.0084, generation=86.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 87: hypervolume=0.8340, igd=0.0251, gd=0.0271, gd_plus=0.0264, igd_plus=0.0250, spacing=0.0072, generation=87.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 3}
# Gen 88: hypervolume=0.8355, igd=0.0240, gd=0.0252, gd_plus=0.0245, igd_plus=0.0239, spacing=0.0076, generation=88.0000, generation_time=0.0087, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 1}
# Gen 89: hypervolume=0.8363, igd=0.0236, gd=0.0250, gd_plus=0.0240, igd_plus=0.0236, spacing=0.0074, generation=89.0000, generation_time=0.0133, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 90: hypervolume=0.8386, igd=0.0221, gd=0.0234, gd_plus=0.0225, igd_plus=0.0221, spacing=0.0074, generation=90.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 91: hypervolume=0.8398, igd=0.0214, gd=0.0227, gd_plus=0.0215, igd_plus=0.0213, spacing=0.0069, generation=91.0000, generation_time=0.0101, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Gen 92: hypervolume=0.8414, igd=0.0203, gd=0.0214, gd_plus=0.0204, igd_plus=0.0202, spacing=0.0068, generation=92.0000, generation_time=0.0081, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 93: hypervolume=0.8426, igd=0.0195, gd=0.0205, gd_plus=0.0195, igd_plus=0.0194, spacing=0.0065, generation=93.0000, generation_time=0.0084, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 5}
# Gen 94: hypervolume=0.8437, igd=0.0191, gd=0.0201, gd_plus=0.0191, igd_plus=0.0189, spacing=0.0072, generation=94.0000, generation_time=0.0062, offspring_evals=100.0000
# ...
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 65, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 8}
# Gen 170: hypervolume=0.8652, igd=0.0064, gd=0.0064, gd_plus=0.0052, igd_plus=0.0059, spacing=0.0067, generation=170.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 5}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 61, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 13}
# Gen 171: hypervolume=0.8653, igd=0.0065, gd=0.0069, gd_plus=0.0052, igd_plus=0.0059, spacing=0.0075, generation=171.0000, generation_time=0.0100, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 70, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 11}
# Gen 172: hypervolume=0.8655, igd=0.0063, gd=0.0070, gd_plus=0.0052, igd_plus=0.0058, spacing=0.0068, generation=172.0000, generation_time=0.0140, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 73, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 11}
# Gen 173: hypervolume=0.8659, igd=0.0061, gd=0.0069, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0068, generation=173.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 75, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 10}
# Gen 174: hypervolume=0.8661, igd=0.0062, gd=0.0073, gd_plus=0.0052, igd_plus=0.0055, spacing=0.0068, generation=174.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 75, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 9}
# Gen 175: hypervolume=0.8662, igd=0.0061, gd=0.0067, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0075, generation=175.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 8}
# Gen 176: hypervolume=0.8662, igd=0.0060, gd=0.0070, gd_plus=0.0049, igd_plus=0.0054, spacing=0.0075, generation=176.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 79, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 9}
# Gen 177: hypervolume=0.8664, igd=0.0060, gd=0.0068, gd_plus=0.0048, igd_plus=0.0053, spacing=0.0068, generation=177.0000, generation_time=0.0088, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 13}
# Gen 178: hypervolume=0.8667, igd=0.0059, gd=0.0067, gd_plus=0.0048, igd_plus=0.0052, spacing=0.0072, generation=178.0000, generation_time=0.0071, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 77, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 10}
# Gen 179: hypervolume=0.8666, igd=0.0059, gd=0.0064, gd_plus=0.0049, igd_plus=0.0052, spacing=0.0074, generation=179.0000, generation_time=0.0073, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 2}
# Gen 180: hypervolume=0.8668, igd=0.0059, gd=0.0071, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0062, generation=180.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 3}
# Gen 181: hypervolume=0.8668, igd=0.0060, gd=0.0071, gd_plus=0.0048, igd_plus=0.0052, spacing=0.0066, generation=181.0000, generation_time=0.0072, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 83, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 4}
# Gen 182: hypervolume=0.8669, igd=0.0058, gd=0.0066, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0062, generation=182.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 82, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 3}
# Gen 183: hypervolume=0.8666, igd=0.0061, gd=0.0065, gd_plus=0.0045, igd_plus=0.0053, spacing=0.0071, generation=183.0000, generation_time=0.0084, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 184: hypervolume=0.8667, igd=0.0060, gd=0.0064, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0075, generation=184.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 85, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 1}
# Gen 185: hypervolume=0.8667, igd=0.0059, gd=0.0064, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0069, generation=185.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 85, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Gen 186: hypervolume=0.8661, igd=0.0063, gd=0.0065, gd_plus=0.0046, igd_plus=0.0055, spacing=0.0068, generation=186.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 79, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 3}
# Gen 187: hypervolume=0.8664, igd=0.0059, gd=0.0064, gd_plus=0.0046, igd_plus=0.0053, spacing=0.0065, generation=187.0000, generation_time=0.0095, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 82, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 1}
# Gen 188: hypervolume=0.8669, igd=0.0056, gd=0.0064, gd_plus=0.0045, igd_plus=0.0051, spacing=0.0054, generation=188.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 3}
# Gen 189: hypervolume=0.8670, igd=0.0054, gd=0.0058, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0055, generation=189.0000, generation_time=0.0057, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Gen 190: hypervolume=0.8671, igd=0.0056, gd=0.0059, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0052, generation=190.0000, generation_time=0.0059, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 77, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 3}
# Gen 191: hypervolume=0.8668, igd=0.0058, gd=0.0059, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0056, generation=191.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 3}
# Gen 192: hypervolume=0.8666, igd=0.0060, gd=0.0062, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0071, generation=192.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 75, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 3}
# Gen 193: hypervolume=0.8670, igd=0.0059, gd=0.0063, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0065, generation=193.0000, generation_time=0.0126, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 3}
# Gen 194: hypervolume=0.8670, igd=0.0058, gd=0.0062, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0061, generation=194.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 73, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 6}
# Gen 195: hypervolume=0.8668, igd=0.0059, gd=0.0066, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0060, generation=195.0000, generation_time=0.0108, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 23, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 66, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 27, 'uniform_crossover_batch': 6}
# Gen 196: hypervolume=0.8670, igd=0.0057, gd=0.0065, gd_plus=0.0046, igd_plus=0.0049, spacing=0.0068, generation=196.0000, generation_time=0.0114, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 53, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 42, 'uniform_crossover_batch': 4}
# Gen 197: hypervolume=0.8665, igd=0.0062, gd=0.0067, gd_plus=0.0046, igd_plus=0.0053, spacing=0.0073, generation=197.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 51, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 44, 'uniform_crossover_batch': 3}
# Gen 198: hypervolume=0.8667, igd=0.0061, gd=0.0063, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0077, generation=198.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 51, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 45, 'uniform_crossover_batch': 3}
# Gen 199: hypervolume=0.8671, igd=0.0055, gd=0.0061, gd_plus=0.0046, igd_plus=0.0049, spacing=0.0070, generation=199.0000, generation_time=0.0056, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 48, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 46, 'uniform_crossover_batch': 3}
# Gen 200: hypervolume=0.8670, igd=0.0058, gd=0.0061, gd_plus=0.0045, igd_plus=0.0051, spacing=0.0079, generation=200.0000, generation_time=0.0066, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100

# %%
### Cell 8: Save Combined Metrics History to Excel 
import pandas as pd
import re

# Convert the all_metrics list to DataFrame
df_metrics = pd.DataFrame(all_metrics)

# Sanitize problem name for filename
problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()


# Define a mapping from the full crossover operator names to shortcuts
crossover_shortcuts = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}

# Convert selected crossover operator names to their shortcut representation
selected_crossover_shortcut_names = [
    crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
]

# Join the shortcuts into a single string (e.g., "sbx-blx")
crossover_str = "-".join(selected_crossover_shortcut_names)

# Create valid filename
excel_filename = (
    f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross 1 poly "
    f"{pop_size}pop {generations}gen.xlsx"
)

#{crossover_str}

# Save to Excel
df_metrics.to_excel(excel_filename, index=False)
print(f"Metrics saved to '{excel_filename}'")
# Out:
# Metrics saved to 'zdt1 4 sbx-spx-blx-ux cross 1 poly 100pop 200gen.xlsx'

# %%
# =========================
# New Cell: Run all Table 2 problems exactly as manual — HNSGA variant
# =========================

import os
import re
import numpy as np
import pandas as pd
from pathlib import Path
from joblib import Parallel, delayed

# Recompute so this cell is self-contained
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None

# -------------------------------------------------
# 1) Table 2 benchmark list
# -------------------------------------------------
TABLE2_PROBLEMS = (
    [{"name": f"zdt{i}",   "n_var": 30, "n_obj": 2, "generations": 200}  for i in [1, 2, 3]] +
    [{"name": f"zdt{i}",   "n_var": 10, "n_obj": 2, "generations": 400}  for i in [4, 6]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 1000} for i in [1, 3]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 200}  for i in [2, 5, 7]] +
    [{"name": "dtlz4",     "n_var": 12, "n_obj": 3, "generations": 500}] +
    [{"name": "dtlz6",     "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": f"wfg{i}",   "n_var": 6,  "n_obj": 3, "generations": 200}  for i in range(1, 10)] +
    [{"name": "c1dtlz1",   "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "c2dtlz2",   "n_var": 12, "n_obj": 3, "generations": 200}] +
    [{"name": "c3dtlz4",   "n_var": 7,  "n_obj": 3, "generations": 500}] +
    [{"name": "dc1dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc1dtlz3",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc3dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}]
)

SEEDS = range(1, 2)
OUTPUT_DIR = Path("HNSGA results time")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

CROSSOVER_SHORTCUTS = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}
MUTATION_SHORTCUTS = {
    "polynomial_mutation_batch": "poly",
    "gaussian_mutation_batch": "gauss"
}


def build_excel_name(problem_name, generations):
    problem_name_clean = re.sub(r"[^a-zA-Z0-9_]", "", problem_name).lower()
    crossover_str = "-".join(
        CROSSOVER_SHORTCUTS.get(name, name)
        for name in selected_crossover_operator_names
    )
    mutation_str = MUTATION_SHORTCUTS.get(selected_mutation_operator_name, selected_mutation_operator_name)
    return (
        f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} "
        f"cross 1 {mutation_str} {pop_size}pop {generations}gen HNSGA.xlsx"
    )


def flatten_columns(columns):
    out = []
    for col in columns:
        if isinstance(col, tuple):
            out.append("_".join([str(x) for x in col if str(x) != ""]).rstrip("_"))
        else:
            out.append(str(col))
    return out


# -------------------------------------------------
# 2) Per-seed runner — identical to manual Cell 7
#    Uses the ORIGINAL get_problem_dynamic from Cell 1
#    NO make_problem_safe wrapper
#    run_nsga2 reads hnsga_alpha from global scope (same as Cell 7)
# -------------------------------------------------
def run_seed_manual(problem_cfg, seed):
    """
    Runs exactly like the manual code:
      - Uses get_problem_dynamic from Cell 1 (family-aware, no safety wrapper)
      - Calls run_nsga2 with the same arguments as Cell 7
      - run_nsga2 internally uses global hnsga_alpha for HNSGA allocation
      - Post-processes with fast_non_dominated_sort just like Cell 7
    """
    problem = get_problem_dynamic(
        problem_cfg["name"],
        n_var=problem_cfg["n_var"],
        n_obj=problem_cfg["n_obj"]
    )

    D_local = problem.n_var
    M_local = problem.n_obj
    mutation_probability_local = 1.0 / D_local

    print(f"\n=== Running NSGA-II (HNSGA) with seed {seed} ===")

    # Call run_nsga2 with the exact same signature as Cell 7
    # hnsga_alpha is read from global scope inside run_nsga2
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,
        population_size=pop_size,
        generations=problem_cfg["generations"],
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability_local,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=False,
        metrics_interval=metrics_interval_value,
        record_history=False
    )

    # Add seed info to metrics — same as Cell 7
    for metric in metrics_history:
        metric["seed"] = seed

    # Identify non-dominated solutions — same as Cell 7
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)
    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D_local:D_local + M_local]

    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")

    return {
        "seed": seed,
        "final_population": final_population,
        "true_pareto": true_pareto,
        "metrics_history": metrics_history,
        "pareto_points": pareto_points,
    }


# -------------------------------------------------
# 3) Run all problems, each with 30 seeds in parallel
# -------------------------------------------------
all_final_tables = []
failures = []

for idx, problem_cfg in enumerate(TABLE2_PROBLEMS, start=1):
    prob_name = problem_cfg["name"].upper()
    print(f"\n{'='*60}")
    print(f"[{idx}/{len(TABLE2_PROBLEMS)}] {prob_name} | "
          f"D={problem_cfg['n_var']}, M={problem_cfg['n_obj']}, G={problem_cfg['generations']}")
    print(f"{'='*60}")

    try:
        # Run 30 seeds in parallel — same as Cell 7 uses Parallel
        seed_results = Parallel(n_jobs=1)(
            delayed(run_seed_manual)(problem_cfg, seed) for seed in SEEDS
        )

        # Collect metrics and final rows — same post-processing as Cell 7
        all_metrics = []
        final_rows = []

        for result in seed_results:
            seed = result["seed"]
            all_metrics.extend(result["metrics_history"])

            # Build final row from last generation metrics
            final_row = {
                "problem": problem_cfg["name"],
                "seed": seed,
                "n_var": problem_cfg["n_var"],
                "n_obj": problem_cfg["n_obj"],
                "configured_generations": problem_cfg["generations"],
                "population_size": pop_size,
                "pareto_size": int(result["pareto_points"].shape[0]),
            }
            if result["metrics_history"]:
                final_row.update(result["metrics_history"][-1])
            final_rows.append(final_row)

        df_metrics = pd.DataFrame(all_metrics)
        df_final = pd.DataFrame(final_rows).sort_values("seed").reset_index(drop=True)

        if not df_metrics.empty:
            # Convert dict columns to strings for Excel compatibility
            for col in ["crossover_survival", "operator_allocation"]:
                if col in df_metrics.columns:
                    df_metrics[col] = df_metrics[col].astype(str)
            df_metrics = df_metrics.sort_values(["seed", "generation"]).reset_index(drop=True)

        # Summary stats
        numeric_cols = [
            c for c in [
                "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
                "spacing", "generation_time", "offspring_evals", "pareto_size"
            ]
            if c in df_final.columns
        ]

        summary_rows = []
        for col in numeric_cols:
            s = pd.to_numeric(df_final[col], errors="coerce").dropna()
            if not s.empty:
                summary_rows.append({
                    "metric": col,
                    "mean": s.mean(),
                    "std": s.std(),
                    "min": s.min(),
                    "max": s.max()
                })
        df_summary = pd.DataFrame(summary_rows)

        # Save per-problem Excel
        excel_path = OUTPUT_DIR / build_excel_name(problem_cfg["name"], problem_cfg["generations"])
        with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
            df_metrics.to_excel(writer, sheet_name="all_metrics", index=False)
            df_final.to_excel(writer, sheet_name="final_gen_by_seed", index=False)
            df_summary.to_excel(writer, sheet_name="summary", index=False)

        print(f"Saved: {excel_path}")
        all_final_tables.append(df_final)

    except Exception as e:
        print(f"FAILED: {problem_cfg['name']} -> {e}")
        failures.append({
            "problem": problem_cfg["name"],
            "n_var": problem_cfg["n_var"],
            "n_obj": problem_cfg["n_obj"],
            "generations": problem_cfg["generations"],
            "error": str(e)
        })

# -------------------------------------------------
# 4) Master summary across all problems
# -------------------------------------------------
df_all_final = pd.concat(all_final_tables, ignore_index=True) if all_final_tables else pd.DataFrame()
df_failures = pd.DataFrame(failures)
df_problem_table = pd.DataFrame(TABLE2_PROBLEMS)

if not df_all_final.empty:
    metric_cols = [
        c for c in [
            "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
            "spacing", "generation_time", "offspring_evals", "pareto_size"
        ]
        if c in df_all_final.columns
    ]
    if metric_cols:
        agg_dict = {col: ["mean", "std"] for col in metric_cols}
        df_problem_summary = (
            df_all_final
            .groupby(["problem", "n_var", "n_obj", "configured_generations"], dropna=False)
            .agg(agg_dict)
            .reset_index()
        )
        df_problem_summary.columns = flatten_columns(df_problem_summary.columns)
        df_problem_summary = df_problem_summary.sort_values("problem").reset_index(drop=True)
    else:
        df_problem_summary = pd.DataFrame()
else:
    df_problem_summary = pd.DataFrame()

summary_path = OUTPUT_DIR / "ALL_PROBLEMS_SUMMARY_HNSGA.xlsx"
with pd.ExcelWriter(summary_path, engine="openpyxl") as writer:
    df_problem_table.to_excel(writer, sheet_name="benchmark_table", index=False)
    df_all_final.to_excel(writer, sheet_name="final_gen_all_seeds", index=False)
    df_problem_summary.to_excel(writer, sheet_name="problem_summary", index=False)
    df_failures.to_excel(writer, sheet_name="failures", index=False)

print(f"\nMaster summary saved: {summary_path}")
if failures:
    print(f"\n{len(failures)} problem(s) failed:")
    for f in failures:
        print(f"  {f['problem']}: {f['error']}")

df_problem_summary
# Out:
# ============================================================
# [1/27] ZDT1 | D=30, M=2, G=200
# ============================================================
#
# === Running NSGA-II (HNSGA) with seed 1 ===
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 9}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 26, 'blend_crossover_batch': 26, 'uniform_crossover_batch': 19}
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.7631, gd_plus=2.7631, igd_plus=1.9687, spacing=0.1956, generation=1.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 6}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 33, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 13}
# Gen 2: hypervolume=0.0000, igd=1.9688, gd=2.3777, gd_plus=2.3777, igd_plus=1.9687, spacing=0.1520, generation=2.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 7}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 38, 'blend_crossover_batch': 22, 'uniform_crossover_batch': 14}
# Gen 3: hypervolume=0.0000, igd=1.9688, gd=2.4655, gd_plus=2.4655, igd_plus=1.9687, spacing=0.1298, generation=3.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 11}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 36, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 18}
# Gen 4: hypervolume=0.0000, igd=1.6552, gd=2.3538, gd_plus=2.3538, igd_plus=1.6552, spacing=0.2321, generation=4.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 20, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 10}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 41, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 20}
# Gen 5: hypervolume=0.0000, igd=1.6552, gd=1.9820, gd_plus=1.9820, igd_plus=1.6552, spacing=0.1511, generation=5.0000, generation_time=0.0059, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 12}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 42, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 25}
# Gen 6: hypervolume=0.0000, igd=1.6066, gd=1.9606, gd_plus=1.9606, igd_plus=1.6066, spacing=0.1032, generation=6.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 15}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 36, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 31}
# Gen 7: hypervolume=0.0000, igd=1.6066, gd=2.0135, gd_plus=2.0135, igd_plus=1.6065, spacing=0.1216, generation=7.0000, generation_time=0.0056, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 18, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 12}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 38, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 27}
# Gen 8: hypervolume=0.0000, igd=1.2202, gd=1.8536, gd_plus=1.8536, igd_plus=1.2202, spacing=0.1757, generation=8.0000, generation_time=0.0058, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 19, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 16}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 39, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 31}
# Gen 9: hypervolume=0.0000, igd=1.0082, gd=1.8007, gd_plus=1.8007, igd_plus=1.0072, spacing=0.2451, generation=9.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 17, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 22}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 32, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 37}
# Gen 10: hypervolume=0.0000, igd=1.0082, gd=1.6413, gd_plus=1.6413, igd_plus=1.0072, spacing=0.2484, generation=10.0000, generation_time=0.0058, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 19}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 30, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 39}
# Gen 11: hypervolume=0.0000, igd=1.0082, gd=1.5644, gd_plus=1.5644, igd_plus=1.0072, spacing=0.1297, generation=11.0000, generation_time=0.0056, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 24}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 29, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 44}
# Gen 12: hypervolume=0.0000, igd=1.0082, gd=1.4106, gd_plus=1.4106, igd_plus=1.0072, spacing=0.1396, generation=12.0000, generation_time=0.0055, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 21}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 25, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 42}
# Gen 13: hypervolume=0.0000, igd=0.9918, gd=1.5735, gd_plus=1.5735, igd_plus=0.9918, spacing=0.1140, generation=13.0000, generation_time=0.0056, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 12, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 17}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 25, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 36}
# Gen 14: hypervolume=0.0038, igd=0.9358, gd=1.3987, gd_plus=1.3987, igd_plus=0.9358, spacing=0.0878, generation=14.0000, generation_time=0.0056, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 18}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 23, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 39}
# Gen 15: hypervolume=0.0043, igd=0.9202, gd=1.4248, gd_plus=1.4248, igd_plus=0.9202, spacing=0.1166, generation=15.0000, generation_time=0.0050, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 23}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 22, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 44}
# Gen 16: hypervolume=0.0117, igd=0.8717, gd=1.3367, gd_plus=1.3367, igd_plus=0.8717, spacing=0.1058, generation=16.0000, generation_time=0.0045, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 19}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 32, 'single_point_crossover_batch': 14, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 44}
# Gen 17: hypervolume=0.0275, igd=0.8077, gd=1.2599, gd_plus=1.2599, igd_plus=0.8077, spacing=0.1040, generation=17.0000, generation_time=0.0136, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 22}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 45}
# Gen 18: hypervolume=0.0337, igd=0.8001, gd=1.0864, gd_plus=1.0864, igd_plus=0.8001, spacing=0.0905, generation=18.0000, generation_time=0.0083, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 22}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 47}
# Gen 19: hypervolume=0.0366, igd=0.7743, gd=1.1537, gd_plus=1.1537, igd_plus=0.7743, spacing=0.1092, generation=19.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 25}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 48}
# Gen 20: hypervolume=0.0712, igd=0.6966, gd=1.0202, gd_plus=1.0202, igd_plus=0.6951, spacing=0.0870, generation=20.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 25}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 47}
# Gen 21: hypervolume=0.0852, igd=0.6626, gd=0.8819, gd_plus=0.8819, igd_plus=0.6626, spacing=0.0767, generation=21.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 21, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 23}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 46}
# Gen 22: hypervolume=0.1032, igd=0.6406, gd=0.8323, gd_plus=0.8323, igd_plus=0.6406, spacing=0.0609, generation=22.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 24}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 46, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 47}
# Gen 23: hypervolume=0.1363, igd=0.5775, gd=0.8075, gd_plus=0.8075, igd_plus=0.5775, spacing=0.1104, generation=23.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 24}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 46, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 46}
# Gen 24: hypervolume=0.1400, igd=0.5757, gd=0.6690, gd_plus=0.6690, igd_plus=0.5757, spacing=0.1083, generation=24.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 19}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 49, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 37}
# Gen 25: hypervolume=0.1416, igd=0.5657, gd=0.7058, gd_plus=0.7058, igd_plus=0.5657, spacing=0.0914, generation=25.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 20}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 41}
# Gen 26: hypervolume=0.1417, igd=0.5655, gd=0.6339, gd_plus=0.6339, igd_plus=0.5655, spacing=0.0917, generation=26.0000, generation_time=0.0087, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 20}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 40}
# Gen 27: hypervolume=0.1706, igd=0.5139, gd=0.6025, gd_plus=0.6025, igd_plus=0.5139, spacing=0.0492, generation=27.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 22}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 46, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 41}
# Gen 28: hypervolume=0.2025, igd=0.5026, gd=0.5570, gd_plus=0.5570, igd_plus=0.5026, spacing=0.0695, generation=28.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 18}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 52, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 39}
# Gen 29: hypervolume=0.2288, igd=0.4712, gd=0.5239, gd_plus=0.5239, igd_plus=0.4701, spacing=0.0562, generation=29.0000, generation_time=0.0059, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 12}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 59, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 30}
# Gen 30: hypervolume=0.2593, igd=0.4437, gd=0.4992, gd_plus=0.4992, igd_plus=0.4427, spacing=0.0580, generation=30.0000, generation_time=0.0077, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 63, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 28}
# Gen 31: hypervolume=0.2835, igd=0.4211, gd=0.5075, gd_plus=0.5075, igd_plus=0.4211, spacing=0.0516, generation=31.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 65, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 28}
# Gen 32: hypervolume=0.3046, igd=0.4075, gd=0.4696, gd_plus=0.4696, igd_plus=0.4075, spacing=0.0378, generation=32.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 64, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 27}
# Gen 33: hypervolume=0.3150, igd=0.3996, gd=0.4501, gd_plus=0.4501, igd_plus=0.3996, spacing=0.0387, generation=33.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 11}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 65, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 25}
# Gen 34: hypervolume=0.3514, igd=0.3660, gd=0.4419, gd_plus=0.4419, igd_plus=0.3660, spacing=0.0428, generation=34.0000, generation_time=0.0097, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 9}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 69, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 21}
# Gen 35: hypervolume=0.3727, igd=0.3415, gd=0.4282, gd_plus=0.4282, igd_plus=0.3403, spacing=0.0473, generation=35.0000, generation_time=0.0085, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 38, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 11}
# Gen 36: hypervolume=0.3805, igd=0.3357, gd=0.4304, gd_plus=0.4304, igd_plus=0.3344, spacing=0.0438, generation=36.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 37: hypervolume=0.4122, igd=0.3012, gd=0.3933, gd_plus=0.3933, igd_plus=0.2996, spacing=0.0333, generation=37.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 47, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 85, 'single_point_crossover_batch': 10, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 3}
# Gen 38: hypervolume=0.4381, igd=0.2828, gd=0.3335, gd_plus=0.3335, igd_plus=0.2811, spacing=0.0324, generation=38.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 39: hypervolume=0.4569, igd=0.2674, gd=0.3263, gd_plus=0.3263, igd_plus=0.2663, spacing=0.0313, generation=39.0000, generation_time=0.0115, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 80, 'single_point_crossover_batch': 16, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 40: hypervolume=0.4678, igd=0.2615, gd=0.3013, gd_plus=0.3013, igd_plus=0.2604, spacing=0.0267, generation=40.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 41: hypervolume=0.4803, igd=0.2534, gd=0.2825, gd_plus=0.2825, igd_plus=0.2523, spacing=0.0264, generation=41.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 42: hypervolume=0.4917, igd=0.2450, gd=0.2763, gd_plus=0.2763, igd_plus=0.2439, spacing=0.0294, generation=42.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 2}
# Gen 43: hypervolume=0.5071, igd=0.2314, gd=0.2610, gd_plus=0.2610, igd_plus=0.2300, spacing=0.0276, generation=43.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 1}
# Gen 44: hypervolume=0.5232, igd=0.2214, gd=0.2409, gd_plus=0.2409, igd_plus=0.2200, spacing=0.0275, generation=44.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 2}
# Gen 45: hypervolume=0.5332, igd=0.2178, gd=0.2224, gd_plus=0.2224, igd_plus=0.2164, spacing=0.0312, generation=45.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 40, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 84, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 2}
# Gen 46: hypervolume=0.5447, igd=0.2134, gd=0.2289, gd_plus=0.2289, igd_plus=0.2121, spacing=0.0233, generation=46.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 13, 'uniform_crossover_batch': 2}
# Gen 47: hypervolume=0.5556, igd=0.2073, gd=0.2116, gd_plus=0.2115, igd_plus=0.2060, spacing=0.0219, generation=47.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 9, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 72, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 20, 'uniform_crossover_batch': 2}
# Gen 48: hypervolume=0.5759, igd=0.1927, gd=0.2029, gd_plus=0.2028, igd_plus=0.1913, spacing=0.0232, generation=48.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 68, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 24, 'uniform_crossover_batch': 2}
# Gen 49: hypervolume=0.5861, igd=0.1888, gd=0.1890, gd_plus=0.1889, igd_plus=0.1875, spacing=0.0192, generation=49.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 32, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 15, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 64, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 29, 'uniform_crossover_batch': 1}
# Gen 50: hypervolume=0.6031, igd=0.1728, gd=0.1819, gd_plus=0.1818, igd_plus=0.1728, spacing=0.0236, generation=50.0000, generation_time=0.0075, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 64, 'single_point_crossover_batch': 7, 'blend_crossover_batch': 27, 'uniform_crossover_batch': 2}
# Gen 51: hypervolume=0.6201, igd=0.1582, gd=0.1669, gd_plus=0.1667, igd_plus=0.1581, spacing=0.0175, generation=51.0000, generation_time=0.0082, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 29, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 68, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 21, 'uniform_crossover_batch': 2}
# Gen 52: hypervolume=0.6295, igd=0.1539, gd=0.1623, gd_plus=0.1622, igd_plus=0.1539, spacing=0.0199, generation=52.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 81, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 14, 'uniform_crossover_batch': 1}
# Gen 53: hypervolume=0.6396, igd=0.1476, gd=0.1509, gd_plus=0.1508, igd_plus=0.1473, spacing=0.0288, generation=53.0000, generation_time=0.0075, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 83, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 1}
# Gen 54: hypervolume=0.6487, igd=0.1416, gd=0.1477, gd_plus=0.1476, igd_plus=0.1416, spacing=0.0185, generation=54.0000, generation_time=0.0097, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 83, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 12, 'uniform_crossover_batch': 1}
# Gen 55: hypervolume=0.6589, igd=0.1347, gd=0.1431, gd_plus=0.1430, igd_plus=0.1347, spacing=0.0221, generation=55.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 2}
# Gen 56: hypervolume=0.6705, igd=0.1273, gd=0.1412, gd_plus=0.1412, igd_plus=0.1272, spacing=0.0218, generation=56.0000, generation_time=0.0071, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 35, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 10, 'uniform_crossover_batch': 1}
# Gen 57: hypervolume=0.6805, igd=0.1181, gd=0.1359, gd_plus=0.1359, igd_plus=0.1181, spacing=0.0229, generation=57.0000, generation_time=0.0076, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 58: hypervolume=0.6903, igd=0.1130, gd=0.1266, gd_plus=0.1266, igd_plus=0.1130, spacing=0.0179, generation=58.0000, generation_time=0.0083, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 38, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 2}
# Gen 59: hypervolume=0.7004, igd=0.1059, gd=0.1182, gd_plus=0.1182, igd_plus=0.1058, spacing=0.0161, generation=59.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 2}
# Gen 60: hypervolume=0.7087, igd=0.1011, gd=0.1159, gd_plus=0.1159, igd_plus=0.1009, spacing=0.0165, generation=60.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 38, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 96, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 61: hypervolume=0.7135, igd=0.0973, gd=0.1092, gd_plus=0.1091, igd_plus=0.0971, spacing=0.0165, generation=61.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 62: hypervolume=0.7195, igd=0.0935, gd=0.1030, gd_plus=0.1028, igd_plus=0.0933, spacing=0.0153, generation=62.0000, generation_time=0.0081, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 63: hypervolume=0.7277, igd=0.0894, gd=0.1015, gd_plus=0.1009, igd_plus=0.0889, spacing=0.0148, generation=63.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 97, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 64: hypervolume=0.7322, igd=0.0878, gd=0.0944, gd_plus=0.0938, igd_plus=0.0874, spacing=0.0120, generation=64.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 2}
# Gen 65: hypervolume=0.7366, igd=0.0845, gd=0.0899, gd_plus=0.0894, igd_plus=0.0841, spacing=0.0119, generation=65.0000, generation_time=0.0076, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 43, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 2}
# Gen 66: hypervolume=0.7407, igd=0.0826, gd=0.0836, gd_plus=0.0830, igd_plus=0.0822, spacing=0.0102, generation=66.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Gen 67: hypervolume=0.7480, igd=0.0771, gd=0.0782, gd_plus=0.0777, igd_plus=0.0767, spacing=0.0116, generation=67.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 42, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 96, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 68: hypervolume=0.7513, igd=0.0752, gd=0.0771, gd_plus=0.0766, igd_plus=0.0750, spacing=0.0108, generation=68.0000, generation_time=0.0752, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Gen 69: hypervolume=0.7568, igd=0.0728, gd=0.0734, gd_plus=0.0728, igd_plus=0.0725, spacing=0.0112, generation=69.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 44, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 70: hypervolume=0.7624, igd=0.0695, gd=0.0725, gd_plus=0.0719, igd_plus=0.0694, spacing=0.0105, generation=70.0000, generation_time=0.0073, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 71: hypervolume=0.7670, igd=0.0667, gd=0.0703, gd_plus=0.0696, igd_plus=0.0663, spacing=0.0098, generation=71.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 72: hypervolume=0.7699, igd=0.0647, gd=0.0670, gd_plus=0.0660, igd_plus=0.0644, spacing=0.0097, generation=72.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 1}
# Gen 73: hypervolume=0.7722, igd=0.0635, gd=0.0670, gd_plus=0.0660, igd_plus=0.0632, spacing=0.0087, generation=73.0000, generation_time=0.0068, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 74: hypervolume=0.7755, igd=0.0611, gd=0.0652, gd_plus=0.0642, igd_plus=0.0608, spacing=0.0077, generation=74.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 97, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 75: hypervolume=0.7787, igd=0.0585, gd=0.0632, gd_plus=0.0624, igd_plus=0.0581, spacing=0.0081, generation=75.0000, generation_time=0.0066, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 94, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 76: hypervolume=0.7812, igd=0.0571, gd=0.0597, gd_plus=0.0589, igd_plus=0.0568, spacing=0.0077, generation=76.0000, generation_time=0.0067, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 96, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 77: hypervolume=0.7859, igd=0.0542, gd=0.0541, gd_plus=0.0533, igd_plus=0.0539, spacing=0.0112, generation=77.0000, generation_time=0.0072, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 31, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 93, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 5}
# Gen 78: hypervolume=0.7876, igd=0.0534, gd=0.0535, gd_plus=0.0524, igd_plus=0.0530, spacing=0.0107, generation=78.0000, generation_time=0.0065, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 34, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 90, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 8}
# Gen 79: hypervolume=0.7898, igd=0.0521, gd=0.0525, gd_plus=0.0513, igd_plus=0.0518, spacing=0.0087, generation=79.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 39, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 80: hypervolume=0.7956, igd=0.0487, gd=0.0506, gd_plus=0.0499, igd_plus=0.0487, spacing=0.0095, generation=80.0000, generation_time=0.0062, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 41, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 81: hypervolume=0.7983, igd=0.0468, gd=0.0488, gd_plus=0.0480, igd_plus=0.0467, spacing=0.0106, generation=81.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 91, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 82: hypervolume=0.8018, igd=0.0446, gd=0.0449, gd_plus=0.0441, igd_plus=0.0445, spacing=0.0111, generation=82.0000, generation_time=0.0073, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 36, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 5}
# Gen 83: hypervolume=0.8050, igd=0.0428, gd=0.0434, gd_plus=0.0426, igd_plus=0.0427, spacing=0.0108, generation=83.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 37, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 84, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 8}
# Gen 84: hypervolume=0.8073, igd=0.0414, gd=0.0428, gd_plus=0.0421, igd_plus=0.0414, spacing=0.0088, generation=84.0000, generation_time=0.0069, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 85: hypervolume=0.8091, igd=0.0402, gd=0.0417, gd_plus=0.0406, igd_plus=0.0401, spacing=0.0088, generation=85.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 33, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 89, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 86: hypervolume=0.8117, igd=0.0390, gd=0.0407, gd_plus=0.0398, igd_plus=0.0390, spacing=0.0070, generation=86.0000, generation_time=0.0061, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 30, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 86, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 87: hypervolume=0.8138, igd=0.0376, gd=0.0386, gd_plus=0.0376, igd_plus=0.0376, spacing=0.0067, generation=87.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 83, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 5, 'uniform_crossover_batch': 6}
# Gen 88: hypervolume=0.8155, igd=0.0364, gd=0.0382, gd_plus=0.0372, igd_plus=0.0364, spacing=0.0069, generation=88.0000, generation_time=0.0063, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 79, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 9}
# Gen 89: hypervolume=0.8172, igd=0.0353, gd=0.0371, gd_plus=0.0361, igd_plus=0.0353, spacing=0.0064, generation=89.0000, generation_time=0.0070, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 27, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 8}
# Gen 90: hypervolume=0.8201, igd=0.0331, gd=0.0353, gd_plus=0.0343, igd_plus=0.0331, spacing=0.0066, generation=90.0000, generation_time=0.0064, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 26, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 4, 'uniform_crossover_batch': 4}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 4, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 11}
# Gen 91: hypervolume=0.8219, igd=0.0321, gd=0.0341, gd_plus=0.0327, igd_plus=0.0321, spacing=0.0061, generation=91.0000, generation_time=0.0059, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 25, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 3}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 70, 'single_point_crossover_batch': 3, 'blend_crossover_batch': 18, 'uniform_crossover_batch': 9}
# Gen 92: hypervolume=0.8240, igd=0.0307, gd=0.0324, gd_plus=0.0313, igd_plus=0.0306, spacing=0.0060, generation=92.0000, generation_time=0.0060, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 17, 'uniform_crossover_batch': 4}
# Gen 93: hypervolume=0.8255, igd=0.0298, gd=0.0311, gd_plus=0.0299, igd_plus=0.0297, spacing=0.0069, generation=93.0000, generation_time=0.0058, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 28, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 74, 'single_point_crossover_batch': 5, 'blend_crossover_batch': 16, 'uniform_crossover_batch': 5}
# ...
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 11, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 988: hypervolume=0.0013, igd=0.4627, gd=0.4997, gd_plus=0.4997, igd_plus=0.4627, spacing=0.0264, generation=988.0000, generation_time=0.0096, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 78, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 6, 'uniform_crossover_batch': 1}
# Gen 989: hypervolume=0.0013, igd=0.4627, gd=0.4997, gd_plus=0.4997, igd_plus=0.4627, spacing=0.0263, generation=989.0000, generation_time=0.0096, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 82, 'single_point_crossover_batch': 9, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 990: hypervolume=0.0013, igd=0.4629, gd=0.5012, gd_plus=0.5012, igd_plus=0.4629, spacing=0.0274, generation=990.0000, generation_time=0.0098, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 83, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 991: hypervolume=0.0012, igd=0.4630, gd=0.5016, gd_plus=0.5016, igd_plus=0.4630, spacing=0.0286, generation=991.0000, generation_time=0.0081, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 15, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 1}
# Gen 992: hypervolume=0.0012, igd=0.4630, gd=0.5026, gd_plus=0.5026, igd_plus=0.4630, spacing=0.0227, generation=992.0000, generation_time=0.0087, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 76, 'single_point_crossover_batch': 8, 'blend_crossover_batch': 11, 'uniform_crossover_batch': 5}
# Gen 993: hypervolume=0.0011, igd=0.4627, gd=0.4997, gd_plus=0.4997, igd_plus=0.4627, spacing=0.0224, generation=993.0000, generation_time=0.0075, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 80, 'single_point_crossover_batch': 2, 'blend_crossover_batch': 7, 'uniform_crossover_batch': 11}
# Gen 994: hypervolume=0.0011, igd=0.4628, gd=0.4993, gd_plus=0.4993, igd_plus=0.4628, spacing=0.0218, generation=994.0000, generation_time=0.0080, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 82, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 8, 'uniform_crossover_batch': 9}
# Gen 995: hypervolume=0.0011, igd=0.4628, gd=0.5005, gd_plus=0.5005, igd_plus=0.4628, spacing=0.0206, generation=995.0000, generation_time=0.0082, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 95, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 996: hypervolume=0.0011, igd=0.4626, gd=0.4995, gd_plus=0.4995, igd_plus=0.4626, spacing=0.0206, generation=996.0000, generation_time=0.0113, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 87, 'single_point_crossover_batch': 6, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 997: hypervolume=0.0011, igd=0.4625, gd=0.5019, gd_plus=0.5019, igd_plus=0.4625, spacing=0.0224, generation=997.0000, generation_time=0.0121, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 97, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 998: hypervolume=0.0011, igd=0.4625, gd=0.5039, gd_plus=0.5039, igd_plus=0.4625, spacing=0.0209, generation=998.0000, generation_time=0.0089, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 0}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 97, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 1}
# Gen 999: hypervolume=0.0011, igd=0.4625, gd=0.5020, gd_plus=0.5020, igd_plus=0.4625, spacing=0.0221, generation=999.0000, generation_time=0.0080, offspring_evals=100.0000
# Successful offspring by operator: {'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 0, 'blend_crossover_batch': 0, 'uniform_crossover_batch': 1}
# Next-generation operator allocation: {'simulated_binary_crossover_batch': 92, 'single_point_crossover_batch': 1, 'blend_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 1000: hypervolume=0.0012, igd=0.4627, gd=0.5034, gd_plus=0.5034, igd_plus=0.4627, spacing=0.0269, generation=1000.0000, generation_time=0.0085, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100
# Saved: HNSGA results time\dc3dtlz1 4 sbx-spx-blx-ux cross 1 poly 100pop 1000gen HNSGA.xlsx
#
# Master summary saved: HNSGA results time\ALL_PROBLEMS_SUMMARY_HNSGA.xlsx
#      problem  n_var  n_obj  configured_generations  hypervolume_mean  \
# 0    c1dtlz1     12      3                    1000          0.137106
# 1    c2dtlz2     12      3                     200          0.638320
# 2    c3dtlz4      7      3                     500          8.198524
# 3   dc1dtlz1     12      3                    1000          0.117180
# 4   dc1dtlz3     12      3                    1000          0.657560
# 5   dc3dtlz1     12      3                    1000          0.001160
# 6      dtlz1     12      3                    1000          0.136093
# 7      dtlz2     12      3                     200          0.694540
# 8      dtlz3     12      3                    1000          0.699461
# 9      dtlz4     12      3                     500          0.697645
# 10     dtlz5     12      3                     200          0.132236
# 11     dtlz6     12      3                    1000          0.132905
# 12     dtlz7     12      3                     200          1.579690
# 13      wfg1      6      3                     200         37.810159
# 14      wfg2      6      3                     200         59.038820
# 15      wfg3      6      3                     200          6.203413
# 16      wfg4      6      3                     200         32.941232
# 17      wfg5      6      3                     200         29.285032
# 18      wfg6      6      3                     200         33.943855
# 19      wfg7      6      3                     200         33.310964
# 20      wfg8      6      3                     200         31.469845
# 21      wfg9      6      3                     200         32.174963
# 22      zdt1     30      2                     200          0.867006
# 23      zdt2     30      2                     200          0.533359
# 24      zdt3     30      2                     200          1.022446
# 25      zdt4     10      2                     400          0.870961
# 26      zdt6     10      2                     400          0.430999
#
#     hypervolume_std  igd_mean  igd_std   gd_mean  gd_std  ...  igd_plus_mean  \
# 0               NaN  0.024549      NaN  0.015501     NaN  ...       0.017202
# 1               NaN  0.053587      NaN  0.057103     NaN  ...       0.024182
# 2               NaN  0.123378      NaN  0.089432     NaN  ...       0.080938
# 3               NaN  0.060986      NaN  0.014661     NaN  ...       0.042396
# 4               NaN  0.131631      NaN  0.041750     NaN  ...       0.056938
# 5               NaN  0.462675      NaN  0.503416     NaN  ...       0.462675
# 6               NaN  0.027107      NaN  0.018079     NaN  ...       0.021776
# 7               NaN  0.074073      NaN  0.052614     NaN  ...       0.041487
# 8               NaN  0.068490      NaN  1.848821     NaN  ...       0.039582
# 9               NaN  0.073449      NaN  0.052020     NaN  ...       0.039756
# 10              NaN  0.005461      NaN  0.004324     NaN  ...       0.003260
# 11              NaN  0.005522      NaN  0.003997     NaN  ...       0.002384
# 12              NaN  0.078048      NaN  0.021266     NaN  ...       0.043372
# 13              NaN  0.791367      NaN  0.801302     NaN  ...       0.785285
# 14              NaN  0.266845      NaN  0.248815     NaN  ...       0.069534
# 15              NaN  0.059223      NaN  0.549060     NaN  ...       0.038950
# 16              NaN  0.220943      NaN  0.191483     NaN  ...       0.114673
# 17              NaN  0.278858      NaN  0.212550     NaN  ...       0.183774
# 18              NaN  0.261258      NaN  0.193328     NaN  ...       0.116593
# 19              NaN  0.239512      NaN  0.227689     NaN  ...       0.127256
# 20              NaN  0.324974      NaN  0.212448     NaN  ...       0.176002
# 21              NaN  0.270029      NaN  0.185940     NaN  ...       0.166920
# 22              NaN  0.005760      NaN  0.006909     NaN  ...       0.005049
# 23              NaN  0.005636      NaN  0.005055     NaN  ...       0.004662
# 24              NaN  0.004909      NaN  0.005275     NaN  ...       0.001829
# 25              NaN  0.004322      NaN  0.004641     NaN  ...       0.002927
# 26              NaN  0.004198      NaN  0.003506     NaN  ...       0.003507
#
#     igd_plus_std  spacing_mean  spacing_std  generation_time_mean  \
# 0            NaN      0.020210          NaN              0.007319
# 1            NaN      0.040464          NaN              0.007813
# 2            NaN      0.091007          NaN              0.008957
# 3            NaN      0.006544          NaN              0.006254
# 4            NaN      0.025201          NaN              0.006818
# 5            NaN      0.026908          NaN              0.008544
# 6            NaN      0.021034          NaN              0.005542
# 7            NaN      0.061113          NaN              0.004887
# 8            NaN     13.402882          NaN              0.005918
# 9            NaN      0.055789          NaN              0.005337
# 10           NaN      0.008172          NaN              0.006263
# 11           NaN      0.010368          NaN              0.005260
# 12           NaN      0.077701          NaN              0.007523
# 13           NaN      0.165309          NaN              0.005598
# 14           NaN      0.220003          NaN              0.006307
# 15           NaN      0.117715          NaN              0.009608
# 16           NaN      0.243343          NaN              0.005561
# 17           NaN      0.196727          NaN              0.005859
# 18           NaN      0.176368          NaN              0.002678
# 19           NaN      0.253149          NaN              0.005972
# 20           NaN      0.224855          NaN              0.007184
# 21           NaN      0.228603          NaN              0.007947
# 22           NaN      0.006494          NaN              0.005700
# 23           NaN      0.006503          NaN              0.005127
# 24           NaN      0.008819          NaN              0.005423
# 25           NaN      0.007003          NaN              0.005486
# 26           NaN      0.005232          NaN              0.004886
#
#     generation_time_std  offspring_evals_mean  offspring_evals_std  \
# 0                   NaN                 100.0                  NaN
# 1                   NaN                 100.0                  NaN
# 2                   NaN                 100.0                  NaN
# 3                   NaN                 100.0                  NaN
# 4                   NaN                 100.0                  NaN
# 5                   NaN                 100.0                  NaN
# 6                   NaN                 100.0                  NaN
# 7                   NaN                 100.0                  NaN
# 8                   NaN                 100.0                  NaN
# 9                   NaN                 100.0                  NaN
# 10                  NaN                 100.0                  NaN
# 11                  NaN                 100.0                  NaN
# 12                  NaN                 100.0                  NaN
# 13                  NaN                 100.0                  NaN
# 14                  NaN                 100.0                  NaN
# 15                  NaN                 100.0                  NaN
# 16                  NaN                 100.0                  NaN
# 17                  NaN                 100.0                  NaN
# 18                  NaN                 100.0                  NaN
# 19                  NaN                 100.0                  NaN
# 20                  NaN                 100.0                  NaN
# 21                  NaN                 100.0                  NaN
# 22                  NaN                 100.0                  NaN
# 23                  NaN                 100.0                  NaN
# 24                  NaN                 100.0                  NaN
# 25                  NaN                 100.0                  NaN
# 26                  NaN                 100.0                  NaN
#
#     pareto_size_mean  pareto_size_std
# 0              100.0              NaN
# 1              100.0              NaN
# 2              100.0              NaN
# 3              100.0              NaN
# 4              100.0              NaN
# 5              100.0              NaN
# 6              100.0              NaN
# 7              100.0              NaN
# 8              100.0              NaN
# 9              100.0              NaN
# 10             100.0              NaN
# 11             100.0              NaN
# 12             100.0              NaN
# 13             100.0              NaN
# 14             100.0              NaN
# 15             100.0              NaN
# 16             100.0              NaN
# 17             100.0              NaN
# 18             100.0              NaN
# 19             100.0              NaN
# 20             100.0              NaN
# 21             100.0              NaN
# 22             100.0              NaN
# 23             100.0              NaN
# 24             100.0              NaN
# 25             100.0              NaN
# 26             100.0              NaN
#
# [27 rows x 22 columns]
