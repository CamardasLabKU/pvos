# %%
#### Cell 0: Imports and Setup

# 1. Problem Selection and Configuration
#According to Table 2 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
problem_name = "ZDT1"
n_var = 30  # Custom number of decision variables 
n_obj = 2  # Custom number of objectives

# 2. Population Settings
# -----------------------
pop_size = 100
generations = 200

# 3. Operator-specific parameters
#According to Table 1 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
crossover_probability = 0.9
mutation_sigma = 0.5           
distribution_index_n_c = 15    # For simulated binary crossover
distribution_index_n_m = 20    # For polynomial mutation
blend_alpha = 0.5              # for blend crossover
swap_prob = 0.5                # For uniform crossover 


# 4. Select Crossover and Mutation Operators
# List all desired crossover operators to be applied in parallel.
selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    "single_point_crossover_batch",
    "blend_crossover_batch",
    "uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# Cell 1:


import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  

# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"  # e.g. c1dtlz1
    return "unknown"

def get_problem_dynamic(name: str, n_var: int | None = None, n_obj: int | None = None):
    """
    Robustly instantiate a Pymoo problem without you having to remember the exact signature.
    Tries the 'right' order per family, then falls back gracefully.
    """
    fam = _family(name)

    # preferred try-orders per family
    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),  # many constrained DTLZ variants expose fixed dims
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for a in attempts:
        try:
            return a()
        except TypeError as e:    # signature mismatch
            last_err = e
        except Exception as e:    # other errors (invalid name, etc.)
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )







# Cell 2: Configuration Parameters

# =============================================================================
#                            PVOS-4C Configuration
# =============================================================================



problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 

# Borg-inspired adaptive controller settings
borg_zeta = 1.0
borg_credit_source = "rank1"   # closest NSGA-II proxy to Borg's elite archive





# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1 


#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


#  Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices, F_start):

    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, F_start: F_start + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))


def select_parents_batch(population, rank, cd, population_size):
    """
    Perform binary tournament selection in a vectorized manner to select parents.
    """
    total_individuals = population.shape[0]
    
    # First set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents1 = np.where(better, parent1_idx, parent2_idx)

    # Second set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents2 = np.where(better, parent1_idx, parent2_idx)

    return selected_parents1, selected_parents2

#cell 4




import numpy as np

def _sbx_core_batch(parents_dec_1, parents_dec_2, xl, xu,
                    eta_arr, prob_var_arr, prob_bin_arr,
                    eps=1e-14):
    """
    Core SBX operator matching pymoo.cross_sbx, but using
    parents_dec_1, parents_dec_2 instead of X.

    parents_dec_1, parents_dec_2 : (N, D)
    eta_arr, prob_var_arr, prob_bin_arr : (N, 1)

    Returns:
        Q : (2, N, D)  # two children per mating
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    xl = np.asarray(xl, dtype=float)
    xu = np.asarray(xu, dtype=float)

    N, D = parents_dec_1.shape
    X = np.stack([parents_dec_1, parents_dec_2], axis=0)  # (2, N, D)

    # probability of crossover for each variable
    prob_var_2d = np.repeat(prob_var_arr, D, axis=1)      # (N, D)
    cross = np.random.rand(N, D) < prob_var_2d

    # when solutions are too close -> do not apply sbx crossover
    too_close = np.abs(X[0] - X[1]) <= eps
    cross[too_close] = False

    # disable crossover when lower and upper bound are identical
    cross[:, xl == xu] = False

    # if no variable crosses at all, just clamp bounds and return
    if not np.any(cross):
        Q = X.copy()
        Q[0] = np.clip(Q[0], xl, xu)
        Q[1] = np.clip(Q[1], xl, xu)
        return Q

    # flatten the crossed positions
    p1 = X[0][cross]  # (n_cross,)
    p2 = X[1][cross]

    # orientation: y1 = smaller, y2 = larger
    sm = p1 < p2
    y1 = np.where(sm, p1, p2)
    y2 = np.where(sm, p2, p1)

    # bounds repeated and masked
    _xl = np.repeat(xl[None, :], N, axis=0)[cross]
    _xu = np.repeat(xu[None, :], N, axis=0)[cross]

    # eta, prob_bin expanded to (N, D) then masked
    eta_flat = np.repeat(eta_arr, D, axis=1)[cross]       # (n_cross,)
    prob_bin_flat = np.repeat(prob_bin_arr, D, axis=1)[cross]

    # shared random for both c1 and c2 (same as pymoo)
    rand = np.random.rand(len(eta_flat))

    def calc_betaq(beta):
        alpha = 2.0 - np.power(beta, -(eta_flat + 1.0))
        mask = rand <= (1.0 / alpha)
        mask_not = ~mask

        betaq = np.zeros_like(beta)
        if np.any(mask):
            betaq[mask] = np.power(rand[mask] * alpha[mask],
                                   1.0 / (eta_flat[mask] + 1.0))
        if np.any(mask_not):
            betaq[mask_not] = np.power(
                1.0 / (2.0 - rand[mask_not] * alpha[mask_not]),
                1.0 / (eta_flat[mask_not] + 1.0)
            )
        return betaq

    # difference between parents
    delta = (y2 - y1)

    # c1
    beta = 1.0 + (2.0 * (y1 - _xl) / delta)
    betaq = calc_betaq(beta)
    c1 = 0.5 * ((y1 + y2) - betaq * delta)

    # c2
    beta = 1.0 + (2.0 * (_xu - y2) / delta)
    betaq = calc_betaq(beta)
    c2 = 0.5 * ((y1 + y2) + betaq * delta)

    # children based on parent orientation
    child1 = np.where(sm, c1, c2)  # child aligned with parent 1
    child2 = np.where(sm, c2, c1)  # child aligned with parent 2

    # exchange children with probability prob_bin_flat and orientation
    b = np.bitwise_xor(
        np.random.rand(len(prob_bin_flat)) < prob_bin_flat,
        X[0][cross] > X[1][cross]
    )
    child1_final = np.where(b, child2, child1)
    child2_final = np.where(b, child1, child2)

    # assemble Q
    Q = X.copy()
    Q[0][cross] = child1_final
    Q[1][cross] = child2_final

    # clamp to bounds
    Q[0] = np.clip(Q[0], xl, xu)
    Q[1] = np.clip(Q[1], xl, xu)
    return Q


def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     prob, eta, min_values, max_values,
                                     n_offsprings=1,
                                     prob_exch=1.0,
                                     prob_bin=0.5,
                                     eps=1e-14):
    """
    Simulated Binary Crossover (SBX) matching pymoo.SBX(prob=..., eta=..., n_offsprings=...)

    Parameters
    ----------
    parents_dec_1 : (N, D)
    parents_dec_2 : (N, D)
    prob          : float
        Per-variable crossover probability (SBX 'prob' / 'prob_var').
    eta           : float
        Distribution index.
    min_values    : (D,)  lower bounds (xl)
    max_values    : (D,)  upper bounds (xu)
    n_offsprings  : 1 or 2
    prob_exch     : float, default 1.0
        Exchange probability (SBX prob_exch).
    prob_bin      : float, default 0.5
        Per-gene child swap probability (SBX prob_bin).
    eps           : float
        Threshold for "too close" parents.

    Returns
    -------
    offspring_dec :
        if n_offsprings == 1 : shape (N, D)
        if n_offsprings == 2 : shape (2*N, D)  [first N rows child1, next N rows child2]
    """
    parents_dec_1 = np.asarray(parents_dec_1, dtype=float)
    parents_dec_2 = np.asarray(parents_dec_2, dtype=float)
    min_values = np.asarray(min_values, dtype=float)
    max_values = np.asarray(max_values, dtype=float)

    N, D = parents_dec_1.shape

    # parameter arrays (N, 1) – same idea as pymoo's get(...)
    eta_arr = np.full((N, 1), eta, dtype=float)
    prob_var_arr = np.full((N, 1), prob, dtype=float)
    prob_exch_arr = np.full((N, 1), prob_exch, dtype=float)
    prob_bin_arr = np.full((N, 1), prob_bin, dtype=float)

    # apply prob_exch: zero out prob_bin if no exchange for that mating
    rand = np.random.rand(N, 1)
    prob_bin_arr[rand > prob_exch_arr] = 0.0

    # core SBX – returns two children per mating: Q shape (2, N, D)
    Q = _sbx_core_batch(parents_dec_1, parents_dec_2,
                        min_values, max_values,
                        eta_arr, prob_var_arr, prob_bin_arr,
                        eps=eps)

    if n_offsprings == 1:
        # randomly pick one of the two offspring per mating (same as SBX.n_offsprings=2)
        child = Q[0].copy()           # (N, D)
        pick_second = np.random.rand(N) < 0.5
        child[pick_second] = Q[1, pick_second]
        return child

    elif n_offsprings == 2:
        # stack to (2*N, D): [child1_0..child1_{N-1}, child2_0..child2_{N-1}]
        return Q.reshape(2 * N, D)

    else:
        raise ValueError("n_offsprings must be 1 or 2")





def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        
    """

    num_offspring, num_decision_variables = parents_dec_1.shape

    # Start with child1 as a copy of parent 1
    child1 = parents_dec_1.copy()

    # Decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # --- NEW: handle no-crossover pairs without bias ---
    no_cross_indices = np.where(~crossover_mask)[0]
    if no_cross_indices.size > 0:
        # For each no-crossover pair, flip a coin: 0 -> keep parent 1, 1 -> copy parent 2
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        # Overwrite those children with parent 2
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # --- Existing crossover logic for the pairs that do crossover ---
    crossover_indices = np.where(crossover_mask)[0]
    if crossover_indices.size > 0:
        # One crossover point per selected pair
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        for idx, cp in zip(crossover_indices, crossover_points):
            # NEW: randomly choose orientation to remove positional bias
            if np.random.rand() < 0.5:
                # suffix from parent2
                child1[idx, cp:] = parents_dec_2[idx, cp:]
            else:
                # prefix from parent2
                child1[idx, :cp] = parents_dec_2[idx, :cp]

    # Clip to bounds and return
    child1 = np.clip(child1, min_values, max_values)
    return child1




import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):

    N, D = parents_dec_1.shape

    child1 = parents_dec_1.copy()

    do_cross = np.random.rand(N) < crossover_probability

    # Handle pairs that do NOT crossover without bias
    no_cross_idx = np.where(~do_cross)[0]
    if no_cross_idx.size > 0:
        use_parent2 = np.random.rand(no_cross_idx.size) < 0.5
        idx_parent2 = no_cross_idx[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    cross_idx = np.where(do_cross)[0]
    if cross_idx.size > 0:
        p1 = parents_dec_1[cross_idx, :]
        p2 = parents_dec_2[cross_idx, :]

        y1 = np.minimum(p1, p2)
        y2 = np.maximum(p1, p2)
        d = y2 - y1

        # Full extended range — NO clamping to bounds here
        lower_bound = y1 - alpha_blend * d
        upper_bound = y2 + alpha_blend * d

        # Sample uniformly in the extended range
        rand1 = np.random.rand(p1.shape[0], D)
        c1 = lower_bound + rand1 * (upper_bound - lower_bound)

        child1[cross_idx, :] = c1

    # Clip AFTER sampling — this creates the boundary bias that helps ZDT convergence
    child1 = np.clip(child1, min_values, max_values)
    return child1


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # Handle pairs that do NOT crossover without bias:
    # for those indices, randomly choose between parent 1 and parent 2.
    no_cross_indices = np.where(~do_cross)[0]
    if no_cross_indices.size > 0:
        # Flip a coin for each no-crossover pair:
        # True -> use parent 2, False -> keep parent 1.
        use_parent2 = np.random.rand(no_cross_indices.size) < 0.5
        idx_parent2 = no_cross_indices[use_parent2]
        child1[idx_parent2, :] = parents_dec_2[idx_parent2, :]

    # If no pairs are selected for crossover, we are done.
    if not np.any(do_cross):
        child1 = np.clip(child1, min_values, max_values)
        return child1

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]

    # Assign the offspring genes back to the full child array.
    child1[do_cross, :] = offspring1

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)

    # Return the generated offspring decision variables.
    return child1





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec

class BorgMOEAAllocationController:
    """
    Borg-inspired adaptive multioperator recombination controller.

    Full Borg updates:
        Q_i = (C_i + zeta) / sum_j (C_j + zeta)

    In this drop-in NSGA-II version, C_i is measured from an NSGA-II elite set.
    Default credit_source='rank1' uses the current rank-1 survivors.
    """

    def __init__(self, operator_names, zeta=1.0, credit_source="rank1"):
        self.operator_names = list(operator_names)
        self.zeta = float(zeta)

        if credit_source not in {"rank1", "population", "surviving_offspring"}:
            raise ValueError(
                "credit_source must be 'rank1', 'population', or 'surviving_offspring'"
            )
        self.credit_source = credit_source
        self.reset()

    def reset(self):
        k = len(self.operator_names)
        self.probabilities = np.full(k, 1.0 / k, dtype=float)

    def probability_dict(self):
        return {
            name: float(p)
            for name, p in zip(self.operator_names, self.probabilities)
        }

    def allocate(self, total_offspring):
        """
        Generational analogue of Borg's per-offspring operator sampling.
        Returns a dict whose counts sum exactly to total_offspring.
        """
        counts = np.random.multinomial(total_offspring, self.probabilities)
        return {
            name: int(c)
            for name, c in zip(self.operator_names, counts)
        }

    def update(self, labels):
        """
        labels: array-like of source operator labels from the chosen credit set.
        """
        labels = np.asarray(labels, dtype=object)

        counts = np.array(
            [(labels == name).sum() for name in self.operator_names],
            dtype=float
        )

        self.probabilities = (counts + self.zeta) / np.sum(counts + self.zeta)

        count_dict = {
            name: int(c)
            for name, c in zip(self.operator_names, counts.astype(int))
        }

        return count_dict, self.probability_dict()

# Cell 5: Complete PVOS-4C Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual

class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval, record_history=False,
             allocation_controller=None):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    # objective slice in your population array [X | F] (or [X | F | CV])
    F_start = num_decision_variables
    F_end   = num_decision_variables + num_objectives

    def _eval_F_and_CV(X):
        """Evaluate F (and CV if you use it) with the same shape handling you already do."""
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(X, return_values_of=['F', 'G'])
            CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, CV
        else:
            eval_result = problem.evaluate(X)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            return F, None
    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]

    if allocation_controller is not None:
        allocation_controller.reset()

    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    population_operator_ids = np.array(["init"] * population_size, dtype=object)
    metrics_history = []
    front_history = []
    true_pf_history = []
    gen_history = []
    
    true_pf_static = problem.pareto_front() if hasattr(problem, "pareto_front") else None
    

    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator, each crossover produced one child.
        if co == simulated_binary_crossover_batch:
            sbx = SBX(prob=crossover_probability,
                      eta=distribution_index_n_c,
                      n_offsprings=1)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            matings = [[Individual(X=p1), Individual(X=p2)]
                       for p1, p2 in zip(parents_dec_1, parents_dec_2)]
        
            # single call → (N, D) offspring
            child_dec = sbx.do(_prob, matings).get("X")      
               


        elif co == single_point_crossover_batch:
            
            child_dec= single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
  

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child_dec = polynomial_mutation_batch(
                child_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )

        elif selected_mutation_operator == gaussian_mutation_batch:
            child_dec = gaussian_mutation_batch(
                child_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )

        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        offspring_dec = child_dec                         
        
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(offspring_dec, return_values_of=['F', 'G'])
            CV   = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F, CV])
        else:
            eval_result = problem.evaluate(offspring_dec)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F])
        
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx, F_start)


        # ----- operator allocation -----
        if allocation_controller is None:
            # Original PVOS-4C equal split
            pair_cnt = population_size // max(2, len(crossover_ops))
            allocation_counts = {op.__name__: pair_cnt for op in crossover_ops}
            operator_probabilities_used = {
                op.__name__: 1.0 / len(crossover_ops) for op in crossover_ops
            }

            p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
            parents1 = population[p1_idx, :num_decision_variables]
            parents2 = population[p2_idx, :num_decision_variables]

            results = Parallel(n_jobs=1)(
                delayed(apply_crossover_and_mutation)(
                    op, parents1, parents2,
                    selected_mutation_operator,
                    mutation_probability,
                    distribution_index_n_c,
                    distribution_index_n_m,
                    mutation_sigma,
                    blend_alpha,
                    swap_prob,
                    min_values,
                    max_values,
                    crossover_probability
                ) for op in crossover_ops
            )
        else:
            # Borg-inspired adaptive allocation
            allocation_counts = allocation_controller.allocate(population_size)
            operator_probabilities_used = allocation_controller.probability_dict()

            # Shared mating pool generalization of your current PVOS design:
            # if allocation is uniform, this reduces exactly to the current behavior.
            pair_cnt = max(1, max(allocation_counts.values()))
            p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
            shared_parents1 = population[p1_idx, :num_decision_variables]
            shared_parents2 = population[p2_idx, :num_decision_variables]

            jobs = []
            for op in crossover_ops:
                n_use = allocation_counts[op.__name__]
                if n_use == 0:
                    continue

                chosen = np.random.permutation(pair_cnt)[:n_use]

                jobs.append(
                    delayed(apply_crossover_and_mutation)(
                        op,
                        shared_parents1[chosen],
                        shared_parents2[chosen],
                        selected_mutation_operator,
                        mutation_probability,
                        distribution_index_n_c,
                        distribution_index_n_m,
                        mutation_sigma,
                        blend_alpha,
                        swap_prob,
                        min_values,
                        max_values,
                        crossover_probability
                    )
                )

            results = Parallel(n_jobs=1)(jobs)
        
        # Separate offspring and operator labels into lists
        offspring_list = []
        operator_ids_list = []
        for res in results:
            offspring_list.append(res["offspring"])
            # Create an array filled with the operator name for each offspring row
            operator_ids_list.append(np.full(res["offspring"].shape[0], res["operator"]))
        
        # Combine offspring from all operators
        all_offspring = np.vstack(offspring_list)
        #all_operator_ids = np.concatenate(operator_ids_list)


        
        # Population combination and survival selection
        combined_offspring = np.vstack(offspring_list)
        combined_operator_ids = np.concatenate(
            [population_operator_ids, np.concatenate(operator_ids_list)]
        )
        n_parent_rows = population.shape[0]
        
        # Now combine the populations
        combined_pop = np.vstack([population, combined_offspring])
        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))

        for r in range(1, rank_combined.max()+1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx, F_start)


        # Environmental selection
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted([(i, crowding_combined[i]) for i in front_idx], 
                                    key=lambda x: -x[1])
                survivors.extend([i for i, _ in sorted_front[:population_size-len(survivors)]])
            current_rank += 1

        population = combined_pop[survivors]
        population_operator_ids = combined_operator_ids[survivors]

        survivor_array = np.asarray(survivors)
        survived_new_mask = survivor_array >= n_parent_rows
        newly_survived_operator_ids = combined_operator_ids[survivor_array[survived_new_mask]]

        if newly_survived_operator_ids.size > 0:
            unique, counts = np.unique(newly_survived_operator_ids, return_counts=True)
            survival_stats = dict(zip(unique.tolist(), counts.tolist()))
        else:
            survival_stats = {}

        print("Survival counts by operator:", survival_stats)

        borg_credit_counts = None
        operator_probabilities_next = None

        if allocation_controller is not None:
            if allocation_controller.credit_source == "rank1":
                credit_labels = population_operator_ids[rank_combined[survivors] == 1]
            elif allocation_controller.credit_source == "population":
                credit_labels = population_operator_ids
            else:   # "surviving_offspring"
                credit_labels = newly_survived_operator_ids

            borg_credit_counts, operator_probabilities_next = allocation_controller.update(credit_labels)

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]
        if record_history:
            front_history.append(non_dominated_front.copy())
            true_pf_history.append(true_pf_static.copy() if true_pf_static is not None else None)
            gen_history.append(generation)

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time
            metrics_results["pair_cnt"] = pair_cnt
            metrics_results["operator_allocation"] = allocation_counts.copy()
            metrics_results["operator_probabilities_used"] = operator_probabilities_used.copy()

            if borg_credit_counts is not None:
                metrics_results["borg_credit_counts"] = borg_credit_counts.copy()
                metrics_results["operator_probabilities_next"] = operator_probabilities_next.copy()
            #metrics_results["pm_used"] = [mut_prob_eff] * len(crossover_ops)
            #metrics_results["eta_m_used"] = [eta_m_eff] * len(crossover_ops)

            # how many offspring were evaluated this generation
            metrics_results["offspring_evals"] = combined_offspring.shape[0]

            # evaluations used for change detection sampling each gen
            #metrics_results["sample_evals"] = n_samples

            # evaluations used when you re-evaluate the whole population after a change
           # metrics_results["parent_reeval_evals"] = population_size if change_detected else 0

            #metrics_results["total_evals_this_gen"] = (
            #    combined_offspring.shape[0] 
            #)
            # ----------------------------------------------------------------------            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    history = None
    if record_history:
        history = {
            "front": front_history,
            "true_pf": true_pf_history,
            "generation": gen_history
        }
    
    return population, problem.pareto_front(), metrics_history, history




#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts (using Pymoo data for the analytical solution)
    
    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib



# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    

    borg_controller = BorgMOEAAllocationController(
        operator_names=selected_crossover_operator_names,
        zeta=borg_zeta,
        credit_source=borg_credit_source
    )
    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,  
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value,
        allocation_controller=borg_controller
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points,
        'history': history

    }

# Run NSGA-II in parallel for seeds 1 to 30 (or 31 if you prefer 1 to 31) in series 
seeds = range(1, 2)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    


    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],

            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)

        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 12, 'uniform_crossover_batch': 18}
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.5401, gd_plus=2.5401, igd_plus=1.9687, spacing=0.1361, generation=1.0000, generation_time=0.0109, pair_cnt=30.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 10, 'uniform_crossover_batch': 17}
# Gen 2: hypervolume=0.0000, igd=1.5095, gd=2.4292, gd_plus=2.4292, igd_plus=1.5093, spacing=0.2247, generation=2.0000, generation_time=0.0080, pair_cnt=29.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 1, 'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 11, 'uniform_crossover_batch': 30}
# Gen 3: hypervolume=0.0000, igd=1.5095, gd=2.0805, gd_plus=2.0805, igd_plus=1.5093, spacing=0.1453, generation=3.0000, generation_time=0.0084, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 25}
# Gen 4: hypervolume=0.0000, igd=1.2663, gd=1.8236, gd_plus=1.8236, igd_plus=1.2663, spacing=0.0957, generation=4.0000, generation_time=0.0103, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 20, 'simulated_binary_crossover_batch': 16, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 19}
# Gen 5: hypervolume=0.0000, igd=1.2663, gd=1.6914, gd_plus=1.6914, igd_plus=1.2663, spacing=0.0641, generation=5.0000, generation_time=0.0066, pair_cnt=33.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 25, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 17}
# Gen 6: hypervolume=0.0000, igd=1.0929, gd=1.5375, gd_plus=1.5375, igd_plus=1.0929, spacing=0.1386, generation=6.0000, generation_time=0.0076, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 34, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 17}
# Gen 7: hypervolume=0.0000, igd=1.0898, gd=1.2670, gd_plus=1.2670, igd_plus=1.0898, spacing=0.0986, generation=7.0000, generation_time=0.0076, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 27, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 19}
# Gen 8: hypervolume=0.0000, igd=1.0136, gd=1.1398, gd_plus=1.1398, igd_plus=1.0136, spacing=0.0617, generation=8.0000, generation_time=0.0058, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 8, 'uniform_crossover_batch': 18}
# Gen 9: hypervolume=0.0000, igd=0.9647, gd=0.9688, gd_plus=0.9688, igd_plus=0.9645, spacing=0.0772, generation=9.0000, generation_time=0.0053, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 13}
# Gen 10: hypervolume=0.0431, igd=0.7533, gd=0.9482, gd_plus=0.9482, igd_plus=0.7533, spacing=0.0817, generation=10.0000, generation_time=0.0053, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 27}
# Gen 11: hypervolume=0.0468, igd=0.7267, gd=0.9170, gd_plus=0.9170, igd_plus=0.7267, spacing=0.0656, generation=11.0000, generation_time=0.0053, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 19, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 14}
# Gen 12: hypervolume=0.0595, igd=0.7067, gd=0.8448, gd_plus=0.8448, igd_plus=0.7067, spacing=0.0583, generation=12.0000, generation_time=0.0053, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 24, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 17}
# Gen 13: hypervolume=0.1104, igd=0.6365, gd=0.7449, gd_plus=0.7449, igd_plus=0.6365, spacing=0.0664, generation=13.0000, generation_time=0.0097, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 17, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 17}
# Gen 14: hypervolume=0.1495, igd=0.5561, gd=0.6829, gd_plus=0.6829, igd_plus=0.5561, spacing=0.0651, generation=14.0000, generation_time=0.0063, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 8}
# Gen 15: hypervolume=0.1808, igd=0.5239, gd=0.5911, gd_plus=0.5911, igd_plus=0.5239, spacing=0.0557, generation=15.0000, generation_time=0.0058, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 16, 'uniform_crossover_batch': 15}
# Gen 16: hypervolume=0.2020, igd=0.5042, gd=0.5880, gd_plus=0.5880, igd_plus=0.5042, spacing=0.0533, generation=16.0000, generation_time=0.0078, pair_cnt=30.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 13, 'uniform_crossover_batch': 11}
# Gen 17: hypervolume=0.2402, igd=0.4606, gd=0.4899, gd_plus=0.4899, igd_plus=0.4602, spacing=0.0685, generation=17.0000, generation_time=0.0054, pair_cnt=38.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 19, 'uniform_crossover_batch': 16}
# Gen 18: hypervolume=0.2882, igd=0.3997, gd=0.4633, gd_plus=0.4633, igd_plus=0.3992, spacing=0.0729, generation=18.0000, generation_time=0.0058, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 15, 'uniform_crossover_batch': 24}
# Gen 19: hypervolume=0.3291, igd=0.3811, gd=0.3950, gd_plus=0.3950, igd_plus=0.3806, spacing=0.0717, generation=19.0000, generation_time=0.0066, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 29}
# Gen 20: hypervolume=0.3748, igd=0.3426, gd=0.3852, gd_plus=0.3852, igd_plus=0.3426, spacing=0.0578, generation=20.0000, generation_time=0.0116, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 25, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 24}
# Gen 21: hypervolume=0.4166, igd=0.3048, gd=0.3613, gd_plus=0.3613, igd_plus=0.3048, spacing=0.0630, generation=21.0000, generation_time=0.0059, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 29, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 12}
# Gen 22: hypervolume=0.4606, igd=0.2622, gd=0.3087, gd_plus=0.3087, igd_plus=0.2622, spacing=0.0582, generation=22.0000, generation_time=0.0050, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 29, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 14, 'uniform_crossover_batch': 7}
# Gen 23: hypervolume=0.4784, igd=0.2510, gd=0.2768, gd_plus=0.2768, igd_plus=0.2509, spacing=0.0591, generation=23.0000, generation_time=0.0050, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 36, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 13, 'uniform_crossover_batch': 3}
# Gen 24: hypervolume=0.5147, igd=0.2275, gd=0.2302, gd_plus=0.2301, igd_plus=0.2275, spacing=0.0341, generation=24.0000, generation_time=0.0065, pair_cnt=62.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 32, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 5}
# Gen 25: hypervolume=0.5306, igd=0.2181, gd=0.2166, gd_plus=0.2166, igd_plus=0.2181, spacing=0.0351, generation=25.0000, generation_time=0.0048, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 33, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 6}
# Gen 26: hypervolume=0.5522, igd=0.2034, gd=0.2125, gd_plus=0.2125, igd_plus=0.2033, spacing=0.0333, generation=26.0000, generation_time=0.0055, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 31, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 7, 'uniform_crossover_batch': 8}
# Gen 27: hypervolume=0.5782, igd=0.1895, gd=0.1975, gd_plus=0.1974, igd_plus=0.1895, spacing=0.0261, generation=27.0000, generation_time=0.0050, pair_cnt=62.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 26, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 11}
# Gen 28: hypervolume=0.5980, igd=0.1770, gd=0.1821, gd_plus=0.1821, igd_plus=0.1769, spacing=0.0220, generation=28.0000, generation_time=0.0047, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 24, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 13}
# Gen 29: hypervolume=0.6212, igd=0.1611, gd=0.1710, gd_plus=0.1708, igd_plus=0.1607, spacing=0.0278, generation=29.0000, generation_time=0.0119, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 30, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 9}
# Gen 30: hypervolume=0.6487, igd=0.1379, gd=0.1586, gd_plus=0.1583, igd_plus=0.1378, spacing=0.0240, generation=30.0000, generation_time=0.0087, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 29, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 14}
# Gen 31: hypervolume=0.6710, igd=0.1245, gd=0.1349, gd_plus=0.1348, igd_plus=0.1245, spacing=0.0265, generation=31.0000, generation_time=0.0052, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 17}
# Gen 32: hypervolume=0.6879, igd=0.1113, gd=0.1203, gd_plus=0.1201, igd_plus=0.1113, spacing=0.0199, generation=32.0000, generation_time=0.0050, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 7, 'uniform_crossover_batch': 14}
# Gen 33: hypervolume=0.7007, igd=0.1058, gd=0.1107, gd_plus=0.1102, igd_plus=0.1058, spacing=0.0202, generation=33.0000, generation_time=0.0051, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 18}
# Gen 34: hypervolume=0.7126, igd=0.0998, gd=0.1058, gd_plus=0.1053, igd_plus=0.0998, spacing=0.0169, generation=34.0000, generation_time=0.0043, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 28, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 13}
# Gen 35: hypervolume=0.7243, igd=0.0917, gd=0.0959, gd_plus=0.0955, igd_plus=0.0917, spacing=0.0212, generation=35.0000, generation_time=0.0051, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 27, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 11}
# Gen 36: hypervolume=0.7325, igd=0.0852, gd=0.0918, gd_plus=0.0914, igd_plus=0.0852, spacing=0.0199, generation=36.0000, generation_time=0.0051, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 28, 'single_point_crossover_batch': 7, 'uniform_crossover_batch': 12}
# Gen 37: hypervolume=0.7445, igd=0.0776, gd=0.0845, gd_plus=0.0839, igd_plus=0.0776, spacing=0.0207, generation=37.0000, generation_time=0.0050, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 31, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 12}
# Gen 38: hypervolume=0.7514, igd=0.0747, gd=0.0773, gd_plus=0.0771, igd_plus=0.0747, spacing=0.0198, generation=38.0000, generation_time=0.0049, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 12}
# Gen 39: hypervolume=0.7550, igd=0.0728, gd=0.0752, gd_plus=0.0750, igd_plus=0.0728, spacing=0.0178, generation=39.0000, generation_time=0.0043, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 30, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 9}
# Gen 40: hypervolume=0.7617, igd=0.0689, gd=0.0703, gd_plus=0.0702, igd_plus=0.0689, spacing=0.0141, generation=40.0000, generation_time=0.0054, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 29, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 10}
# Gen 41: hypervolume=0.7678, igd=0.0650, gd=0.0664, gd_plus=0.0662, igd_plus=0.0650, spacing=0.0169, generation=41.0000, generation_time=0.0064, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 35, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 4}
# Gen 42: hypervolume=0.7734, igd=0.0619, gd=0.0647, gd_plus=0.0642, igd_plus=0.0619, spacing=0.0132, generation=42.0000, generation_time=0.0050, pair_cnt=77.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 30, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 6}
# Gen 43: hypervolume=0.7828, igd=0.0557, gd=0.0608, gd_plus=0.0604, igd_plus=0.0557, spacing=0.0120, generation=43.0000, generation_time=0.0049, pair_cnt=74.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 34, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 4}
# Gen 44: hypervolume=0.7899, igd=0.0506, gd=0.0544, gd_plus=0.0540, igd_plus=0.0506, spacing=0.0136, generation=44.0000, generation_time=0.0045, pair_cnt=78.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 31, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 45: hypervolume=0.7964, igd=0.0463, gd=0.0491, gd_plus=0.0487, igd_plus=0.0463, spacing=0.0120, generation=45.0000, generation_time=0.0043, pair_cnt=79.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 28, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 4}
# Gen 46: hypervolume=0.8023, igd=0.0420, gd=0.0442, gd_plus=0.0437, igd_plus=0.0419, spacing=0.0126, generation=46.0000, generation_time=0.0048, pair_cnt=78.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 33, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 8}
# Gen 47: hypervolume=0.8088, igd=0.0392, gd=0.0404, gd_plus=0.0400, igd_plus=0.0392, spacing=0.0107, generation=47.0000, generation_time=0.0047, pair_cnt=74.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 32, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Gen 48: hypervolume=0.8126, igd=0.0378, gd=0.0388, gd_plus=0.0378, igd_plus=0.0377, spacing=0.0078, generation=48.0000, generation_time=0.0048, pair_cnt=78.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 21, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Gen 49: hypervolume=0.8153, igd=0.0360, gd=0.0371, gd_plus=0.0364, igd_plus=0.0360, spacing=0.0069, generation=49.0000, generation_time=0.0047, pair_cnt=76.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 50: hypervolume=0.8181, igd=0.0346, gd=0.0363, gd_plus=0.0358, igd_plus=0.0346, spacing=0.0071, generation=50.0000, generation_time=0.0052, pair_cnt=73.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 11}
# Gen 51: hypervolume=0.8213, igd=0.0328, gd=0.0345, gd_plus=0.0338, igd_plus=0.0328, spacing=0.0071, generation=51.0000, generation_time=0.0044, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 52: hypervolume=0.8233, igd=0.0316, gd=0.0328, gd_plus=0.0320, igd_plus=0.0316, spacing=0.0072, generation=52.0000, generation_time=0.0068, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 53: hypervolume=0.8252, igd=0.0311, gd=0.0323, gd_plus=0.0316, igd_plus=0.0310, spacing=0.0069, generation=53.0000, generation_time=0.0045, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 8}
# Gen 54: hypervolume=0.8274, igd=0.0296, gd=0.0309, gd_plus=0.0302, igd_plus=0.0295, spacing=0.0071, generation=54.0000, generation_time=0.0068, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 7}
# Gen 55: hypervolume=0.8288, igd=0.0286, gd=0.0300, gd_plus=0.0292, igd_plus=0.0285, spacing=0.0067, generation=55.0000, generation_time=0.0046, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 7, 'uniform_crossover_batch': 7}
# Gen 56: hypervolume=0.8305, igd=0.0274, gd=0.0286, gd_plus=0.0279, igd_plus=0.0273, spacing=0.0067, generation=56.0000, generation_time=0.0059, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 3}
# Gen 57: hypervolume=0.8326, igd=0.0260, gd=0.0271, gd_plus=0.0264, igd_plus=0.0259, spacing=0.0066, generation=57.0000, generation_time=0.0044, pair_cnt=58.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 7}
# Gen 58: hypervolume=0.8346, igd=0.0248, gd=0.0259, gd_plus=0.0249, igd_plus=0.0247, spacing=0.0060, generation=58.0000, generation_time=0.0049, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 21, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 5}
# Gen 59: hypervolume=0.8364, igd=0.0238, gd=0.0249, gd_plus=0.0238, igd_plus=0.0238, spacing=0.0061, generation=59.0000, generation_time=0.0050, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 10}
# Gen 60: hypervolume=0.8388, igd=0.0220, gd=0.0232, gd_plus=0.0222, igd_plus=0.0220, spacing=0.0061, generation=60.0000, generation_time=0.0043, pair_cnt=66.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 7}
# Gen 61: hypervolume=0.8406, igd=0.0209, gd=0.0222, gd_plus=0.0209, igd_plus=0.0208, spacing=0.0064, generation=61.0000, generation_time=0.0047, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 21, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 62: hypervolume=0.8417, igd=0.0201, gd=0.0213, gd_plus=0.0203, igd_plus=0.0201, spacing=0.0066, generation=62.0000, generation_time=0.0065, pair_cnt=77.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 11}
# Gen 63: hypervolume=0.8430, igd=0.0194, gd=0.0207, gd_plus=0.0196, igd_plus=0.0193, spacing=0.0067, generation=63.0000, generation_time=0.0135, pair_cnt=66.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'uniform_crossover_batch': 11}
# Gen 64: hypervolume=0.8437, igd=0.0191, gd=0.0205, gd_plus=0.0193, igd_plus=0.0189, spacing=0.0057, generation=64.0000, generation_time=0.0135, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 65: hypervolume=0.8443, igd=0.0186, gd=0.0198, gd_plus=0.0186, igd_plus=0.0185, spacing=0.0058, generation=65.0000, generation_time=0.0066, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 66: hypervolume=0.8453, igd=0.0179, gd=0.0193, gd_plus=0.0181, igd_plus=0.0178, spacing=0.0051, generation=66.0000, generation_time=0.0115, pair_cnt=57.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 7}
# Gen 67: hypervolume=0.8464, igd=0.0173, gd=0.0186, gd_plus=0.0175, igd_plus=0.0172, spacing=0.0047, generation=67.0000, generation_time=0.0053, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 11}
# Gen 68: hypervolume=0.8478, igd=0.0166, gd=0.0179, gd_plus=0.0167, igd_plus=0.0165, spacing=0.0064, generation=68.0000, generation_time=0.0046, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 20, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 12}
# Gen 69: hypervolume=0.8495, igd=0.0156, gd=0.0167, gd_plus=0.0154, igd_plus=0.0155, spacing=0.0065, generation=69.0000, generation_time=0.0046, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 10}
# Gen 70: hypervolume=0.8502, igd=0.0152, gd=0.0159, gd_plus=0.0150, igd_plus=0.0151, spacing=0.0061, generation=70.0000, generation_time=0.0077, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 71: hypervolume=0.8509, igd=0.0150, gd=0.0157, gd_plus=0.0147, igd_plus=0.0148, spacing=0.0061, generation=71.0000, generation_time=0.0061, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 72: hypervolume=0.8525, igd=0.0139, gd=0.0150, gd_plus=0.0139, igd_plus=0.0138, spacing=0.0055, generation=72.0000, generation_time=0.0055, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 73: hypervolume=0.8532, igd=0.0135, gd=0.0145, gd_plus=0.0134, igd_plus=0.0133, spacing=0.0056, generation=73.0000, generation_time=0.0047, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 12}
# Gen 74: hypervolume=0.8544, igd=0.0127, gd=0.0138, gd_plus=0.0125, igd_plus=0.0125, spacing=0.0054, generation=74.0000, generation_time=0.0045, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 75: hypervolume=0.8551, igd=0.0122, gd=0.0133, gd_plus=0.0119, igd_plus=0.0120, spacing=0.0056, generation=75.0000, generation_time=0.0043, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 8}
# Gen 76: hypervolume=0.8555, igd=0.0120, gd=0.0131, gd_plus=0.0116, igd_plus=0.0118, spacing=0.0054, generation=76.0000, generation_time=0.0051, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 12}
# Gen 77: hypervolume=0.8560, igd=0.0117, gd=0.0126, gd_plus=0.0112, igd_plus=0.0116, spacing=0.0059, generation=77.0000, generation_time=0.0055, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 78: hypervolume=0.8568, igd=0.0113, gd=0.0122, gd_plus=0.0108, igd_plus=0.0111, spacing=0.0060, generation=78.0000, generation_time=0.0105, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 79: hypervolume=0.8575, igd=0.0108, gd=0.0114, gd_plus=0.0105, igd_plus=0.0106, spacing=0.0060, generation=79.0000, generation_time=0.0118, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 15}
# Gen 80: hypervolume=0.8577, igd=0.0106, gd=0.0112, gd_plus=0.0101, igd_plus=0.0104, spacing=0.0069, generation=80.0000, generation_time=0.0052, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 16}
# Gen 81: hypervolume=0.8581, igd=0.0103, gd=0.0109, gd_plus=0.0098, igd_plus=0.0101, spacing=0.0068, generation=81.0000, generation_time=0.0075, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 16}
# Gen 82: hypervolume=0.8586, igd=0.0101, gd=0.0107, gd_plus=0.0095, igd_plus=0.0098, spacing=0.0067, generation=82.0000, generation_time=0.0050, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 83: hypervolume=0.8589, igd=0.0099, gd=0.0109, gd_plus=0.0094, igd_plus=0.0098, spacing=0.0063, generation=83.0000, generation_time=0.0062, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 18}
# Gen 84: hypervolume=0.8596, igd=0.0095, gd=0.0106, gd_plus=0.0091, igd_plus=0.0093, spacing=0.0063, generation=84.0000, generation_time=0.0056, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 12}
# Gen 85: hypervolume=0.8599, igd=0.0093, gd=0.0104, gd_plus=0.0090, igd_plus=0.0091, spacing=0.0063, generation=85.0000, generation_time=0.0049, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 15}
# Gen 86: hypervolume=0.8602, igd=0.0092, gd=0.0103, gd_plus=0.0088, igd_plus=0.0090, spacing=0.0063, generation=86.0000, generation_time=0.0044, pair_cnt=57.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 2, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 19}
# Gen 87: hypervolume=0.8605, igd=0.0089, gd=0.0100, gd_plus=0.0085, igd_plus=0.0087, spacing=0.0064, generation=87.0000, generation_time=0.0044, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 22}
# Gen 88: hypervolume=0.8609, igd=0.0088, gd=0.0096, gd_plus=0.0082, igd_plus=0.0085, spacing=0.0061, generation=88.0000, generation_time=0.0044, pair_cnt=71.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 18}
# Gen 89: hypervolume=0.8614, igd=0.0086, gd=0.0093, gd_plus=0.0079, igd_plus=0.0083, spacing=0.0069, generation=89.0000, generation_time=0.0051, pair_cnt=68.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 22}
# Gen 90: hypervolume=0.8619, igd=0.0083, gd=0.0091, gd_plus=0.0076, igd_plus=0.0079, spacing=0.0067, generation=90.0000, generation_time=0.0045, pair_cnt=69.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Gen 91: hypervolume=0.8624, igd=0.0080, gd=0.0089, gd_plus=0.0072, igd_plus=0.0077, spacing=0.0067, generation=91.0000, generation_time=0.0047, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 20}
# Gen 92: hypervolume=0.8629, igd=0.0076, gd=0.0082, gd_plus=0.0069, igd_plus=0.0073, spacing=0.0067, generation=92.0000, generation_time=0.0046, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 18}
# Gen 93: hypervolume=0.8631, igd=0.0075, gd=0.0081, gd_plus=0.0068, igd_plus=0.0072, spacing=0.0064, generation=93.0000, generation_time=0.0048, pair_cnt=66.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 12}
# Gen 94: hypervolume=0.8634, igd=0.0075, gd=0.0080, gd_plus=0.0066, igd_plus=0.0071, spacing=0.0061, generation=94.0000, generation_time=0.0052, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 19}
# Gen 95: hypervolume=0.8638, igd=0.0073, gd=0.0078, gd_plus=0.0064, igd_plus=0.0069, spacing=0.0066, generation=95.0000, generation_time=0.0047, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 21}
# Gen 96: hypervolume=0.8641, igd=0.0070, gd=0.0077, gd_plus=0.0062, igd_plus=0.0066, spacing=0.0073, generation=96.0000, generation_time=0.0044, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 20}
# Gen 97: hypervolume=0.8642, igd=0.0070, gd=0.0077, gd_plus=0.0062, igd_plus=0.0067, spacing=0.0074, generation=97.0000, generation_time=0.0046, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 98: hypervolume=0.8646, igd=0.0068, gd=0.0073, gd_plus=0.0058, igd_plus=0.0064, spacing=0.0077, generation=98.0000, generation_time=0.0046, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 99: hypervolume=0.8649, igd=0.0066, gd=0.0072, gd_plus=0.0057, igd_plus=0.0062, spacing=0.0070, generation=99.0000, generation_time=0.0046, pair_cnt=62.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Gen 100: hypervolume=0.8653, igd=0.0064, gd=0.0069, gd_plus=0.0056, igd_plus=0.0060, spacing=0.0064, generation=100.0000, generation_time=0.0047, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 16}
# Gen 101: hypervolume=0.8654, igd=0.0063, gd=0.0068, gd_plus=0.0055, igd_plus=0.0059, spacing=0.0078, generation=101.0000, generation_time=0.0043, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 14}
# Gen 102: hypervolume=0.8657, igd=0.0061, gd=0.0070, gd_plus=0.0053, igd_plus=0.0057, spacing=0.0072, generation=102.0000, generation_time=0.0059, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 103: hypervolume=0.8656, igd=0.0061, gd=0.0069, gd_plus=0.0051, igd_plus=0.0057, spacing=0.0076, generation=103.0000, generation_time=0.0051, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 14}
# Gen 104: hypervolume=0.8656, igd=0.0062, gd=0.0066, gd_plus=0.0051, igd_plus=0.0057, spacing=0.0072, generation=104.0000, generation_time=0.0058, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 14}
# Gen 105: hypervolume=0.8660, igd=0.0060, gd=0.0065, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0062, generation=105.0000, generation_time=0.0070, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 15}
# Gen 106: hypervolume=0.8662, igd=0.0059, gd=0.0066, gd_plus=0.0051, igd_plus=0.0054, spacing=0.0063, generation=106.0000, generation_time=0.0058, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 20}
# Gen 107: hypervolume=0.8662, igd=0.0062, gd=0.0065, gd_plus=0.0049, igd_plus=0.0055, spacing=0.0070, generation=107.0000, generation_time=0.0056, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 108: hypervolume=0.8663, igd=0.0063, gd=0.0066, gd_plus=0.0049, igd_plus=0.0056, spacing=0.0062, generation=108.0000, generation_time=0.0049, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 12}
# Gen 109: hypervolume=0.8665, igd=0.0064, gd=0.0067, gd_plus=0.0049, igd_plus=0.0055, spacing=0.0068, generation=109.0000, generation_time=0.0048, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 13}
# Gen 110: hypervolume=0.8665, igd=0.0064, gd=0.0068, gd_plus=0.0050, igd_plus=0.0055, spacing=0.0066, generation=110.0000, generation_time=0.0083, pair_cnt=57.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 19}
# Gen 111: hypervolume=0.8669, igd=0.0060, gd=0.0068, gd_plus=0.0048, igd_plus=0.0052, spacing=0.0060, generation=111.0000, generation_time=0.0083, pair_cnt=60.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 112: hypervolume=0.8669, igd=0.0062, gd=0.0067, gd_plus=0.0048, igd_plus=0.0053, spacing=0.0065, generation=112.0000, generation_time=0.0060, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 21}
# Gen 113: hypervolume=0.8673, igd=0.0059, gd=0.0065, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0062, generation=113.0000, generation_time=0.0049, pair_cnt=57.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 18}
# Gen 114: hypervolume=0.8675, igd=0.0059, gd=0.0068, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0064, generation=114.0000, generation_time=0.0072, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 13}
# Gen 115: hypervolume=0.8675, igd=0.0058, gd=0.0068, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0065, generation=115.0000, generation_time=0.0050, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 9}
# Gen 116: hypervolume=0.8677, igd=0.0057, gd=0.0066, gd_plus=0.0045, igd_plus=0.0048, spacing=0.0059, generation=116.0000, generation_time=0.0049, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 15}
# Gen 117: hypervolume=0.8679, igd=0.0054, gd=0.0064, gd_plus=0.0042, igd_plus=0.0046, spacing=0.0063, generation=117.0000, generation_time=0.0048, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 17}
# Gen 118: hypervolume=0.8678, igd=0.0055, gd=0.0065, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0072, generation=118.0000, generation_time=0.0048, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'uniform_crossover_batch': 12}
# Gen 119: hypervolume=0.8680, igd=0.0053, gd=0.0065, gd_plus=0.0042, igd_plus=0.0046, spacing=0.0070, generation=119.0000, generation_time=0.0045, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'uniform_crossover_batch': 15}
# Gen 120: hypervolume=0.8679, igd=0.0054, gd=0.0065, gd_plus=0.0040, igd_plus=0.0046, spacing=0.0068, generation=120.0000, generation_time=0.0050, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 15}
# Gen 121: hypervolume=0.8682, igd=0.0053, gd=0.0056, gd_plus=0.0038, igd_plus=0.0045, spacing=0.0076, generation=121.0000, generation_time=0.0050, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 14}
# Gen 122: hypervolume=0.8683, igd=0.0052, gd=0.0055, gd_plus=0.0038, igd_plus=0.0044, spacing=0.0075, generation=122.0000, generation_time=0.0048, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'uniform_crossover_batch': 15}
# Gen 123: hypervolume=0.8685, igd=0.0053, gd=0.0057, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0063, generation=123.0000, generation_time=0.0043, pair_cnt=58.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 8}
# Gen 124: hypervolume=0.8684, igd=0.0054, gd=0.0057, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0061, generation=124.0000, generation_time=0.0043, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Gen 125: hypervolume=0.8686, igd=0.0052, gd=0.0055, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0066, generation=125.0000, generation_time=0.0061, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Gen 126: hypervolume=0.8685, igd=0.0052, gd=0.0057, gd_plus=0.0036, igd_plus=0.0042, spacing=0.0058, generation=126.0000, generation_time=0.0070, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 14}
# Gen 127: hypervolume=0.8686, igd=0.0051, gd=0.0059, gd_plus=0.0036, igd_plus=0.0042, spacing=0.0071, generation=127.0000, generation_time=0.0048, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 128: hypervolume=0.8684, igd=0.0055, gd=0.0060, gd_plus=0.0037, igd_plus=0.0045, spacing=0.0066, generation=128.0000, generation_time=0.0043, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'uniform_crossover_batch': 19}
# Gen 129: hypervolume=0.8684, igd=0.0055, gd=0.0062, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0058, generation=129.0000, generation_time=0.0042, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 1, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 16}
# Gen 130: hypervolume=0.8686, igd=0.0054, gd=0.0061, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0061, generation=130.0000, generation_time=0.0071, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 16}
# Gen 131: hypervolume=0.8692, igd=0.0049, gd=0.0057, gd_plus=0.0037, igd_plus=0.0039, spacing=0.0052, generation=131.0000, generation_time=0.0046, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 18}
# Gen 132: hypervolume=0.8693, igd=0.0047, gd=0.0054, gd_plus=0.0034, igd_plus=0.0038, spacing=0.0060, generation=132.0000, generation_time=0.0082, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'uniform_crossover_batch': 20}
# Gen 133: hypervolume=0.8693, igd=0.0047, gd=0.0055, gd_plus=0.0034, igd_plus=0.0037, spacing=0.0066, generation=133.0000, generation_time=0.0040, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'uniform_crossover_batch': 20}
# Gen 134: hypervolume=0.8695, igd=0.0045, gd=0.0055, gd_plus=0.0034, igd_plus=0.0036, spacing=0.0063, generation=134.0000, generation_time=0.0043, pair_cnt=72.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'uniform_crossover_batch': 21}
# Gen 135: hypervolume=0.8694, igd=0.0046, gd=0.0056, gd_plus=0.0034, igd_plus=0.0036, spacing=0.0062, generation=135.0000, generation_time=0.0041, pair_cnt=74.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'uniform_crossover_batch': 18}
# Gen 136: hypervolume=0.8695, igd=0.0046, gd=0.0056, gd_plus=0.0033, igd_plus=0.0036, spacing=0.0065, generation=136.0000, generation_time=0.0042, pair_cnt=71.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 137: hypervolume=0.8695, igd=0.0047, gd=0.0056, gd_plus=0.0033, igd_plus=0.0037, spacing=0.0064, generation=137.0000, generation_time=0.0047, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 19}
# Gen 138: hypervolume=0.8698, igd=0.0047, gd=0.0054, gd_plus=0.0032, igd_plus=0.0036, spacing=0.0067, generation=138.0000, generation_time=0.0040, pair_cnt=72.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 15}
# Gen 139: hypervolume=0.8697, igd=0.0048, gd=0.0056, gd_plus=0.0034, igd_plus=0.0037, spacing=0.0065, generation=139.0000, generation_time=0.0043, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 19}
# Gen 140: hypervolume=0.8697, igd=0.0048, gd=0.0056, gd_plus=0.0034, igd_plus=0.0036, spacing=0.0064, generation=140.0000, generation_time=0.0063, pair_cnt=70.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 15}
# Gen 141: hypervolume=0.8696, igd=0.0049, gd=0.0058, gd_plus=0.0035, igd_plus=0.0038, spacing=0.0070, generation=141.0000, generation_time=0.0041, pair_cnt=69.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 18}
# Gen 142: hypervolume=0.8696, igd=0.0051, gd=0.0061, gd_plus=0.0036, igd_plus=0.0038, spacing=0.0067, generation=142.0000, generation_time=0.0063, pair_cnt=58.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 14}
# ...
# Gen 152: hypervolume=0.8698, igd=0.0047, gd=0.0052, gd_plus=0.0031, igd_plus=0.0036, spacing=0.0068, generation=152.0000, generation_time=0.0053, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 7}
# Gen 153: hypervolume=0.8699, igd=0.0046, gd=0.0052, gd_plus=0.0032, igd_plus=0.0035, spacing=0.0060, generation=153.0000, generation_time=0.0044, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 154: hypervolume=0.8699, igd=0.0048, gd=0.0053, gd_plus=0.0032, igd_plus=0.0037, spacing=0.0071, generation=154.0000, generation_time=0.0048, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 11}
# Gen 155: hypervolume=0.8695, igd=0.0049, gd=0.0051, gd_plus=0.0030, igd_plus=0.0037, spacing=0.0065, generation=155.0000, generation_time=0.0062, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 4}
# Gen 156: hypervolume=0.8697, igd=0.0048, gd=0.0049, gd_plus=0.0029, igd_plus=0.0035, spacing=0.0066, generation=156.0000, generation_time=0.0046, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 157: hypervolume=0.8699, igd=0.0046, gd=0.0049, gd_plus=0.0029, igd_plus=0.0034, spacing=0.0069, generation=157.0000, generation_time=0.0059, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 14}
# Gen 158: hypervolume=0.8701, igd=0.0045, gd=0.0053, gd_plus=0.0029, igd_plus=0.0034, spacing=0.0069, generation=158.0000, generation_time=0.0052, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 9}
# Gen 159: hypervolume=0.8702, igd=0.0044, gd=0.0054, gd_plus=0.0031, igd_plus=0.0033, spacing=0.0060, generation=159.0000, generation_time=0.0104, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 8}
# Gen 160: hypervolume=0.8700, igd=0.0045, gd=0.0053, gd_plus=0.0030, igd_plus=0.0033, spacing=0.0070, generation=160.0000, generation_time=0.0044, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 13}
# Gen 161: hypervolume=0.8702, igd=0.0042, gd=0.0050, gd_plus=0.0028, igd_plus=0.0031, spacing=0.0068, generation=161.0000, generation_time=0.0048, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Gen 162: hypervolume=0.8698, igd=0.0047, gd=0.0054, gd_plus=0.0030, igd_plus=0.0035, spacing=0.0059, generation=162.0000, generation_time=0.0044, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 163: hypervolume=0.8696, igd=0.0048, gd=0.0055, gd_plus=0.0031, igd_plus=0.0036, spacing=0.0055, generation=163.0000, generation_time=0.0050, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 16}
# Gen 164: hypervolume=0.8700, igd=0.0045, gd=0.0054, gd_plus=0.0030, igd_plus=0.0034, spacing=0.0057, generation=164.0000, generation_time=0.0056, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 165: hypervolume=0.8701, igd=0.0044, gd=0.0053, gd_plus=0.0030, igd_plus=0.0034, spacing=0.0062, generation=165.0000, generation_time=0.0079, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Gen 166: hypervolume=0.8702, igd=0.0043, gd=0.0051, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0060, generation=166.0000, generation_time=0.0082, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 8}
# Gen 167: hypervolume=0.8701, igd=0.0045, gd=0.0050, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0072, generation=167.0000, generation_time=0.0068, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 10}
# Gen 168: hypervolume=0.8699, igd=0.0047, gd=0.0052, gd_plus=0.0030, igd_plus=0.0034, spacing=0.0068, generation=168.0000, generation_time=0.0042, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 7}
# Gen 169: hypervolume=0.8703, igd=0.0046, gd=0.0055, gd_plus=0.0031, igd_plus=0.0034, spacing=0.0061, generation=169.0000, generation_time=0.0097, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 12}
# Gen 170: hypervolume=0.8701, igd=0.0048, gd=0.0054, gd_plus=0.0031, igd_plus=0.0035, spacing=0.0061, generation=170.0000, generation_time=0.0047, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 9}
# Gen 171: hypervolume=0.8702, igd=0.0048, gd=0.0052, gd_plus=0.0030, igd_plus=0.0035, spacing=0.0067, generation=171.0000, generation_time=0.0091, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 11}
# Gen 172: hypervolume=0.8706, igd=0.0044, gd=0.0052, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0054, generation=172.0000, generation_time=0.0060, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 10}
# Gen 173: hypervolume=0.8706, igd=0.0042, gd=0.0051, gd_plus=0.0028, igd_plus=0.0030, spacing=0.0055, generation=173.0000, generation_time=0.0069, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 10}
# Gen 174: hypervolume=0.8707, igd=0.0041, gd=0.0051, gd_plus=0.0027, igd_plus=0.0030, spacing=0.0057, generation=174.0000, generation_time=0.0050, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 10}
# Gen 175: hypervolume=0.8706, igd=0.0045, gd=0.0052, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0062, generation=175.0000, generation_time=0.0045, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 9}
# Gen 176: hypervolume=0.8706, igd=0.0044, gd=0.0052, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0057, generation=176.0000, generation_time=0.0046, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 10}
# Gen 177: hypervolume=0.8706, igd=0.0045, gd=0.0050, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0069, generation=177.0000, generation_time=0.0051, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 4}
# Gen 178: hypervolume=0.8706, igd=0.0046, gd=0.0052, gd_plus=0.0029, igd_plus=0.0033, spacing=0.0073, generation=178.0000, generation_time=0.0047, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 9}
# Gen 179: hypervolume=0.8704, igd=0.0046, gd=0.0052, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0077, generation=179.0000, generation_time=0.0046, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 7}
# Gen 180: hypervolume=0.8706, igd=0.0044, gd=0.0053, gd_plus=0.0027, igd_plus=0.0031, spacing=0.0061, generation=180.0000, generation_time=0.0050, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 1}
# Gen 181: hypervolume=0.8706, igd=0.0047, gd=0.0054, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0066, generation=181.0000, generation_time=0.0051, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 10, 'uniform_crossover_batch': 11}
# Gen 182: hypervolume=0.8704, igd=0.0046, gd=0.0053, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0068, generation=182.0000, generation_time=0.0049, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 6}
# Gen 183: hypervolume=0.8701, igd=0.0049, gd=0.0056, gd_plus=0.0028, igd_plus=0.0035, spacing=0.0061, generation=183.0000, generation_time=0.0060, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 12}
# Gen 184: hypervolume=0.8701, igd=0.0048, gd=0.0053, gd_plus=0.0028, igd_plus=0.0034, spacing=0.0065, generation=184.0000, generation_time=0.0107, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 10, 'uniform_crossover_batch': 3}
# Gen 185: hypervolume=0.8700, igd=0.0048, gd=0.0045, gd_plus=0.0028, igd_plus=0.0034, spacing=0.0077, generation=185.0000, generation_time=0.0072, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 5}
# Gen 186: hypervolume=0.8700, igd=0.0048, gd=0.0052, gd_plus=0.0029, igd_plus=0.0035, spacing=0.0074, generation=186.0000, generation_time=0.0051, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 8, 'uniform_crossover_batch': 6}
# Gen 187: hypervolume=0.8703, igd=0.0049, gd=0.0052, gd_plus=0.0029, igd_plus=0.0035, spacing=0.0080, generation=187.0000, generation_time=0.0052, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 188: hypervolume=0.8704, igd=0.0045, gd=0.0051, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0076, generation=188.0000, generation_time=0.0053, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 189: hypervolume=0.8704, igd=0.0045, gd=0.0051, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0066, generation=189.0000, generation_time=0.0053, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 6}
# Gen 190: hypervolume=0.8705, igd=0.0044, gd=0.0050, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0061, generation=190.0000, generation_time=0.0047, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 3}
# Gen 191: hypervolume=0.8705, igd=0.0046, gd=0.0048, gd_plus=0.0027, igd_plus=0.0033, spacing=0.0062, generation=191.0000, generation_time=0.0056, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 8}
# Gen 192: hypervolume=0.8706, igd=0.0042, gd=0.0050, gd_plus=0.0025, igd_plus=0.0030, spacing=0.0054, generation=192.0000, generation_time=0.0048, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 193: hypervolume=0.8704, igd=0.0044, gd=0.0051, gd_plus=0.0027, igd_plus=0.0033, spacing=0.0057, generation=193.0000, generation_time=0.0061, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 194: hypervolume=0.8703, igd=0.0045, gd=0.0051, gd_plus=0.0029, igd_plus=0.0033, spacing=0.0059, generation=194.0000, generation_time=0.0047, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 5}
# Gen 195: hypervolume=0.8704, igd=0.0043, gd=0.0049, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0059, generation=195.0000, generation_time=0.0048, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 11, 'uniform_crossover_batch': 6}
# Gen 196: hypervolume=0.8704, igd=0.0044, gd=0.0050, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0063, generation=196.0000, generation_time=0.0049, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 8, 'uniform_crossover_batch': 6}
# Gen 197: hypervolume=0.8703, igd=0.0045, gd=0.0050, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0061, generation=197.0000, generation_time=0.0050, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 8, 'uniform_crossover_batch': 6}
# Gen 198: hypervolume=0.8703, igd=0.0046, gd=0.0053, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0066, generation=198.0000, generation_time=0.0070, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 13, 'uniform_crossover_batch': 8}
# Gen 199: hypervolume=0.8700, igd=0.0047, gd=0.0053, gd_plus=0.0029, igd_plus=0.0034, spacing=0.0072, generation=199.0000, generation_time=0.0051, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 200: hypervolume=0.8701, igd=0.0047, gd=0.0055, gd_plus=0.0029, igd_plus=0.0034, spacing=0.0061, generation=200.0000, generation_time=0.0071, pair_cnt=45.0000, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100

# %% [markdown]
# ### Cell 8: Save Combined Metrics History to Excel
# import pandas as pd
# import re
#
# # Convert the all_metrics list to DataFrame
# df_metrics = pd.DataFrame(all_metrics)
#
# # Sanitize problem name for filename
# problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()
#
#
# # Define a mapping from the full crossover operator names to shortcuts
# crossover_shortcuts = {
#     "simulated_binary_crossover_batch": "sbx",
#     "blend_crossover_batch": "blx",
#     "single_point_crossover_batch": "spx",
#     "uniform_crossover_batch": "ux"
# }
#
# # Convert selected crossover operator names to their shortcut representation
# selected_crossover_shortcut_names = [
#     crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
# ]
#
# # Join the shortcuts into a single string (e.g., "sbx-blx")
# crossover_str = "-".join(selected_crossover_shortcut_names)
#
# # Create valid filename
# excel_filename = (
#     f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross 1 poly "
#     f"{pop_size}pop {generations}gen.xlsx"
# )
#
# #{crossover_str}
#
# # Save to Excel
# df_metrics.to_excel(excel_filename, index=False)
# print(f"Metrics saved to '{excel_filename}'")

# %%
# =========================
# New Cell: Run all Table 2 problems exactly as manual — Borg-MOEA variant
# =========================

import os
import re
import numpy as np
import pandas as pd
from pathlib import Path
from joblib import Parallel, delayed

# Recompute so this cell is self-contained
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None

# -------------------------------------------------
# 1) Table 2 benchmark list
# -------------------------------------------------
TABLE2_PROBLEMS = (
    [{"name": f"zdt{i}",   "n_var": 30, "n_obj": 2, "generations": 200}  for i in [1, 2, 3]] +
    [{"name": f"zdt{i}",   "n_var": 10, "n_obj": 2, "generations": 400}  for i in [4, 6]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 1000} for i in [1, 3]] +
    [{"name": f"dtlz{i}",  "n_var": 12, "n_obj": 3, "generations": 200}  for i in [2, 5, 7]] +
    [{"name": "dtlz4",     "n_var": 12, "n_obj": 3, "generations": 500}] +
    [{"name": "dtlz6",     "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": f"wfg{i}",   "n_var": 6,  "n_obj": 3, "generations": 200}  for i in range(1, 10)] +
    [{"name": "c1dtlz1",   "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "c2dtlz2",   "n_var": 12, "n_obj": 3, "generations": 200}] +
    [{"name": "c3dtlz4",   "n_var": 7,  "n_obj": 3, "generations": 500}] +
    [{"name": "dc1dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc1dtlz3",  "n_var": 12, "n_obj": 3, "generations": 1000}] +
    [{"name": "dc3dtlz1",  "n_var": 12, "n_obj": 3, "generations": 1000}]
)

SEEDS = range(1, 2)
OUTPUT_DIR = Path("Borg results time")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

CROSSOVER_SHORTCUTS = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}
MUTATION_SHORTCUTS = {
    "polynomial_mutation_batch": "poly",
    "gaussian_mutation_batch": "gauss"
}


def build_excel_name(problem_name, generations):
    problem_name_clean = re.sub(r"[^a-zA-Z0-9_]", "", problem_name).lower()
    crossover_str = "-".join(
        CROSSOVER_SHORTCUTS.get(name, name)
        for name in selected_crossover_operator_names
    )
    mutation_str = MUTATION_SHORTCUTS.get(selected_mutation_operator_name, selected_mutation_operator_name)
    return (
        f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} "
        f"cross 1 {mutation_str} {pop_size}pop {generations}gen Borg.xlsx"
    )


def flatten_columns(columns):
    out = []
    for col in columns:
        if isinstance(col, tuple):
            out.append("_".join([str(x) for x in col if str(x) != ""]).rstrip("_"))
        else:
            out.append(str(col))
    return out


# -------------------------------------------------
# 2) Per-seed runner — identical to manual Cell 7
#    Uses the ORIGINAL get_problem_dynamic from Cell 1
#    NO make_problem_safe wrapper
#    Creates BorgMOEAAllocationController per seed exactly as Cell 7
# -------------------------------------------------
def run_seed_manual(problem_cfg, seed):
    """
    Runs exactly like the manual code:
      - Uses get_problem_dynamic from Cell 1 (family-aware, no safety wrapper)
      - Creates a fresh BorgMOEAAllocationController per seed (same as Cell 7)
      - Calls run_nsga2 with allocation_controller=borg_controller
      - Post-processes with fast_non_dominated_sort just like Cell 7
    """
    problem = get_problem_dynamic(
        problem_cfg["name"],
        n_var=problem_cfg["n_var"],
        n_obj=problem_cfg["n_obj"]
    )

    D_local = problem.n_var
    M_local = problem.n_obj
    mutation_probability_local = 1.0 / D_local

    print(f"\n=== Running NSGA-II (Borg) with seed {seed} ===")

    # Create a fresh Borg controller per seed — same as Cell 7
    borg_controller = BorgMOEAAllocationController(
        operator_names=selected_crossover_operator_names,
        zeta=borg_zeta,
        credit_source=borg_credit_source
    )

    # Call run_nsga2 with the exact same signature as Cell 7
    final_population, true_pareto, metrics_history, history = run_nsga2(
        problem=problem,
        population_size=pop_size,
        generations=problem_cfg["generations"],
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability_local,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=False,
        metrics_interval=metrics_interval_value,
        record_history=False,
        allocation_controller=borg_controller
    )

    # Add seed info to metrics — same as Cell 7
    for metric in metrics_history:
        metric["seed"] = seed

    # Identify non-dominated solutions — same as Cell 7
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)
    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D_local:D_local + M_local]

    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")

    return {
        "seed": seed,
        "final_population": final_population,
        "true_pareto": true_pareto,
        "metrics_history": metrics_history,
        "pareto_points": pareto_points,
    }


# -------------------------------------------------
# 3) Run all problems, each with 30 seeds in parallel
# -------------------------------------------------
all_final_tables = []
failures = []

for idx, problem_cfg in enumerate(TABLE2_PROBLEMS, start=1):
    prob_name = problem_cfg["name"].upper()
    print(f"\n{'='*60}")
    print(f"[{idx}/{len(TABLE2_PROBLEMS)}] {prob_name} | "
          f"D={problem_cfg['n_var']}, M={problem_cfg['n_obj']}, G={problem_cfg['generations']}")
    print(f"{'='*60}")

    try:
        # Run 30 seeds in parallel — same as Cell 7 uses Parallel
        seed_results = Parallel(n_jobs=1)(
            delayed(run_seed_manual)(problem_cfg, seed) for seed in SEEDS
        )

        # Collect metrics and final rows — same post-processing as Cell 7
        all_metrics = []
        final_rows = []

        for result in seed_results:
            seed = result["seed"]
            all_metrics.extend(result["metrics_history"])

            # Build final row from last generation metrics
            final_row = {
                "problem": problem_cfg["name"],
                "seed": seed,
                "n_var": problem_cfg["n_var"],
                "n_obj": problem_cfg["n_obj"],
                "configured_generations": problem_cfg["generations"],
                "population_size": pop_size,
                "pareto_size": int(result["pareto_points"].shape[0]),
            }
            if result["metrics_history"]:
                final_row.update(result["metrics_history"][-1])
            final_rows.append(final_row)

        df_metrics = pd.DataFrame(all_metrics)
        df_final = pd.DataFrame(final_rows).sort_values("seed").reset_index(drop=True)

        if not df_metrics.empty:
            # Convert dict columns to strings for Excel compatibility
            for col in ["crossover_survival", "operator_allocation",
                        "operator_probabilities_used", "borg_credit_counts",
                        "operator_probabilities_next"]:
                if col in df_metrics.columns:
                    df_metrics[col] = df_metrics[col].astype(str)
            df_metrics = df_metrics.sort_values(["seed", "generation"]).reset_index(drop=True)

        # Summary stats
        numeric_cols = [
            c for c in [
                "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
                "spacing", "generation_time", "offspring_evals", "pareto_size"
            ]
            if c in df_final.columns
        ]

        summary_rows = []
        for col in numeric_cols:
            s = pd.to_numeric(df_final[col], errors="coerce").dropna()
            if not s.empty:
                summary_rows.append({
                    "metric": col,
                    "mean": s.mean(),
                    "std": s.std(),
                    "min": s.min(),
                    "max": s.max()
                })
        df_summary = pd.DataFrame(summary_rows)

        # Save per-problem Excel
        excel_path = OUTPUT_DIR / build_excel_name(problem_cfg["name"], problem_cfg["generations"])
        with pd.ExcelWriter(excel_path, engine="openpyxl") as writer:
            df_metrics.to_excel(writer, sheet_name="all_metrics", index=False)
            df_final.to_excel(writer, sheet_name="final_gen_by_seed", index=False)
            df_summary.to_excel(writer, sheet_name="summary", index=False)

        print(f"Saved: {excel_path}")
        all_final_tables.append(df_final)

    except Exception as e:
        print(f"FAILED: {problem_cfg['name']} -> {e}")
        failures.append({
            "problem": problem_cfg["name"],
            "n_var": problem_cfg["n_var"],
            "n_obj": problem_cfg["n_obj"],
            "generations": problem_cfg["generations"],
            "error": str(e)
        })

# -------------------------------------------------
# 4) Master summary across all problems
# -------------------------------------------------
df_all_final = pd.concat(all_final_tables, ignore_index=True) if all_final_tables else pd.DataFrame()
df_failures = pd.DataFrame(failures)
df_problem_table = pd.DataFrame(TABLE2_PROBLEMS)

if not df_all_final.empty:
    metric_cols = [
        c for c in [
            "hypervolume", "igd", "gd", "gd_plus", "igd_plus",
            "spacing", "generation_time", "offspring_evals", "pareto_size"
        ]
        if c in df_all_final.columns
    ]
    if metric_cols:
        agg_dict = {col: ["mean", "std"] for col in metric_cols}
        df_problem_summary = (
            df_all_final
            .groupby(["problem", "n_var", "n_obj", "configured_generations"], dropna=False)
            .agg(agg_dict)
            .reset_index()
        )
        df_problem_summary.columns = flatten_columns(df_problem_summary.columns)
        df_problem_summary = df_problem_summary.sort_values("problem").reset_index(drop=True)
    else:
        df_problem_summary = pd.DataFrame()
else:
    df_problem_summary = pd.DataFrame()

summary_path = OUTPUT_DIR / "ALL_PROBLEMS_SUMMARY_Borg.xlsx"
with pd.ExcelWriter(summary_path, engine="openpyxl") as writer:
    df_problem_table.to_excel(writer, sheet_name="benchmark_table", index=False)
    df_all_final.to_excel(writer, sheet_name="final_gen_all_seeds", index=False)
    df_problem_summary.to_excel(writer, sheet_name="problem_summary", index=False)
    df_failures.to_excel(writer, sheet_name="failures", index=False)

print(f"\nMaster summary saved: {summary_path}")
if failures:
    print(f"\n{len(failures)} problem(s) failed:")
    for f in failures:
        print(f"  {f['problem']}: {f['error']}")

df_problem_summary
# Out:
# ============================================================
# [1/27] ZDT1 | D=30, M=2, G=200
# ============================================================
#
# === Running NSGA-II (Borg) with seed 1 ===
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 11, 'uniform_crossover_batch': 17}
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.4652, gd_plus=2.4652, igd_plus=1.9687, spacing=0.2010, generation=1.0000, generation_time=0.0108, pair_cnt=30.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 11, 'uniform_crossover_batch': 22}
# Gen 2: hypervolume=0.0000, igd=1.6584, gd=2.1238, gd_plus=2.1238, igd_plus=1.6584, spacing=0.1370, generation=2.0000, generation_time=0.0063, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 26}
# Gen 3: hypervolume=0.0000, igd=1.6584, gd=2.0072, gd_plus=2.0072, igd_plus=1.6584, spacing=0.1014, generation=3.0000, generation_time=0.0074, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 20, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 25}
# Gen 4: hypervolume=0.0000, igd=1.6142, gd=1.7748, gd_plus=1.7748, igd_plus=1.6142, spacing=0.0865, generation=4.0000, generation_time=0.0076, pair_cnt=38.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 33, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 9}
# Gen 5: hypervolume=0.0000, igd=1.2784, gd=1.5145, gd_plus=1.5145, igd_plus=1.2784, spacing=0.1358, generation=5.0000, generation_time=0.0101, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 30, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 15}
# Gen 6: hypervolume=0.0000, igd=1.1257, gd=1.4965, gd_plus=1.4965, igd_plus=1.1257, spacing=0.0809, generation=6.0000, generation_time=0.0092, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 18}
# Gen 7: hypervolume=0.0000, igd=1.1214, gd=1.3535, gd_plus=1.3535, igd_plus=1.1214, spacing=0.1302, generation=7.0000, generation_time=0.0126, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Gen 8: hypervolume=0.0000, igd=0.9645, gd=1.1979, gd_plus=1.1979, igd_plus=0.9645, spacing=0.0877, generation=8.0000, generation_time=0.0082, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 17}
# Gen 9: hypervolume=0.0258, igd=0.8270, gd=1.0773, gd_plus=1.0773, igd_plus=0.8270, spacing=0.0656, generation=9.0000, generation_time=0.0058, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 10, 'uniform_crossover_batch': 11}
# Gen 10: hypervolume=0.0355, igd=0.7711, gd=0.9572, gd_plus=0.9572, igd_plus=0.7711, spacing=0.0781, generation=10.0000, generation_time=0.0063, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 33, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 20}
# Gen 11: hypervolume=0.0692, igd=0.7117, gd=0.8780, gd_plus=0.8780, igd_plus=0.7117, spacing=0.0932, generation=11.0000, generation_time=0.0051, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 32, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 15}
# Gen 12: hypervolume=0.0949, igd=0.6353, gd=0.7770, gd_plus=0.7770, igd_plus=0.6352, spacing=0.0617, generation=12.0000, generation_time=0.0051, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 33, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Gen 13: hypervolume=0.1196, igd=0.5868, gd=0.7144, gd_plus=0.7144, igd_plus=0.5868, spacing=0.0692, generation=13.0000, generation_time=0.0052, pair_cnt=63.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 36, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 14}
# Gen 14: hypervolume=0.1420, igd=0.5631, gd=0.5898, gd_plus=0.5898, igd_plus=0.5631, spacing=0.0371, generation=14.0000, generation_time=0.0049, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 40, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 9}
# Gen 15: hypervolume=0.1904, igd=0.5200, gd=0.5243, gd_plus=0.5243, igd_plus=0.5200, spacing=0.0431, generation=15.0000, generation_time=0.0055, pair_cnt=80.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 34, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 12}
# Gen 16: hypervolume=0.2448, igd=0.4600, gd=0.5443, gd_plus=0.5443, igd_plus=0.4600, spacing=0.0831, generation=16.0000, generation_time=0.0050, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 23, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 19}
# Gen 17: hypervolume=0.2728, igd=0.4410, gd=0.4788, gd_plus=0.4788, igd_plus=0.4410, spacing=0.0838, generation=17.0000, generation_time=0.0052, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 24}
# Gen 18: hypervolume=0.3260, igd=0.3695, gd=0.3980, gd_plus=0.3980, igd_plus=0.3695, spacing=0.0803, generation=18.0000, generation_time=0.0059, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 10, 'uniform_crossover_batch': 24}
# Gen 19: hypervolume=0.3729, igd=0.3302, gd=0.3789, gd_plus=0.3789, igd_plus=0.3302, spacing=0.0597, generation=19.0000, generation_time=0.0056, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 16, 'uniform_crossover_batch': 22}
# Gen 20: hypervolume=0.4018, igd=0.3126, gd=0.3371, gd_plus=0.3371, igd_plus=0.3126, spacing=0.0438, generation=20.0000, generation_time=0.0060, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 21, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 20}
# Gen 21: hypervolume=0.4469, igd=0.2703, gd=0.2933, gd_plus=0.2933, igd_plus=0.2703, spacing=0.0410, generation=21.0000, generation_time=0.0059, pair_cnt=38.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 14}
# Gen 22: hypervolume=0.4990, igd=0.2373, gd=0.2640, gd_plus=0.2640, igd_plus=0.2372, spacing=0.0251, generation=22.0000, generation_time=0.0051, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 25, 'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 14}
# Gen 23: hypervolume=0.5318, igd=0.2109, gd=0.2432, gd_plus=0.2432, igd_plus=0.2106, spacing=0.0309, generation=23.0000, generation_time=0.0058, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 21, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 17}
# Gen 24: hypervolume=0.5627, igd=0.1950, gd=0.2315, gd_plus=0.2315, igd_plus=0.1950, spacing=0.0231, generation=24.0000, generation_time=0.0051, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 14}
# Gen 25: hypervolume=0.5867, igd=0.1770, gd=0.2058, gd_plus=0.2058, igd_plus=0.1770, spacing=0.0312, generation=25.0000, generation_time=0.0057, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 24}
# Gen 26: hypervolume=0.6158, igd=0.1550, gd=0.1737, gd_plus=0.1737, igd_plus=0.1550, spacing=0.0359, generation=26.0000, generation_time=0.0050, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 28}
# Gen 27: hypervolume=0.6305, igd=0.1472, gd=0.1544, gd_plus=0.1544, igd_plus=0.1472, spacing=0.0299, generation=27.0000, generation_time=0.0054, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 23}
# Gen 28: hypervolume=0.6493, igd=0.1362, gd=0.1418, gd_plus=0.1416, igd_plus=0.1361, spacing=0.0280, generation=28.0000, generation_time=0.0053, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 27}
# Gen 29: hypervolume=0.6707, igd=0.1227, gd=0.1297, gd_plus=0.1295, igd_plus=0.1226, spacing=0.0257, generation=29.0000, generation_time=0.0053, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 25}
# Gen 30: hypervolume=0.6905, igd=0.1123, gd=0.1163, gd_plus=0.1161, igd_plus=0.1123, spacing=0.0253, generation=30.0000, generation_time=0.0065, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 21}
# Gen 31: hypervolume=0.7029, igd=0.1050, gd=0.1045, gd_plus=0.1034, igd_plus=0.1050, spacing=0.0270, generation=31.0000, generation_time=0.0051, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 13, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 32: hypervolume=0.7152, igd=0.0984, gd=0.0963, gd_plus=0.0953, igd_plus=0.0984, spacing=0.0174, generation=32.0000, generation_time=0.0060, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 17}
# Gen 33: hypervolume=0.7293, igd=0.0874, gd=0.0879, gd_plus=0.0868, igd_plus=0.0874, spacing=0.0224, generation=33.0000, generation_time=0.0053, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 22, 'simulated_binary_crossover_batch': 8, 'uniform_crossover_batch': 18}
# Gen 34: hypervolume=0.7389, igd=0.0828, gd=0.0823, gd_plus=0.0813, igd_plus=0.0828, spacing=0.0199, generation=34.0000, generation_time=0.0055, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 9, 'uniform_crossover_batch': 28}
# Gen 35: hypervolume=0.7458, igd=0.0794, gd=0.0806, gd_plus=0.0802, igd_plus=0.0794, spacing=0.0123, generation=35.0000, generation_time=0.0050, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 24}
# Gen 36: hypervolume=0.7549, igd=0.0730, gd=0.0743, gd_plus=0.0738, igd_plus=0.0729, spacing=0.0119, generation=36.0000, generation_time=0.0055, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 10, 'uniform_crossover_batch': 25}
# Gen 37: hypervolume=0.7614, igd=0.0686, gd=0.0699, gd_plus=0.0697, igd_plus=0.0686, spacing=0.0133, generation=37.0000, generation_time=0.0055, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 11, 'uniform_crossover_batch': 26}
# Gen 38: hypervolume=0.7690, igd=0.0640, gd=0.0648, gd_plus=0.0646, igd_plus=0.0640, spacing=0.0136, generation=38.0000, generation_time=0.0049, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 22}
# Gen 39: hypervolume=0.7766, igd=0.0596, gd=0.0623, gd_plus=0.0618, igd_plus=0.0595, spacing=0.0145, generation=39.0000, generation_time=0.0056, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 26}
# Gen 40: hypervolume=0.7840, igd=0.0555, gd=0.0545, gd_plus=0.0535, igd_plus=0.0554, spacing=0.0186, generation=40.0000, generation_time=0.0053, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 19}
# Gen 41: hypervolume=0.7888, igd=0.0519, gd=0.0537, gd_plus=0.0529, igd_plus=0.0518, spacing=0.0183, generation=41.0000, generation_time=0.0050, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 29}
# Gen 42: hypervolume=0.7951, igd=0.0479, gd=0.0509, gd_plus=0.0500, igd_plus=0.0478, spacing=0.0165, generation=42.0000, generation_time=0.0054, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 1, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 29}
# Gen 43: hypervolume=0.8014, igd=0.0440, gd=0.0462, gd_plus=0.0452, igd_plus=0.0440, spacing=0.0176, generation=43.0000, generation_time=0.0067, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 30}
# Gen 44: hypervolume=0.8080, igd=0.0401, gd=0.0427, gd_plus=0.0420, igd_plus=0.0400, spacing=0.0188, generation=44.0000, generation_time=0.0090, pair_cnt=64.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 26}
# Gen 45: hypervolume=0.8103, igd=0.0385, gd=0.0394, gd_plus=0.0387, igd_plus=0.0384, spacing=0.0178, generation=45.0000, generation_time=0.0076, pair_cnt=66.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 29}
# Gen 46: hypervolume=0.8157, igd=0.0350, gd=0.0353, gd_plus=0.0341, igd_plus=0.0350, spacing=0.0190, generation=46.0000, generation_time=0.0047, pair_cnt=69.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 32}
# Gen 47: hypervolume=0.8211, igd=0.0320, gd=0.0330, gd_plus=0.0315, igd_plus=0.0318, spacing=0.0165, generation=47.0000, generation_time=0.0047, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 23}
# Gen 48: hypervolume=0.8262, igd=0.0295, gd=0.0301, gd_plus=0.0288, igd_plus=0.0291, spacing=0.0141, generation=48.0000, generation_time=0.0062, pair_cnt=58.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 20}
# Gen 49: hypervolume=0.8295, igd=0.0279, gd=0.0293, gd_plus=0.0277, igd_plus=0.0275, spacing=0.0136, generation=49.0000, generation_time=0.0068, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 50: hypervolume=0.8333, igd=0.0254, gd=0.0278, gd_plus=0.0263, igd_plus=0.0250, spacing=0.0121, generation=50.0000, generation_time=0.0058, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 26, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 12}
# Gen 51: hypervolume=0.8368, igd=0.0234, gd=0.0255, gd_plus=0.0244, igd_plus=0.0230, spacing=0.0092, generation=51.0000, generation_time=0.0054, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 14}
# Gen 52: hypervolume=0.8390, igd=0.0219, gd=0.0238, gd_plus=0.0227, igd_plus=0.0216, spacing=0.0097, generation=52.0000, generation_time=0.0044, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 20, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 14}
# Gen 53: hypervolume=0.8415, igd=0.0208, gd=0.0221, gd_plus=0.0209, igd_plus=0.0206, spacing=0.0068, generation=53.0000, generation_time=0.0045, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 14}
# Gen 54: hypervolume=0.8436, igd=0.0196, gd=0.0208, gd_plus=0.0196, igd_plus=0.0194, spacing=0.0065, generation=54.0000, generation_time=0.0056, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 17, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 13}
# Gen 55: hypervolume=0.8451, igd=0.0186, gd=0.0197, gd_plus=0.0189, igd_plus=0.0184, spacing=0.0060, generation=55.0000, generation_time=0.0046, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 1, 'uniform_crossover_batch': 13}
# Gen 56: hypervolume=0.8457, igd=0.0182, gd=0.0193, gd_plus=0.0180, igd_plus=0.0180, spacing=0.0058, generation=56.0000, generation_time=0.0059, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Gen 57: hypervolume=0.8465, igd=0.0177, gd=0.0183, gd_plus=0.0174, igd_plus=0.0176, spacing=0.0049, generation=57.0000, generation_time=0.0051, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 18, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Gen 58: hypervolume=0.8474, igd=0.0171, gd=0.0175, gd_plus=0.0165, igd_plus=0.0169, spacing=0.0061, generation=58.0000, generation_time=0.0099, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 19, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 10}
# Gen 59: hypervolume=0.8489, igd=0.0160, gd=0.0170, gd_plus=0.0160, igd_plus=0.0159, spacing=0.0054, generation=59.0000, generation_time=0.0046, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 10}
# Gen 60: hypervolume=0.8500, igd=0.0152, gd=0.0163, gd_plus=0.0152, igd_plus=0.0151, spacing=0.0065, generation=60.0000, generation_time=0.0048, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 12}
# Gen 61: hypervolume=0.8510, igd=0.0146, gd=0.0156, gd_plus=0.0144, igd_plus=0.0145, spacing=0.0065, generation=61.0000, generation_time=0.0046, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 62: hypervolume=0.8520, igd=0.0142, gd=0.0153, gd_plus=0.0141, igd_plus=0.0141, spacing=0.0059, generation=62.0000, generation_time=0.0050, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 63: hypervolume=0.8529, igd=0.0136, gd=0.0147, gd_plus=0.0135, igd_plus=0.0135, spacing=0.0062, generation=63.0000, generation_time=0.0049, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 20, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 64: hypervolume=0.8540, igd=0.0130, gd=0.0141, gd_plus=0.0129, igd_plus=0.0128, spacing=0.0059, generation=64.0000, generation_time=0.0046, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 15}
# Gen 65: hypervolume=0.8548, igd=0.0125, gd=0.0136, gd_plus=0.0122, igd_plus=0.0123, spacing=0.0058, generation=65.0000, generation_time=0.0047, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 7}
# Gen 66: hypervolume=0.8553, igd=0.0122, gd=0.0132, gd_plus=0.0119, igd_plus=0.0121, spacing=0.0053, generation=66.0000, generation_time=0.0045, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 14, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 7}
# Gen 67: hypervolume=0.8559, igd=0.0118, gd=0.0129, gd_plus=0.0116, igd_plus=0.0117, spacing=0.0050, generation=67.0000, generation_time=0.0051, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 6}
# Gen 68: hypervolume=0.8567, igd=0.0113, gd=0.0126, gd_plus=0.0112, igd_plus=0.0112, spacing=0.0054, generation=68.0000, generation_time=0.0045, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 11}
# Gen 69: hypervolume=0.8572, igd=0.0111, gd=0.0122, gd_plus=0.0107, igd_plus=0.0109, spacing=0.0058, generation=69.0000, generation_time=0.0048, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Gen 70: hypervolume=0.8576, igd=0.0108, gd=0.0119, gd_plus=0.0104, igd_plus=0.0106, spacing=0.0046, generation=70.0000, generation_time=0.0061, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 3, 'uniform_crossover_batch': 17}
# Gen 71: hypervolume=0.8581, igd=0.0105, gd=0.0115, gd_plus=0.0099, igd_plus=0.0103, spacing=0.0054, generation=71.0000, generation_time=0.0049, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 5, 'uniform_crossover_batch': 13}
# Gen 72: hypervolume=0.8581, igd=0.0105, gd=0.0112, gd_plus=0.0099, igd_plus=0.0103, spacing=0.0059, generation=72.0000, generation_time=0.0047, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 2, 'uniform_crossover_batch': 14}
# Gen 73: hypervolume=0.8589, igd=0.0099, gd=0.0109, gd_plus=0.0093, igd_plus=0.0098, spacing=0.0061, generation=73.0000, generation_time=0.0044, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 12}
# Gen 74: hypervolume=0.8595, igd=0.0095, gd=0.0104, gd_plus=0.0090, igd_plus=0.0093, spacing=0.0057, generation=74.0000, generation_time=0.0076, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 75: hypervolume=0.8598, igd=0.0095, gd=0.0104, gd_plus=0.0090, igd_plus=0.0093, spacing=0.0057, generation=75.0000, generation_time=0.0049, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 7, 'uniform_crossover_batch': 10}
# Gen 76: hypervolume=0.8602, igd=0.0091, gd=0.0099, gd_plus=0.0087, igd_plus=0.0090, spacing=0.0063, generation=76.0000, generation_time=0.0055, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 77: hypervolume=0.8606, igd=0.0089, gd=0.0101, gd_plus=0.0084, igd_plus=0.0087, spacing=0.0061, generation=77.0000, generation_time=0.0048, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 10, 'uniform_crossover_batch': 15}
# Gen 78: hypervolume=0.8609, igd=0.0088, gd=0.0097, gd_plus=0.0081, igd_plus=0.0085, spacing=0.0060, generation=78.0000, generation_time=0.0047, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 13, 'uniform_crossover_batch': 7}
# Gen 79: hypervolume=0.8610, igd=0.0088, gd=0.0096, gd_plus=0.0079, igd_plus=0.0085, spacing=0.0060, generation=79.0000, generation_time=0.0052, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 10}
# Gen 80: hypervolume=0.8616, igd=0.0085, gd=0.0094, gd_plus=0.0077, igd_plus=0.0083, spacing=0.0058, generation=80.0000, generation_time=0.0064, pair_cnt=38.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 81: hypervolume=0.8617, igd=0.0083, gd=0.0093, gd_plus=0.0077, igd_plus=0.0081, spacing=0.0057, generation=81.0000, generation_time=0.0057, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 6, 'uniform_crossover_batch': 10}
# Gen 82: hypervolume=0.8621, igd=0.0081, gd=0.0091, gd_plus=0.0075, igd_plus=0.0078, spacing=0.0061, generation=82.0000, generation_time=0.0053, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 83: hypervolume=0.8627, igd=0.0078, gd=0.0089, gd_plus=0.0072, igd_plus=0.0075, spacing=0.0052, generation=83.0000, generation_time=0.0057, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 84: hypervolume=0.8628, igd=0.0077, gd=0.0087, gd_plus=0.0071, igd_plus=0.0075, spacing=0.0049, generation=84.0000, generation_time=0.0050, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 14, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 9}
# Gen 85: hypervolume=0.8629, igd=0.0075, gd=0.0083, gd_plus=0.0069, igd_plus=0.0073, spacing=0.0055, generation=85.0000, generation_time=0.0058, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 13}
# Gen 86: hypervolume=0.8633, igd=0.0073, gd=0.0081, gd_plus=0.0068, igd_plus=0.0071, spacing=0.0058, generation=86.0000, generation_time=0.0050, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 16, 'uniform_crossover_batch': 5}
# Gen 87: hypervolume=0.8637, igd=0.0070, gd=0.0078, gd_plus=0.0064, igd_plus=0.0068, spacing=0.0058, generation=87.0000, generation_time=0.0054, pair_cnt=45.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 13, 'uniform_crossover_batch': 9}
# Gen 88: hypervolume=0.8641, igd=0.0065, gd=0.0074, gd_plus=0.0062, igd_plus=0.0064, spacing=0.0065, generation=88.0000, generation_time=0.0053, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 17, 'uniform_crossover_batch': 6}
# Gen 89: hypervolume=0.8645, igd=0.0065, gd=0.0074, gd_plus=0.0060, igd_plus=0.0063, spacing=0.0055, generation=89.0000, generation_time=0.0064, pair_cnt=47.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 18, 'uniform_crossover_batch': 6}
# Gen 90: hypervolume=0.8648, igd=0.0064, gd=0.0072, gd_plus=0.0058, igd_plus=0.0061, spacing=0.0067, generation=90.0000, generation_time=0.0059, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 14, 'uniform_crossover_batch': 7}
# Gen 91: hypervolume=0.8651, igd=0.0063, gd=0.0072, gd_plus=0.0058, igd_plus=0.0060, spacing=0.0060, generation=91.0000, generation_time=0.0054, pair_cnt=54.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 16, 'uniform_crossover_batch': 9}
# Gen 92: hypervolume=0.8654, igd=0.0061, gd=0.0070, gd_plus=0.0054, igd_plus=0.0057, spacing=0.0067, generation=92.0000, generation_time=0.0056, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 18, 'uniform_crossover_batch': 6}
# Gen 93: hypervolume=0.8656, igd=0.0060, gd=0.0065, gd_plus=0.0052, igd_plus=0.0056, spacing=0.0063, generation=93.0000, generation_time=0.0050, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 17, 'uniform_crossover_batch': 8}
# Gen 94: hypervolume=0.8655, igd=0.0063, gd=0.0067, gd_plus=0.0053, igd_plus=0.0058, spacing=0.0068, generation=94.0000, generation_time=0.0057, pair_cnt=62.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 14, 'uniform_crossover_batch': 9}
# Gen 95: hypervolume=0.8656, igd=0.0063, gd=0.0069, gd_plus=0.0052, igd_plus=0.0057, spacing=0.0069, generation=95.0000, generation_time=0.0054, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 22, 'uniform_crossover_batch': 7}
# Gen 96: hypervolume=0.8661, igd=0.0060, gd=0.0069, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0056, generation=96.0000, generation_time=0.0055, pair_cnt=61.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 13, 'uniform_crossover_batch': 9}
# Gen 97: hypervolume=0.8659, igd=0.0062, gd=0.0072, gd_plus=0.0051, igd_plus=0.0057, spacing=0.0061, generation=97.0000, generation_time=0.0048, pair_cnt=49.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 98: hypervolume=0.8662, igd=0.0061, gd=0.0070, gd_plus=0.0051, igd_plus=0.0056, spacing=0.0059, generation=98.0000, generation_time=0.0055, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 10}
# Gen 99: hypervolume=0.8664, igd=0.0060, gd=0.0066, gd_plus=0.0048, igd_plus=0.0054, spacing=0.0065, generation=99.0000, generation_time=0.0050, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 100: hypervolume=0.8666, igd=0.0058, gd=0.0065, gd_plus=0.0049, igd_plus=0.0053, spacing=0.0071, generation=100.0000, generation_time=0.0052, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 13, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 8}
# Gen 101: hypervolume=0.8667, igd=0.0059, gd=0.0067, gd_plus=0.0050, igd_plus=0.0053, spacing=0.0066, generation=101.0000, generation_time=0.0050, pair_cnt=34.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 8}
# Gen 102: hypervolume=0.8669, igd=0.0060, gd=0.0068, gd_plus=0.0048, igd_plus=0.0053, spacing=0.0062, generation=102.0000, generation_time=0.0050, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 8, 'uniform_crossover_batch': 9}
# Gen 103: hypervolume=0.8671, igd=0.0059, gd=0.0068, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0061, generation=103.0000, generation_time=0.0053, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 4}
# Gen 104: hypervolume=0.8672, igd=0.0058, gd=0.0066, gd_plus=0.0047, igd_plus=0.0051, spacing=0.0066, generation=104.0000, generation_time=0.0050, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 9}
# Gen 105: hypervolume=0.8675, igd=0.0056, gd=0.0063, gd_plus=0.0045, igd_plus=0.0048, spacing=0.0065, generation=105.0000, generation_time=0.0048, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 11}
# Gen 106: hypervolume=0.8674, igd=0.0056, gd=0.0062, gd_plus=0.0045, igd_plus=0.0048, spacing=0.0061, generation=106.0000, generation_time=0.0053, pair_cnt=36.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 107: hypervolume=0.8675, igd=0.0056, gd=0.0064, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0055, generation=107.0000, generation_time=0.0051, pair_cnt=34.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 11, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 108: hypervolume=0.8676, igd=0.0055, gd=0.0062, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0057, generation=108.0000, generation_time=0.0056, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 4}
# Gen 109: hypervolume=0.8677, igd=0.0055, gd=0.0062, gd_plus=0.0044, igd_plus=0.0048, spacing=0.0058, generation=109.0000, generation_time=0.0057, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 110: hypervolume=0.8677, igd=0.0055, gd=0.0062, gd_plus=0.0044, igd_plus=0.0047, spacing=0.0059, generation=110.0000, generation_time=0.0066, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 16, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 3}
# Gen 111: hypervolume=0.8678, igd=0.0056, gd=0.0063, gd_plus=0.0042, igd_plus=0.0047, spacing=0.0071, generation=111.0000, generation_time=0.0049, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 15, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 112: hypervolume=0.8680, igd=0.0053, gd=0.0060, gd_plus=0.0040, igd_plus=0.0045, spacing=0.0058, generation=112.0000, generation_time=0.0058, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 113: hypervolume=0.8682, igd=0.0053, gd=0.0062, gd_plus=0.0041, igd_plus=0.0045, spacing=0.0060, generation=113.0000, generation_time=0.0050, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 8}
# Gen 114: hypervolume=0.8681, igd=0.0054, gd=0.0061, gd_plus=0.0041, igd_plus=0.0045, spacing=0.0064, generation=114.0000, generation_time=0.0050, pair_cnt=38.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 9, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 8}
# Gen 115: hypervolume=0.8682, igd=0.0053, gd=0.0060, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0064, generation=115.0000, generation_time=0.0050, pair_cnt=33.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 8}
# Gen 116: hypervolume=0.8684, igd=0.0053, gd=0.0056, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0071, generation=116.0000, generation_time=0.0048, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 12, 'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 8}
# Gen 117: hypervolume=0.8687, igd=0.0051, gd=0.0058, gd_plus=0.0037, igd_plus=0.0041, spacing=0.0074, generation=117.0000, generation_time=0.0057, pair_cnt=33.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 11, 'simulated_binary_crossover_batch': 4, 'uniform_crossover_batch': 5}
# Gen 118: hypervolume=0.8685, igd=0.0052, gd=0.0056, gd_plus=0.0039, igd_plus=0.0042, spacing=0.0067, generation=118.0000, generation_time=0.0047, pair_cnt=34.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 9, 'uniform_crossover_batch': 11}
# Gen 119: hypervolume=0.8686, igd=0.0051, gd=0.0054, gd_plus=0.0038, igd_plus=0.0041, spacing=0.0064, generation=119.0000, generation_time=0.0053, pair_cnt=32.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 12, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 6}
# Gen 120: hypervolume=0.8684, igd=0.0053, gd=0.0054, gd_plus=0.0039, igd_plus=0.0043, spacing=0.0064, generation=120.0000, generation_time=0.0051, pair_cnt=35.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 10, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 7}
# Gen 121: hypervolume=0.8684, igd=0.0054, gd=0.0054, gd_plus=0.0037, igd_plus=0.0044, spacing=0.0069, generation=121.0000, generation_time=0.0051, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 18, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 6}
# Gen 122: hypervolume=0.8688, igd=0.0050, gd=0.0053, gd_plus=0.0036, igd_plus=0.0041, spacing=0.0074, generation=122.0000, generation_time=0.0055, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 3, 'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 2}
# Gen 123: hypervolume=0.8688, igd=0.0050, gd=0.0057, gd_plus=0.0038, igd_plus=0.0041, spacing=0.0068, generation=123.0000, generation_time=0.0053, pair_cnt=48.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 3}
# Gen 124: hypervolume=0.8686, igd=0.0049, gd=0.0055, gd_plus=0.0037, igd_plus=0.0041, spacing=0.0066, generation=124.0000, generation_time=0.0059, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 15, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 2}
# Gen 125: hypervolume=0.8682, igd=0.0053, gd=0.0054, gd_plus=0.0036, igd_plus=0.0044, spacing=0.0065, generation=125.0000, generation_time=0.0055, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 18, 'uniform_crossover_batch': 1}
# Gen 126: hypervolume=0.8684, igd=0.0055, gd=0.0057, gd_plus=0.0037, igd_plus=0.0044, spacing=0.0060, generation=126.0000, generation_time=0.0057, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 20, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 3}
# Gen 127: hypervolume=0.8684, igd=0.0054, gd=0.0057, gd_plus=0.0037, igd_plus=0.0043, spacing=0.0077, generation=127.0000, generation_time=0.0057, pair_cnt=56.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 19, 'uniform_crossover_batch': 3}
# Gen 128: hypervolume=0.8686, igd=0.0054, gd=0.0057, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0075, generation=128.0000, generation_time=0.0058, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 10, 'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 1}
# Gen 129: hypervolume=0.8684, igd=0.0055, gd=0.0057, gd_plus=0.0037, igd_plus=0.0043, spacing=0.0082, generation=129.0000, generation_time=0.0057, pair_cnt=68.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 8, 'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 2}
# Gen 130: hypervolume=0.8689, igd=0.0049, gd=0.0053, gd_plus=0.0034, igd_plus=0.0040, spacing=0.0071, generation=130.0000, generation_time=0.0057, pair_cnt=65.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 23, 'uniform_crossover_batch': 1}
# Gen 131: hypervolume=0.8691, igd=0.0048, gd=0.0053, gd_plus=0.0035, igd_plus=0.0039, spacing=0.0072, generation=131.0000, generation_time=0.0058, pair_cnt=70.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 24, 'uniform_crossover_batch': 5}
# Gen 132: hypervolume=0.8692, igd=0.0048, gd=0.0054, gd_plus=0.0035, igd_plus=0.0038, spacing=0.0068, generation=132.0000, generation_time=0.0058, pair_cnt=72.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 2, 'simulated_binary_crossover_batch': 21, 'uniform_crossover_batch': 3}
# Gen 133: hypervolume=0.8692, igd=0.0049, gd=0.0056, gd_plus=0.0035, igd_plus=0.0038, spacing=0.0072, generation=133.0000, generation_time=0.0057, pair_cnt=72.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 5, 'simulated_binary_crossover_batch': 22, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 3}
# Gen 134: hypervolume=0.8692, igd=0.0048, gd=0.0055, gd_plus=0.0034, igd_plus=0.0038, spacing=0.0075, generation=134.0000, generation_time=0.0057, pair_cnt=73.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 21}
# Gen 135: hypervolume=0.8695, igd=0.0046, gd=0.0053, gd_plus=0.0034, igd_plus=0.0037, spacing=0.0071, generation=135.0000, generation_time=0.0056, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 15, 'uniform_crossover_batch': 1}
# Gen 136: hypervolume=0.8695, igd=0.0046, gd=0.0051, gd_plus=0.0032, igd_plus=0.0036, spacing=0.0061, generation=136.0000, generation_time=0.0063, pair_cnt=68.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 4, 'simulated_binary_crossover_batch': 23, 'uniform_crossover_batch': 4}
# Gen 137: hypervolume=0.8698, igd=0.0045, gd=0.0051, gd_plus=0.0032, igd_plus=0.0035, spacing=0.0059, generation=137.0000, generation_time=0.0056, pair_cnt=69.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 22, 'uniform_crossover_batch': 1}
# Gen 138: hypervolume=0.8698, igd=0.0046, gd=0.0053, gd_plus=0.0033, igd_plus=0.0036, spacing=0.0061, generation=138.0000, generation_time=0.0055, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 6, 'simulated_binary_crossover_batch': 19, 'uniform_crossover_batch': 3}
# Gen 139: hypervolume=0.8696, igd=0.0048, gd=0.0055, gd_plus=0.0034, igd_plus=0.0037, spacing=0.0063, generation=139.0000, generation_time=0.0056, pair_cnt=68.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 24}
# Gen 140: hypervolume=0.8696, igd=0.0047, gd=0.0052, gd_plus=0.0033, igd_plus=0.0037, spacing=0.0063, generation=140.0000, generation_time=0.0056, pair_cnt=74.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 13, 'uniform_crossover_batch': 1}
# Gen 141: hypervolume=0.8693, igd=0.0049, gd=0.0052, gd_plus=0.0034, igd_plus=0.0038, spacing=0.0070, generation=141.0000, generation_time=0.0058, pair_cnt=67.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 7, 'simulated_binary_crossover_batch': 23}
# ...
# Survival counts by operator: {'single_point_crossover_batch': 4, 'uniform_crossover_batch': 14}
# Gen 981: hypervolume=0.0409, igd=0.2265, gd=0.2328, gd_plus=0.2328, igd_plus=0.2265, spacing=0.0223, generation=981.0000, generation_time=0.0070, pair_cnt=59.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 7}
# Gen 982: hypervolume=0.0407, igd=0.2268, gd=0.2339, gd_plus=0.2339, igd_plus=0.2268, spacing=0.0167, generation=982.0000, generation_time=0.0069, pair_cnt=55.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 9, 'uniform_crossover_batch': 8}
# Gen 983: hypervolume=0.0408, igd=0.2267, gd=0.2319, gd_plus=0.2319, igd_plus=0.2267, spacing=0.0179, generation=983.0000, generation_time=0.0062, pair_cnt=57.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 11}
# Gen 984: hypervolume=0.0412, igd=0.2267, gd=0.2309, gd_plus=0.2309, igd_plus=0.2267, spacing=0.0175, generation=984.0000, generation_time=0.0066, pair_cnt=43.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 9, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 7}
# Gen 985: hypervolume=0.0418, igd=0.2266, gd=0.2315, gd_plus=0.2315, igd_plus=0.2266, spacing=0.0151, generation=985.0000, generation_time=0.0067, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 3, 'uniform_crossover_batch': 9}
# Gen 986: hypervolume=0.0418, igd=0.2266, gd=0.2323, gd_plus=0.2323, igd_plus=0.2266, spacing=0.0150, generation=986.0000, generation_time=0.0066, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 1, 'simulated_binary_crossover_batch': 2, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 8}
# Gen 987: hypervolume=0.0418, igd=0.2267, gd=0.2327, gd_plus=0.2327, igd_plus=0.2267, spacing=0.0142, generation=987.0000, generation_time=0.0064, pair_cnt=53.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 6, 'uniform_crossover_batch': 11}
# Gen 988: hypervolume=0.0417, igd=0.2267, gd=0.2309, gd_plus=0.2309, igd_plus=0.2267, spacing=0.0182, generation=988.0000, generation_time=0.0063, pair_cnt=51.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 10}
# Gen 989: hypervolume=0.0418, igd=0.2267, gd=0.2313, gd_plus=0.2313, igd_plus=0.2267, spacing=0.0188, generation=989.0000, generation_time=0.0060, pair_cnt=58.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 7}
# Gen 990: hypervolume=0.0418, igd=0.2266, gd=0.2329, gd_plus=0.2329, igd_plus=0.2266, spacing=0.0158, generation=990.0000, generation_time=0.0033, pair_cnt=46.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 991: hypervolume=0.0418, igd=0.2265, gd=0.2328, gd_plus=0.2328, igd_plus=0.2265, spacing=0.0163, generation=991.0000, generation_time=0.0034, pair_cnt=52.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 3, 'single_point_crossover_batch': 1, 'uniform_crossover_batch': 6}
# Gen 992: hypervolume=0.0413, igd=0.2265, gd=0.2315, gd_plus=0.2315, igd_plus=0.2265, spacing=0.0156, generation=992.0000, generation_time=0.0033, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'blend_crossover_batch': 1, 'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 2, 'uniform_crossover_batch': 7}
# Gen 993: hypervolume=0.0414, igd=0.2264, gd=0.2308, gd_plus=0.2308, igd_plus=0.2264, spacing=0.0152, generation=993.0000, generation_time=0.0054, pair_cnt=50.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 4, 'single_point_crossover_batch': 8, 'uniform_crossover_batch': 5}
# Gen 994: hypervolume=0.0416, igd=0.2263, gd=0.2312, gd_plus=0.2312, igd_plus=0.2263, spacing=0.0169, generation=994.0000, generation_time=0.0051, pair_cnt=42.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 10, 'uniform_crossover_batch': 4}
# Gen 995: hypervolume=0.0416, igd=0.2262, gd=0.2306, gd_plus=0.2306, igd_plus=0.2262, spacing=0.0153, generation=995.0000, generation_time=0.0032, pair_cnt=44.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 6, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 6}
# Gen 996: hypervolume=0.0416, igd=0.2263, gd=0.2293, gd_plus=0.2293, igd_plus=0.2263, spacing=0.0186, generation=996.0000, generation_time=0.0032, pair_cnt=39.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 7, 'uniform_crossover_batch': 9}
# Gen 997: hypervolume=0.0416, igd=0.2263, gd=0.2299, gd_plus=0.2299, igd_plus=0.2263, spacing=0.0164, generation=997.0000, generation_time=0.0049, pair_cnt=37.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 5, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 5}
# Gen 998: hypervolume=0.0416, igd=0.2263, gd=0.2286, gd_plus=0.2286, igd_plus=0.2263, spacing=0.0158, generation=998.0000, generation_time=0.0138, pair_cnt=41.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 7, 'single_point_crossover_batch': 5, 'uniform_crossover_batch': 6}
# Gen 999: hypervolume=0.0419, igd=0.2259, gd=0.2287, gd_plus=0.2287, igd_plus=0.2259, spacing=0.0153, generation=999.0000, generation_time=0.0150, pair_cnt=40.0000, offspring_evals=100.0000
# Survival counts by operator: {'simulated_binary_crossover_batch': 8, 'single_point_crossover_batch': 4, 'uniform_crossover_batch': 6}
# Gen 1000: hypervolume=0.0419, igd=0.2258, gd=0.2309, gd_plus=0.2309, igd_plus=0.2258, spacing=0.0181, generation=1000.0000, generation_time=0.0073, pair_cnt=39.0000, offspring_evals=100.0000
# Seed 1 - Number of Pareto front points: 100
# Saved: Borg results time\dc3dtlz1 4 sbx-spx-blx-ux cross 1 poly 100pop 1000gen Borg.xlsx
#
# Master summary saved: Borg results time\ALL_PROBLEMS_SUMMARY_Borg.xlsx
#      problem  n_var  n_obj  configured_generations  hypervolume_mean  \
# 0    c1dtlz1     12      3                    1000          0.137824
# 1    c2dtlz2     12      3                     200          0.661514
# 2    c3dtlz4      7      3                     500          8.159834
# 3   dc1dtlz1     12      3                    1000          0.117147
# 4   dc1dtlz3     12      3                    1000          0.666003
# 5   dc3dtlz1     12      3                    1000          0.041920
# 6      dtlz1     12      3                    1000          0.137640
# 7      dtlz2     12      3                     200          0.701918
# 8      dtlz3     12      3                    1000          0.710877
# 9      dtlz4     12      3                     500          0.709895
# 10     dtlz5     12      3                     200          0.132367
# 11     dtlz6     12      3                    1000          0.132989
# 12     dtlz7     12      3                     200          1.560927
# 13      wfg1      6      3                     200         41.113714
# 14      wfg2      6      3                     200         58.860532
# 15      wfg3      6      3                     200          6.315012
# 16      wfg4      6      3                     200         33.308896
# 17      wfg5      6      3                     200         29.822939
# 18      wfg6      6      3                     200         33.539654
# 19      wfg7      6      3                     200         33.983736
# 20      wfg8      6      3                     200         30.827898
# 21      wfg9      6      3                     200         32.492121
# 22      zdt1     30      2                     200          0.869873
# 23      zdt2     30      2                     200          0.536911
# 24      zdt3     30      2                     200          1.022337
# 25      zdt4     10      2                     400          0.870552
# 26      zdt6     10      2                     400          0.432572
#
#     hypervolume_std  igd_mean  igd_std   gd_mean  gd_std  ...  igd_plus_mean  \
# 0               NaN  0.024949      NaN  0.015931     NaN  ...       0.017018
# 1               NaN  0.058177      NaN  0.058695     NaN  ...       0.022029
# 2               NaN  0.125902      NaN  0.090008     NaN  ...       0.085600
# 3               NaN  0.060097      NaN  0.015598     NaN  ...       0.042856
# 4               NaN  0.132365      NaN  0.039239     NaN  ...       0.055333
# 5               NaN  0.225835      NaN  0.230908     NaN  ...       0.225835
# 6               NaN  0.025488      NaN  0.014740     NaN  ...       0.017322
# 7               NaN  0.069029      NaN  0.048102     NaN  ...       0.036969
# 8               NaN  0.069339      NaN  0.045623     NaN  ...       0.034819
# 9               NaN  0.067526      NaN  0.046022     NaN  ...       0.034732
# 10              NaN  0.005534      NaN  0.004080     NaN  ...       0.003224
# 11              NaN  0.004855      NaN  0.003789     NaN  ...       0.002169
# 12              NaN  0.087814      NaN  0.038144     NaN  ...       0.048953
# 13              NaN  0.704784      NaN  0.669803     NaN  ...       0.689934
# 14              NaN  0.247805      NaN  0.218783     NaN  ...       0.064538
# 15              NaN  0.067700      NaN  0.606223     NaN  ...       0.043949
# 16              NaN  0.239158      NaN  0.207570     NaN  ...       0.108575
# 17              NaN  0.262556      NaN  0.211211     NaN  ...       0.165752
# 18              NaN  0.250470      NaN  0.189655     NaN  ...       0.120474
# 19              NaN  0.215065      NaN  0.202821     NaN  ...       0.108483
# 20              NaN  0.343197      NaN  0.223598     NaN  ...       0.188089
# 21              NaN  0.273927      NaN  0.201836     NaN  ...       0.153298
# 22              NaN  0.004626      NaN  0.005408     NaN  ...       0.003561
# 23              NaN  0.004824      NaN  0.004192     NaN  ...       0.003128
# 24              NaN  0.005177      NaN  0.005421     NaN  ...       0.001772
# 25              NaN  0.004375      NaN  0.004831     NaN  ...       0.003089
# 26              NaN  0.003593      NaN  0.002846     NaN  ...       0.002415
#
#     igd_plus_std  spacing_mean  spacing_std  generation_time_mean  \
# 0            NaN      0.023469          NaN              0.007225
# 1            NaN      0.037402          NaN              0.006382
# 2            NaN      0.094144          NaN              0.011572
# 3            NaN      0.008861          NaN              0.005735
# 4            NaN      0.033241          NaN              0.006374
# 5            NaN      0.018059          NaN              0.007308
# 6            NaN      0.018809          NaN              0.005727
# 7            NaN      0.052649          NaN              0.004302
# 8            NaN      0.053821          NaN              0.011048
# 9            NaN      0.052946          NaN              0.004776
# 10           NaN      0.008321          NaN              0.005389
# 11           NaN      0.009331          NaN              0.005192
# 12           NaN      0.072815          NaN              0.010284
# 13           NaN      0.134921          NaN              0.008648
# 14           NaN      0.210904          NaN              0.006186
# 15           NaN      0.138489          NaN              0.006186
# 16           NaN      0.230197          NaN              0.005764
# 17           NaN      0.191529          NaN              0.005425
# 18           NaN      0.174585          NaN              0.006765
# 19           NaN      0.221426          NaN              0.005746
# 20           NaN      0.214379          NaN              0.007457
# 21           NaN      0.182833          NaN              0.007521
# 22           NaN      0.006691          NaN              0.005058
# 23           NaN      0.007046          NaN              0.004934
# 24           NaN      0.007418          NaN              0.005014
# 25           NaN      0.007218          NaN              0.009186
# 26           NaN      0.007097          NaN              0.005673
#
#     generation_time_std  offspring_evals_mean  offspring_evals_std  \
# 0                   NaN                 100.0                  NaN
# 1                   NaN                 100.0                  NaN
# 2                   NaN                 100.0                  NaN
# 3                   NaN                 100.0                  NaN
# 4                   NaN                 100.0                  NaN
# 5                   NaN                 100.0                  NaN
# 6                   NaN                 100.0                  NaN
# 7                   NaN                 100.0                  NaN
# 8                   NaN                 100.0                  NaN
# 9                   NaN                 100.0                  NaN
# 10                  NaN                 100.0                  NaN
# 11                  NaN                 100.0                  NaN
# 12                  NaN                 100.0                  NaN
# 13                  NaN                 100.0                  NaN
# 14                  NaN                 100.0                  NaN
# 15                  NaN                 100.0                  NaN
# 16                  NaN                 100.0                  NaN
# 17                  NaN                 100.0                  NaN
# 18                  NaN                 100.0                  NaN
# 19                  NaN                 100.0                  NaN
# 20                  NaN                 100.0                  NaN
# 21                  NaN                 100.0                  NaN
# 22                  NaN                 100.0                  NaN
# 23                  NaN                 100.0                  NaN
# 24                  NaN                 100.0                  NaN
# 25                  NaN                 100.0                  NaN
# 26                  NaN                 100.0                  NaN
#
#     pareto_size_mean  pareto_size_std
# 0              100.0              NaN
# 1              100.0              NaN
# 2              100.0              NaN
# 3              100.0              NaN
# 4              100.0              NaN
# 5              100.0              NaN
# 6              100.0              NaN
# 7              100.0              NaN
# 8              100.0              NaN
# 9              100.0              NaN
# 10             100.0              NaN
# 11             100.0              NaN
# 12             100.0              NaN
# 13             100.0              NaN
# 14             100.0              NaN
# 15             100.0              NaN
# 16             100.0              NaN
# 17             100.0              NaN
# 18             100.0              NaN
# 19             100.0              NaN
# 20             100.0              NaN
# 21             100.0              NaN
# 22             100.0              NaN
# 23             100.0              NaN
# 24             100.0              NaN
# 25             100.0              NaN
# 26             100.0              NaN
#
# [27 rows x 22 columns]
