# %%
#### Cell 0: Imports and Setup

# 1. Problem Selection and Configuration
#According to Table 2 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
problem_name = "zdt1"
n_var = 30  # Custom number of decision variables 
n_obj = 2  # Custom number of objectives

# 2. Population Settings
# -----------------------
pop_size = 100
generations = 200

# 3. Operator-specific parameters
#According to Table 1 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
crossover_probability = 0.9
mutation_sigma = 0.5           
distribution_index_n_c = 15    # For simulated binary crossover
distribution_index_n_m = 20    # For polynomial mutation
blend_alpha = 0.5              # for blend crossover
swap_prob = 0.5                # For uniform crossover

# %%
#### Cell 1: Imports and Setup

import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  


# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"  # e.g. c1dtlz1
    return "unknown"

def get_problem_dynamic(name: str, n_var: int | None = None, n_obj: int | None = None):
    """
    Robustly instantiate a Pymoo problem without you having to remember the exact signature.
    Tries the 'right' order per family, then falls back gracefully.
    """
    fam = _family(name)

    # preferred try-orders per family
    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),  # many constrained DTLZ variants expose fixed dims
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for a in attempts:
        try:
            return a()
        except TypeError as e:    # signature mismatch
            last_err = e
        except Exception as e:    # other errors (invalid name, etc.)
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )




problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 



# 3.a. Select Crossover and Mutation Operators

selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    #"single_point_crossover_batch",
    #"blend_crossover_batch",
    #"uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1
#seeds=31

#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


# Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices):
    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, problem.n_var: problem.n_var + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))


def select_parents_batch(population, rank, cd, population_size):
    """
    Perform binary tournament selection in a vectorized manner to select parents.
    """
    total_individuals = population.shape[0]
    
    # First set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents1 = np.where(better, parent1_idx, parent2_idx)

    # Second set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents2 = np.where(better, parent1_idx, parent2_idx)

    return selected_parents1, selected_parents2

#cell 4

def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     crossover_probability, distribution_index_n_c,
                                     min_values, max_values, eps=1e-14):
    """
    Perform Simulated Binary Crossover (SBX) on a batch of parent pairs.

    This implementation mimics the pymoo SBX operator with gene‐wise crossover probabilities,
    handling cases when parent genes are too close or when lower and upper bounds are identical.
    
    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover per gene.
        distribution_index_n_c (float): Crossover distribution index (η₍c₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        eps (float): A small constant to avoid numerical issues when parent genes are nearly equal.
        
    Returns:
       
    """
    N, D = parents_dec_1.shape
    eta_c = distribution_index_n_c

    # Initialize offspring as copies of the parents.
    child1 = parents_dec_1.copy()
    child2 = parents_dec_2.copy()

    # Create a gene-wise mask deciding whether to perform crossover.
    do_cross = np.random.rand(N, D) < crossover_probability

    # Disable crossover for genes where the parents are too close.
    do_cross[np.abs(parents_dec_1 - parents_dec_2) <= eps] = False

    # Disable crossover for genes where the lower and upper bounds are identical.
    do_cross[:, (min_values == max_values)] = False

    # Compute gene-wise minima and maxima.
    y1 = np.minimum(parents_dec_1, parents_dec_2)
    y2 = np.maximum(parents_dec_1, parents_dec_2)
    delta = y2 - y1

    # Prepare arrays to hold the new offspring values.
    c1_new = child1.copy()
    c2_new = child2.copy()

    if np.any(do_cross):
        # === First Child Calculation ===
        # Compute beta for the first offspring using the lower bound.
        beta1 = 1.0 + 2.0 * (y1 - min_values) / (delta + eps)
        # Calculate alpha1 as in pymoo: 2 - beta^(-(η₍c₎+1))
        alpha1 = 2.0 - np.power(beta1, -(eta_c + 1.0))
        # Draw independent random numbers for each gene.
        rand1 = np.random.rand(N, D)
        # Compute betaq1 according to the condition.
        betaq1 = np.where(rand1 <= (1.0 / alpha1),
                          np.power(rand1 * alpha1, 1.0 / (eta_c + 1.0)),
                          np.power(1.0 / (2.0 - rand1 * alpha1), 1.0 / (eta_c + 1.0)))
        # Compute the offspring gene values.
        c1_calc = 0.5 * ((y1 + y2) - betaq1 * delta)

        # === Second Child Calculation ===
        # Compute beta for the second offspring using the upper bound.
        beta2 = 1.0 + 2.0 * (max_values - y2) / (delta + eps)
        alpha2 = 2.0 - np.power(beta2, -(eta_c + 1.0))
        rand2 = np.random.rand(N, D)
        betaq2 = np.where(rand2 <= (1.0 / alpha2),
                          np.power(rand2 * alpha2, 1.0 / (eta_c + 1.0)),
                          np.power(1.0 / (2.0 - rand2 * alpha2), 1.0 / (eta_c + 1.0)))
        c2_calc = 0.5 * ((y1 + y2) + betaq2 * delta)

        # === Optional Swap Step ===
        # With probability 0.5 per gene (for those that undergo crossover) swap the two offspring.
        swap_mask = np.random.rand(N, D) < 0.5
        # It is important to apply swapping only where crossover is done.
        # (Since c1_calc and c2_calc are computed for all genes, we swap only at indices in do_cross.)
        temp = np.copy(c1_calc)
        c1_calc[swap_mask] = c2_calc[swap_mask]
        c2_calc[swap_mask] = temp[swap_mask]

        # Assign the newly calculated gene values only where crossover is applied.
        c1_new[do_cross] = c1_calc[do_cross]
        c2_new[do_cross] = c2_calc[do_cross]

    # Clip the offspring to ensure they lie within the given bounds.
    child1 = np.clip(c1_new, min_values, max_values)
    child2 = np.clip(c2_new, min_values, max_values)

    return child1, child2

def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    num_offspring, num_decision_variables = parents_dec_1.shape
    # Initialize offspring arrays as copies of parent genes
    child1 = parents_dec_1.copy()
    child2 = parents_dec_2.copy()

    # Create a mask to decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # Get indices of parent pairs that will crossover
    crossover_indices = np.nonzero(crossover_mask)[0]

    # For each selected pair, determine a random crossover point and perform crossover
    if crossover_indices.size > 0:
        # Randomly select a crossover point for each individual selected for crossover
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        # Iterate over each selected pair and apply single-point crossover
        for idx, cp in zip(crossover_indices, crossover_points):
            # Swap segments after the crossover point between the two parents
            child1[idx, cp:], child2[idx, cp:] = child2[idx, cp:], child1[idx, cp:]

    # Ensure offspring values are within the specified bounds
    child1 = np.clip(child1, min_values, max_values)
    child2 = np.clip(child2, min_values, max_values)

    return child1, child2





import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):
    """
    Perform BLX-α (Blend Crossover) on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of crossover.
        alpha_blend (float): Blend factor α controlling the range extension.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    child2 = parents_dec_2.copy()

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < crossover_probability

    # If no pairs are selected, return the copies.
    if not np.any(do_cross):
        return child1, child2

    # Extract only the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Compute element-wise minima and maxima for each gene.
    y1 = np.minimum(p1, p2)
    y2 = np.maximum(p1, p2)
    d = y2 - y1  # difference between the parents for each gene

    # Calculate the extended lower and upper bounds for each gene.
    lower_bound = y1 - alpha_blend * d
    upper_bound = y2 + alpha_blend * d

    # Generate two sets of random numbers for each gene of each selected pair.
    rand1 = np.random.rand(p1.shape[0], D)
    rand2 = np.random.rand(p1.shape[0], D)

    # Create offspring within the extended range.
    c1 = lower_bound + rand1 * (upper_bound - lower_bound)
    c2 = lower_bound + rand2 * (upper_bound - lower_bound)

    # Assign the newly generated offspring back into the full child arrays.
    child1[do_cross, :] = c1
    child2[do_cross, :] = c2

    # Ensure offspring values stay within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
    child2 = np.clip(child2, min_values, max_values)

    return child1, child2


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    child2 = parents_dec_2.copy()

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # If no pairs are selected for crossover, return the copies.
    if not np.any(do_cross):
        return child1, child2

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()
    offspring2 = p2.copy()

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]
    offspring2[swap_mask] = p1[swap_mask]

    # Assign the offspring genes back to the full child arrays.
    child1[do_cross, :] = offspring1
    child2[do_cross, :] = offspring2

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
    child2 = np.clip(child2, min_values, max_values)

    # Return the generated offspring decision variables.
    return child1, child2





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec



# Cell 5: Complete NSGA-II Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual

class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0

    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]

    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    metrics_history = []

    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator
        if co == simulated_binary_crossover_batch:           
            sbx = SBX(prob=crossover_probability, eta=distribution_index_n_c)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            
            matings = []
            for p1, p2 in zip(parents_dec_1, parents_dec_2):
                matings.append([Individual(X=p1), Individual(X=p2)])
            
        
            offspring_pop = sbx.do(_prob, matings)           
            offspring_dec = offspring_pop.get("X")           
        
            child1_dec, child2_dec = offspring_dec[0::2], offspring_dec[1::2]


        elif co == single_point_crossover_batch:
            child1_dec, child2_dec = single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child1_dec, child2_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child1_dec, child2_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
 

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child1_dec = polynomial_mutation_batch(
                child1_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )
            child2_dec = polynomial_mutation_batch(
                child2_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )
        elif selected_mutation_operator == gaussian_mutation_batch:
            child1_dec = gaussian_mutation_batch(
                child1_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )
            child2_dec = gaussian_mutation_batch(
                child2_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )
        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        combined = np.vstack([child1_dec, child2_dec])
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            eval_result = problem.evaluate(combined, return_values_of=['F', 'G'])
            F = eval_result[0]
            G = eval_result[1]
            CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([combined, F, CV])
        else:
            eval_result = problem.evaluate(combined)
            if isinstance(eval_result, tuple):
                F = eval_result[0]
            else:
                F = eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([combined, F])
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx)


        pair_cnt = population_size // 2      # 50 pairs when pop_size = 100
        p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
        parents1 = population[p1_idx, :num_decision_variables]
        parents2 = population[p2_idx, :num_decision_variables]


        results = Parallel(n_jobs=len(crossover_ops))(
            delayed(apply_crossover_and_mutation)(
                op, parents1, parents2,
                selected_mutation_operator,
                mutation_probability,
                distribution_index_n_c,
                distribution_index_n_m,
                mutation_sigma,
                blend_alpha,
                swap_prob,
                min_values,
                max_values,
                crossover_probability
            ) for op in crossover_ops
        )

        
        # Separate offspring and operator labels into lists
        offspring_list = []
        operator_ids_list = []
        for res in results:
            offspring_list.append(res["offspring"])
            # Create an array filled with the operator name for each offspring row
            operator_ids_list.append(np.full(res["offspring"].shape[0], res["operator"]))
        
        # Combine offspring from all operators
        all_offspring = np.vstack(offspring_list)
        #all_operator_ids = np.concatenate(operator_ids_list)


        
        # Population combination and survival selection
        # Tag the original population with a default label (e.g., "parent")
        original_operator_ids = np.array(["parent"] * population.shape[0])
        
        # Combine the offspring from all operators
        combined_offspring = np.vstack(offspring_list)
        combined_operator_ids = np.concatenate([original_operator_ids, np.concatenate(operator_ids_list)])
        
        # Now combine the populations
        combined_pop = np.vstack([population, combined_offspring])
        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))

        for r in range(1, rank_combined.max()+1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx)

        # Environmental selection
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted([(i, crowding_combined[i]) for i in front_idx], 
                                    key=lambda x: -x[1])
                survivors.extend([i for i, _ in sorted_front[:population_size-len(survivors)]])
            current_rank += 1

        population = combined_pop[survivors]
        # Extract operator labels for the survivors
        surviving_operator_ids = combined_operator_ids[survivors]
        
        # Compute counts of survivors per operator
        unique, counts = np.unique(surviving_operator_ids, return_counts=True)
        survival_stats = dict(zip(unique, counts))
        print("Survival counts by operator:", survival_stats)

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time
            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    return population, problem.pareto_front(), metrics_history



#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts using Pymoo data

    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib

# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    

    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history = run_nsga2(
        problem=problem,  # Single problem parameter
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points
    }

# Run NSGA-II in series for seeds 1 to 30 (or 31 if you prefer 1 to 31)
seeds = range(1, 31)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    
    # Note: Plotting in parallel jobs might sometimes cause issues due to thread/process conflicts.
    # It may be safer to collect the pareto_points and plot them serially here.
    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],
            
            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
            
        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# Survival counts by operator: {np.str_('parent'): np.int64(38), np.str_('simulated_binary_crossover_batch'): np.int64(62)}
#
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
#
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.4654, gd_plus=2.4654, igd_plus=1.9687, spacing=0.2359, generation=1.0000, generation_time=0.0091
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 2: hypervolume=0.0000, igd=1.6477, gd=2.3459, gd_plus=2.3459, igd_plus=1.6477, spacing=0.1841, generation=2.0000, generation_time=0.0091
# Survival counts by operator: {np.str_('parent'): np.int64(39), np.str_('simulated_binary_crossover_batch'): np.int64(61)}
# Gen 3: hypervolume=0.0000, igd=1.3902, gd=2.5393, gd_plus=2.5393, igd_plus=1.3898, spacing=0.2368, generation=3.0000, generation_time=0.0074
# Survival counts by operator: {np.str_('parent'): np.int64(39), np.str_('simulated_binary_crossover_batch'): np.int64(61)}
# Gen 4: hypervolume=0.0000, igd=1.3902, gd=2.0900, gd_plus=2.0900, igd_plus=1.3898, spacing=0.0873, generation=4.0000, generation_time=0.0100
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(58)}
# Gen 5: hypervolume=0.0000, igd=1.3902, gd=2.1077, gd_plus=2.1077, igd_plus=1.3898, spacing=0.0932, generation=5.0000, generation_time=0.0092
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(56)}
# Gen 6: hypervolume=0.0000, igd=1.2324, gd=2.0359, gd_plus=2.0359, igd_plus=1.2320, spacing=0.0741, generation=6.0000, generation_time=0.0164
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(54)}
# Gen 7: hypervolume=0.0000, igd=1.2283, gd=1.5711, gd_plus=1.5711, igd_plus=1.2279, spacing=0.1442, generation=7.0000, generation_time=0.0058
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(58)}
# Gen 8: hypervolume=0.0000, igd=1.1081, gd=1.5493, gd_plus=1.5493, igd_plus=1.1077, spacing=0.0667, generation=8.0000, generation_time=0.0087
# Survival counts by operator: {np.str_('parent'): np.int64(38), np.str_('simulated_binary_crossover_batch'): np.int64(62)}
# Gen 9: hypervolume=0.0000, igd=1.1010, gd=1.3020, gd_plus=1.3020, igd_plus=1.1006, spacing=0.0731, generation=9.0000, generation_time=0.0073
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 10: hypervolume=0.0072, igd=0.8365, gd=1.2721, gd_plus=1.2721, igd_plus=0.8365, spacing=0.1202, generation=10.0000, generation_time=0.0062
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(55)}
# Gen 11: hypervolume=0.0170, igd=0.8054, gd=1.2328, gd_plus=1.2328, igd_plus=0.8054, spacing=0.0767, generation=11.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(54)}
# Gen 12: hypervolume=0.0188, igd=0.8005, gd=1.0574, gd_plus=1.0574, igd_plus=0.8005, spacing=0.0745, generation=12.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 13: hypervolume=0.0628, igd=0.7353, gd=1.1467, gd_plus=1.1467, igd_plus=0.7339, spacing=0.0633, generation=13.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(55)}
# Gen 14: hypervolume=0.0646, igd=0.7288, gd=0.9934, gd_plus=0.9934, igd_plus=0.7282, spacing=0.0695, generation=14.0000, generation_time=0.0076
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(55)}
# Gen 15: hypervolume=0.0833, igd=0.6991, gd=0.8172, gd_plus=0.8172, igd_plus=0.6985, spacing=0.0917, generation=15.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(59)}
# Gen 16: hypervolume=0.1519, igd=0.5679, gd=0.8132, gd_plus=0.8132, igd_plus=0.5679, spacing=0.0609, generation=16.0000, generation_time=0.0059
# Survival counts by operator: {np.str_('parent'): np.int64(38), np.str_('simulated_binary_crossover_batch'): np.int64(62)}
# Gen 17: hypervolume=0.1696, igd=0.5590, gd=0.7614, gd_plus=0.7614, igd_plus=0.5589, spacing=0.0627, generation=17.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(54)}
# Gen 18: hypervolume=0.1919, igd=0.5330, gd=0.7077, gd_plus=0.7077, igd_plus=0.5330, spacing=0.0530, generation=18.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 19: hypervolume=0.2240, igd=0.4938, gd=0.6389, gd_plus=0.6389, igd_plus=0.4937, spacing=0.0506, generation=19.0000, generation_time=0.0074
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(49)}
# Gen 20: hypervolume=0.2449, igd=0.4765, gd=0.6141, gd_plus=0.6141, igd_plus=0.4764, spacing=0.0392, generation=20.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(58)}
# Gen 21: hypervolume=0.2880, igd=0.4123, gd=0.5519, gd_plus=0.5519, igd_plus=0.4122, spacing=0.0778, generation=21.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(58)}
# Gen 22: hypervolume=0.3153, igd=0.3810, gd=0.5006, gd_plus=0.5006, igd_plus=0.3809, spacing=0.0293, generation=22.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 23: hypervolume=0.3441, igd=0.3621, gd=0.4753, gd_plus=0.4753, igd_plus=0.3621, spacing=0.0289, generation=23.0000, generation_time=0.0071
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 24: hypervolume=0.3526, igd=0.3593, gd=0.4262, gd_plus=0.4262, igd_plus=0.3593, spacing=0.0329, generation=24.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(56)}
# Gen 25: hypervolume=0.3690, igd=0.3424, gd=0.3686, gd_plus=0.3686, igd_plus=0.3423, spacing=0.0208, generation=25.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 26: hypervolume=0.4028, igd=0.3069, gd=0.3473, gd_plus=0.3473, igd_plus=0.3068, spacing=0.0358, generation=26.0000, generation_time=0.0061
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 27: hypervolume=0.4248, igd=0.2903, gd=0.3472, gd_plus=0.3472, igd_plus=0.2902, spacing=0.0323, generation=27.0000, generation_time=0.0081
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 28: hypervolume=0.4433, igd=0.2747, gd=0.3516, gd_plus=0.3516, igd_plus=0.2746, spacing=0.0438, generation=28.0000, generation_time=0.0078
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 29: hypervolume=0.4618, igd=0.2657, gd=0.3453, gd_plus=0.3453, igd_plus=0.2656, spacing=0.0459, generation=29.0000, generation_time=0.0057
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 30: hypervolume=0.4835, igd=0.2509, gd=0.3072, gd_plus=0.3072, igd_plus=0.2508, spacing=0.0274, generation=30.0000, generation_time=0.0059
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(54)}
# Gen 31: hypervolume=0.4996, igd=0.2431, gd=0.2708, gd_plus=0.2708, igd_plus=0.2429, spacing=0.0213, generation=31.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(49)}
# Gen 32: hypervolume=0.5151, igd=0.2327, gd=0.2739, gd_plus=0.2738, igd_plus=0.2322, spacing=0.0278, generation=32.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(50)}
# Gen 33: hypervolume=0.5273, igd=0.2253, gd=0.2456, gd_plus=0.2456, igd_plus=0.2249, spacing=0.0230, generation=33.0000, generation_time=0.0070
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 34: hypervolume=0.5391, igd=0.2198, gd=0.2445, gd_plus=0.2445, igd_plus=0.2198, spacing=0.0206, generation=34.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(46)}
# Gen 35: hypervolume=0.5468, igd=0.2135, gd=0.2160, gd_plus=0.2160, igd_plus=0.2135, spacing=0.0236, generation=35.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(48)}
# Gen 36: hypervolume=0.5588, igd=0.2057, gd=0.2157, gd_plus=0.2157, igd_plus=0.2057, spacing=0.0237, generation=36.0000, generation_time=0.0079
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(55)}
# Gen 37: hypervolume=0.5741, igd=0.1953, gd=0.2079, gd_plus=0.2079, igd_plus=0.1953, spacing=0.0272, generation=37.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 38: hypervolume=0.5847, igd=0.1892, gd=0.2128, gd_plus=0.2127, igd_plus=0.1892, spacing=0.0182, generation=38.0000, generation_time=0.0058
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(43)}
# Gen 39: hypervolume=0.5992, igd=0.1764, gd=0.1821, gd_plus=0.1819, igd_plus=0.1764, spacing=0.0205, generation=39.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(48)}
# Gen 40: hypervolume=0.6246, igd=0.1553, gd=0.1630, gd_plus=0.1628, igd_plus=0.1543, spacing=0.0177, generation=40.0000, generation_time=0.0077
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(48)}
# Gen 41: hypervolume=0.6369, igd=0.1474, gd=0.1549, gd_plus=0.1546, igd_plus=0.1464, spacing=0.0168, generation=41.0000, generation_time=0.0085
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(53)}
# Gen 42: hypervolume=0.6482, igd=0.1395, gd=0.1454, gd_plus=0.1454, igd_plus=0.1385, spacing=0.0173, generation=42.0000, generation_time=0.0067
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(50)}
# Gen 43: hypervolume=0.6601, igd=0.1344, gd=0.1417, gd_plus=0.1415, igd_plus=0.1334, spacing=0.0175, generation=43.0000, generation_time=0.0065
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(45)}
# Gen 44: hypervolume=0.6678, igd=0.1302, gd=0.1308, gd_plus=0.1303, igd_plus=0.1282, spacing=0.0208, generation=44.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(51)}
# Gen 45: hypervolume=0.6814, igd=0.1204, gd=0.1264, gd_plus=0.1261, igd_plus=0.1181, spacing=0.0150, generation=45.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(50)}
# Gen 46: hypervolume=0.6907, igd=0.1144, gd=0.1114, gd_plus=0.1112, igd_plus=0.1121, spacing=0.0183, generation=46.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(49)}
# Gen 47: hypervolume=0.7001, igd=0.1091, gd=0.1061, gd_plus=0.1059, igd_plus=0.1066, spacing=0.0155, generation=47.0000, generation_time=0.0067
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(47)}
# Gen 48: hypervolume=0.7100, igd=0.1025, gd=0.0959, gd_plus=0.0954, igd_plus=0.1000, spacing=0.0164, generation=48.0000, generation_time=0.0065
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(46)}
# Gen 49: hypervolume=0.7187, igd=0.0963, gd=0.0919, gd_plus=0.0912, igd_plus=0.0941, spacing=0.0189, generation=49.0000, generation_time=0.0069
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(48)}
# Gen 50: hypervolume=0.7304, igd=0.0874, gd=0.0865, gd_plus=0.0857, igd_plus=0.0868, spacing=0.0177, generation=50.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(52)}
# Gen 51: hypervolume=0.7386, igd=0.0829, gd=0.0876, gd_plus=0.0875, igd_plus=0.0823, spacing=0.0159, generation=51.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(50)}
# Gen 52: hypervolume=0.7452, igd=0.0787, gd=0.0811, gd_plus=0.0809, igd_plus=0.0781, spacing=0.0148, generation=52.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(43)}
# Gen 53: hypervolume=0.7550, igd=0.0736, gd=0.0744, gd_plus=0.0741, igd_plus=0.0712, spacing=0.0173, generation=53.0000, generation_time=0.0083
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(40)}
# Gen 54: hypervolume=0.7625, igd=0.0689, gd=0.0693, gd_plus=0.0686, igd_plus=0.0665, spacing=0.0165, generation=54.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(50)}
# Gen 55: hypervolume=0.7668, igd=0.0673, gd=0.0648, gd_plus=0.0634, igd_plus=0.0648, spacing=0.0158, generation=55.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(44)}
# Gen 56: hypervolume=0.7709, igd=0.0645, gd=0.0627, gd_plus=0.0614, igd_plus=0.0620, spacing=0.0115, generation=56.0000, generation_time=0.0057
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(39)}
# Gen 57: hypervolume=0.7737, igd=0.0634, gd=0.0588, gd_plus=0.0582, igd_plus=0.0609, spacing=0.0101, generation=57.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(37)}
# Gen 58: hypervolume=0.7779, igd=0.0616, gd=0.0574, gd_plus=0.0568, igd_plus=0.0592, spacing=0.0113, generation=58.0000, generation_time=0.0064
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(45)}
# Gen 59: hypervolume=0.7838, igd=0.0574, gd=0.0532, gd_plus=0.0520, igd_plus=0.0549, spacing=0.0122, generation=59.0000, generation_time=0.0064
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(45)}
# Gen 60: hypervolume=0.7872, igd=0.0548, gd=0.0491, gd_plus=0.0481, igd_plus=0.0522, spacing=0.0117, generation=60.0000, generation_time=0.0076
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(46)}
# Gen 61: hypervolume=0.7916, igd=0.0522, gd=0.0470, gd_plus=0.0463, igd_plus=0.0495, spacing=0.0109, generation=61.0000, generation_time=0.0072
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(40)}
# Gen 62: hypervolume=0.7942, igd=0.0505, gd=0.0447, gd_plus=0.0441, igd_plus=0.0478, spacing=0.0099, generation=62.0000, generation_time=0.0069
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(44)}
# Gen 63: hypervolume=0.7974, igd=0.0488, gd=0.0457, gd_plus=0.0451, igd_plus=0.0460, spacing=0.0092, generation=63.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(59), np.str_('simulated_binary_crossover_batch'): np.int64(41)}
# Gen 64: hypervolume=0.8002, igd=0.0474, gd=0.0444, gd_plus=0.0435, igd_plus=0.0446, spacing=0.0080, generation=64.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(37)}
# Gen 65: hypervolume=0.8048, igd=0.0453, gd=0.0414, gd_plus=0.0405, igd_plus=0.0417, spacing=0.0087, generation=65.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(37)}
# Gen 66: hypervolume=0.8073, igd=0.0435, gd=0.0396, gd_plus=0.0385, igd_plus=0.0398, spacing=0.0082, generation=66.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(38)}
# Gen 67: hypervolume=0.8101, igd=0.0421, gd=0.0381, gd_plus=0.0372, igd_plus=0.0383, spacing=0.0066, generation=67.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(39)}
# Gen 68: hypervolume=0.8124, igd=0.0407, gd=0.0365, gd_plus=0.0354, igd_plus=0.0371, spacing=0.0073, generation=68.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(38)}
# Gen 69: hypervolume=0.8147, igd=0.0391, gd=0.0336, gd_plus=0.0325, igd_plus=0.0354, spacing=0.0070, generation=69.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(39)}
# Gen 70: hypervolume=0.8164, igd=0.0377, gd=0.0321, gd_plus=0.0309, igd_plus=0.0345, spacing=0.0070, generation=70.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 71: hypervolume=0.8173, igd=0.0371, gd=0.0320, gd_plus=0.0307, igd_plus=0.0340, spacing=0.0060, generation=71.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 72: hypervolume=0.8191, igd=0.0360, gd=0.0296, gd_plus=0.0281, igd_plus=0.0329, spacing=0.0066, generation=72.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 73: hypervolume=0.8269, igd=0.0291, gd=0.0274, gd_plus=0.0262, igd_plus=0.0281, spacing=0.0091, generation=73.0000, generation_time=0.0059
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 74: hypervolume=0.8296, igd=0.0272, gd=0.0263, gd_plus=0.0251, igd_plus=0.0265, spacing=0.0077, generation=74.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 75: hypervolume=0.8309, igd=0.0265, gd=0.0256, gd_plus=0.0244, igd_plus=0.0257, spacing=0.0070, generation=75.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 76: hypervolume=0.8354, igd=0.0237, gd=0.0246, gd_plus=0.0234, igd_plus=0.0236, spacing=0.0075, generation=76.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 77: hypervolume=0.8363, igd=0.0232, gd=0.0243, gd_plus=0.0231, igd_plus=0.0231, spacing=0.0074, generation=77.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(38)}
# Gen 78: hypervolume=0.8373, igd=0.0226, gd=0.0238, gd_plus=0.0226, igd_plus=0.0225, spacing=0.0075, generation=78.0000, generation_time=0.0059
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 79: hypervolume=0.8386, igd=0.0219, gd=0.0230, gd_plus=0.0218, igd_plus=0.0217, spacing=0.0072, generation=79.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 80: hypervolume=0.8394, igd=0.0212, gd=0.0222, gd_plus=0.0213, igd_plus=0.0211, spacing=0.0061, generation=80.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 81: hypervolume=0.8403, igd=0.0208, gd=0.0218, gd_plus=0.0207, igd_plus=0.0205, spacing=0.0065, generation=81.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 82: hypervolume=0.8410, igd=0.0204, gd=0.0212, gd_plus=0.0201, igd_plus=0.0201, spacing=0.0064, generation=82.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 83: hypervolume=0.8414, igd=0.0200, gd=0.0205, gd_plus=0.0191, igd_plus=0.0198, spacing=0.0062, generation=83.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(36)}
# Gen 84: hypervolume=0.8422, igd=0.0196, gd=0.0198, gd_plus=0.0185, igd_plus=0.0193, spacing=0.0071, generation=84.0000, generation_time=0.0061
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 85: hypervolume=0.8434, igd=0.0189, gd=0.0196, gd_plus=0.0182, igd_plus=0.0187, spacing=0.0063, generation=85.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 86: hypervolume=0.8444, igd=0.0184, gd=0.0191, gd_plus=0.0177, igd_plus=0.0182, spacing=0.0061, generation=86.0000, generation_time=0.0066
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 87: hypervolume=0.8450, igd=0.0180, gd=0.0185, gd_plus=0.0171, igd_plus=0.0179, spacing=0.0072, generation=87.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 88: hypervolume=0.8460, igd=0.0174, gd=0.0180, gd_plus=0.0167, igd_plus=0.0172, spacing=0.0078, generation=88.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 89: hypervolume=0.8468, igd=0.0169, gd=0.0178, gd_plus=0.0165, igd_plus=0.0168, spacing=0.0074, generation=89.0000, generation_time=0.0071
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 90: hypervolume=0.8470, igd=0.0169, gd=0.0177, gd_plus=0.0163, igd_plus=0.0167, spacing=0.0069, generation=90.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 91: hypervolume=0.8477, igd=0.0165, gd=0.0170, gd_plus=0.0156, igd_plus=0.0163, spacing=0.0069, generation=91.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(39)}
# Gen 92: hypervolume=0.8487, igd=0.0158, gd=0.0162, gd_plus=0.0153, igd_plus=0.0156, spacing=0.0072, generation=92.0000, generation_time=0.0072
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 93: hypervolume=0.8492, igd=0.0155, gd=0.0162, gd_plus=0.0149, igd_plus=0.0153, spacing=0.0074, generation=93.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 94: hypervolume=0.8498, igd=0.0151, gd=0.0159, gd_plus=0.0146, igd_plus=0.0148, spacing=0.0067, generation=94.0000, generation_time=0.0061
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 95: hypervolume=0.8504, igd=0.0150, gd=0.0157, gd_plus=0.0143, igd_plus=0.0146, spacing=0.0070, generation=95.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 96: hypervolume=0.8507, igd=0.0146, gd=0.0155, gd_plus=0.0141, igd_plus=0.0143, spacing=0.0059, generation=96.0000, generation_time=0.0067
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 97: hypervolume=0.8509, igd=0.0145, gd=0.0152, gd_plus=0.0141, igd_plus=0.0142, spacing=0.0064, generation=97.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 98: hypervolume=0.8522, igd=0.0139, gd=0.0150, gd_plus=0.0135, igd_plus=0.0137, spacing=0.0074, generation=98.0000, generation_time=0.0064
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 99: hypervolume=0.8527, igd=0.0136, gd=0.0144, gd_plus=0.0133, igd_plus=0.0134, spacing=0.0068, generation=99.0000, generation_time=0.0058
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 100: hypervolume=0.8531, igd=0.0134, gd=0.0145, gd_plus=0.0131, igd_plus=0.0132, spacing=0.0063, generation=100.0000, generation_time=0.0064
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 101: hypervolume=0.8537, igd=0.0130, gd=0.0140, gd_plus=0.0127, igd_plus=0.0128, spacing=0.0058, generation=101.0000, generation_time=0.0068
# Survival counts by operator: {np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 102: hypervolume=0.8538, igd=0.0130, gd=0.0139, gd_plus=0.0125, igd_plus=0.0128, spacing=0.0076, generation=102.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 103: hypervolume=0.8538, igd=0.0129, gd=0.0138, gd_plus=0.0123, igd_plus=0.0128, spacing=0.0081, generation=103.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(25)}
# Gen 104: hypervolume=0.8541, igd=0.0126, gd=0.0133, gd_plus=0.0121, igd_plus=0.0125, spacing=0.0070, generation=104.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 105: hypervolume=0.8542, igd=0.0125, gd=0.0132, gd_plus=0.0120, igd_plus=0.0124, spacing=0.0066, generation=105.0000, generation_time=0.0046
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 106: hypervolume=0.8542, igd=0.0126, gd=0.0128, gd_plus=0.0119, igd_plus=0.0124, spacing=0.0070, generation=106.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(38)}
# Gen 107: hypervolume=0.8546, igd=0.0125, gd=0.0130, gd_plus=0.0117, igd_plus=0.0123, spacing=0.0078, generation=107.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 108: hypervolume=0.8551, igd=0.0123, gd=0.0129, gd_plus=0.0115, igd_plus=0.0121, spacing=0.0074, generation=108.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 109: hypervolume=0.8557, igd=0.0118, gd=0.0121, gd_plus=0.0112, igd_plus=0.0116, spacing=0.0075, generation=109.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 110: hypervolume=0.8559, igd=0.0116, gd=0.0119, gd_plus=0.0110, igd_plus=0.0115, spacing=0.0076, generation=110.0000, generation_time=0.0091
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(37)}
# Gen 111: hypervolume=0.8566, igd=0.0112, gd=0.0117, gd_plus=0.0108, igd_plus=0.0110, spacing=0.0069, generation=111.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 112: hypervolume=0.8570, igd=0.0110, gd=0.0114, gd_plus=0.0104, igd_plus=0.0109, spacing=0.0067, generation=112.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 113: hypervolume=0.8572, igd=0.0110, gd=0.0112, gd_plus=0.0102, igd_plus=0.0108, spacing=0.0068, generation=113.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 114: hypervolume=0.8575, igd=0.0108, gd=0.0114, gd_plus=0.0100, igd_plus=0.0106, spacing=0.0072, generation=114.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 115: hypervolume=0.8581, igd=0.0105, gd=0.0112, gd_plus=0.0097, igd_plus=0.0103, spacing=0.0069, generation=115.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 116: hypervolume=0.8583, igd=0.0102, gd=0.0109, gd_plus=0.0095, igd_plus=0.0100, spacing=0.0071, generation=116.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 117: hypervolume=0.8584, igd=0.0099, gd=0.0108, gd_plus=0.0093, igd_plus=0.0098, spacing=0.0063, generation=117.0000, generation_time=0.0065
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 118: hypervolume=0.8589, igd=0.0097, gd=0.0104, gd_plus=0.0090, igd_plus=0.0095, spacing=0.0057, generation=118.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 119: hypervolume=0.8588, igd=0.0097, gd=0.0104, gd_plus=0.0090, igd_plus=0.0095, spacing=0.0056, generation=119.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 120: hypervolume=0.8589, igd=0.0097, gd=0.0103, gd_plus=0.0089, igd_plus=0.0095, spacing=0.0059, generation=120.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 121: hypervolume=0.8593, igd=0.0096, gd=0.0102, gd_plus=0.0088, igd_plus=0.0094, spacing=0.0062, generation=121.0000, generation_time=0.0078
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 122: hypervolume=0.8596, igd=0.0092, gd=0.0101, gd_plus=0.0086, igd_plus=0.0091, spacing=0.0066, generation=122.0000, generation_time=0.0062
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 123: hypervolume=0.8601, igd=0.0090, gd=0.0100, gd_plus=0.0084, igd_plus=0.0088, spacing=0.0071, generation=123.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 124: hypervolume=0.8605, igd=0.0088, gd=0.0095, gd_plus=0.0084, igd_plus=0.0086, spacing=0.0064, generation=124.0000, generation_time=0.0056
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 125: hypervolume=0.8605, igd=0.0089, gd=0.0096, gd_plus=0.0084, igd_plus=0.0087, spacing=0.0066, generation=125.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(25)}
# Gen 126: hypervolume=0.8606, igd=0.0088, gd=0.0094, gd_plus=0.0082, igd_plus=0.0086, spacing=0.0070, generation=126.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 127: hypervolume=0.8609, igd=0.0086, gd=0.0095, gd_plus=0.0080, igd_plus=0.0084, spacing=0.0066, generation=127.0000, generation_time=0.0065
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 128: hypervolume=0.8613, igd=0.0086, gd=0.0096, gd_plus=0.0078, igd_plus=0.0082, spacing=0.0062, generation=128.0000, generation_time=0.0058
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 129: hypervolume=0.8615, igd=0.0083, gd=0.0090, gd_plus=0.0074, igd_plus=0.0081, spacing=0.0068, generation=129.0000, generation_time=0.0069
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 130: hypervolume=0.8620, igd=0.0080, gd=0.0088, gd_plus=0.0072, igd_plus=0.0077, spacing=0.0065, generation=130.0000, generation_time=0.0081
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 131: hypervolume=0.8621, igd=0.0079, gd=0.0088, gd_plus=0.0072, igd_plus=0.0077, spacing=0.0060, generation=131.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 132: hypervolume=0.8623, igd=0.0076, gd=0.0082, gd_plus=0.0071, igd_plus=0.0074, spacing=0.0064, generation=132.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(78), np.str_('simulated_binary_crossover_batch'): np.int64(22)}
# Gen 133: hypervolume=0.8622, igd=0.0077, gd=0.0083, gd_plus=0.0071, igd_plus=0.0075, spacing=0.0072, generation=133.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 134: hypervolume=0.8624, igd=0.0076, gd=0.0080, gd_plus=0.0070, igd_plus=0.0074, spacing=0.0071, generation=134.0000, generation_time=0.0063
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 135: hypervolume=0.8625, igd=0.0078, gd=0.0082, gd_plus=0.0069, igd_plus=0.0075, spacing=0.0071, generation=135.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 136: hypervolume=0.8627, igd=0.0078, gd=0.0081, gd_plus=0.0069, igd_plus=0.0074, spacing=0.0061, generation=136.0000, generation_time=0.0057
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 137: hypervolume=0.8631, igd=0.0075, gd=0.0083, gd_plus=0.0068, igd_plus=0.0072, spacing=0.0063, generation=137.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(37)}
# Gen 138: hypervolume=0.8632, igd=0.0075, gd=0.0083, gd_plus=0.0067, igd_plus=0.0072, spacing=0.0061, generation=138.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 139: hypervolume=0.8633, igd=0.0074, gd=0.0082, gd_plus=0.0066, igd_plus=0.0071, spacing=0.0063, generation=139.0000, generation_time=0.0072
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 140: hypervolume=0.8633, igd=0.0074, gd=0.0081, gd_plus=0.0066, igd_plus=0.0070, spacing=0.0068, generation=140.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 141: hypervolume=0.8634, igd=0.0073, gd=0.0076, gd_plus=0.0066, igd_plus=0.0071, spacing=0.0075, generation=141.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 142: hypervolume=0.8634, igd=0.0074, gd=0.0077, gd_plus=0.0064, igd_plus=0.0071, spacing=0.0069, generation=142.0000, generation_time=0.0050
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 143: hypervolume=0.8633, igd=0.0076, gd=0.0077, gd_plus=0.0065, igd_plus=0.0071, spacing=0.0070, generation=143.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 144: hypervolume=0.8637, igd=0.0073, gd=0.0077, gd_plus=0.0061, igd_plus=0.0068, spacing=0.0068, generation=144.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 145: hypervolume=0.8642, igd=0.0069, gd=0.0077, gd_plus=0.0061, igd_plus=0.0065, spacing=0.0061, generation=145.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 146: hypervolume=0.8640, igd=0.0069, gd=0.0073, gd_plus=0.0060, igd_plus=0.0065, spacing=0.0058, generation=146.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(36)}
# Gen 147: hypervolume=0.8639, igd=0.0070, gd=0.0074, gd_plus=0.0060, igd_plus=0.0065, spacing=0.0064, generation=147.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 148: hypervolume=0.8640, igd=0.0068, gd=0.0076, gd_plus=0.0059, igd_plus=0.0065, spacing=0.0064, generation=148.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 149: hypervolume=0.8643, igd=0.0068, gd=0.0078, gd_plus=0.0059, igd_plus=0.0064, spacing=0.0063, generation=149.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 150: hypervolume=0.8642, igd=0.0068, gd=0.0075, gd_plus=0.0058, igd_plus=0.0064, spacing=0.0068, generation=150.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 151: hypervolume=0.8644, igd=0.0067, gd=0.0077, gd_plus=0.0060, igd_plus=0.0064, spacing=0.0069, generation=151.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 152: hypervolume=0.8646, igd=0.0065, gd=0.0074, gd_plus=0.0059, igd_plus=0.0062, spacing=0.0065, generation=152.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 153: hypervolume=0.8647, igd=0.0066, gd=0.0075, gd_plus=0.0058, igd_plus=0.0062, spacing=0.0069, generation=153.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 154: hypervolume=0.8647, igd=0.0067, gd=0.0070, gd_plus=0.0056, igd_plus=0.0062, spacing=0.0072, generation=154.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 155: hypervolume=0.8649, igd=0.0065, gd=0.0067, gd_plus=0.0054, igd_plus=0.0060, spacing=0.0076, generation=155.0000, generation_time=0.0060
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 156: hypervolume=0.8653, igd=0.0062, gd=0.0068, gd_plus=0.0055, igd_plus=0.0058, spacing=0.0074, generation=156.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 157: hypervolume=0.8657, igd=0.0060, gd=0.0067, gd_plus=0.0053, igd_plus=0.0056, spacing=0.0068, generation=157.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 158: hypervolume=0.8657, igd=0.0060, gd=0.0071, gd_plus=0.0052, igd_plus=0.0055, spacing=0.0065, generation=158.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 159: hypervolume=0.8658, igd=0.0060, gd=0.0070, gd_plus=0.0051, igd_plus=0.0056, spacing=0.0072, generation=159.0000, generation_time=0.0047
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 160: hypervolume=0.8656, igd=0.0062, gd=0.0070, gd_plus=0.0050, igd_plus=0.0057, spacing=0.0079, generation=160.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 161: hypervolume=0.8658, igd=0.0062, gd=0.0071, gd_plus=0.0049, igd_plus=0.0057, spacing=0.0075, generation=161.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 162: hypervolume=0.8659, igd=0.0061, gd=0.0069, gd_plus=0.0049, igd_plus=0.0056, spacing=0.0084, generation=162.0000, generation_time=0.0057
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 163: hypervolume=0.8661, igd=0.0061, gd=0.0068, gd_plus=0.0050, igd_plus=0.0055, spacing=0.0075, generation=163.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 164: hypervolume=0.8658, igd=0.0064, gd=0.0069, gd_plus=0.0051, igd_plus=0.0057, spacing=0.0074, generation=164.0000, generation_time=0.0093
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 165: hypervolume=0.8660, igd=0.0062, gd=0.0070, gd_plus=0.0050, igd_plus=0.0055, spacing=0.0070, generation=165.0000, generation_time=0.0083
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 166: hypervolume=0.8660, igd=0.0061, gd=0.0068, gd_plus=0.0049, igd_plus=0.0055, spacing=0.0071, generation=166.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 167: hypervolume=0.8660, igd=0.0061, gd=0.0066, gd_plus=0.0048, igd_plus=0.0055, spacing=0.0075, generation=167.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 168: hypervolume=0.8660, igd=0.0062, gd=0.0068, gd_plus=0.0047, igd_plus=0.0055, spacing=0.0067, generation=168.0000, generation_time=0.0058
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 169: hypervolume=0.8664, igd=0.0060, gd=0.0067, gd_plus=0.0047, igd_plus=0.0053, spacing=0.0068, generation=169.0000, generation_time=0.0089
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 170: hypervolume=0.8665, igd=0.0061, gd=0.0068, gd_plus=0.0046, igd_plus=0.0053, spacing=0.0073, generation=170.0000, generation_time=0.0077
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(36)}
# Gen 171: hypervolume=0.8667, igd=0.0060, gd=0.0067, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0071, generation=171.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 172: hypervolume=0.8668, igd=0.0059, gd=0.0067, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0075, generation=172.0000, generation_time=0.0068
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 173: hypervolume=0.8672, igd=0.0058, gd=0.0066, gd_plus=0.0048, igd_plus=0.0051, spacing=0.0077, generation=173.0000, generation_time=0.0072
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 174: hypervolume=0.8674, igd=0.0055, gd=0.0062, gd_plus=0.0046, igd_plus=0.0049, spacing=0.0074, generation=174.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 175: hypervolume=0.8671, igd=0.0059, gd=0.0063, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0073, generation=175.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 176: hypervolume=0.8672, igd=0.0059, gd=0.0060, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0080, generation=176.0000, generation_time=0.0062
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 177: hypervolume=0.8671, igd=0.0060, gd=0.0068, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0079, generation=177.0000, generation_time=0.0059
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 178: hypervolume=0.8673, igd=0.0056, gd=0.0063, gd_plus=0.0047, igd_plus=0.0050, spacing=0.0066, generation=178.0000, generation_time=0.0082
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 179: hypervolume=0.8671, igd=0.0056, gd=0.0065, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0072, generation=179.0000, generation_time=0.0071
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 180: hypervolume=0.8673, igd=0.0055, gd=0.0064, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0067, generation=180.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 181: hypervolume=0.8673, igd=0.0057, gd=0.0065, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0061, generation=181.0000, generation_time=0.0052
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 182: hypervolume=0.8675, igd=0.0057, gd=0.0064, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0064, generation=182.0000, generation_time=0.0077
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 183: hypervolume=0.8676, igd=0.0057, gd=0.0063, gd_plus=0.0044, igd_plus=0.0050, spacing=0.0074, generation=183.0000, generation_time=0.0063
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 184: hypervolume=0.8675, igd=0.0058, gd=0.0067, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0064, generation=184.0000, generation_time=0.0063
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 185: hypervolume=0.8675, igd=0.0057, gd=0.0061, gd_plus=0.0042, igd_plus=0.0049, spacing=0.0073, generation=185.0000, generation_time=0.0070
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(38)}
# Gen 186: hypervolume=0.8676, igd=0.0056, gd=0.0060, gd_plus=0.0042, igd_plus=0.0049, spacing=0.0068, generation=186.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 187: hypervolume=0.8676, igd=0.0056, gd=0.0060, gd_plus=0.0041, igd_plus=0.0048, spacing=0.0071, generation=187.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 188: hypervolume=0.8678, igd=0.0055, gd=0.0060, gd_plus=0.0041, igd_plus=0.0047, spacing=0.0069, generation=188.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 189: hypervolume=0.8680, igd=0.0055, gd=0.0061, gd_plus=0.0042, igd_plus=0.0047, spacing=0.0075, generation=189.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 190: hypervolume=0.8674, igd=0.0059, gd=0.0067, gd_plus=0.0043, igd_plus=0.0049, spacing=0.0077, generation=190.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 191: hypervolume=0.8677, igd=0.0057, gd=0.0060, gd_plus=0.0042, igd_plus=0.0048, spacing=0.0074, generation=191.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 192: hypervolume=0.8679, igd=0.0055, gd=0.0061, gd_plus=0.0041, igd_plus=0.0046, spacing=0.0072, generation=192.0000, generation_time=0.0055
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 193: hypervolume=0.8681, igd=0.0055, gd=0.0061, gd_plus=0.0041, igd_plus=0.0045, spacing=0.0077, generation=193.0000, generation_time=0.0062
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 194: hypervolume=0.8681, igd=0.0053, gd=0.0057, gd_plus=0.0041, igd_plus=0.0045, spacing=0.0073, generation=194.0000, generation_time=0.0053
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 195: hypervolume=0.8682, igd=0.0051, gd=0.0055, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0077, generation=195.0000, generation_time=0.0048
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 196: hypervolume=0.8680, igd=0.0054, gd=0.0054, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0076, generation=196.0000, generation_time=0.0049
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(35)}
# Gen 197: hypervolume=0.8682, igd=0.0051, gd=0.0053, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0074, generation=197.0000, generation_time=0.0054
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 198: hypervolume=0.8684, igd=0.0051, gd=0.0056, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0058, generation=198.0000, generation_time=0.0065
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 199: hypervolume=0.8684, igd=0.0053, gd=0.0059, gd_plus=0.0038, igd_plus=0.0044, spacing=0.0064, generation=199.0000, generation_time=0.0051
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 200: hypervolume=0.8684, igd=0.0053, gd=0.0055, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0065, generation=200.0000, generation_time=0.0071
# Seed 1 - Number of Pareto front points: 100

# %%
### Cell 8: Save Combined Metrics History to Excel 
import pandas as pd
import re

# Convert the all_metrics list to DataFrame
df_metrics = pd.DataFrame(all_metrics)

# Sanitize problem name for filename
problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()


# Define a mapping from the full crossover operator names to shortcuts
crossover_shortcuts = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
     "single_point_crossover_batch": "spx",
     "uniform_crossover_batch": "ux"
}

# Convert selected crossover operator names to their shortcut representation
selected_crossover_shortcut_names = [
    crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
]

# Join the shortcuts into a single string (e.g., "sbx-blx")
crossover_str = "-".join(selected_crossover_shortcut_names)

# Create valid filename
excel_filename = (
    f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross poly "
    f"{pop_size}pop {generations}gen  Baseline NSGA2.xlsx"
)

#{crossover_str}

# Save to Excel
df_metrics.to_excel(excel_filename, index=False)
print(f"Metrics saved to '{excel_filename}'")
# Out:
# Metrics saved to 'zdt1 1 sbx cross poly 100pop 200gen  Baseline NSGA2.xlsx'

# %%
# Select Crossover and Mutation Operators
# List all desired crossover operators to be applied in parallel.
selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    "single_point_crossover_batch",
    #"blend_crossover_batch",
    #"uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# Cell 1:


import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  

# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"  # e.g. c1dtlz1
    return "unknown"

def get_problem_dynamic(name: str, n_var: int | None = None, n_obj: int | None = None):
    """
    Robustly instantiate a Pymoo problem without you having to remember the exact signature.
    Tries the 'right' order per family, then falls back gracefully.
    """
    fam = _family(name)

    # preferred try-orders per family
    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),  # many constrained DTLZ variants expose fixed dims
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for a in attempts:
        try:
            return a()
        except TypeError as e:    # signature mismatch
            last_err = e
        except Exception as e:    # other errors (invalid name, etc.)
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )







# Cell 2: Configuration Parameters

# =============================================================================
#                            PVOS-2C Configuration
# =============================================================================



problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 







# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1 


#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


#  Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices):
    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, problem.n_var: problem.n_var + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))


def select_parents_batch(population, rank, cd, population_size):
    """
    Perform binary tournament selection in a vectorized manner to select parents.
    """
    total_individuals = population.shape[0]
    
    # First set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents1 = np.where(better, parent1_idx, parent2_idx)

    # Second set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents2 = np.where(better, parent1_idx, parent2_idx)

    return selected_parents1, selected_parents2

#cell 4

def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     crossover_probability, distribution_index_n_c,
                                     min_values, max_values, eps=1e-14):
    """
    Perform Simulated Binary Crossover (SBX) on a batch of parent pairs.

    This implementation mimics the pymoo SBX operator with gene‐wise crossover probabilities,
    handling cases when parent genes are too close or when lower and upper bounds are identical.
    
    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover per gene.
        distribution_index_n_c (float): Crossover distribution index (η₍c₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        eps (float): A small constant to avoid numerical issues when parent genes are nearly equal.
        
    Returns:
        
    """
    N, D = parents_dec_1.shape
    eta_c = distribution_index_n_c

    # Initialize offspring as copies of the parents.
    
    c1_new = parents_dec_1.copy()

    # Create a gene-wise mask deciding whether to perform crossover.
    do_cross = np.random.rand(N, D) < crossover_probability

    # Disable crossover for genes where the parents are too close.
    do_cross[np.abs(parents_dec_1 - parents_dec_2) <= eps] = False

    # Disable crossover for genes where the lower and upper bounds are identical.
    do_cross[:, (min_values == max_values)] = False

    # Compute gene-wise minima and maxima.
    y1 = np.minimum(parents_dec_1, parents_dec_2)
    y2 = np.maximum(parents_dec_1, parents_dec_2)
    delta = y2 - y1

    # Prepare arrays to hold the new offspring values.



    if np.any(do_cross):
        # === First Child Calculation ===
        # Compute beta for the first offspring using the lower bound.
        beta1 = 1.0 + 2.0 * (y1 - min_values) / (delta + eps)
        # Calculate alpha1 as in pymoo: 2 - beta^(-(η₍c₎+1))
        alpha1 = 2.0 - np.power(beta1, -(eta_c + 1.0))
        # Draw independent random numbers for each gene.
        rand1 = np.random.rand(N, D)
        # Compute betaq1 according to the condition.
        betaq1 = np.where(rand1 <= (1.0 / alpha1),
                          np.power(rand1 * alpha1, 1.0 / (eta_c + 1.0)),
                          np.power(1.0 / (2.0 - rand1 * alpha1), 1.0 / (eta_c + 1.0)))
        # Compute the offspring gene values.
        c1_calc = 0.5 * ((y1 + y2) - betaq1 * delta)






        # Assign the newly calculated gene values only where crossover is applied.
        c1_new[do_cross] = c1_calc[do_cross]


    # Clip the offspring to ensure they lie within the given bounds.
    
    

    return np.clip(c1_new, min_values, max_values)



def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        
    """
    num_offspring, num_decision_variables = parents_dec_1.shape
    # Initialize offspring arrays as copies of parent genes
    child1 = parents_dec_1.copy()
    

    # Create a mask to decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # Get indices of parent pairs that will crossover
    crossover_indices = np.nonzero(crossover_mask)[0]

    # For each selected pair, determine a random crossover point and perform crossover
    if crossover_indices.size > 0:
        # Randomly select a crossover point for each individual selected for crossover
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        # Iterate over each selected pair and apply single-point crossover
        for idx, cp in zip(crossover_indices, crossover_points):
            # Swap segments after the crossover point between the two parents
            child1[idx, cp:] = parents_dec_2[idx, cp:]

    # Ensure offspring values are within the specified bounds
    child1 = np.clip(child1, min_values, max_values)
    

    return np.clip(child1, min_values, max_values)





import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):
    """
    Perform BLX-α (Blend Crossover) on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of crossover.
        alpha_blend (float): Blend factor α controlling the range extension.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < crossover_probability

    # If no pairs are selected, return the copies.
    if not np.any(do_cross):
        return child1

    # Extract only the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Compute element-wise minima and maxima for each gene.
    y1 = np.minimum(p1, p2)
    y2 = np.maximum(p1, p2)
    d = y2 - y1  # difference between the parents for each gene

    # Calculate the extended lower and upper bounds for each gene.
    lower_bound = y1 - alpha_blend * d
    upper_bound = y2 + alpha_blend * d

    # Generate two sets of random numbers for each gene of each selected pair.
    rand1 = np.random.rand(p1.shape[0], D)
    

    # Create offspring within the extended range.
    c1 = lower_bound + rand1 * (upper_bound - lower_bound)
    

    # Assign the newly generated offspring back into the full child arrays.
    child1[do_cross, :] = c1
    

    # Ensure offspring values stay within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
    

    return child1


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # If no pairs are selected for crossover, return the copies.
    if not np.any(do_cross):
        return child1

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()
    

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]
    

    # Assign the offspring genes back to the full child arrays.
    child1[do_cross, :] = offspring1
    

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
   

    # Return the generated offspring decision variables.
    return child1





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec



# Cell 5: Complete PVOS-2C Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual

class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0

    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]

    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    metrics_history = []

    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator, each crossover produced one child.
        if co == simulated_binary_crossover_batch:
            sbx = SBX(prob=crossover_probability,
                      eta=distribution_index_n_c,
                      n_offsprings=1)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            matings = [[Individual(X=p1), Individual(X=p2)]
                       for p1, p2 in zip(parents_dec_1, parents_dec_2)]
        
            # single call → (N, D) offspring
            child_dec = sbx.do(_prob, matings).get("X")      
               


        elif co == single_point_crossover_batch:
            
            child_dec= single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
  

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child_dec = polynomial_mutation_batch(
                child_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )

        elif selected_mutation_operator == gaussian_mutation_batch:
            child_dec = gaussian_mutation_batch(
                child_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )

        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        offspring_dec = child_dec                         
        
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(offspring_dec, return_values_of=['F', 'G'])
            CV   = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F, CV])
        else:
            eval_result = problem.evaluate(offspring_dec)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F])
        
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx)


        pair_cnt = population_size // len(crossover_ops)      # 50 pairs when pop_size = 100
        p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
        parents1 = population[p1_idx, :num_decision_variables]
        parents2 = population[p2_idx, :num_decision_variables]

     
        results = Parallel(n_jobs=len(crossover_ops))(  # the 4 crossovers work in parallel 
            delayed(apply_crossover_and_mutation)(
                op, parents1, parents2,
                selected_mutation_operator,
                mutation_probability,
                distribution_index_n_c,
                distribution_index_n_m,
                mutation_sigma,
                blend_alpha,
                swap_prob,
                min_values,
                max_values,
                crossover_probability
            ) for op in crossover_ops
        )

        
        # Separate offspring and operator labels into lists
        offspring_list = []
        operator_ids_list = []
        for res in results:
            offspring_list.append(res["offspring"])
            # Create an array filled with the operator name for each offspring row
            operator_ids_list.append(np.full(res["offspring"].shape[0], res["operator"]))
        
        # Combine offspring from all operators
        all_offspring = np.vstack(offspring_list)
        #all_operator_ids = np.concatenate(operator_ids_list)


        
        # Population combination and survival selection
        # Tag the original population with a default label (e.g., "parent")
        original_operator_ids = np.array(["parent"] * population.shape[0])
        
        # Combine the offspring from all operators
        combined_offspring = np.vstack(offspring_list)
        combined_operator_ids = np.concatenate([original_operator_ids, np.concatenate(operator_ids_list)])
        
        # Now combine the populations
        combined_pop = np.vstack([population, combined_offspring])
        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))

        for r in range(1, rank_combined.max()+1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx)

        # Environmental selection
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted([(i, crowding_combined[i]) for i in front_idx], 
                                    key=lambda x: -x[1])
                survivors.extend([i for i, _ in sorted_front[:population_size-len(survivors)]])
            current_rank += 1

        population = combined_pop[survivors]
        # Extract operator labels for the survivors
        surviving_operator_ids = combined_operator_ids[survivors]
        
        # Compute counts of survivors per operator
        unique, counts = np.unique(surviving_operator_ids, return_counts=True)
        survival_stats = dict(zip(unique, counts))
        print("Survival counts by operator:", survival_stats)

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time
            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    return population, problem.pareto_front(), metrics_history



#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts (using Pymoo data for the analytical solution)
    
    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib



# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    


    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history = run_nsga2(
        problem=problem,  
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points
    }

# Run NSGA-II in series for seeds 1 to 30 (or 31 if you prefer 1 to 31)  
seeds = range(1, 31)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    


    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],

            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)

        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 1: hypervolume=0.0000, igd=1.9688, gd=2.4028, gd_plus=2.4028, igd_plus=1.9687, spacing=0.1161, generation=1.0000, generation_time=0.5478
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 2: hypervolume=0.0000, igd=1.9688, gd=2.0371, gd_plus=2.0371, igd_plus=1.9687, spacing=0.2165, generation=2.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('parent'): np.int64(38), np.str_('simulated_binary_crossover_batch'): np.int64(32), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 3: hypervolume=0.0000, igd=1.8720, gd=2.1077, gd_plus=2.1077, igd_plus=1.8720, spacing=0.0553, generation=3.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(31)}
# Gen 4: hypervolume=0.0000, igd=1.4321, gd=2.0427, gd_plus=2.0427, igd_plus=1.4315, spacing=0.1579, generation=4.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 5: hypervolume=0.0000, igd=1.4321, gd=1.7325, gd_plus=1.7325, igd_plus=1.4315, spacing=0.1792, generation=5.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(39), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(33)}
# Gen 6: hypervolume=0.0000, igd=1.4321, gd=1.8687, gd_plus=1.8687, igd_plus=1.4315, spacing=0.1196, generation=6.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 7: hypervolume=0.0000, igd=1.3826, gd=1.6634, gd_plus=1.6634, igd_plus=1.3825, spacing=0.0744, generation=7.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 8: hypervolume=0.0000, igd=1.2667, gd=1.4591, gd_plus=1.4591, igd_plus=1.2653, spacing=0.0724, generation=8.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 9: hypervolume=0.0000, igd=1.1136, gd=1.2498, gd_plus=1.2498, igd_plus=1.1129, spacing=0.0944, generation=9.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(31)}
# Gen 10: hypervolume=0.0000, igd=1.0871, gd=1.2069, gd_plus=1.2069, igd_plus=1.0864, spacing=0.0463, generation=10.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 11: hypervolume=0.0000, igd=1.0224, gd=1.2195, gd_plus=1.2195, igd_plus=1.0216, spacing=0.0801, generation=11.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 12: hypervolume=0.0000, igd=1.0089, gd=1.1303, gd_plus=1.1303, igd_plus=1.0081, spacing=0.1683, generation=12.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 13: hypervolume=0.0000, igd=0.9092, gd=1.0611, gd_plus=1.0611, igd_plus=0.9084, spacing=0.1061, generation=13.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(40), np.str_('simulated_binary_crossover_batch'): np.int64(32), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 14: hypervolume=0.0075, igd=0.8760, gd=0.9412, gd_plus=0.9412, igd_plus=0.8749, spacing=0.0763, generation=14.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 15: hypervolume=0.0163, igd=0.8469, gd=0.8377, gd_plus=0.8377, igd_plus=0.8458, spacing=0.0576, generation=15.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 16: hypervolume=0.0572, igd=0.7439, gd=0.7799, gd_plus=0.7799, igd_plus=0.7427, spacing=0.0660, generation=16.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 17: hypervolume=0.0705, igd=0.7205, gd=0.7210, gd_plus=0.7210, igd_plus=0.7193, spacing=0.0678, generation=17.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 18: hypervolume=0.1142, igd=0.6419, gd=0.6743, gd_plus=0.6743, igd_plus=0.6404, spacing=0.0520, generation=18.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 19: hypervolume=0.1288, igd=0.6124, gd=0.6776, gd_plus=0.6776, igd_plus=0.6109, spacing=0.0443, generation=19.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 20: hypervolume=0.1511, igd=0.5749, gd=0.6300, gd_plus=0.6300, igd_plus=0.5716, spacing=0.0569, generation=20.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 21: hypervolume=0.1646, igd=0.5581, gd=0.6080, gd_plus=0.6080, igd_plus=0.5547, spacing=0.0494, generation=21.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 22: hypervolume=0.1904, igd=0.5364, gd=0.5781, gd_plus=0.5781, igd_plus=0.5340, spacing=0.0499, generation=22.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 23: hypervolume=0.2230, igd=0.4837, gd=0.5919, gd_plus=0.5919, igd_plus=0.4790, spacing=0.0670, generation=23.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(31)}
# Gen 24: hypervolume=0.2296, igd=0.4787, gd=0.5217, gd_plus=0.5217, igd_plus=0.4739, spacing=0.0488, generation=24.0000, generation_time=0.0166
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 25: hypervolume=0.2521, igd=0.4700, gd=0.5371, gd_plus=0.5371, igd_plus=0.4652, spacing=0.0395, generation=25.0000, generation_time=0.0295
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 26: hypervolume=0.2739, igd=0.4430, gd=0.4848, gd_plus=0.4848, igd_plus=0.4380, spacing=0.0529, generation=26.0000, generation_time=0.0259
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 27: hypervolume=0.2861, igd=0.4367, gd=0.4677, gd_plus=0.4677, igd_plus=0.4317, spacing=0.0473, generation=27.0000, generation_time=0.0176
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 28: hypervolume=0.3040, igd=0.4169, gd=0.4612, gd_plus=0.4612, igd_plus=0.4117, spacing=0.0422, generation=28.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 29: hypervolume=0.3294, igd=0.3854, gd=0.4146, gd_plus=0.4146, igd_plus=0.3796, spacing=0.0574, generation=29.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 30: hypervolume=0.3400, igd=0.3806, gd=0.4224, gd_plus=0.4224, igd_plus=0.3749, spacing=0.0253, generation=30.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 31: hypervolume=0.3572, igd=0.3707, gd=0.3876, gd_plus=0.3876, igd_plus=0.3659, spacing=0.0167, generation=31.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 32: hypervolume=0.3634, igd=0.3670, gd=0.3534, gd_plus=0.3534, igd_plus=0.3622, spacing=0.0165, generation=32.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 33: hypervolume=0.3771, igd=0.3521, gd=0.3409, gd_plus=0.3409, igd_plus=0.3484, spacing=0.0224, generation=33.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 34: hypervolume=0.4007, igd=0.3279, gd=0.3236, gd_plus=0.3236, igd_plus=0.3236, spacing=0.0319, generation=34.0000, generation_time=0.0205
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 35: hypervolume=0.4098, igd=0.3217, gd=0.3075, gd_plus=0.3075, igd_plus=0.3174, spacing=0.0303, generation=35.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 36: hypervolume=0.4305, igd=0.3040, gd=0.3105, gd_plus=0.3105, igd_plus=0.2995, spacing=0.0208, generation=36.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 37: hypervolume=0.4457, igd=0.2973, gd=0.2649, gd_plus=0.2649, igd_plus=0.2951, spacing=0.0199, generation=37.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 38: hypervolume=0.4688, igd=0.2755, gd=0.2674, gd_plus=0.2674, igd_plus=0.2730, spacing=0.0201, generation=38.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 39: hypervolume=0.4751, igd=0.2703, gd=0.2591, gd_plus=0.2591, igd_plus=0.2679, spacing=0.0183, generation=39.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 40: hypervolume=0.4847, igd=0.2639, gd=0.2490, gd_plus=0.2490, igd_plus=0.2610, spacing=0.0195, generation=40.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 41: hypervolume=0.4971, igd=0.2581, gd=0.2445, gd_plus=0.2444, igd_plus=0.2552, spacing=0.0177, generation=41.0000, generation_time=0.0132
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 42: hypervolume=0.5065, igd=0.2527, gd=0.2371, gd_plus=0.2371, igd_plus=0.2496, spacing=0.0139, generation=42.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 43: hypervolume=0.5120, igd=0.2500, gd=0.2318, gd_plus=0.2318, igd_plus=0.2468, spacing=0.0160, generation=43.0000, generation_time=0.0297
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 44: hypervolume=0.5276, igd=0.2371, gd=0.2257, gd_plus=0.2257, igd_plus=0.2337, spacing=0.0163, generation=44.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 45: hypervolume=0.5370, igd=0.2292, gd=0.2249, gd_plus=0.2249, igd_plus=0.2257, spacing=0.0168, generation=45.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 46: hypervolume=0.5450, igd=0.2229, gd=0.2147, gd_plus=0.2145, igd_plus=0.2195, spacing=0.0182, generation=46.0000, generation_time=0.0190
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 47: hypervolume=0.5594, igd=0.2123, gd=0.2099, gd_plus=0.2098, igd_plus=0.2098, spacing=0.0225, generation=47.0000, generation_time=0.0178
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 48: hypervolume=0.5676, igd=0.2063, gd=0.2014, gd_plus=0.2012, igd_plus=0.2038, spacing=0.0216, generation=48.0000, generation_time=0.0181
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 49: hypervolume=0.5796, igd=0.1968, gd=0.1924, gd_plus=0.1924, igd_plus=0.1941, spacing=0.0195, generation=49.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 50: hypervolume=0.5956, igd=0.1840, gd=0.1883, gd_plus=0.1882, igd_plus=0.1811, spacing=0.0164, generation=50.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 51: hypervolume=0.6022, igd=0.1781, gd=0.1804, gd_plus=0.1803, igd_plus=0.1752, spacing=0.0192, generation=51.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 52: hypervolume=0.6108, igd=0.1732, gd=0.1736, gd_plus=0.1734, igd_plus=0.1702, spacing=0.0200, generation=52.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 53: hypervolume=0.6227, igd=0.1650, gd=0.1632, gd_plus=0.1630, igd_plus=0.1617, spacing=0.0174, generation=53.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 54: hypervolume=0.6294, igd=0.1595, gd=0.1536, gd_plus=0.1534, igd_plus=0.1573, spacing=0.0169, generation=54.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 55: hypervolume=0.6375, igd=0.1548, gd=0.1462, gd_plus=0.1461, igd_plus=0.1515, spacing=0.0157, generation=55.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 56: hypervolume=0.6466, igd=0.1503, gd=0.1422, gd_plus=0.1421, igd_plus=0.1452, spacing=0.0196, generation=56.0000, generation_time=0.0247
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 57: hypervolume=0.6532, igd=0.1458, gd=0.1407, gd_plus=0.1405, igd_plus=0.1408, spacing=0.0226, generation=57.0000, generation_time=0.0138
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 58: hypervolume=0.6587, igd=0.1428, gd=0.1313, gd_plus=0.1309, igd_plus=0.1378, spacing=0.0222, generation=58.0000, generation_time=0.0162
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 59: hypervolume=0.6636, igd=0.1384, gd=0.1280, gd_plus=0.1275, igd_plus=0.1350, spacing=0.0154, generation=59.0000, generation_time=0.0225
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 60: hypervolume=0.6691, igd=0.1347, gd=0.1205, gd_plus=0.1202, igd_plus=0.1301, spacing=0.0197, generation=60.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 61: hypervolume=0.6809, igd=0.1277, gd=0.1184, gd_plus=0.1181, igd_plus=0.1223, spacing=0.0203, generation=61.0000, generation_time=0.0180
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 62: hypervolume=0.6864, igd=0.1244, gd=0.1132, gd_plus=0.1129, igd_plus=0.1189, spacing=0.0171, generation=62.0000, generation_time=0.0178
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 63: hypervolume=0.6941, igd=0.1184, gd=0.1083, gd_plus=0.1079, igd_plus=0.1128, spacing=0.0199, generation=63.0000, generation_time=0.0220
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 64: hypervolume=0.6994, igd=0.1148, gd=0.1006, gd_plus=0.1002, igd_plus=0.1092, spacing=0.0190, generation=64.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 65: hypervolume=0.7065, igd=0.1112, gd=0.0986, gd_plus=0.0982, igd_plus=0.1044, spacing=0.0206, generation=65.0000, generation_time=0.0401
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 66: hypervolume=0.7156, igd=0.0997, gd=0.0910, gd_plus=0.0905, igd_plus=0.0983, spacing=0.0186, generation=66.0000, generation_time=0.0183
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 67: hypervolume=0.7244, igd=0.0935, gd=0.0891, gd_plus=0.0884, igd_plus=0.0920, spacing=0.0200, generation=67.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 68: hypervolume=0.7335, igd=0.0861, gd=0.0849, gd_plus=0.0847, igd_plus=0.0861, spacing=0.0237, generation=68.0000, generation_time=0.0195
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 69: hypervolume=0.7419, igd=0.0802, gd=0.0792, gd_plus=0.0788, igd_plus=0.0801, spacing=0.0228, generation=69.0000, generation_time=0.0188
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 70: hypervolume=0.7477, igd=0.0771, gd=0.0763, gd_plus=0.0761, igd_plus=0.0771, spacing=0.0133, generation=70.0000, generation_time=0.0241
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 71: hypervolume=0.7558, igd=0.0712, gd=0.0730, gd_plus=0.0727, igd_plus=0.0712, spacing=0.0147, generation=71.0000, generation_time=0.0169
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 72: hypervolume=0.7610, igd=0.0678, gd=0.0690, gd_plus=0.0685, igd_plus=0.0676, spacing=0.0164, generation=72.0000, generation_time=0.0272
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 73: hypervolume=0.7668, igd=0.0646, gd=0.0644, gd_plus=0.0639, igd_plus=0.0644, spacing=0.0166, generation=73.0000, generation_time=0.0170
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 74: hypervolume=0.7720, igd=0.0612, gd=0.0621, gd_plus=0.0617, igd_plus=0.0612, spacing=0.0134, generation=74.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 75: hypervolume=0.7779, igd=0.0584, gd=0.0578, gd_plus=0.0573, igd_plus=0.0584, spacing=0.0123, generation=75.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 76: hypervolume=0.7840, igd=0.0555, gd=0.0557, gd_plus=0.0545, igd_plus=0.0554, spacing=0.0111, generation=76.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 77: hypervolume=0.7890, igd=0.0523, gd=0.0537, gd_plus=0.0525, igd_plus=0.0522, spacing=0.0112, generation=77.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(59), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 78: hypervolume=0.7926, igd=0.0507, gd=0.0524, gd_plus=0.0520, igd_plus=0.0506, spacing=0.0130, generation=78.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 79: hypervolume=0.7952, igd=0.0490, gd=0.0501, gd_plus=0.0495, igd_plus=0.0489, spacing=0.0109, generation=79.0000, generation_time=0.0194
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 80: hypervolume=0.7980, igd=0.0473, gd=0.0480, gd_plus=0.0474, igd_plus=0.0472, spacing=0.0113, generation=80.0000, generation_time=0.0200
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 81: hypervolume=0.7999, igd=0.0459, gd=0.0463, gd_plus=0.0453, igd_plus=0.0458, spacing=0.0097, generation=81.0000, generation_time=0.0163
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 82: hypervolume=0.8024, igd=0.0444, gd=0.0451, gd_plus=0.0440, igd_plus=0.0443, spacing=0.0094, generation=82.0000, generation_time=0.0163
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 83: hypervolume=0.8047, igd=0.0424, gd=0.0431, gd_plus=0.0420, igd_plus=0.0422, spacing=0.0121, generation=83.0000, generation_time=0.0175
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 84: hypervolume=0.8076, igd=0.0406, gd=0.0413, gd_plus=0.0404, igd_plus=0.0405, spacing=0.0136, generation=84.0000, generation_time=0.0311
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 85: hypervolume=0.8109, igd=0.0387, gd=0.0401, gd_plus=0.0392, igd_plus=0.0387, spacing=0.0094, generation=85.0000, generation_time=0.0245
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 86: hypervolume=0.8129, igd=0.0378, gd=0.0394, gd_plus=0.0384, igd_plus=0.0377, spacing=0.0097, generation=86.0000, generation_time=0.0268
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 87: hypervolume=0.8148, igd=0.0368, gd=0.0380, gd_plus=0.0369, igd_plus=0.0367, spacing=0.0087, generation=87.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 88: hypervolume=0.8170, igd=0.0353, gd=0.0369, gd_plus=0.0356, igd_plus=0.0352, spacing=0.0090, generation=88.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 89: hypervolume=0.8190, igd=0.0344, gd=0.0361, gd_plus=0.0350, igd_plus=0.0343, spacing=0.0068, generation=89.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 90: hypervolume=0.8206, igd=0.0333, gd=0.0349, gd_plus=0.0338, igd_plus=0.0332, spacing=0.0066, generation=90.0000, generation_time=0.0237
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 91: hypervolume=0.8225, igd=0.0324, gd=0.0333, gd_plus=0.0322, igd_plus=0.0323, spacing=0.0066, generation=91.0000, generation_time=0.0169
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 92: hypervolume=0.8242, igd=0.0313, gd=0.0323, gd_plus=0.0313, igd_plus=0.0313, spacing=0.0069, generation=92.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 93: hypervolume=0.8256, igd=0.0304, gd=0.0311, gd_plus=0.0301, igd_plus=0.0304, spacing=0.0071, generation=93.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 94: hypervolume=0.8264, igd=0.0301, gd=0.0309, gd_plus=0.0298, igd_plus=0.0299, spacing=0.0069, generation=94.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 95: hypervolume=0.8276, igd=0.0291, gd=0.0297, gd_plus=0.0287, igd_plus=0.0290, spacing=0.0069, generation=95.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 96: hypervolume=0.8288, igd=0.0281, gd=0.0290, gd_plus=0.0279, igd_plus=0.0280, spacing=0.0066, generation=96.0000, generation_time=0.0348
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 97: hypervolume=0.8294, igd=0.0276, gd=0.0285, gd_plus=0.0279, igd_plus=0.0275, spacing=0.0067, generation=97.0000, generation_time=0.0251
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 98: hypervolume=0.8308, igd=0.0267, gd=0.0278, gd_plus=0.0271, igd_plus=0.0266, spacing=0.0062, generation=98.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 99: hypervolume=0.8319, igd=0.0261, gd=0.0271, gd_plus=0.0261, igd_plus=0.0261, spacing=0.0067, generation=99.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 100: hypervolume=0.8336, igd=0.0251, gd=0.0261, gd_plus=0.0252, igd_plus=0.0250, spacing=0.0076, generation=100.0000, generation_time=0.0307
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 101: hypervolume=0.8346, igd=0.0244, gd=0.0257, gd_plus=0.0245, igd_plus=0.0243, spacing=0.0070, generation=101.0000, generation_time=0.0167
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 102: hypervolume=0.8354, igd=0.0240, gd=0.0249, gd_plus=0.0240, igd_plus=0.0239, spacing=0.0071, generation=102.0000, generation_time=0.0171
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 103: hypervolume=0.8371, igd=0.0228, gd=0.0238, gd_plus=0.0231, igd_plus=0.0227, spacing=0.0068, generation=103.0000, generation_time=0.0259
# Survival counts by operator: {np.str_('parent'): np.int64(78), np.str_('simulated_binary_crossover_batch'): np.int64(9), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 104: hypervolume=0.8383, igd=0.0221, gd=0.0233, gd_plus=0.0221, igd_plus=0.0220, spacing=0.0073, generation=104.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 105: hypervolume=0.8393, igd=0.0215, gd=0.0224, gd_plus=0.0214, igd_plus=0.0214, spacing=0.0070, generation=105.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 106: hypervolume=0.8402, igd=0.0209, gd=0.0217, gd_plus=0.0210, igd_plus=0.0208, spacing=0.0070, generation=106.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 107: hypervolume=0.8410, igd=0.0203, gd=0.0210, gd_plus=0.0203, igd_plus=0.0202, spacing=0.0073, generation=107.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 108: hypervolume=0.8426, igd=0.0194, gd=0.0203, gd_plus=0.0192, igd_plus=0.0193, spacing=0.0075, generation=108.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 109: hypervolume=0.8443, igd=0.0185, gd=0.0194, gd_plus=0.0182, igd_plus=0.0184, spacing=0.0069, generation=109.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 110: hypervolume=0.8452, igd=0.0178, gd=0.0187, gd_plus=0.0175, igd_plus=0.0178, spacing=0.0074, generation=110.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 111: hypervolume=0.8464, igd=0.0172, gd=0.0180, gd_plus=0.0168, igd_plus=0.0171, spacing=0.0075, generation=111.0000, generation_time=0.0138
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 112: hypervolume=0.8471, igd=0.0168, gd=0.0175, gd_plus=0.0163, igd_plus=0.0167, spacing=0.0084, generation=112.0000, generation_time=0.0271
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 113: hypervolume=0.8478, igd=0.0164, gd=0.0173, gd_plus=0.0161, igd_plus=0.0163, spacing=0.0067, generation=113.0000, generation_time=0.0319
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 114: hypervolume=0.8485, igd=0.0160, gd=0.0169, gd_plus=0.0157, igd_plus=0.0159, spacing=0.0068, generation=114.0000, generation_time=0.0163
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 115: hypervolume=0.8491, igd=0.0155, gd=0.0165, gd_plus=0.0154, igd_plus=0.0154, spacing=0.0065, generation=115.0000, generation_time=0.0298
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 116: hypervolume=0.8498, igd=0.0150, gd=0.0159, gd_plus=0.0149, igd_plus=0.0149, spacing=0.0075, generation=116.0000, generation_time=0.0247
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 117: hypervolume=0.8501, igd=0.0150, gd=0.0161, gd_plus=0.0150, igd_plus=0.0148, spacing=0.0071, generation=117.0000, generation_time=0.0185
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 118: hypervolume=0.8508, igd=0.0145, gd=0.0154, gd_plus=0.0144, igd_plus=0.0144, spacing=0.0075, generation=118.0000, generation_time=0.0159
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 119: hypervolume=0.8513, igd=0.0142, gd=0.0154, gd_plus=0.0139, igd_plus=0.0141, spacing=0.0077, generation=119.0000, generation_time=0.0222
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 120: hypervolume=0.8521, igd=0.0139, gd=0.0148, gd_plus=0.0136, igd_plus=0.0137, spacing=0.0076, generation=120.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 121: hypervolume=0.8526, igd=0.0136, gd=0.0144, gd_plus=0.0132, igd_plus=0.0134, spacing=0.0072, generation=121.0000, generation_time=0.0181
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 122: hypervolume=0.8533, igd=0.0131, gd=0.0141, gd_plus=0.0128, igd_plus=0.0129, spacing=0.0065, generation=122.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 123: hypervolume=0.8539, igd=0.0128, gd=0.0139, gd_plus=0.0125, igd_plus=0.0127, spacing=0.0068, generation=123.0000, generation_time=0.0178
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 124: hypervolume=0.8547, igd=0.0124, gd=0.0134, gd_plus=0.0120, igd_plus=0.0122, spacing=0.0069, generation=124.0000, generation_time=0.0173
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 125: hypervolume=0.8553, igd=0.0118, gd=0.0129, gd_plus=0.0116, igd_plus=0.0117, spacing=0.0062, generation=125.0000, generation_time=0.0164
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 126: hypervolume=0.8556, igd=0.0116, gd=0.0128, gd_plus=0.0114, igd_plus=0.0115, spacing=0.0068, generation=126.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 127: hypervolume=0.8559, igd=0.0114, gd=0.0124, gd_plus=0.0112, igd_plus=0.0113, spacing=0.0076, generation=127.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 128: hypervolume=0.8565, igd=0.0110, gd=0.0120, gd_plus=0.0108, igd_plus=0.0109, spacing=0.0065, generation=128.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 129: hypervolume=0.8573, igd=0.0105, gd=0.0114, gd_plus=0.0102, igd_plus=0.0104, spacing=0.0064, generation=129.0000, generation_time=0.0254
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 130: hypervolume=0.8578, igd=0.0104, gd=0.0114, gd_plus=0.0102, igd_plus=0.0103, spacing=0.0067, generation=130.0000, generation_time=0.0316
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 131: hypervolume=0.8580, igd=0.0102, gd=0.0109, gd_plus=0.0099, igd_plus=0.0101, spacing=0.0069, generation=131.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 132: hypervolume=0.8584, igd=0.0101, gd=0.0107, gd_plus=0.0097, igd_plus=0.0099, spacing=0.0077, generation=132.0000, generation_time=0.0157
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 133: hypervolume=0.8589, igd=0.0099, gd=0.0111, gd_plus=0.0095, igd_plus=0.0097, spacing=0.0076, generation=133.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 134: hypervolume=0.8594, igd=0.0096, gd=0.0108, gd_plus=0.0092, igd_plus=0.0094, spacing=0.0076, generation=134.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 135: hypervolume=0.8598, igd=0.0094, gd=0.0105, gd_plus=0.0088, igd_plus=0.0092, spacing=0.0066, generation=135.0000, generation_time=0.0169
# Survival counts by operator: {np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 136: hypervolume=0.8601, igd=0.0092, gd=0.0100, gd_plus=0.0087, igd_plus=0.0090, spacing=0.0071, generation=136.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 137: hypervolume=0.8606, igd=0.0088, gd=0.0097, gd_plus=0.0083, igd_plus=0.0086, spacing=0.0072, generation=137.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 138: hypervolume=0.8610, igd=0.0086, gd=0.0095, gd_plus=0.0082, igd_plus=0.0083, spacing=0.0062, generation=138.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 139: hypervolume=0.8613, igd=0.0084, gd=0.0094, gd_plus=0.0081, igd_plus=0.0082, spacing=0.0064, generation=139.0000, generation_time=0.0157
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 140: hypervolume=0.8614, igd=0.0086, gd=0.0093, gd_plus=0.0081, igd_plus=0.0082, spacing=0.0067, generation=140.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 141: hypervolume=0.8616, igd=0.0084, gd=0.0092, gd_plus=0.0079, igd_plus=0.0081, spacing=0.0067, generation=141.0000, generation_time=0.0166
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 142: hypervolume=0.8617, igd=0.0083, gd=0.0089, gd_plus=0.0077, igd_plus=0.0080, spacing=0.0070, generation=142.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(80), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 143: hypervolume=0.8619, igd=0.0082, gd=0.0092, gd_plus=0.0075, igd_plus=0.0079, spacing=0.0070, generation=143.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 144: hypervolume=0.8624, igd=0.0079, gd=0.0088, gd_plus=0.0072, igd_plus=0.0076, spacing=0.0073, generation=144.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 145: hypervolume=0.8628, igd=0.0076, gd=0.0082, gd_plus=0.0069, igd_plus=0.0072, spacing=0.0065, generation=145.0000, generation_time=0.0161
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 146: hypervolume=0.8629, igd=0.0077, gd=0.0084, gd_plus=0.0068, igd_plus=0.0073, spacing=0.0072, generation=146.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 147: hypervolume=0.8629, igd=0.0076, gd=0.0082, gd_plus=0.0066, igd_plus=0.0073, spacing=0.0073, generation=147.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 148: hypervolume=0.8632, igd=0.0074, gd=0.0083, gd_plus=0.0066, igd_plus=0.0071, spacing=0.0064, generation=148.0000, generation_time=0.0191
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 149: hypervolume=0.8635, igd=0.0072, gd=0.0082, gd_plus=0.0064, igd_plus=0.0069, spacing=0.0066, generation=149.0000, generation_time=0.0314
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(15)}
# ...
# Gen 151: hypervolume=0.8639, igd=0.0069, gd=0.0079, gd_plus=0.0060, igd_plus=0.0066, spacing=0.0060, generation=151.0000, generation_time=0.0209
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 152: hypervolume=0.8640, igd=0.0069, gd=0.0079, gd_plus=0.0060, igd_plus=0.0065, spacing=0.0066, generation=152.0000, generation_time=0.0193
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 153: hypervolume=0.8643, igd=0.0067, gd=0.0076, gd_plus=0.0059, igd_plus=0.0064, spacing=0.0067, generation=153.0000, generation_time=0.0164
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 154: hypervolume=0.8644, igd=0.0066, gd=0.0076, gd_plus=0.0059, igd_plus=0.0063, spacing=0.0063, generation=154.0000, generation_time=0.0230
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 155: hypervolume=0.8647, igd=0.0065, gd=0.0075, gd_plus=0.0057, igd_plus=0.0062, spacing=0.0067, generation=155.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 156: hypervolume=0.8649, igd=0.0064, gd=0.0073, gd_plus=0.0056, igd_plus=0.0060, spacing=0.0066, generation=156.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 157: hypervolume=0.8649, igd=0.0066, gd=0.0073, gd_plus=0.0055, igd_plus=0.0061, spacing=0.0060, generation=157.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 158: hypervolume=0.8650, igd=0.0066, gd=0.0072, gd_plus=0.0054, igd_plus=0.0061, spacing=0.0064, generation=158.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 159: hypervolume=0.8650, igd=0.0065, gd=0.0071, gd_plus=0.0053, igd_plus=0.0060, spacing=0.0067, generation=159.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 160: hypervolume=0.8650, igd=0.0065, gd=0.0070, gd_plus=0.0053, igd_plus=0.0059, spacing=0.0072, generation=160.0000, generation_time=0.0286
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 161: hypervolume=0.8653, igd=0.0064, gd=0.0072, gd_plus=0.0054, igd_plus=0.0059, spacing=0.0064, generation=161.0000, generation_time=0.0300
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 162: hypervolume=0.8655, igd=0.0063, gd=0.0069, gd_plus=0.0052, igd_plus=0.0058, spacing=0.0063, generation=162.0000, generation_time=0.0208
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(7)}
# Gen 163: hypervolume=0.8656, igd=0.0063, gd=0.0070, gd_plus=0.0053, igd_plus=0.0057, spacing=0.0062, generation=163.0000, generation_time=0.0218
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 164: hypervolume=0.8657, igd=0.0062, gd=0.0069, gd_plus=0.0052, igd_plus=0.0056, spacing=0.0066, generation=164.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 165: hypervolume=0.8660, igd=0.0060, gd=0.0069, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0073, generation=165.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('parent'): np.int64(82), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(8)}
# Gen 166: hypervolume=0.8662, igd=0.0060, gd=0.0069, gd_plus=0.0050, igd_plus=0.0054, spacing=0.0067, generation=166.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 167: hypervolume=0.8662, igd=0.0059, gd=0.0064, gd_plus=0.0050, igd_plus=0.0054, spacing=0.0065, generation=167.0000, generation_time=0.0163
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 168: hypervolume=0.8664, igd=0.0059, gd=0.0065, gd_plus=0.0050, igd_plus=0.0054, spacing=0.0063, generation=168.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 169: hypervolume=0.8664, igd=0.0058, gd=0.0065, gd_plus=0.0050, igd_plus=0.0053, spacing=0.0067, generation=169.0000, generation_time=0.0185
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 170: hypervolume=0.8665, igd=0.0058, gd=0.0064, gd_plus=0.0050, igd_plus=0.0054, spacing=0.0063, generation=170.0000, generation_time=0.0270
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 171: hypervolume=0.8666, igd=0.0058, gd=0.0068, gd_plus=0.0050, igd_plus=0.0053, spacing=0.0064, generation=171.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 172: hypervolume=0.8666, igd=0.0057, gd=0.0062, gd_plus=0.0049, igd_plus=0.0052, spacing=0.0066, generation=172.0000, generation_time=0.0237
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 173: hypervolume=0.8666, igd=0.0057, gd=0.0062, gd_plus=0.0049, igd_plus=0.0053, spacing=0.0061, generation=173.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 174: hypervolume=0.8666, igd=0.0057, gd=0.0062, gd_plus=0.0049, igd_plus=0.0052, spacing=0.0059, generation=174.0000, generation_time=0.0301
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 175: hypervolume=0.8667, igd=0.0058, gd=0.0063, gd_plus=0.0049, igd_plus=0.0052, spacing=0.0066, generation=175.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 176: hypervolume=0.8667, igd=0.0059, gd=0.0063, gd_plus=0.0049, igd_plus=0.0053, spacing=0.0074, generation=176.0000, generation_time=0.0174
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 177: hypervolume=0.8667, igd=0.0059, gd=0.0064, gd_plus=0.0047, igd_plus=0.0053, spacing=0.0077, generation=177.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 178: hypervolume=0.8668, igd=0.0059, gd=0.0065, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0069, generation=178.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 179: hypervolume=0.8669, igd=0.0058, gd=0.0064, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0067, generation=179.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 180: hypervolume=0.8668, igd=0.0060, gd=0.0068, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0068, generation=180.0000, generation_time=0.0278
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 181: hypervolume=0.8667, igd=0.0062, gd=0.0068, gd_plus=0.0046, igd_plus=0.0053, spacing=0.0084, generation=181.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 182: hypervolume=0.8670, igd=0.0059, gd=0.0067, gd_plus=0.0045, igd_plus=0.0051, spacing=0.0079, generation=182.0000, generation_time=0.0218
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 183: hypervolume=0.8672, igd=0.0057, gd=0.0066, gd_plus=0.0044, igd_plus=0.0050, spacing=0.0076, generation=183.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 184: hypervolume=0.8673, igd=0.0054, gd=0.0066, gd_plus=0.0044, igd_plus=0.0047, spacing=0.0074, generation=184.0000, generation_time=0.0218
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 185: hypervolume=0.8675, igd=0.0053, gd=0.0062, gd_plus=0.0045, igd_plus=0.0046, spacing=0.0073, generation=185.0000, generation_time=0.0203
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 186: hypervolume=0.8678, igd=0.0052, gd=0.0060, gd_plus=0.0044, igd_plus=0.0045, spacing=0.0072, generation=186.0000, generation_time=0.0161
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 187: hypervolume=0.8679, igd=0.0053, gd=0.0063, gd_plus=0.0043, igd_plus=0.0045, spacing=0.0075, generation=187.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 188: hypervolume=0.8680, igd=0.0052, gd=0.0062, gd_plus=0.0041, igd_plus=0.0044, spacing=0.0077, generation=188.0000, generation_time=0.0123
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 189: hypervolume=0.8682, igd=0.0051, gd=0.0061, gd_plus=0.0040, igd_plus=0.0044, spacing=0.0077, generation=189.0000, generation_time=0.0270
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 190: hypervolume=0.8683, igd=0.0051, gd=0.0061, gd_plus=0.0040, igd_plus=0.0044, spacing=0.0075, generation=190.0000, generation_time=0.0266
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 191: hypervolume=0.8683, igd=0.0051, gd=0.0059, gd_plus=0.0038, igd_plus=0.0044, spacing=0.0073, generation=191.0000, generation_time=0.0174
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 192: hypervolume=0.8685, igd=0.0048, gd=0.0057, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0069, generation=192.0000, generation_time=0.0172
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 193: hypervolume=0.8686, igd=0.0048, gd=0.0053, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0070, generation=193.0000, generation_time=0.0200
# Survival counts by operator: {np.str_('parent'): np.int64(78), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 194: hypervolume=0.8686, igd=0.0049, gd=0.0053, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0069, generation=194.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 195: hypervolume=0.8685, igd=0.0051, gd=0.0058, gd_plus=0.0037, igd_plus=0.0044, spacing=0.0069, generation=195.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 196: hypervolume=0.8687, igd=0.0051, gd=0.0054, gd_plus=0.0037, igd_plus=0.0043, spacing=0.0068, generation=196.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 197: hypervolume=0.8687, igd=0.0050, gd=0.0054, gd_plus=0.0037, igd_plus=0.0042, spacing=0.0062, generation=197.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 198: hypervolume=0.8686, igd=0.0051, gd=0.0057, gd_plus=0.0036, igd_plus=0.0042, spacing=0.0069, generation=198.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 199: hypervolume=0.8687, igd=0.0048, gd=0.0056, gd_plus=0.0036, igd_plus=0.0040, spacing=0.0069, generation=199.0000, generation_time=0.0179
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 200: hypervolume=0.8687, igd=0.0047, gd=0.0055, gd_plus=0.0035, igd_plus=0.0039, spacing=0.0064, generation=200.0000, generation_time=0.0155
# Seed 1 - Number of Pareto front points: 100

# %%
### Cell 8: Save Combined Metrics History to Excel 
import pandas as pd
import re

# Convert the all_metrics list to DataFrame
df_metrics = pd.DataFrame(all_metrics)

# Sanitize problem name for filename
problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()


# Define a mapping from the full crossover operator names to shortcuts
crossover_shortcuts = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}

# Convert selected crossover operator names to their shortcut representation
selected_crossover_shortcut_names = [
    crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
]

# Join the shortcuts into a single string (e.g., "sbx-blx")
crossover_str = "-".join(selected_crossover_shortcut_names)

# Create valid filename
excel_filename = (
    f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross poly "
    f"{pop_size}pop {generations}gen experiment1 PVOS-2C.xlsx"
)

#{crossover_str}

# Save to Excel
df_metrics.to_excel(excel_filename, index=False)
print(f"Metrics saved to '{excel_filename}'")
# Out:
# Metrics saved to 'zdt1 2 sbx-spx cross poly 100pop 200gen experiment1 PVOS-2C.xlsx'
