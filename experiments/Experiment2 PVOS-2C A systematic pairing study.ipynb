# %%
#### Cell 0: Imports and Setup

# 1. Problem Selection and Configuration
#According to Table 2 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
problem_name = "zdt1"
n_var = 30  # Custom number of decision variables 
n_obj = 2  # Custom number of objectives

# 2. Population Settings
# -----------------------
pop_size = 100
generations = 200

# 3. Operator-specific parameters
#According to Table 1 in the Parallel Variation Operator Strategy: Equal‑Budget Parallel Crossover Ensembles for NSGA‑II
crossover_probability = 0.9
mutation_sigma = 0.5           
distribution_index_n_c = 15    # For simulated binary crossover
distribution_index_n_m = 20    # For polynomial mutation
blend_alpha = 0.5              # for blend crossover
swap_prob = 0.5                # For uniform crossover

# %%
# Select Crossover and Mutation Operators
# List all desired crossover operators to be applied in parallel.
selected_crossover_operator_names = [
    "simulated_binary_crossover_batch",
    "single_point_crossover_batch",
    #"blend_crossover_batch",
    #"uniform_crossover_batch"
    
]

selected_mutation_operator_name = "polynomial_mutation_batch"




# Cell 1:


import numpy as np
import matplotlib.pyplot as plt
import importlib
import sys
from IPython.display import display, clear_output
import time  
from pymoo.indicators.hv import HV
from pymoo.indicators.igd import IGD
import random
from pymoo.problems import get_problem
from pymoo.operators.crossover.sbx import SBX
# --- Additional Metrics Imports (if not already imported) ---
from pymoo.indicators.gd import GD
from pymoo.indicators.gd_plus import GDPlus
from pymoo.indicators.igd_plus import IGDPlus
from pymoo.indicators.spacing import SpacingIndicator as Spacing
# %matplotlib inline
plt.ion()  

# benchmarks.py
from pymoo.problems import get_problem as _get_problem

def _family(name: str) -> str:
    n = name.lower()
    if n.startswith("zdt"): return "zdt"
    if n.startswith("wfg"): return "wfg"
    if n.startswith("dtlz"): return "dtlz"
    if n.startswith("c") and "dtlz" in n: return "cdtlz"  # e.g. c1dtlz1
    return "unknown"

def get_problem_dynamic(name: str, n_var: int | None = None, n_obj: int | None = None):
    """
    Robustly instantiate a Pymoo problem without you having to remember the exact signature.
    Tries the 'right' order per family, then falls back gracefully.
    """
    fam = _family(name)

    # preferred try-orders per family
    if fam in {"dtlz", "wfg"}:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "zdt":
        attempts = [
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]
    elif fam == "cdtlz":
        attempts = [
            lambda: _get_problem(name),  # many constrained DTLZ variants expose fixed dims
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
        ]
    else:
        attempts = [
            lambda: _get_problem(name, n_var=n_var, n_obj=n_obj),
            lambda: _get_problem(name, n_var=n_var),
            lambda: _get_problem(name),
        ]

    last_err = None
    for a in attempts:
        try:
            return a()
        except TypeError as e:    # signature mismatch
            last_err = e
        except Exception as e:    # other errors (invalid name, etc.)
            last_err = e

    raise RuntimeError(
        f"Could not instantiate '{name}' with n_var={n_var}, n_obj={n_obj}. Last error: {last_err}"
    )







# Cell 2: Configuration Parameters

# =============================================================================
#                            PVOS-2C Configuration
# =============================================================================



problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)


D = problem.n_var        
M = problem.n_obj        
min_values = problem.xl  
max_values = problem.xu  
mutation_probability = 1/D 







# --- Dictionary Mapping for Metrics ---
metrics_dict = {
    "hv": lambda front, ref_point: HV(ref_point=ref_point).do(front) if ref_point is not None else None,
    "igd": lambda front, true_front: IGD(true_front).do(front),
    "gd": lambda front, true_front: GD(true_front).do(front),
    "gd_plus": lambda front, true_front: GDPlus(true_front).do(front),
    "igd_plus": lambda front, true_front: IGDPlus(true_front).do(front),
    "spacing": lambda front: np.nan if front.shape[0] < 2 else Spacing().do(front)

}



#  Random Seed for Reproducibility
# -----------------------------------
random_seed = 1 


#  Visualization Settings
# --------------------------
plot_interval = 1
display_intermediate = False


#  Metrics Computation Control
compute_metrics_each_gen = True    # Set True to compute metrics every generation
default_metrics_interval = 1    # Interval to use if not computing each generation




# main.ipynb - Cell 3
import numpy as np


def initial_population(population_size, min_values, max_values, problem):
    # Generate random decision variables within bounds
    rand_matrix = np.random.rand(population_size, problem.n_var)
    decision_vars = min_values + rand_matrix * (max_values - min_values)
    
    if hasattr(problem, 'n_constr') and problem.n_constr > 0:
        # Evaluate and get both objectives and constraints
        eval_result = problem.evaluate(decision_vars, return_values_of=['F', 'G'])
        F = eval_result[0]
        G = eval_result[1]
        # Compute aggregated constraint violation (CV) for each individual
        CV = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F, CV])
    else:
        eval_result = problem.evaluate(decision_vars)
        if isinstance(eval_result, tuple):
            F = eval_result[0]
        else:
            F = eval_result
        if F.ndim == 3 and F.shape[1] == 1:
            F = np.squeeze(F, axis=1)
        return np.hstack([decision_vars, F])






def fast_non_dominated_sort(population, num_objectives, num_constraints=0):


    
    population_size = population.shape[0]
    if num_constraints > 0:
        # Determine the starting index of objectives (exclude decision variables and constraint column)
        D = population.shape[1] - num_objectives - num_constraints
        F = population[:, D:D+num_objectives]
        cv = population[:, -num_constraints].flatten()  # aggregated constraint violation
        feasible = (cv == 0)
        
        # Pairwise objective comparisons (for feasible solutions)
        ObjA = F[:, None, :]  # shape (n, 1, M)
        ObjB = F[None, :, :]   # shape (1, n, M)
        dom_obj = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
        
        # For infeasible solutions, compare only based on constraint violation
        cv_i = cv[:, None]
        cv_j = cv[None, :]
        dom_cv = cv_i < cv_j
        
        # Overall dominance: a feasible solution always dominates an infeasible one.
        # If both are feasible, use objective dominance.
        # If both are infeasible, the one with lower CV is better.
        dominates = ((feasible[:, None] & ~feasible[None, :]) |
                     (feasible[:, None] & feasible[None, :] & dom_obj) |
                     ((~feasible[:, None]) & (~feasible[None, :]) & dom_cv))
    else:
        F = population[:, -num_objectives:]
        ObjA = F[:, None, :]
        ObjB = F[None, :, :]
        dominates = (ObjA <= ObjB).all(axis=2) & (ObjA < ObjB).any(axis=2)
    

    adjacency = dominates
    n_dominate = adjacency.sum(axis=0)

    # Initialize rank assignments
    rank = np.full(population_size, -1, dtype=int)
    current_front = np.where(n_dominate == 0)[0]
    rank_level = 1

    # Identify subsequent Pareto fronts
    while len(current_front) > 0:
        rank[current_front] = rank_level
        dominated_any = adjacency[current_front, :].any(axis=0)
        
        counts = adjacency[current_front, :][:, dominated_any].sum(axis=0)
        n_dominate[dominated_any] -= counts

        newly_zero = (n_dominate == 0) & (rank == -1)
        current_front = np.where(newly_zero)[0]
        rank_level += 1

    return rank


def crowding_distance(population, num_objectives, front_indices):
    """
    Compute the crowding distance for the sub-population specified by 'front_indices'.
    """
    # Initialize crowding distance array for entire population
    cd = np.zeros(population.shape[0])
    
    # Handle boundary conditions: empty front or very small front
    if len(front_indices) == 0:
        return cd
    if len(front_indices) <= 2:
        cd[front_indices] = np.inf
        return cd

    # Extract objectives for the current front
    objectives = population[front_indices, problem.n_var: problem.n_var + num_objectives]

    num_individuals = len(front_indices)
    cd_local = np.zeros(num_individuals)

    # Calculate crowding distance for each objective
    for m in range(num_objectives):
        # Sort indices based on objective m
        sorted_idx_local = np.argsort(objectives[:, m])
        sorted_vals = objectives[sorted_idx_local, m]

        # Assign infinity to boundary points
        cd_local[sorted_idx_local[0]] = np.inf
        cd_local[sorted_idx_local[-1]] = np.inf

        # Normalize distance between neighboring individuals
        denom = sorted_vals[-1] - sorted_vals[0]
        if denom == 0:
            continue

        for i in range(1, num_individuals - 1):
            cd_local[sorted_idx_local[i]] += (sorted_vals[i+1] - sorted_vals[i-1]) / denom

    # Update the crowding distance for individuals in the current front
    cd[front_indices] = cd_local
    return cd


def compare_individuals(rank1, rank2, cd1, cd2):
    """
    Compare two individuals based on Pareto rank and crowding distance.
    """
    # Return True if first individual is better than second based on rank, 
    # or same rank but higher crowding distance.
    return (rank1 < rank2) | ((rank1 == rank2) & (cd1 > cd2))


def select_parents_batch(population, rank, cd, population_size):
    """
    Perform binary tournament selection in a vectorized manner to select parents.
    """
    total_individuals = population.shape[0]
    
    # First set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents1 = np.where(better, parent1_idx, parent2_idx)

    # Second set of parents selection
    idx = np.random.randint(0, total_individuals, size=(population_size, 2))
    better = compare_individuals(rank[idx[:, 0]], rank[idx[:, 1]], cd[idx[:, 0]], cd[idx[:, 1]])
    parent1_idx = idx[:, 0]
    parent2_idx = idx[:, 1]
    selected_parents2 = np.where(better, parent1_idx, parent2_idx)

    return selected_parents1, selected_parents2

#cell 4

def simulated_binary_crossover_batch(parents_dec_1, parents_dec_2,
                                     crossover_probability, distribution_index_n_c,
                                     min_values, max_values, eps=1e-14):
    """
    Perform Simulated Binary Crossover (SBX) on a batch of parent pairs.

    This implementation mimics the pymoo SBX operator with gene‐wise crossover probabilities,
    handling cases when parent genes are too close or when lower and upper bounds are identical.
    
    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover per gene.
        distribution_index_n_c (float): Crossover distribution index (η₍c₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        eps (float): A small constant to avoid numerical issues when parent genes are nearly equal.
        
    Returns:
        
    """
    N, D = parents_dec_1.shape
    eta_c = distribution_index_n_c

    # Initialize offspring as copies of the parents.
    
    c1_new = parents_dec_1.copy()

    # Create a gene-wise mask deciding whether to perform crossover.
    do_cross = np.random.rand(N, D) < crossover_probability

    # Disable crossover for genes where the parents are too close.
    do_cross[np.abs(parents_dec_1 - parents_dec_2) <= eps] = False

    # Disable crossover for genes where the lower and upper bounds are identical.
    do_cross[:, (min_values == max_values)] = False

    # Compute gene-wise minima and maxima.
    y1 = np.minimum(parents_dec_1, parents_dec_2)
    y2 = np.maximum(parents_dec_1, parents_dec_2)
    delta = y2 - y1

    # Prepare arrays to hold the new offspring values.



    if np.any(do_cross):
        # === First Child Calculation ===
        # Compute beta for the first offspring using the lower bound.
        beta1 = 1.0 + 2.0 * (y1 - min_values) / (delta + eps)
        # Calculate alpha1 as in pymoo: 2 - beta^(-(η₍c₎+1))
        alpha1 = 2.0 - np.power(beta1, -(eta_c + 1.0))
        # Draw independent random numbers for each gene.
        rand1 = np.random.rand(N, D)
        # Compute betaq1 according to the condition.
        betaq1 = np.where(rand1 <= (1.0 / alpha1),
                          np.power(rand1 * alpha1, 1.0 / (eta_c + 1.0)),
                          np.power(1.0 / (2.0 - rand1 * alpha1), 1.0 / (eta_c + 1.0)))
        # Compute the offspring gene values.
        c1_calc = 0.5 * ((y1 + y2) - betaq1 * delta)






        # Assign the newly calculated gene values only where crossover is applied.
        c1_new[do_cross] = c1_calc[do_cross]


    # Clip the offspring to ensure they lie within the given bounds.
    
    

    return np.clip(c1_new, min_values, max_values)



def single_point_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, min_values, max_values):
    """
    Perform single-point crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on a parent pair.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        
    """
    num_offspring, num_decision_variables = parents_dec_1.shape
    # Initialize offspring arrays as copies of parent genes
    child1 = parents_dec_1.copy()
    

    # Create a mask to decide which pairs will undergo crossover
    crossover_mask = np.random.rand(num_offspring) < crossover_probability

    # Get indices of parent pairs that will crossover
    crossover_indices = np.nonzero(crossover_mask)[0]

    # For each selected pair, determine a random crossover point and perform crossover
    if crossover_indices.size > 0:
        # Randomly select a crossover point for each individual selected for crossover
        crossover_points = np.random.randint(1, num_decision_variables, size=crossover_indices.size)

        # Iterate over each selected pair and apply single-point crossover
        for idx, cp in zip(crossover_indices, crossover_points):
            # Swap segments after the crossover point between the two parents
            child1[idx, cp:] = parents_dec_2[idx, cp:]

    # Ensure offspring values are within the specified bounds
    child1 = np.clip(child1, min_values, max_values)
    

    return np.clip(child1, min_values, max_values)





import numpy as np

def blend_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability, alpha_blend, min_values, max_values):
    """
    Perform BLX-α (Blend Crossover) on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of crossover.
        alpha_blend (float): Blend factor α controlling the range extension.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < crossover_probability

    # If no pairs are selected, return the copies.
    if not np.any(do_cross):
        return child1

    # Extract only the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Compute element-wise minima and maxima for each gene.
    y1 = np.minimum(p1, p2)
    y2 = np.maximum(p1, p2)
    d = y2 - y1  # difference between the parents for each gene

    # Calculate the extended lower and upper bounds for each gene.
    lower_bound = y1 - alpha_blend * d
    upper_bound = y2 + alpha_blend * d

    # Generate two sets of random numbers for each gene of each selected pair.
    rand1 = np.random.rand(p1.shape[0], D)
    

    # Create offspring within the extended range.
    c1 = lower_bound + rand1 * (upper_bound - lower_bound)
    

    # Assign the newly generated offspring back into the full child arrays.
    child1[do_cross, :] = c1
    

    # Ensure offspring values stay within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
    

    return child1


import numpy as np

def uniform_crossover_batch(parents_dec_1, parents_dec_2, crossover_probability,  min_values, max_values, swap_prob=swap_prob):
    """
    Perform Uniform Crossover on a batch of parent pairs.

    Parameters:
        parents_dec_1 (np.ndarray): Decision variables of parent 1, shape (N, D).
        parents_dec_2 (np.ndarray): Decision variables of parent 2, shape (N, D).
        crossover_probability (float): Probability of performing crossover on each parent pair.
        swap_prob (float, optional): Probability of swapping each gene. Defaults to 0.5.
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).

    Returns:
        tuple: Two arrays containing offspring decision variables, each of shape (N, D).
    """
    # Determine the number of parent pairs (N) and number of decision variables (D).
    N, D = parents_dec_1.shape
    p_c = crossover_probability

    # Initialize offspring arrays as copies of the parent decision variables.
    child1 = parents_dec_1.copy()
    

    # Determine which parent pairs will undergo crossover based on probability.
    do_cross = np.random.rand(N) < p_c

    # If no pairs are selected for crossover, return the copies.
    if not np.any(do_cross):
        return child1

    # Extract the parent pairs selected for crossover.
    p1 = parents_dec_1[do_cross, :]
    p2 = parents_dec_2[do_cross, :]

    # Generate a mask for each gene indicating whether to swap based on swap_prob.
    swap_mask = np.random.rand(p1.shape[0], D) < swap_prob

    # Create copies to hold the offspring genes.
    offspring1 = p1.copy()
    

    # Perform the swap where the mask is True.
    offspring1[swap_mask] = p2[swap_mask]
    

    # Assign the offspring genes back to the full child arrays.
    child1[do_cross, :] = offspring1
    

    # Ensure offspring values are within the specified bounds.
    child1 = np.clip(child1, min_values, max_values)
   

    # Return the generated offspring decision variables.
    return child1





def polynomial_mutation_batch(offspring_dec, mutation_probability, distribution_index_n_m,
                              min_values, max_values, at_least_once=False):
    """
    Perform Polynomial Mutation on a batch of offspring decision variables.

    This operator follows the conventional scheme (as in pymoo) and
    applies a mutation to each gene with a given probability.
    
    Parameters:
        offspring_dec (np.ndarray): Offspring decision variables, shape (N, D).
        mutation_probability (float): Mutation probability per gene.
        distribution_index_n_m (float): Mutation distribution index (η₍m₎).
        min_values (np.ndarray): Lower bounds for decision variables, shape (D,).
        max_values (np.ndarray): Upper bounds for decision variables, shape (D,).
        at_least_once (bool): If True, ensure that at least one gene per individual is mutated.
        
    Returns:
        np.ndarray: Mutated offspring decision variables, shape (N, D).
    """
    N, D = offspring_dec.shape
    p_m = mutation_probability
    eta_m = distribution_index_n_m

    # Create a gene-wise mutation mask.
    mutation_mask = np.random.rand(N, D) < p_m
    # Do not allow mutation where lower and upper bounds are identical.
    mutation_mask[:, (min_values == max_values)] = False

    # If at_least_once is True, force at least one mutation per individual (if possible).
    if at_least_once:
        for i in range(N):
            if not np.any(mutation_mask[i]):
                # Identify genes that are allowed to be mutated.
                allowed = np.where(min_values != max_values)[0]
                if allowed.size > 0:
                    j = np.random.choice(allowed)
                    mutation_mask[i, j] = True

    # Convert offspring_dec to float for mutation computations.
    x = offspring_dec.astype(float).copy()

    # Compute the range for each decision variable.
    range_ = max_values - min_values

    # Compute normalized distances to the bounds.
    delta1 = (x - min_values) / (range_ + 1e-14)
    delta2 = (max_values - x) / (range_ + 1e-14)

    # Generate random numbers for the mutation process.
    u = np.random.rand(N, D)

    # Initialize delta_q (the mutation step sizes).
    deltaq = np.zeros((N, D))

    # Mutation: apply the polynomial mutation formula only for genes marked for mutation.
    # Branch where u < 0.5:
    mask1 = mutation_mask & (u < 0.5)
    if np.any(mask1):
        tmp = 2 * u[mask1] + (1 - 2 * u[mask1]) * np.power(1 - delta1[mask1], (eta_m + 1))
        deltaq[mask1] = np.power(tmp, 1.0 / (eta_m + 1)) - 1.0

    # Branch where u >= 0.5:
    mask2 = mutation_mask & (u >= 0.5)
    if np.any(mask2):
        tmp = 2 * (1 - u[mask2]) + 2 * (u[mask2] - 0.5) * np.power(1 - delta2[mask2], (eta_m + 1))
        deltaq[mask2] = 1.0 - np.power(tmp, 1.0 / (eta_m + 1))

    # Apply the mutation step.
    x = x + deltaq * range_
    # Ensure the mutated values are within the bounds.
    x = np.clip(x, min_values, max_values)

    return x


def gaussian_mutation_batch(offspring_dec, mutation_probability, sigma, min_values, max_values):
    """
    Perform Gaussian mutation on a batch of offspring decision variables.
    """
    # Determine population size and number of decision variables
    num_offspring, num_decision_variables = offspring_dec.shape
    
    # Create a mutation mask for each decision variable of each offspring
    mutation_mask = np.random.rand(num_offspring, num_decision_variables) < mutation_probability
    # Generate Gaussian noise where mutation is to be applied
    noise = np.random.normal(0, sigma, (num_offspring, num_decision_variables)) * mutation_mask
    # Apply mutation
    offspring_dec = offspring_dec + noise
    
    # Ensure mutated offspring values are within bounds
    offspring_dec = np.clip(offspring_dec, min_values, max_values)
    return offspring_dec



# Cell 5: Complete PVOS-2C Implementation with Pymoo Benchmarks
from joblib import Parallel, delayed
from pymoo.core.population import Population
from pymoo.core.individual import Individual

class _ArrayProblem:
    """Minimal stub so SBX sees n_var, xl, xu."""
    def __init__(self, xl, xu):
        self.xl, self.xu = xl, xu
        self.n_var = len(xl)
def run_nsga2(problem, population_size, generations,
             crossover_probability, mutation_probability,
             selected_crossover_operator_names,
             selected_mutation_operator_name,
             distribution_index_n_c, distribution_index_n_m,
             blend_alpha, swap_prob, mutation_sigma,
             random_seed, plot_interval, display_intermediate,
             metrics_interval):
    
    # Get problem parameters from Pymoo object
    num_objectives = problem.n_obj
    num_decision_variables = problem.n_var
    min_values = problem.xl
    max_values = problem.xu
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0

    # Initialize operator map
    operator_map = {
        "simulated_binary_crossover_batch": simulated_binary_crossover_batch,
        "single_point_crossover_batch": single_point_crossover_batch,
        "polynomial_mutation_batch": polynomial_mutation_batch,
        "gaussian_mutation_batch": gaussian_mutation_batch,
        "blend_crossover_batch": blend_crossover_batch,
        "uniform_crossover_batch": uniform_crossover_batch
    }

    # Convert crossover operator names to function objects
    crossover_ops = [operator_map[co_name] for co_name in selected_crossover_operator_names]
    # Get mutation operator
    selected_mutation_operator = operator_map[selected_mutation_operator_name]

    # Set random seeds
    np.random.seed(random_seed)
    random.seed(random_seed)

    # Initialize population
    population = initial_population(population_size, min_values, max_values, problem)
    metrics_history = []

    # Helper function for parallel variation
    def apply_crossover_and_mutation(co, parents_dec_1, parents_dec_2, selected_mutation_operator,
                                     mutation_probability, distribution_index_n_c, distribution_index_n_m,
                                     mutation_sigma, blend_alpha, swap_prob, min_values, max_values, 
                                     crossover_probability):
        # Apply the specified crossover operator, each crossover produced one child.
        if co == simulated_binary_crossover_batch:
            sbx = SBX(prob=crossover_probability,
                      eta=distribution_index_n_c,
                      n_offsprings=1)
        
            _prob = _ArrayProblem(min_values, max_values)
        
            matings = [[Individual(X=p1), Individual(X=p2)]
                       for p1, p2 in zip(parents_dec_1, parents_dec_2)]
        
            # single call → (N, D) offspring
            child_dec = sbx.do(_prob, matings).get("X")      
               


        elif co == single_point_crossover_batch:
            
            child_dec= single_point_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values
            )
        elif co == blend_crossover_batch:
            child_dec = blend_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                blend_alpha,
                min_values,
                max_values
            )
        elif co == uniform_crossover_batch:
            child_dec = uniform_crossover_batch(
                parents_dec_1,
                parents_dec_2,
                crossover_probability,
                min_values,
                max_values,
                swap_prob
            )
  

        else:
            raise ValueError("Crossover operator not recognized.")
    
        # Apply the selected mutation operator on the offspring
        if selected_mutation_operator == polynomial_mutation_batch:
            child_dec = polynomial_mutation_batch(
                child_dec,
                mutation_probability,
                distribution_index_n_m,
                min_values,
                max_values
            )

        elif selected_mutation_operator == gaussian_mutation_batch:
            child_dec = gaussian_mutation_batch(
                child_dec,
                mutation_probability,
                mutation_sigma,
                min_values,
                max_values
            )

        else:
            raise ValueError("Selected mutation operator not recognized.")
    
        # Evaluate offspring
        offspring_dec = child_dec                         
        
        if hasattr(problem, 'n_constr') and problem.n_constr > 0:
            F, G = problem.evaluate(offspring_dec, return_values_of=['F', 'G'])
            CV   = np.sum(np.maximum(G, 0), axis=1, keepdims=True)
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F, CV])
        else:
            eval_result = problem.evaluate(offspring_dec)
            F = eval_result[0] if isinstance(eval_result, tuple) else eval_result
            if F.ndim == 3 and F.shape[1] == 1:
                F = np.squeeze(F, axis=1)
            offspring = np.hstack([offspring_dec, F])
        
        return {"offspring": offspring, "operator": co.__name__}



    # Main evolutionary loop
    for generation in range(1, generations + 1):
        gen_start = time.time()
        
        # Non-dominated sorting
        rank = fast_non_dominated_sort(population, num_objectives, num_constraints)

        
        # Crowding distance calculation
        crowding = np.zeros(len(population))
        for r in range(1, rank.max()+1):
            front_idx = np.where(rank == r)[0]
            crowding += crowding_distance(population, num_objectives, front_idx)


        pair_cnt = population_size // len(crossover_ops)      # 50 pairs when pop_size = 100
        p1_idx, p2_idx = select_parents_batch(population, rank, crowding, pair_cnt)
        parents1 = population[p1_idx, :num_decision_variables]
        parents2 = population[p2_idx, :num_decision_variables]

     
        results = Parallel(n_jobs=len(crossover_ops))(  # the 4 crossovers work in parallel 
            delayed(apply_crossover_and_mutation)(
                op, parents1, parents2,
                selected_mutation_operator,
                mutation_probability,
                distribution_index_n_c,
                distribution_index_n_m,
                mutation_sigma,
                blend_alpha,
                swap_prob,
                min_values,
                max_values,
                crossover_probability
            ) for op in crossover_ops
        )

        
        # Separate offspring and operator labels into lists
        offspring_list = []
        operator_ids_list = []
        for res in results:
            offspring_list.append(res["offspring"])
            # Create an array filled with the operator name for each offspring row
            operator_ids_list.append(np.full(res["offspring"].shape[0], res["operator"]))
        
        # Combine offspring from all operators
        all_offspring = np.vstack(offspring_list)
        #all_operator_ids = np.concatenate(operator_ids_list)


        
        # Population combination and survival selection
        # Tag the original population with a default label (e.g., "parent")
        original_operator_ids = np.array(["parent"] * population.shape[0])
        
        # Combine the offspring from all operators
        combined_offspring = np.vstack(offspring_list)
        combined_operator_ids = np.concatenate([original_operator_ids, np.concatenate(operator_ids_list)])
        
        # Now combine the populations
        combined_pop = np.vstack([population, combined_offspring])
        rank_combined = fast_non_dominated_sort(combined_pop, num_objectives, num_constraints)

        crowding_combined = np.zeros(len(combined_pop))

        for r in range(1, rank_combined.max()+1):
            front_idx = np.where(rank_combined == r)[0]
            crowding_combined += crowding_distance(combined_pop, num_objectives, front_idx)

        # Environmental selection
        survivors = []
        current_rank = 1
        while len(survivors) < population_size and current_rank <= rank_combined.max():
            front_idx = np.where(rank_combined == current_rank)[0]
            if len(survivors) + len(front_idx) <= population_size:
                survivors.extend(front_idx)
            else:
                sorted_front = sorted([(i, crowding_combined[i]) for i in front_idx], 
                                    key=lambda x: -x[1])
                survivors.extend([i for i, _ in sorted_front[:population_size-len(survivors)]])
            current_rank += 1

        population = combined_pop[survivors]
        # Extract operator labels for the survivors
        surviving_operator_ids = combined_operator_ids[survivors]
        
        # Compute counts of survivors per operator
        unique, counts = np.unique(surviving_operator_ids, return_counts=True)
        survival_stats = dict(zip(unique, counts))
        print("Survival counts by operator:", survival_stats)

        # Identify the non-dominated front in the new population
        non_dominated_indices = [i for i in survivors if rank_combined[i] == 1]
        non_dominated_front = combined_pop[non_dominated_indices, problem.n_var: problem.n_var + num_objectives]

        gen_time = time.time() - gen_start

        # Metrics calculation
        if metrics_interval and generation % metrics_interval == 0:
            current_front = non_dominated_front
            
            # Reference point handling
            
            if num_objectives in [2, 3]:
                true_pareto_front = problem.pareto_front() if hasattr(problem, "pareto_front") else None
                if true_pareto_front is not None:
                    nadir_point = np.max(true_pareto_front, axis=0)
                    ref_point = nadir_point * 1.1
                else:
                    ref_point = None  # or define a default reference point, e.g., np.array([1.0, 1.0])


            else:
                ref_point = None

                
            # Metric calculations
            # Compute metrics using the mapping defined in Cell 2
            # Dictionary to hold computed metrics for this generation
            metrics_results = {}
            
            for metric_name, metric_func in metrics_dict.items():
                if metric_name == "hv":
                    metrics_results["hypervolume"] = metric_func(current_front, ref_point)
                elif metric_name in ["igd", "gd", "gd_plus", "igd_plus"]:
                    metrics_results[metric_name] = metric_func(current_front, true_pareto_front) if true_pareto_front is not None else None
                elif metric_name == "spacing":
                    metrics_results["spacing"] = metric_func(current_front)
                else:
                    # If you add other metrics with different signatures, adjust here.
                    metrics_results[metric_name] = metric_func(current_front)
            
            # Add generation and generation time to the metrics record
            metrics_results["crossover_survival"] = survival_stats
            metrics_results["generation"] = generation
            metrics_results["generation_time"] = gen_time
            
            # Append to the overall metrics history
            metrics_history.append(metrics_results)
            
            # Optionally print computed metrics for this generation
            print("Gen {}: {}".format(
                generation,
                ", ".join([f"{k}={v:.4f}" for k, v in metrics_results.items() if isinstance(v, (int, float))])
            ))
        # Visualization
        if display_intermediate and (generation % plot_interval == 0):
            current_front = non_dominated_front
            true_pf = problem.pareto_front() if hasattr(problem, 'pareto_front') else None
            
            plt.figure(figsize=(8, 6))
            if num_objectives == 2:
                plt.scatter(current_front[:, 0], current_front[:, 1], c='blue', label='Approximated')
                if true_pf is not None:
                    plt.scatter(true_pf[:, 0], true_pf[:, 1], c='red', alpha=0.5, label='True')
                plt.xlabel("f1"), plt.ylabel("f2")
            elif num_objectives == 3:
                ax = plt.axes(projection='3d')
                ax.scatter3D(current_front[:, 0], current_front[:, 1], current_front[:, 2], c='blue')
                if true_pf is not None:
                    ax.scatter3D(true_pf[:, 0], true_pf[:, 1], true_pf[:, 2], c='red', alpha=0.5)
                ax.set_xlabel("f1"), ax.set_ylabel("f2"), ax.set_zlabel("f3")
            
            plt.title(f"{problem.__class__.__name__} Generation {generation}")
            plt.legend()
            plt.show()
            clear_output(wait=True)

    return population, problem.pareto_front(), metrics_history



#cell6
def plot_pareto_front(approximated_front, true_front, problem):
    """
    Plot comparison between approximated and true Pareto fronts (using Pymoo data for the analytical solution)
    
    """
    plt.figure(figsize=(10, 6))
    
    # Get problem metadata from Pymoo
    num_objectives = problem.n_obj
    problem_name = problem.__class__.__name__
    
    if num_objectives == 2:
        # 2D Plot for approximated front
        plt.scatter(approximated_front[:, 0], approximated_front[:, 1], 
                   c='blue', s=30, edgecolors='k', label='NSGA-II')
        
        # Plot true Pareto front only if available
        if true_front is not None:
            plt.scatter(true_front[:, 0], true_front[:, 1],
                        c='red', s=15, alpha=0.6, label='True Pareto')
        
        plt.xlabel("$f_1$", fontsize=12)
        plt.ylabel("$f_2$", fontsize=12)
        plt.title(f"{problem_name} Pareto Front Comparison", fontsize=14)
        
    elif num_objectives == 3:
        # 3D Plot for approximated front
        ax = plt.axes(projection='3d')
        ax.scatter3D(approximated_front[:, 0], approximated_front[:, 1], approximated_front[:, 2],
                     c='blue', s=30, edgecolors='k', label='NSGA-II')
        if true_front is not None:
            ax.scatter3D(true_front[:, 0], true_front[:, 1], true_front[:, 2],
                         c='red', s=15, alpha=0.6, label='True Pareto')
        
        ax.set_xlabel("$f_1$", fontsize=10)
        ax.set_ylabel("$f_2$", fontsize=10)
        ax.set_zlabel("$f_3$", fontsize=10)
        ax.view_init(elev=45, azim=45)
        plt.title(f"{problem_name} 3D Pareto Front", fontsize=14)
    else:
        print(f"Visualization not supported for {num_objectives} objectives")
        return

    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    
    # Optionally, if a true Pareto front is available and it is 2D, you can plot a continuous line.
    if true_front is not None and num_objectives == 2:
        plt.plot(true_front[:, 0], true_front[:, 1], 
                 c='black', lw=1, ls='--', alpha=0.7, label='Analytical Solution')
            
    plt.show()




# cell 7

import numpy as np
import importlib



# Determine the metrics interval based on the control flag.
metrics_interval_value = default_metrics_interval if compute_metrics_each_gen else None


# =============================================================================
#                         Modified Execution Function
# =============================================================================

def run_nsga2_for_seed(seed):
    """Run NSGA-II for a single seed with proper Pymoo integration"""
    print(f"\n=== Running NSGA-II with seed {seed} ===")
    
    
    
    problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    

    


    
    # 2. Run NSGA-II with corrected parameters
    final_population, true_pareto, metrics_history = run_nsga2(
        problem=problem,  
        population_size=pop_size,
        generations=generations,
        crossover_probability=crossover_probability,
        mutation_probability=mutation_probability,
        selected_crossover_operator_names=selected_crossover_operator_names,
        selected_mutation_operator_name=selected_mutation_operator_name,
        distribution_index_n_c=distribution_index_n_c,
        distribution_index_n_m=distribution_index_n_m,
        blend_alpha=blend_alpha,
        swap_prob=swap_prob,
        mutation_sigma=mutation_sigma,
        random_seed=seed,
        plot_interval=plot_interval,
        display_intermediate=display_intermediate,
        metrics_interval=metrics_interval_value
    )
    
    # 3. Add seed information to metrics
    for metric in metrics_history:
        metric['seed'] = seed

    # 4. Identify non-dominated solutions
    num_constraints = 1 if (hasattr(problem, 'n_constr') and problem.n_constr > 0) else 0
    final_rank = fast_non_dominated_sort(final_population, problem.n_obj, num_constraints)

    non_dominated_indices = np.where(final_rank == 1)[0]
    pareto_points = final_population[non_dominated_indices, D : D + M]
    
    # 5. Plot results if enabled
    if display_intermediate:
        plot_pareto_front(pareto_points, true_pareto, problem)
        
    return {
        'seed': seed,
        'final_population': final_population,
        'true_pareto': true_pareto,
        'metrics_history': metrics_history,
        'pareto_points': pareto_points
    }

# Run NSGA-II in series for seeds 1 to 30 (or 31 if you prefer 1 to 31)  
seeds = range(1, 31)
results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)

# Prepare containers for combined metrics and final populations.
all_metrics = []      
final_populations = []  
true_paretos = []       

# Process the results from parallel runs.
for result in results:
    seed = result['seed']
    final_populations.append(result['final_population'])
    true_paretos.append(result['true_pareto'])
    all_metrics.extend(result['metrics_history'])
    
    pareto_points = result['pareto_points']
    print(f"Seed {seed} - Number of Pareto front points: {pareto_points.shape[0]}")
    


    if pareto_points.size > 0:
        plot_pareto_front(
            approximated_front=pareto_points,
            true_front=result['true_pareto'],

            problem = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)

        )
    else:
        print(f"Seed {seed}: Empty Pareto front")
# Out:
# === Running NSGA-II with seed 1 ===
# Survival counts by operator: {np.str_('parent'): np.int64(37), np.str_('simulated_binary_crossover_batch'): np.int64(32), np.str_('single_point_crossover_batch'): np.int64(31)}
#
# Compiled modules for significant speedup can not be used!
# https://pymoo.org/installation.html#installation
#
# To disable this warning:
# from pymoo.config import Config
# Config.warnings['not_compiled'] = False
#
# Gen 1: hypervolume=0.0000, igd=1.9062, gd=2.3972, gd_plus=2.3972, igd_plus=1.9062, spacing=0.1884, generation=1.0000, generation_time=0.5375
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 2: hypervolume=0.0000, igd=1.9062, gd=2.2652, gd_plus=2.2652, igd_plus=1.9062, spacing=0.2057, generation=2.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(32)}
# Gen 3: hypervolume=0.0000, igd=1.6045, gd=2.1934, gd_plus=2.1934, igd_plus=1.6045, spacing=0.1456, generation=3.0000, generation_time=0.0190
# Survival counts by operator: {np.str_('parent'): np.int64(37), np.str_('simulated_binary_crossover_batch'): np.int64(35), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 4: hypervolume=0.0000, igd=1.5263, gd=2.1486, gd_plus=2.1486, igd_plus=1.5263, spacing=0.1311, generation=4.0000, generation_time=0.0178
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 5: hypervolume=0.0000, igd=1.4185, gd=2.0625, gd_plus=2.0625, igd_plus=1.4184, spacing=0.1737, generation=5.0000, generation_time=0.0303
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(32)}
# Gen 6: hypervolume=0.0000, igd=1.2786, gd=1.7758, gd_plus=1.7758, igd_plus=1.2785, spacing=0.1164, generation=6.0000, generation_time=0.0256
# Survival counts by operator: {np.str_('parent'): np.int64(39), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(30)}
# Gen 7: hypervolume=0.0000, igd=1.1509, gd=1.5140, gd_plus=1.5140, igd_plus=1.1508, spacing=0.1140, generation=7.0000, generation_time=0.0204
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(30), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 8: hypervolume=0.0000, igd=1.1312, gd=1.4814, gd_plus=1.4814, igd_plus=1.1311, spacing=0.0687, generation=8.0000, generation_time=0.0149
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 9: hypervolume=0.0000, igd=1.1212, gd=1.3205, gd_plus=1.3205, igd_plus=1.1212, spacing=0.0595, generation=9.0000, generation_time=0.0269
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 10: hypervolume=0.0000, igd=0.9694, gd=1.3769, gd_plus=1.3769, igd_plus=0.9693, spacing=0.0577, generation=10.0000, generation_time=0.0138
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(31)}
# Gen 11: hypervolume=0.0000, igd=0.9667, gd=1.1469, gd_plus=1.1469, igd_plus=0.9665, spacing=0.0718, generation=11.0000, generation_time=0.0274
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 12: hypervolume=0.0322, igd=0.8104, gd=1.2205, gd_plus=1.2205, igd_plus=0.8104, spacing=0.0688, generation=12.0000, generation_time=0.0230
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(32)}
# Gen 13: hypervolume=0.0332, igd=0.7989, gd=1.1548, gd_plus=1.1548, igd_plus=0.7988, spacing=0.0603, generation=13.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 14: hypervolume=0.0422, igd=0.7545, gd=1.0917, gd_plus=1.0917, igd_plus=0.7544, spacing=0.0719, generation=14.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 15: hypervolume=0.0673, igd=0.6992, gd=1.0644, gd_plus=1.0644, igd_plus=0.6991, spacing=0.0648, generation=15.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 16: hypervolume=0.0727, igd=0.6941, gd=0.9559, gd_plus=0.9559, igd_plus=0.6940, spacing=0.0769, generation=16.0000, generation_time=0.0180
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 17: hypervolume=0.0881, igd=0.6616, gd=0.8252, gd_plus=0.8252, igd_plus=0.6615, spacing=0.0479, generation=17.0000, generation_time=0.0204
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 18: hypervolume=0.0995, igd=0.6388, gd=0.8213, gd_plus=0.8213, igd_plus=0.6386, spacing=0.0528, generation=18.0000, generation_time=0.0239
# Survival counts by operator: {np.str_('parent'): np.int64(40), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(33)}
# Gen 19: hypervolume=0.1120, igd=0.6194, gd=0.7372, gd_plus=0.7372, igd_plus=0.6192, spacing=0.0614, generation=19.0000, generation_time=0.0296
# Survival counts by operator: {np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 20: hypervolume=0.1511, igd=0.5237, gd=0.6613, gd_plus=0.6613, igd_plus=0.5237, spacing=0.0638, generation=20.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(32), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 21: hypervolume=0.1666, igd=0.5162, gd=0.6128, gd_plus=0.6128, igd_plus=0.5162, spacing=0.0532, generation=21.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(41), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(32)}
# Gen 22: hypervolume=0.2036, igd=0.4846, gd=0.5983, gd_plus=0.5983, igd_plus=0.4846, spacing=0.0640, generation=22.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 23: hypervolume=0.2440, igd=0.4502, gd=0.6074, gd_plus=0.6074, igd_plus=0.4502, spacing=0.0596, generation=23.0000, generation_time=0.0157
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 24: hypervolume=0.2723, igd=0.4158, gd=0.5278, gd_plus=0.5278, igd_plus=0.4158, spacing=0.0480, generation=24.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 25: hypervolume=0.2874, igd=0.4055, gd=0.4685, gd_plus=0.4685, igd_plus=0.4055, spacing=0.0338, generation=25.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(31)}
# Gen 26: hypervolume=0.3319, igd=0.3547, gd=0.4613, gd_plus=0.4613, igd_plus=0.3546, spacing=0.0335, generation=26.0000, generation_time=0.0189
# Survival counts by operator: {np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(32), np.str_('single_point_crossover_batch'): np.int64(26)}
# Gen 27: hypervolume=0.3458, igd=0.3502, gd=0.4324, gd_plus=0.4324, igd_plus=0.3502, spacing=0.0324, generation=27.0000, generation_time=0.0249
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(29)}
# Gen 28: hypervolume=0.3571, igd=0.3423, gd=0.3642, gd_plus=0.3642, igd_plus=0.3423, spacing=0.0348, generation=28.0000, generation_time=0.0287
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 29: hypervolume=0.3747, igd=0.3321, gd=0.3593, gd_plus=0.3593, igd_plus=0.3321, spacing=0.0348, generation=29.0000, generation_time=0.0289
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 30: hypervolume=0.3957, igd=0.3256, gd=0.3572, gd_plus=0.3572, igd_plus=0.3256, spacing=0.0248, generation=30.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 31: hypervolume=0.4120, igd=0.3111, gd=0.3527, gd_plus=0.3526, igd_plus=0.3110, spacing=0.0294, generation=31.0000, generation_time=0.0281
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 32: hypervolume=0.4231, igd=0.2988, gd=0.3443, gd_plus=0.3443, igd_plus=0.2988, spacing=0.0298, generation=32.0000, generation_time=0.0233
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 33: hypervolume=0.4372, igd=0.2885, gd=0.3155, gd_plus=0.3155, igd_plus=0.2885, spacing=0.0363, generation=33.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 34: hypervolume=0.4481, igd=0.2788, gd=0.2958, gd_plus=0.2958, igd_plus=0.2788, spacing=0.0443, generation=34.0000, generation_time=0.0251
# Survival counts by operator: {np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 35: hypervolume=0.4612, igd=0.2709, gd=0.3045, gd_plus=0.3045, igd_plus=0.2709, spacing=0.0266, generation=35.0000, generation_time=0.0261
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 36: hypervolume=0.4749, igd=0.2591, gd=0.3010, gd_plus=0.3010, igd_plus=0.2591, spacing=0.0281, generation=36.0000, generation_time=0.0264
# Survival counts by operator: {np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 37: hypervolume=0.4867, igd=0.2462, gd=0.2961, gd_plus=0.2961, igd_plus=0.2461, spacing=0.0318, generation=37.0000, generation_time=0.0302
# Survival counts by operator: {np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 38: hypervolume=0.4967, igd=0.2410, gd=0.2729, gd_plus=0.2729, igd_plus=0.2409, spacing=0.0316, generation=38.0000, generation_time=0.0161
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 39: hypervolume=0.5138, igd=0.2310, gd=0.2623, gd_plus=0.2622, igd_plus=0.2309, spacing=0.0262, generation=39.0000, generation_time=0.0261
# Survival counts by operator: {np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 40: hypervolume=0.5227, igd=0.2245, gd=0.2469, gd_plus=0.2468, igd_plus=0.2244, spacing=0.0240, generation=40.0000, generation_time=0.0303
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 41: hypervolume=0.5296, igd=0.2197, gd=0.2419, gd_plus=0.2418, igd_plus=0.2195, spacing=0.0197, generation=41.0000, generation_time=0.0282
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 42: hypervolume=0.5378, igd=0.2172, gd=0.2233, gd_plus=0.2232, igd_plus=0.2171, spacing=0.0235, generation=42.0000, generation_time=0.0311
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 43: hypervolume=0.5557, igd=0.2038, gd=0.2124, gd_plus=0.2123, igd_plus=0.2037, spacing=0.0268, generation=43.0000, generation_time=0.0280
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 44: hypervolume=0.5718, igd=0.1942, gd=0.1997, gd_plus=0.1995, igd_plus=0.1941, spacing=0.0254, generation=44.0000, generation_time=0.0301
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(31), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 45: hypervolume=0.5799, igd=0.1901, gd=0.1991, gd_plus=0.1990, igd_plus=0.1899, spacing=0.0178, generation=45.0000, generation_time=0.0168
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 46: hypervolume=0.5843, igd=0.1884, gd=0.1986, gd_plus=0.1985, igd_plus=0.1883, spacing=0.0190, generation=46.0000, generation_time=0.0176
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 47: hypervolume=0.5912, igd=0.1826, gd=0.1887, gd_plus=0.1885, igd_plus=0.1825, spacing=0.0189, generation=47.0000, generation_time=0.0321
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 48: hypervolume=0.6019, igd=0.1760, gd=0.1847, gd_plus=0.1846, igd_plus=0.1758, spacing=0.0201, generation=48.0000, generation_time=0.0300
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 49: hypervolume=0.6112, igd=0.1698, gd=0.1785, gd_plus=0.1784, igd_plus=0.1696, spacing=0.0176, generation=49.0000, generation_time=0.0203
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 50: hypervolume=0.6154, igd=0.1666, gd=0.1672, gd_plus=0.1671, igd_plus=0.1664, spacing=0.0204, generation=50.0000, generation_time=0.0289
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 51: hypervolume=0.6248, igd=0.1577, gd=0.1605, gd_plus=0.1603, igd_plus=0.1575, spacing=0.0189, generation=51.0000, generation_time=0.0325
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(23)}
# Gen 52: hypervolume=0.6373, igd=0.1482, gd=0.1482, gd_plus=0.1479, igd_plus=0.1481, spacing=0.0213, generation=52.0000, generation_time=0.0185
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 53: hypervolume=0.6466, igd=0.1416, gd=0.1407, gd_plus=0.1406, igd_plus=0.1416, spacing=0.0191, generation=53.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(24)}
# Gen 54: hypervolume=0.6537, igd=0.1365, gd=0.1427, gd_plus=0.1425, igd_plus=0.1364, spacing=0.0216, generation=54.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 55: hypervolume=0.6614, igd=0.1294, gd=0.1328, gd_plus=0.1327, igd_plus=0.1293, spacing=0.0208, generation=55.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 56: hypervolume=0.6657, igd=0.1284, gd=0.1290, gd_plus=0.1290, igd_plus=0.1284, spacing=0.0156, generation=56.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(28)}
# Gen 57: hypervolume=0.6796, igd=0.1196, gd=0.1225, gd_plus=0.1222, igd_plus=0.1196, spacing=0.0195, generation=57.0000, generation_time=0.0179
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 58: hypervolume=0.6856, igd=0.1166, gd=0.1221, gd_plus=0.1219, igd_plus=0.1165, spacing=0.0186, generation=58.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 59: hypervolume=0.6938, igd=0.1112, gd=0.1223, gd_plus=0.1219, igd_plus=0.1111, spacing=0.0177, generation=59.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 60: hypervolume=0.7024, igd=0.1061, gd=0.1173, gd_plus=0.1169, igd_plus=0.1060, spacing=0.0229, generation=60.0000, generation_time=0.0149
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(25)}
# Gen 61: hypervolume=0.7130, igd=0.0997, gd=0.1090, gd_plus=0.1086, igd_plus=0.0996, spacing=0.0217, generation=61.0000, generation_time=0.0184
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 62: hypervolume=0.7194, igd=0.0968, gd=0.1007, gd_plus=0.1002, igd_plus=0.0967, spacing=0.0173, generation=62.0000, generation_time=0.0157
# Survival counts by operator: {np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 63: hypervolume=0.7272, igd=0.0907, gd=0.0884, gd_plus=0.0879, igd_plus=0.0900, spacing=0.0189, generation=63.0000, generation_time=0.0157
# Survival counts by operator: {np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 64: hypervolume=0.7360, igd=0.0851, gd=0.0834, gd_plus=0.0829, igd_plus=0.0844, spacing=0.0185, generation=64.0000, generation_time=0.0244
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 65: hypervolume=0.7430, igd=0.0811, gd=0.0817, gd_plus=0.0812, igd_plus=0.0801, spacing=0.0172, generation=65.0000, generation_time=0.0240
# Survival counts by operator: {np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 66: hypervolume=0.7500, igd=0.0762, gd=0.0769, gd_plus=0.0763, igd_plus=0.0751, spacing=0.0170, generation=66.0000, generation_time=0.0286
# Survival counts by operator: {np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(27)}
# Gen 67: hypervolume=0.7537, igd=0.0732, gd=0.0735, gd_plus=0.0729, igd_plus=0.0722, spacing=0.0146, generation=67.0000, generation_time=0.0250
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 68: hypervolume=0.7573, igd=0.0711, gd=0.0697, gd_plus=0.0693, igd_plus=0.0700, spacing=0.0158, generation=68.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(20)}
# Gen 69: hypervolume=0.7623, igd=0.0683, gd=0.0680, gd_plus=0.0673, igd_plus=0.0672, spacing=0.0130, generation=69.0000, generation_time=0.0291
# Survival counts by operator: {np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(27), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 70: hypervolume=0.7688, igd=0.0642, gd=0.0627, gd_plus=0.0620, igd_plus=0.0631, spacing=0.0118, generation=70.0000, generation_time=0.0170
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(24), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 71: hypervolume=0.7754, igd=0.0597, gd=0.0590, gd_plus=0.0585, igd_plus=0.0597, spacing=0.0123, generation=71.0000, generation_time=0.0266
# Survival counts by operator: {np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(29), np.str_('single_point_crossover_batch'): np.int64(22)}
# Gen 72: hypervolume=0.7806, igd=0.0570, gd=0.0575, gd_plus=0.0569, igd_plus=0.0570, spacing=0.0093, generation=72.0000, generation_time=0.0276
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 73: hypervolume=0.7840, igd=0.0547, gd=0.0569, gd_plus=0.0562, igd_plus=0.0544, spacing=0.0113, generation=73.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 74: hypervolume=0.7871, igd=0.0531, gd=0.0530, gd_plus=0.0527, igd_plus=0.0528, spacing=0.0108, generation=74.0000, generation_time=0.0280
# Survival counts by operator: {np.str_('parent'): np.int64(59), np.str_('simulated_binary_crossover_batch'): np.int64(28), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 75: hypervolume=0.7913, igd=0.0505, gd=0.0508, gd_plus=0.0504, igd_plus=0.0501, spacing=0.0091, generation=75.0000, generation_time=0.0250
# Survival counts by operator: {np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(26), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 76: hypervolume=0.7948, igd=0.0486, gd=0.0477, gd_plus=0.0474, igd_plus=0.0482, spacing=0.0102, generation=76.0000, generation_time=0.0296
# Survival counts by operator: {np.str_('parent'): np.int64(57), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 77: hypervolume=0.7989, igd=0.0458, gd=0.0460, gd_plus=0.0455, igd_plus=0.0455, spacing=0.0101, generation=77.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('parent'): np.int64(59), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 78: hypervolume=0.8016, igd=0.0444, gd=0.0446, gd_plus=0.0436, igd_plus=0.0441, spacing=0.0104, generation=78.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 79: hypervolume=0.8030, igd=0.0435, gd=0.0434, gd_plus=0.0424, igd_plus=0.0432, spacing=0.0113, generation=79.0000, generation_time=0.0206
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 80: hypervolume=0.8053, igd=0.0419, gd=0.0413, gd_plus=0.0404, igd_plus=0.0415, spacing=0.0107, generation=80.0000, generation_time=0.0180
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 81: hypervolume=0.8076, igd=0.0405, gd=0.0399, gd_plus=0.0390, igd_plus=0.0404, spacing=0.0104, generation=81.0000, generation_time=0.0138
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 82: hypervolume=0.8099, igd=0.0389, gd=0.0394, gd_plus=0.0381, igd_plus=0.0388, spacing=0.0109, generation=82.0000, generation_time=0.0194
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 83: hypervolume=0.8128, igd=0.0367, gd=0.0373, gd_plus=0.0360, igd_plus=0.0366, spacing=0.0099, generation=83.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 84: hypervolume=0.8150, igd=0.0357, gd=0.0365, gd_plus=0.0360, igd_plus=0.0356, spacing=0.0109, generation=84.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 85: hypervolume=0.8170, igd=0.0343, gd=0.0357, gd_plus=0.0347, igd_plus=0.0343, spacing=0.0098, generation=85.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 86: hypervolume=0.8199, igd=0.0329, gd=0.0338, gd_plus=0.0327, igd_plus=0.0329, spacing=0.0093, generation=86.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 87: hypervolume=0.8214, igd=0.0320, gd=0.0331, gd_plus=0.0320, igd_plus=0.0320, spacing=0.0083, generation=87.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 88: hypervolume=0.8231, igd=0.0309, gd=0.0322, gd_plus=0.0312, igd_plus=0.0309, spacing=0.0090, generation=88.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 89: hypervolume=0.8256, igd=0.0294, gd=0.0311, gd_plus=0.0302, igd_plus=0.0294, spacing=0.0097, generation=89.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 90: hypervolume=0.8273, igd=0.0284, gd=0.0300, gd_plus=0.0289, igd_plus=0.0284, spacing=0.0086, generation=90.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 91: hypervolume=0.8281, igd=0.0278, gd=0.0287, gd_plus=0.0276, igd_plus=0.0278, spacing=0.0083, generation=91.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(9)}
# Gen 92: hypervolume=0.8308, igd=0.0265, gd=0.0278, gd_plus=0.0267, igd_plus=0.0265, spacing=0.0082, generation=92.0000, generation_time=0.0121
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 93: hypervolume=0.8326, igd=0.0254, gd=0.0267, gd_plus=0.0255, igd_plus=0.0253, spacing=0.0085, generation=93.0000, generation_time=0.0162
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 94: hypervolume=0.8332, igd=0.0252, gd=0.0261, gd_plus=0.0248, igd_plus=0.0252, spacing=0.0071, generation=94.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 95: hypervolume=0.8340, igd=0.0248, gd=0.0255, gd_plus=0.0243, igd_plus=0.0247, spacing=0.0068, generation=95.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 96: hypervolume=0.8351, igd=0.0240, gd=0.0247, gd_plus=0.0234, igd_plus=0.0239, spacing=0.0069, generation=96.0000, generation_time=0.0220
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 97: hypervolume=0.8363, igd=0.0235, gd=0.0240, gd_plus=0.0230, igd_plus=0.0234, spacing=0.0069, generation=97.0000, generation_time=0.0220
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 98: hypervolume=0.8376, igd=0.0227, gd=0.0235, gd_plus=0.0225, igd_plus=0.0227, spacing=0.0063, generation=98.0000, generation_time=0.0246
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 99: hypervolume=0.8386, igd=0.0221, gd=0.0231, gd_plus=0.0220, igd_plus=0.0220, spacing=0.0058, generation=99.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 100: hypervolume=0.8394, igd=0.0216, gd=0.0228, gd_plus=0.0218, igd_plus=0.0215, spacing=0.0060, generation=100.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 101: hypervolume=0.8399, igd=0.0213, gd=0.0223, gd_plus=0.0211, igd_plus=0.0212, spacing=0.0056, generation=101.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 102: hypervolume=0.8409, igd=0.0205, gd=0.0216, gd_plus=0.0203, igd_plus=0.0204, spacing=0.0062, generation=102.0000, generation_time=0.0302
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 103: hypervolume=0.8420, igd=0.0198, gd=0.0206, gd_plus=0.0196, igd_plus=0.0198, spacing=0.0067, generation=103.0000, generation_time=0.0234
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 104: hypervolume=0.8424, igd=0.0195, gd=0.0208, gd_plus=0.0194, igd_plus=0.0195, spacing=0.0070, generation=104.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 105: hypervolume=0.8431, igd=0.0191, gd=0.0203, gd_plus=0.0189, igd_plus=0.0191, spacing=0.0065, generation=105.0000, generation_time=0.0235
# Survival counts by operator: {np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(25), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 106: hypervolume=0.8440, igd=0.0184, gd=0.0194, gd_plus=0.0181, igd_plus=0.0184, spacing=0.0059, generation=106.0000, generation_time=0.0302
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 107: hypervolume=0.8451, igd=0.0180, gd=0.0187, gd_plus=0.0178, igd_plus=0.0180, spacing=0.0058, generation=107.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 108: hypervolume=0.8458, igd=0.0176, gd=0.0182, gd_plus=0.0174, igd_plus=0.0175, spacing=0.0063, generation=108.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 109: hypervolume=0.8461, igd=0.0173, gd=0.0180, gd_plus=0.0170, igd_plus=0.0173, spacing=0.0067, generation=109.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 110: hypervolume=0.8465, igd=0.0172, gd=0.0178, gd_plus=0.0167, igd_plus=0.0171, spacing=0.0064, generation=110.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(8)}
# Gen 111: hypervolume=0.8472, igd=0.0168, gd=0.0173, gd_plus=0.0162, igd_plus=0.0168, spacing=0.0065, generation=111.0000, generation_time=0.0229
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 112: hypervolume=0.8482, igd=0.0162, gd=0.0169, gd_plus=0.0156, igd_plus=0.0161, spacing=0.0065, generation=112.0000, generation_time=0.0288
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 113: hypervolume=0.8487, igd=0.0159, gd=0.0166, gd_plus=0.0151, igd_plus=0.0158, spacing=0.0061, generation=113.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 114: hypervolume=0.8498, igd=0.0151, gd=0.0157, gd_plus=0.0144, igd_plus=0.0150, spacing=0.0073, generation=114.0000, generation_time=0.0197
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 115: hypervolume=0.8498, igd=0.0149, gd=0.0157, gd_plus=0.0144, igd_plus=0.0148, spacing=0.0076, generation=115.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 116: hypervolume=0.8506, igd=0.0144, gd=0.0153, gd_plus=0.0140, igd_plus=0.0143, spacing=0.0076, generation=116.0000, generation_time=0.0198
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 117: hypervolume=0.8514, igd=0.0140, gd=0.0149, gd_plus=0.0136, igd_plus=0.0139, spacing=0.0075, generation=117.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 118: hypervolume=0.8518, igd=0.0138, gd=0.0147, gd_plus=0.0132, igd_plus=0.0137, spacing=0.0073, generation=118.0000, generation_time=0.0175
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 119: hypervolume=0.8526, igd=0.0133, gd=0.0142, gd_plus=0.0128, igd_plus=0.0132, spacing=0.0069, generation=119.0000, generation_time=0.0163
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 120: hypervolume=0.8535, igd=0.0127, gd=0.0137, gd_plus=0.0125, igd_plus=0.0126, spacing=0.0066, generation=120.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 121: hypervolume=0.8541, igd=0.0124, gd=0.0136, gd_plus=0.0121, igd_plus=0.0123, spacing=0.0066, generation=121.0000, generation_time=0.0317
# Survival counts by operator: {np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 122: hypervolume=0.8546, igd=0.0122, gd=0.0132, gd_plus=0.0116, igd_plus=0.0120, spacing=0.0068, generation=122.0000, generation_time=0.0209
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(23), np.str_('single_point_crossover_batch'): np.int64(8)}
# Gen 123: hypervolume=0.8552, igd=0.0118, gd=0.0126, gd_plus=0.0115, igd_plus=0.0117, spacing=0.0068, generation=123.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 124: hypervolume=0.8555, igd=0.0117, gd=0.0126, gd_plus=0.0112, igd_plus=0.0116, spacing=0.0072, generation=124.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 125: hypervolume=0.8561, igd=0.0114, gd=0.0122, gd_plus=0.0111, igd_plus=0.0113, spacing=0.0069, generation=125.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 126: hypervolume=0.8563, igd=0.0113, gd=0.0119, gd_plus=0.0108, igd_plus=0.0111, spacing=0.0079, generation=126.0000, generation_time=0.0186
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 127: hypervolume=0.8572, igd=0.0107, gd=0.0117, gd_plus=0.0102, igd_plus=0.0105, spacing=0.0075, generation=127.0000, generation_time=0.0311
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 128: hypervolume=0.8577, igd=0.0105, gd=0.0114, gd_plus=0.0099, igd_plus=0.0103, spacing=0.0067, generation=128.0000, generation_time=0.0226
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 129: hypervolume=0.8580, igd=0.0103, gd=0.0112, gd_plus=0.0098, igd_plus=0.0101, spacing=0.0059, generation=129.0000, generation_time=0.0287
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 130: hypervolume=0.8583, igd=0.0102, gd=0.0111, gd_plus=0.0098, igd_plus=0.0100, spacing=0.0059, generation=130.0000, generation_time=0.0166
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 131: hypervolume=0.8587, igd=0.0099, gd=0.0109, gd_plus=0.0095, igd_plus=0.0096, spacing=0.0066, generation=131.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 132: hypervolume=0.8589, igd=0.0100, gd=0.0110, gd_plus=0.0095, igd_plus=0.0096, spacing=0.0068, generation=132.0000, generation_time=0.0278
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 133: hypervolume=0.8594, igd=0.0099, gd=0.0109, gd_plus=0.0093, igd_plus=0.0094, spacing=0.0067, generation=133.0000, generation_time=0.0276
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 134: hypervolume=0.8599, igd=0.0094, gd=0.0103, gd_plus=0.0089, igd_plus=0.0090, spacing=0.0067, generation=134.0000, generation_time=0.0370
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 135: hypervolume=0.8604, igd=0.0092, gd=0.0098, gd_plus=0.0085, igd_plus=0.0089, spacing=0.0066, generation=135.0000, generation_time=0.0241
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 136: hypervolume=0.8605, igd=0.0091, gd=0.0097, gd_plus=0.0083, igd_plus=0.0088, spacing=0.0064, generation=136.0000, generation_time=0.0173
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 137: hypervolume=0.8606, igd=0.0090, gd=0.0095, gd_plus=0.0081, igd_plus=0.0086, spacing=0.0069, generation=137.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 138: hypervolume=0.8606, igd=0.0089, gd=0.0095, gd_plus=0.0080, igd_plus=0.0086, spacing=0.0068, generation=138.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 139: hypervolume=0.8607, igd=0.0088, gd=0.0094, gd_plus=0.0080, igd_plus=0.0085, spacing=0.0069, generation=139.0000, generation_time=0.0256
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 140: hypervolume=0.8612, igd=0.0085, gd=0.0091, gd_plus=0.0077, igd_plus=0.0082, spacing=0.0067, generation=140.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 141: hypervolume=0.8615, igd=0.0082, gd=0.0089, gd_plus=0.0074, igd_plus=0.0079, spacing=0.0070, generation=141.0000, generation_time=0.0298
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 142: hypervolume=0.8615, igd=0.0082, gd=0.0086, gd_plus=0.0072, igd_plus=0.0079, spacing=0.0068, generation=142.0000, generation_time=0.0265
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(22), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 143: hypervolume=0.8624, igd=0.0075, gd=0.0083, gd_plus=0.0069, igd_plus=0.0073, spacing=0.0070, generation=143.0000, generation_time=0.0250
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 144: hypervolume=0.8624, igd=0.0076, gd=0.0084, gd_plus=0.0067, igd_plus=0.0073, spacing=0.0068, generation=144.0000, generation_time=0.0167
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 145: hypervolume=0.8626, igd=0.0076, gd=0.0079, gd_plus=0.0066, igd_plus=0.0072, spacing=0.0075, generation=145.0000, generation_time=0.0173
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 146: hypervolume=0.8627, igd=0.0075, gd=0.0077, gd_plus=0.0064, igd_plus=0.0072, spacing=0.0075, generation=146.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(6)}
# Gen 147: hypervolume=0.8631, igd=0.0073, gd=0.0076, gd_plus=0.0063, igd_plus=0.0070, spacing=0.0066, generation=147.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(8), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 148: hypervolume=0.8632, igd=0.0072, gd=0.0075, gd_plus=0.0062, igd_plus=0.0069, spacing=0.0065, generation=148.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(8)}
# Gen 149: hypervolume=0.8634, igd=0.0072, gd=0.0078, gd_plus=0.0062, igd_plus=0.0069, spacing=0.0076, generation=149.0000, generation_time=0.0154
# ...
# Gen 151: hypervolume=0.8638, igd=0.0070, gd=0.0076, gd_plus=0.0062, igd_plus=0.0065, spacing=0.0067, generation=151.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(7)}
# Gen 152: hypervolume=0.8640, igd=0.0068, gd=0.0075, gd_plus=0.0061, igd_plus=0.0064, spacing=0.0072, generation=152.0000, generation_time=0.0138
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 153: hypervolume=0.8642, igd=0.0069, gd=0.0075, gd_plus=0.0061, igd_plus=0.0064, spacing=0.0071, generation=153.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 154: hypervolume=0.8646, igd=0.0067, gd=0.0074, gd_plus=0.0057, igd_plus=0.0062, spacing=0.0069, generation=154.0000, generation_time=0.0267
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 155: hypervolume=0.8645, igd=0.0067, gd=0.0073, gd_plus=0.0056, igd_plus=0.0061, spacing=0.0074, generation=155.0000, generation_time=0.0132
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 156: hypervolume=0.8648, igd=0.0066, gd=0.0074, gd_plus=0.0057, igd_plus=0.0061, spacing=0.0059, generation=156.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 157: hypervolume=0.8650, igd=0.0064, gd=0.0073, gd_plus=0.0057, igd_plus=0.0060, spacing=0.0061, generation=157.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 158: hypervolume=0.8653, igd=0.0062, gd=0.0071, gd_plus=0.0055, igd_plus=0.0057, spacing=0.0059, generation=158.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 159: hypervolume=0.8656, igd=0.0061, gd=0.0064, gd_plus=0.0055, igd_plus=0.0056, spacing=0.0065, generation=159.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 160: hypervolume=0.8655, igd=0.0061, gd=0.0064, gd_plus=0.0055, igd_plus=0.0057, spacing=0.0064, generation=160.0000, generation_time=0.0261
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 161: hypervolume=0.8654, igd=0.0061, gd=0.0068, gd_plus=0.0053, igd_plus=0.0057, spacing=0.0058, generation=161.0000, generation_time=0.0253
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(20), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 162: hypervolume=0.8654, igd=0.0063, gd=0.0071, gd_plus=0.0053, igd_plus=0.0058, spacing=0.0060, generation=162.0000, generation_time=0.0230
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 163: hypervolume=0.8657, igd=0.0060, gd=0.0070, gd_plus=0.0051, igd_plus=0.0056, spacing=0.0064, generation=163.0000, generation_time=0.0275
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 164: hypervolume=0.8658, igd=0.0060, gd=0.0071, gd_plus=0.0052, igd_plus=0.0055, spacing=0.0065, generation=164.0000, generation_time=0.0247
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 165: hypervolume=0.8657, igd=0.0060, gd=0.0068, gd_plus=0.0050, igd_plus=0.0055, spacing=0.0067, generation=165.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 166: hypervolume=0.8659, igd=0.0058, gd=0.0068, gd_plus=0.0049, igd_plus=0.0053, spacing=0.0068, generation=166.0000, generation_time=0.0168
# Survival counts by operator: {np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 167: hypervolume=0.8661, igd=0.0057, gd=0.0067, gd_plus=0.0048, igd_plus=0.0052, spacing=0.0063, generation=167.0000, generation_time=0.0166
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 168: hypervolume=0.8661, igd=0.0056, gd=0.0062, gd_plus=0.0047, igd_plus=0.0051, spacing=0.0068, generation=168.0000, generation_time=0.0238
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 169: hypervolume=0.8661, igd=0.0056, gd=0.0062, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0074, generation=169.0000, generation_time=0.0302
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 170: hypervolume=0.8665, igd=0.0056, gd=0.0063, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0065, generation=170.0000, generation_time=0.0327
# Survival counts by operator: {np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(21)}
# Gen 171: hypervolume=0.8666, igd=0.0056, gd=0.0062, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0061, generation=171.0000, generation_time=0.0159
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 172: hypervolume=0.8667, igd=0.0055, gd=0.0062, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0060, generation=172.0000, generation_time=0.0245
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 173: hypervolume=0.8667, igd=0.0056, gd=0.0063, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0061, generation=173.0000, generation_time=0.0275
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 174: hypervolume=0.8667, igd=0.0057, gd=0.0063, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0061, generation=174.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 175: hypervolume=0.8668, igd=0.0056, gd=0.0059, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0063, generation=175.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(18)}
# Gen 176: hypervolume=0.8668, igd=0.0056, gd=0.0059, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0067, generation=176.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(16)}
# Gen 177: hypervolume=0.8671, igd=0.0053, gd=0.0057, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0058, generation=177.0000, generation_time=0.0123
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(10), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 178: hypervolume=0.8672, igd=0.0054, gd=0.0058, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0064, generation=178.0000, generation_time=0.0320
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 179: hypervolume=0.8671, igd=0.0055, gd=0.0058, gd_plus=0.0044, igd_plus=0.0048, spacing=0.0066, generation=179.0000, generation_time=0.0162
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 180: hypervolume=0.8670, igd=0.0056, gd=0.0057, gd_plus=0.0044, igd_plus=0.0048, spacing=0.0067, generation=180.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(18), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 181: hypervolume=0.8670, igd=0.0055, gd=0.0057, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0062, generation=181.0000, generation_time=0.0230
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 182: hypervolume=0.8671, igd=0.0054, gd=0.0059, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0064, generation=182.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 183: hypervolume=0.8674, igd=0.0054, gd=0.0060, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0067, generation=183.0000, generation_time=0.0159
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(11), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 184: hypervolume=0.8674, igd=0.0053, gd=0.0059, gd_plus=0.0042, igd_plus=0.0047, spacing=0.0059, generation=184.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 185: hypervolume=0.8674, igd=0.0053, gd=0.0057, gd_plus=0.0041, igd_plus=0.0046, spacing=0.0068, generation=185.0000, generation_time=0.0174
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(13), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 186: hypervolume=0.8673, igd=0.0055, gd=0.0060, gd_plus=0.0041, igd_plus=0.0048, spacing=0.0076, generation=186.0000, generation_time=0.0214
# Survival counts by operator: {np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(12)}
# Gen 187: hypervolume=0.8675, igd=0.0054, gd=0.0060, gd_plus=0.0041, igd_plus=0.0047, spacing=0.0075, generation=187.0000, generation_time=0.0274
# Survival counts by operator: {np.str_('parent'): np.int64(64), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(19)}
# Gen 188: hypervolume=0.8676, igd=0.0052, gd=0.0059, gd_plus=0.0040, igd_plus=0.0046, spacing=0.0079, generation=188.0000, generation_time=0.0258
# Survival counts by operator: {np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(17)}
# Gen 189: hypervolume=0.8675, igd=0.0054, gd=0.0058, gd_plus=0.0039, igd_plus=0.0047, spacing=0.0076, generation=189.0000, generation_time=0.0330
# Survival counts by operator: {np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(7)}
# Gen 190: hypervolume=0.8674, igd=0.0054, gd=0.0058, gd_plus=0.0040, igd_plus=0.0047, spacing=0.0074, generation=190.0000, generation_time=0.0178
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 191: hypervolume=0.8678, igd=0.0051, gd=0.0058, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0067, generation=191.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 192: hypervolume=0.8678, igd=0.0051, gd=0.0058, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0070, generation=192.0000, generation_time=0.0240
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 193: hypervolume=0.8677, igd=0.0052, gd=0.0056, gd_plus=0.0040, igd_plus=0.0045, spacing=0.0065, generation=193.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(15)}
# Gen 194: hypervolume=0.8678, igd=0.0052, gd=0.0055, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0068, generation=194.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(10)}
# Gen 195: hypervolume=0.8679, igd=0.0051, gd=0.0059, gd_plus=0.0039, igd_plus=0.0044, spacing=0.0067, generation=195.0000, generation_time=0.0125
# Survival counts by operator: {np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(12), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 196: hypervolume=0.8678, igd=0.0052, gd=0.0058, gd_plus=0.0037, igd_plus=0.0044, spacing=0.0062, generation=196.0000, generation_time=0.0216
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(19), np.str_('single_point_crossover_batch'): np.int64(11)}
# Gen 197: hypervolume=0.8676, igd=0.0056, gd=0.0058, gd_plus=0.0038, igd_plus=0.0046, spacing=0.0075, generation=197.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(16), np.str_('single_point_crossover_batch'): np.int64(14)}
# Gen 198: hypervolume=0.8678, igd=0.0055, gd=0.0056, gd_plus=0.0038, igd_plus=0.0044, spacing=0.0069, generation=198.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(21), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 199: hypervolume=0.8678, igd=0.0055, gd=0.0057, gd_plus=0.0039, igd_plus=0.0045, spacing=0.0076, generation=199.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14), np.str_('single_point_crossover_batch'): np.int64(13)}
# Gen 200: hypervolume=0.8682, igd=0.0053, gd=0.0059, gd_plus=0.0038, igd_plus=0.0043, spacing=0.0074, generation=200.0000, generation_time=0.0128
# Seed 1 - Number of Pareto front points: 100

# %%
### Cell 8: Save Combined Metrics History to Excel 
import pandas as pd
import re

# Convert the all_metrics list to DataFrame
df_metrics = pd.DataFrame(all_metrics)

# Sanitize problem name for filename
problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem.__class__.__name__).lower()


# Define a mapping from the full crossover operator names to shortcuts
crossover_shortcuts = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}

# Convert selected crossover operator names to their shortcut representation
selected_crossover_shortcut_names = [
    crossover_shortcuts.get(name, name) for name in selected_crossover_operator_names
]

# Join the shortcuts into a single string (e.g., "sbx-blx")
crossover_str = "-".join(selected_crossover_shortcut_names)

# Create valid filename
excel_filename = (
    f"{problem_name_clean} {len(selected_crossover_operator_names)} {crossover_str} cross poly "
    f"{pop_size}pop {generations}gen experiment2 PVOS-2C.xlsx"
)

#{crossover_str}

# Save to Excel
df_metrics.to_excel(excel_filename, index=False)
print(f"Metrics saved to '{excel_filename}'")
# Out:
# Metrics saved to 'zdt1 2 sbx-blx cross poly 100pop 200gen experiment2 PVOS-2C.xlsx'

# %%
# Cell 9: Sequential Study for Different Crossover Combinations

import pandas as pd
import re
from joblib import Parallel, delayed
from pymoo.problems import get_problem

# Define a dictionary mapping full operator names to short names (as in Cell 8)
crossover_shortcuts = {
    "simulated_binary_crossover_batch": "sbx",
    "blend_crossover_batch": "blx",
    "single_point_crossover_batch": "spx",
    "uniform_crossover_batch": "ux"
}

# Define the list of crossover combinations to study.
# Each combination is a list of operator names.
crossover_combinations = [
    ["simulated_binary_crossover_batch", "blend_crossover_batch"],           # sbx-blx
    ["simulated_binary_crossover_batch", "uniform_crossover_batch"],         # sbx-ux
    ["single_point_crossover_batch", "blend_crossover_batch"],               # spx-blx
    ["single_point_crossover_batch", "uniform_crossover_batch"],             # spx-ux
    ["blend_crossover_batch", "uniform_crossover_batch"],                    # blx-ux

]


# Loop over each crossover combination
for combination in crossover_combinations:
    # Set the selected crossover operators for this run.
    selected_crossover_operator_names = combination
    
    # Create a short string to represent the combination (e.g., "sbx-spx")
    comb_str = "-".join([crossover_shortcuts.get(name, name) for name in combination])
    print(f"\n=== Running NSGA-II for crossover combination: {comb_str} ===")
    
    # Run NSGA-II over multiple seeds using the provided run_nsga2_for_seed function.
    # (Adjust the seed range and number.)
    seeds = range(1, 31)
    results = Parallel(n_jobs=1)(delayed(run_nsga2_for_seed)(seed) for seed in seeds)
    
    # Collect all metrics from the runs
    all_metrics = []
    for res in results:
        all_metrics.extend(res['metrics_history'])
    
    # Create a DataFrame of the metrics
    df_metrics = pd.DataFrame(all_metrics)
    

    problem_instance = get_problem_dynamic(problem_name, n_var=n_var, n_obj=n_obj)
    problem_name_clean = re.sub(r'[^a-zA-Z0-9_]', '', problem_instance.__class__.__name__).lower()
    
    # Construct the filename with the combination, population, and generation info.
     
    excel_filename = f"{problem_name_clean} {len(selected_crossover_operator_names)} {comb_str} cross poly {pop_size}pop {generations}gen experiment2 PVOS-2C.xlsx"
    # Save the metrics DataFrame to Excel
    df_metrics.to_excel(excel_filename, index=False)
    print(f"Metrics for {comb_str} saved to '{excel_filename}'")
# Out:
# === Running NSGA-II for crossover combination: sbx-blx ===
#
# === Running NSGA-II with seed 1 ===
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(30), np.str_('parent'): np.int64(40), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 1: hypervolume=0.0000, igd=1.9632, gd=2.4815, gd_plus=2.4815, igd_plus=1.9632, spacing=0.1077, generation=1.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(26), np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 2: hypervolume=0.0000, igd=1.9158, gd=2.3262, gd_plus=2.3262, igd_plus=1.9158, spacing=0.0684, generation=2.0000, generation_time=0.0149
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 3: hypervolume=0.0000, igd=1.8303, gd=2.3805, gd_plus=2.3805, igd_plus=1.8303, spacing=0.1324, generation=3.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(26), np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 4: hypervolume=0.0000, igd=1.5949, gd=2.0260, gd_plus=2.0260, igd_plus=1.5896, spacing=0.0748, generation=4.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(28), np.str_('parent'): np.int64(40), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 5: hypervolume=0.0000, igd=1.3236, gd=1.8915, gd_plus=1.8915, igd_plus=1.3236, spacing=0.1861, generation=5.0000, generation_time=0.0174
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 6: hypervolume=0.0000, igd=1.3236, gd=1.8300, gd_plus=1.8300, igd_plus=1.3236, spacing=0.1531, generation=6.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(27), np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 7: hypervolume=0.0000, igd=1.2571, gd=1.4133, gd_plus=1.4133, igd_plus=1.2571, spacing=0.1234, generation=7.0000, generation_time=0.0149
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(32), np.str_('parent'): np.int64(37), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 8: hypervolume=0.0000, igd=1.0556, gd=1.2892, gd_plus=1.2892, igd_plus=1.0556, spacing=0.0811, generation=8.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(27), np.str_('parent'): np.int64(40), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 9: hypervolume=0.0000, igd=1.0009, gd=1.2263, gd_plus=1.2263, igd_plus=1.0009, spacing=0.0734, generation=9.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(26), np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 10: hypervolume=0.0000, igd=0.9099, gd=1.0331, gd_plus=1.0331, igd_plus=0.9098, spacing=0.0837, generation=10.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(26), np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(25)}
# Gen 11: hypervolume=0.0182, igd=0.8388, gd=0.9819, gd_plus=0.9819, igd_plus=0.8388, spacing=0.0526, generation=11.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(27), np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 12: hypervolume=0.0382, igd=0.7954, gd=0.9169, gd_plus=0.9169, igd_plus=0.7954, spacing=0.0382, generation=12.0000, generation_time=0.0213
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(43), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 13: hypervolume=0.0782, igd=0.6444, gd=0.8171, gd_plus=0.8171, igd_plus=0.6443, spacing=0.0885, generation=13.0000, generation_time=0.0191
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(24), np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 14: hypervolume=0.0928, igd=0.6252, gd=0.6840, gd_plus=0.6840, igd_plus=0.6251, spacing=0.0639, generation=14.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(44), np.str_('simulated_binary_crossover_batch'): np.int64(31)}
# Gen 15: hypervolume=0.1843, igd=0.5366, gd=0.6058, gd_plus=0.6058, igd_plus=0.5360, spacing=0.0665, generation=15.0000, generation_time=0.0149
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(34)}
# Gen 16: hypervolume=0.1882, igd=0.5297, gd=0.5841, gd_plus=0.5841, igd_plus=0.5293, spacing=0.0621, generation=16.0000, generation_time=0.0161
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 17: hypervolume=0.2474, igd=0.4502, gd=0.4951, gd_plus=0.4951, igd_plus=0.4496, spacing=0.0656, generation=17.0000, generation_time=0.0172
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(28), np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(25)}
# Gen 18: hypervolume=0.2654, igd=0.4336, gd=0.5028, gd_plus=0.5028, igd_plus=0.4336, spacing=0.0448, generation=18.0000, generation_time=0.0164
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(27), np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 19: hypervolume=0.3017, igd=0.4006, gd=0.4639, gd_plus=0.4639, igd_plus=0.4006, spacing=0.0537, generation=19.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(48), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 20: hypervolume=0.3384, igd=0.3539, gd=0.4167, gd_plus=0.4167, igd_plus=0.3539, spacing=0.0366, generation=20.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(22), np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(33)}
# Gen 21: hypervolume=0.3684, igd=0.3404, gd=0.4076, gd_plus=0.4076, igd_plus=0.3404, spacing=0.0275, generation=21.0000, generation_time=0.0153
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 22: hypervolume=0.4048, igd=0.3195, gd=0.3344, gd_plus=0.3344, igd_plus=0.3195, spacing=0.0231, generation=22.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 23: hypervolume=0.4315, igd=0.2950, gd=0.3131, gd_plus=0.3130, igd_plus=0.2950, spacing=0.0251, generation=23.0000, generation_time=0.0276
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(24), np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(30)}
# Gen 24: hypervolume=0.4607, igd=0.2750, gd=0.3100, gd_plus=0.3099, igd_plus=0.2750, spacing=0.0300, generation=24.0000, generation_time=0.0270
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 25: hypervolume=0.4760, igd=0.2635, gd=0.2683, gd_plus=0.2682, igd_plus=0.2635, spacing=0.0358, generation=25.0000, generation_time=0.0254
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 26: hypervolume=0.4914, igd=0.2496, gd=0.2590, gd_plus=0.2589, igd_plus=0.2496, spacing=0.0307, generation=26.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(29), np.str_('parent'): np.int64(42), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 27: hypervolume=0.5158, igd=0.2263, gd=0.2349, gd_plus=0.2348, igd_plus=0.2262, spacing=0.0177, generation=27.0000, generation_time=0.0164
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(50), np.str_('simulated_binary_crossover_batch'): np.int64(32)}
# Gen 28: hypervolume=0.5374, igd=0.2115, gd=0.2294, gd_plus=0.2293, igd_plus=0.2115, spacing=0.0254, generation=28.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(26), np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 29: hypervolume=0.5644, igd=0.1928, gd=0.2099, gd_plus=0.2098, igd_plus=0.1928, spacing=0.0272, generation=29.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 30: hypervolume=0.5801, igd=0.1881, gd=0.2023, gd_plus=0.2023, igd_plus=0.1881, spacing=0.0173, generation=30.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(47), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 31: hypervolume=0.6004, igd=0.1737, gd=0.1895, gd_plus=0.1895, igd_plus=0.1737, spacing=0.0199, generation=31.0000, generation_time=0.0310
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(51), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 32: hypervolume=0.6202, igd=0.1600, gd=0.1725, gd_plus=0.1725, igd_plus=0.1600, spacing=0.0229, generation=32.0000, generation_time=0.0240
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(53), np.str_('simulated_binary_crossover_batch'): np.int64(22)}
# Gen 33: hypervolume=0.6455, igd=0.1400, gd=0.1496, gd_plus=0.1496, igd_plus=0.1400, spacing=0.0319, generation=33.0000, generation_time=0.0339
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(46), np.str_('simulated_binary_crossover_batch'): np.int64(29)}
# Gen 34: hypervolume=0.6687, igd=0.1248, gd=0.1285, gd_plus=0.1281, igd_plus=0.1247, spacing=0.0244, generation=34.0000, generation_time=0.0211
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(24), np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(21)}
# Gen 35: hypervolume=0.6795, igd=0.1181, gd=0.1238, gd_plus=0.1237, igd_plus=0.1181, spacing=0.0190, generation=35.0000, generation_time=0.0255
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(24)}
# Gen 36: hypervolume=0.6966, igd=0.1085, gd=0.1155, gd_plus=0.1151, igd_plus=0.1084, spacing=0.0193, generation=36.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(22), np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 37: hypervolume=0.7071, igd=0.1019, gd=0.1095, gd_plus=0.1088, igd_plus=0.1018, spacing=0.0189, generation=37.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 38: hypervolume=0.7221, igd=0.0898, gd=0.1018, gd_plus=0.1015, igd_plus=0.0896, spacing=0.0180, generation=38.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(22), np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(26)}
# Gen 39: hypervolume=0.7349, igd=0.0846, gd=0.0901, gd_plus=0.0894, igd_plus=0.0844, spacing=0.0201, generation=39.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(52), np.str_('simulated_binary_crossover_batch'): np.int64(27)}
# Gen 40: hypervolume=0.7440, igd=0.0796, gd=0.0855, gd_plus=0.0848, igd_plus=0.0795, spacing=0.0161, generation=40.0000, generation_time=0.0216
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(27), np.str_('parent'): np.int64(45), np.str_('simulated_binary_crossover_batch'): np.int64(28)}
# Gen 41: hypervolume=0.7555, igd=0.0734, gd=0.0741, gd_plus=0.0735, igd_plus=0.0732, spacing=0.0141, generation=41.0000, generation_time=0.0299
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(29), np.str_('parent'): np.int64(49), np.str_('simulated_binary_crossover_batch'): np.int64(22)}
# Gen 42: hypervolume=0.7639, igd=0.0673, gd=0.0691, gd_plus=0.0686, igd_plus=0.0672, spacing=0.0124, generation=42.0000, generation_time=0.0297
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(54), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 43: hypervolume=0.7733, igd=0.0620, gd=0.0649, gd_plus=0.0643, igd_plus=0.0620, spacing=0.0131, generation=43.0000, generation_time=0.0324
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(22), np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 44: hypervolume=0.7809, igd=0.0573, gd=0.0601, gd_plus=0.0595, igd_plus=0.0573, spacing=0.0139, generation=44.0000, generation_time=0.0170
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(21)}
# Gen 45: hypervolume=0.7855, igd=0.0549, gd=0.0573, gd_plus=0.0568, igd_plus=0.0549, spacing=0.0111, generation=45.0000, generation_time=0.0192
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(61), np.str_('simulated_binary_crossover_batch'): np.int64(25)}
# Gen 46: hypervolume=0.7916, igd=0.0509, gd=0.0547, gd_plus=0.0541, igd_plus=0.0509, spacing=0.0098, generation=46.0000, generation_time=0.0200
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(56), np.str_('simulated_binary_crossover_batch'): np.int64(24)}
# Gen 47: hypervolume=0.7970, igd=0.0471, gd=0.0499, gd_plus=0.0493, igd_plus=0.0471, spacing=0.0113, generation=47.0000, generation_time=0.0206
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(19), np.str_('parent'): np.int64(59), np.str_('simulated_binary_crossover_batch'): np.int64(22)}
# Gen 48: hypervolume=0.8051, igd=0.0418, gd=0.0440, gd_plus=0.0434, igd_plus=0.0418, spacing=0.0117, generation=48.0000, generation_time=0.0232
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 49: hypervolume=0.8074, igd=0.0404, gd=0.0432, gd_plus=0.0422, igd_plus=0.0404, spacing=0.0102, generation=49.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(22), np.str_('parent'): np.int64(55), np.str_('simulated_binary_crossover_batch'): np.int64(23)}
# Gen 50: hypervolume=0.8128, igd=0.0372, gd=0.0394, gd_plus=0.0384, igd_plus=0.0371, spacing=0.0099, generation=50.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(23), np.str_('parent'): np.int64(58), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 51: hypervolume=0.8172, igd=0.0352, gd=0.0363, gd_plus=0.0355, igd_plus=0.0351, spacing=0.0079, generation=51.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(19), np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 52: hypervolume=0.8210, igd=0.0326, gd=0.0344, gd_plus=0.0336, igd_plus=0.0325, spacing=0.0077, generation=52.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 53: hypervolume=0.8244, igd=0.0307, gd=0.0322, gd_plus=0.0311, igd_plus=0.0307, spacing=0.0062, generation=53.0000, generation_time=0.0175
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 54: hypervolume=0.8271, igd=0.0291, gd=0.0303, gd_plus=0.0295, igd_plus=0.0290, spacing=0.0064, generation=54.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 55: hypervolume=0.8289, igd=0.0281, gd=0.0292, gd_plus=0.0284, igd_plus=0.0280, spacing=0.0058, generation=55.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 56: hypervolume=0.8306, igd=0.0268, gd=0.0280, gd_plus=0.0272, igd_plus=0.0268, spacing=0.0056, generation=56.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 57: hypervolume=0.8325, igd=0.0258, gd=0.0271, gd_plus=0.0262, igd_plus=0.0258, spacing=0.0063, generation=57.0000, generation_time=0.0208
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(63), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 58: hypervolume=0.8347, igd=0.0244, gd=0.0261, gd_plus=0.0252, igd_plus=0.0244, spacing=0.0058, generation=58.0000, generation_time=0.0282
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 59: hypervolume=0.8362, igd=0.0233, gd=0.0248, gd_plus=0.0239, igd_plus=0.0233, spacing=0.0069, generation=59.0000, generation_time=0.0243
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 60: hypervolume=0.8379, igd=0.0220, gd=0.0235, gd_plus=0.0226, igd_plus=0.0220, spacing=0.0062, generation=60.0000, generation_time=0.0256
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 61: hypervolume=0.8403, igd=0.0208, gd=0.0221, gd_plus=0.0212, igd_plus=0.0207, spacing=0.0062, generation=61.0000, generation_time=0.0147
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(25), np.str_('parent'): np.int64(60), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 62: hypervolume=0.8436, igd=0.0189, gd=0.0204, gd_plus=0.0193, igd_plus=0.0187, spacing=0.0064, generation=62.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 63: hypervolume=0.8454, igd=0.0178, gd=0.0192, gd_plus=0.0182, igd_plus=0.0176, spacing=0.0069, generation=63.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 64: hypervolume=0.8476, igd=0.0165, gd=0.0177, gd_plus=0.0168, igd_plus=0.0163, spacing=0.0070, generation=64.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 65: hypervolume=0.8490, igd=0.0156, gd=0.0171, gd_plus=0.0159, igd_plus=0.0155, spacing=0.0060, generation=65.0000, generation_time=0.0134
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 66: hypervolume=0.8500, igd=0.0149, gd=0.0163, gd_plus=0.0150, igd_plus=0.0148, spacing=0.0056, generation=66.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 67: hypervolume=0.8514, igd=0.0141, gd=0.0155, gd_plus=0.0142, igd_plus=0.0139, spacing=0.0058, generation=67.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(62), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 68: hypervolume=0.8527, igd=0.0136, gd=0.0147, gd_plus=0.0137, igd_plus=0.0134, spacing=0.0047, generation=68.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(9), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 69: hypervolume=0.8535, igd=0.0132, gd=0.0142, gd_plus=0.0133, igd_plus=0.0130, spacing=0.0055, generation=69.0000, generation_time=0.0132
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 70: hypervolume=0.8545, igd=0.0125, gd=0.0134, gd_plus=0.0124, igd_plus=0.0124, spacing=0.0054, generation=70.0000, generation_time=0.0166
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 71: hypervolume=0.8552, igd=0.0121, gd=0.0129, gd_plus=0.0119, igd_plus=0.0119, spacing=0.0068, generation=71.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 72: hypervolume=0.8551, igd=0.0120, gd=0.0131, gd_plus=0.0117, igd_plus=0.0118, spacing=0.0064, generation=72.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 73: hypervolume=0.8557, igd=0.0117, gd=0.0129, gd_plus=0.0113, igd_plus=0.0116, spacing=0.0067, generation=73.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 74: hypervolume=0.8561, igd=0.0117, gd=0.0126, gd_plus=0.0110, igd_plus=0.0115, spacing=0.0060, generation=74.0000, generation_time=0.0199
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 75: hypervolume=0.8561, igd=0.0116, gd=0.0124, gd_plus=0.0107, igd_plus=0.0114, spacing=0.0053, generation=75.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 76: hypervolume=0.8568, igd=0.0111, gd=0.0118, gd_plus=0.0105, igd_plus=0.0109, spacing=0.0059, generation=76.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(10), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 77: hypervolume=0.8578, igd=0.0107, gd=0.0113, gd_plus=0.0101, igd_plus=0.0105, spacing=0.0065, generation=77.0000, generation_time=0.0174
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 78: hypervolume=0.8579, igd=0.0105, gd=0.0116, gd_plus=0.0100, igd_plus=0.0103, spacing=0.0062, generation=78.0000, generation_time=0.0123
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(19), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 79: hypervolume=0.8583, igd=0.0102, gd=0.0112, gd_plus=0.0099, igd_plus=0.0100, spacing=0.0061, generation=79.0000, generation_time=0.0275
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(20)}
# Gen 80: hypervolume=0.8590, igd=0.0098, gd=0.0106, gd_plus=0.0092, igd_plus=0.0096, spacing=0.0066, generation=80.0000, generation_time=0.0182
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 81: hypervolume=0.8591, igd=0.0101, gd=0.0106, gd_plus=0.0093, igd_plus=0.0097, spacing=0.0059, generation=81.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 82: hypervolume=0.8597, igd=0.0096, gd=0.0102, gd_plus=0.0090, igd_plus=0.0093, spacing=0.0060, generation=82.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 83: hypervolume=0.8601, igd=0.0093, gd=0.0100, gd_plus=0.0087, igd_plus=0.0091, spacing=0.0053, generation=83.0000, generation_time=0.0268
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(9), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 84: hypervolume=0.8604, igd=0.0091, gd=0.0099, gd_plus=0.0085, igd_plus=0.0089, spacing=0.0049, generation=84.0000, generation_time=0.0171
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 85: hypervolume=0.8607, igd=0.0089, gd=0.0101, gd_plus=0.0084, igd_plus=0.0087, spacing=0.0058, generation=85.0000, generation_time=0.0195
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 86: hypervolume=0.8607, igd=0.0088, gd=0.0095, gd_plus=0.0080, igd_plus=0.0085, spacing=0.0061, generation=86.0000, generation_time=0.0129
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 87: hypervolume=0.8607, igd=0.0089, gd=0.0092, gd_plus=0.0079, igd_plus=0.0086, spacing=0.0056, generation=87.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(8)}
# Gen 88: hypervolume=0.8612, igd=0.0085, gd=0.0091, gd_plus=0.0077, igd_plus=0.0082, spacing=0.0058, generation=88.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 89: hypervolume=0.8614, igd=0.0085, gd=0.0088, gd_plus=0.0074, igd_plus=0.0081, spacing=0.0060, generation=89.0000, generation_time=0.0125
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 90: hypervolume=0.8620, igd=0.0082, gd=0.0087, gd_plus=0.0073, igd_plus=0.0078, spacing=0.0054, generation=90.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(9)}
# Gen 91: hypervolume=0.8623, igd=0.0079, gd=0.0088, gd_plus=0.0073, igd_plus=0.0076, spacing=0.0056, generation=91.0000, generation_time=0.0124
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 92: hypervolume=0.8621, igd=0.0080, gd=0.0086, gd_plus=0.0073, igd_plus=0.0077, spacing=0.0070, generation=92.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 93: hypervolume=0.8624, igd=0.0080, gd=0.0086, gd_plus=0.0074, igd_plus=0.0077, spacing=0.0072, generation=93.0000, generation_time=0.0296
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 94: hypervolume=0.8622, igd=0.0081, gd=0.0086, gd_plus=0.0073, igd_plus=0.0077, spacing=0.0069, generation=94.0000, generation_time=0.0284
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 95: hypervolume=0.8624, igd=0.0078, gd=0.0082, gd_plus=0.0069, igd_plus=0.0075, spacing=0.0080, generation=95.0000, generation_time=0.0244
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 96: hypervolume=0.8627, igd=0.0079, gd=0.0084, gd_plus=0.0070, igd_plus=0.0075, spacing=0.0066, generation=96.0000, generation_time=0.0252
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 97: hypervolume=0.8628, igd=0.0075, gd=0.0084, gd_plus=0.0069, igd_plus=0.0073, spacing=0.0065, generation=97.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 98: hypervolume=0.8630, igd=0.0077, gd=0.0086, gd_plus=0.0068, igd_plus=0.0074, spacing=0.0064, generation=98.0000, generation_time=0.0188
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 99: hypervolume=0.8629, igd=0.0076, gd=0.0082, gd_plus=0.0064, igd_plus=0.0073, spacing=0.0071, generation=99.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(20)}
# Gen 100: hypervolume=0.8635, igd=0.0073, gd=0.0084, gd_plus=0.0067, igd_plus=0.0070, spacing=0.0071, generation=100.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 101: hypervolume=0.8635, igd=0.0073, gd=0.0084, gd_plus=0.0068, igd_plus=0.0071, spacing=0.0064, generation=101.0000, generation_time=0.0172
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 102: hypervolume=0.8630, igd=0.0076, gd=0.0082, gd_plus=0.0066, igd_plus=0.0073, spacing=0.0065, generation=102.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 103: hypervolume=0.8630, igd=0.0078, gd=0.0082, gd_plus=0.0068, igd_plus=0.0074, spacing=0.0062, generation=103.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 104: hypervolume=0.8635, igd=0.0074, gd=0.0080, gd_plus=0.0066, igd_plus=0.0071, spacing=0.0060, generation=104.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 105: hypervolume=0.8635, igd=0.0075, gd=0.0079, gd_plus=0.0065, igd_plus=0.0070, spacing=0.0062, generation=105.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(21), np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 106: hypervolume=0.8644, igd=0.0071, gd=0.0078, gd_plus=0.0062, igd_plus=0.0066, spacing=0.0056, generation=106.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 107: hypervolume=0.8646, igd=0.0071, gd=0.0079, gd_plus=0.0061, igd_plus=0.0065, spacing=0.0060, generation=107.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(9), np.str_('parent'): np.int64(81), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 108: hypervolume=0.8645, igd=0.0069, gd=0.0079, gd_plus=0.0062, igd_plus=0.0064, spacing=0.0069, generation=108.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 109: hypervolume=0.8647, igd=0.0067, gd=0.0078, gd_plus=0.0061, igd_plus=0.0063, spacing=0.0063, generation=109.0000, generation_time=0.0136
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 110: hypervolume=0.8650, igd=0.0067, gd=0.0077, gd_plus=0.0060, igd_plus=0.0063, spacing=0.0066, generation=110.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 111: hypervolume=0.8653, igd=0.0066, gd=0.0080, gd_plus=0.0059, igd_plus=0.0062, spacing=0.0052, generation=111.0000, generation_time=0.0294
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 112: hypervolume=0.8655, igd=0.0065, gd=0.0074, gd_plus=0.0058, igd_plus=0.0061, spacing=0.0065, generation=112.0000, generation_time=0.0192
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 113: hypervolume=0.8655, igd=0.0065, gd=0.0076, gd_plus=0.0056, igd_plus=0.0061, spacing=0.0062, generation=113.0000, generation_time=0.0234
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(9), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 114: hypervolume=0.8654, igd=0.0065, gd=0.0075, gd_plus=0.0055, igd_plus=0.0060, spacing=0.0076, generation=114.0000, generation_time=0.0151
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(9)}
# Gen 115: hypervolume=0.8656, igd=0.0065, gd=0.0073, gd_plus=0.0054, igd_plus=0.0059, spacing=0.0069, generation=115.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 116: hypervolume=0.8654, igd=0.0065, gd=0.0072, gd_plus=0.0053, igd_plus=0.0060, spacing=0.0065, generation=116.0000, generation_time=0.0173
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(19), np.str_('parent'): np.int64(66), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 117: hypervolume=0.8657, igd=0.0063, gd=0.0070, gd_plus=0.0054, igd_plus=0.0058, spacing=0.0062, generation=117.0000, generation_time=0.0158
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 118: hypervolume=0.8661, igd=0.0060, gd=0.0064, gd_plus=0.0052, igd_plus=0.0055, spacing=0.0067, generation=118.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 119: hypervolume=0.8653, igd=0.0065, gd=0.0064, gd_plus=0.0051, igd_plus=0.0059, spacing=0.0066, generation=119.0000, generation_time=0.0144
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(76), np.str_('simulated_binary_crossover_batch'): np.int64(9)}
# Gen 120: hypervolume=0.8657, igd=0.0063, gd=0.0067, gd_plus=0.0051, igd_plus=0.0057, spacing=0.0070, generation=120.0000, generation_time=0.0177
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(19), np.str_('parent'): np.int64(69), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 121: hypervolume=0.8660, igd=0.0061, gd=0.0066, gd_plus=0.0051, igd_plus=0.0055, spacing=0.0069, generation=121.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 122: hypervolume=0.8666, igd=0.0057, gd=0.0061, gd_plus=0.0048, igd_plus=0.0051, spacing=0.0059, generation=122.0000, generation_time=0.0181
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 123: hypervolume=0.8668, igd=0.0054, gd=0.0062, gd_plus=0.0045, igd_plus=0.0048, spacing=0.0053, generation=123.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(10), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 124: hypervolume=0.8668, igd=0.0056, gd=0.0062, gd_plus=0.0045, igd_plus=0.0050, spacing=0.0053, generation=124.0000, generation_time=0.0273
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 125: hypervolume=0.8668, igd=0.0056, gd=0.0063, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0058, generation=125.0000, generation_time=0.0307
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 126: hypervolume=0.8667, igd=0.0057, gd=0.0063, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0054, generation=126.0000, generation_time=0.0208
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 127: hypervolume=0.8669, igd=0.0056, gd=0.0063, gd_plus=0.0047, igd_plus=0.0051, spacing=0.0054, generation=127.0000, generation_time=0.0155
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 128: hypervolume=0.8666, igd=0.0058, gd=0.0064, gd_plus=0.0046, igd_plus=0.0053, spacing=0.0065, generation=128.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 129: hypervolume=0.8665, igd=0.0057, gd=0.0061, gd_plus=0.0046, igd_plus=0.0052, spacing=0.0060, generation=129.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 130: hypervolume=0.8665, igd=0.0058, gd=0.0065, gd_plus=0.0045, igd_plus=0.0052, spacing=0.0068, generation=130.0000, generation_time=0.0201
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 131: hypervolume=0.8667, igd=0.0057, gd=0.0067, gd_plus=0.0046, igd_plus=0.0051, spacing=0.0067, generation=131.0000, generation_time=0.0300
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 132: hypervolume=0.8669, igd=0.0056, gd=0.0063, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0067, generation=132.0000, generation_time=0.0258
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 133: hypervolume=0.8669, igd=0.0055, gd=0.0061, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0071, generation=133.0000, generation_time=0.0333
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(65), np.str_('simulated_binary_crossover_batch'): np.int64(19)}
# Gen 134: hypervolume=0.8671, igd=0.0056, gd=0.0066, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0066, generation=134.0000, generation_time=0.0259
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(70), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 135: hypervolume=0.8670, igd=0.0056, gd=0.0068, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0066, generation=135.0000, generation_time=0.0125
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 136: hypervolume=0.8668, igd=0.0058, gd=0.0066, gd_plus=0.0045, igd_plus=0.0051, spacing=0.0071, generation=136.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 137: hypervolume=0.8671, igd=0.0055, gd=0.0065, gd_plus=0.0042, igd_plus=0.0048, spacing=0.0072, generation=137.0000, generation_time=0.0222
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(10)}
# Gen 138: hypervolume=0.8673, igd=0.0053, gd=0.0067, gd_plus=0.0043, igd_plus=0.0047, spacing=0.0060, generation=138.0000, generation_time=0.0202
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 139: hypervolume=0.8671, igd=0.0053, gd=0.0065, gd_plus=0.0042, igd_plus=0.0048, spacing=0.0073, generation=139.0000, generation_time=0.0201
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 140: hypervolume=0.8674, igd=0.0052, gd=0.0062, gd_plus=0.0043, igd_plus=0.0046, spacing=0.0062, generation=140.0000, generation_time=0.0320
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(18)}
# Gen 141: hypervolume=0.8669, igd=0.0058, gd=0.0059, gd_plus=0.0044, igd_plus=0.0049, spacing=0.0082, generation=141.0000, generation_time=0.0275
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(75), np.str_('simulated_binary_crossover_batch'): np.int64(11)}
# Gen 142: hypervolume=0.8669, igd=0.0057, gd=0.0064, gd_plus=0.0043, igd_plus=0.0048, spacing=0.0073, generation=142.0000, generation_time=0.0277
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 143: hypervolume=0.8669, igd=0.0058, gd=0.0065, gd_plus=0.0044, igd_plus=0.0050, spacing=0.0074, generation=143.0000, generation_time=0.0165
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(71), np.str_('simulated_binary_crossover_batch'): np.int64(17)}
# Gen 144: hypervolume=0.8670, igd=0.0059, gd=0.0065, gd_plus=0.0044, igd_plus=0.0051, spacing=0.0077, generation=144.0000, generation_time=0.0152
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 145: hypervolume=0.8671, igd=0.0059, gd=0.0066, gd_plus=0.0047, igd_plus=0.0052, spacing=0.0075, generation=145.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(8), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(20)}
# Gen 146: hypervolume=0.8672, igd=0.0059, gd=0.0064, gd_plus=0.0044, igd_plus=0.0050, spacing=0.0065, generation=146.0000, generation_time=0.0277
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(72), np.str_('simulated_binary_crossover_batch'): np.int64(13)}
# Gen 147: hypervolume=0.8674, igd=0.0057, gd=0.0066, gd_plus=0.0045, igd_plus=0.0049, spacing=0.0062, generation=147.0000, generation_time=0.0321
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(15)}
# Gen 148: hypervolume=0.8676, igd=0.0055, gd=0.0066, gd_plus=0.0046, igd_plus=0.0048, spacing=0.0057, generation=148.0000, generation_time=0.0390
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(67), np.str_('simulated_binary_crossover_batch'): np.int64(16)}
# Gen 149: hypervolume=0.8676, igd=0.0055, gd=0.0065, gd_plus=0.0044, igd_plus=0.0048, spacing=0.0054, generation=149.0000, generation_time=0.0320
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# Gen 150: hypervolume=0.8670, igd=0.0058, gd=0.0066, gd_plus=0.0047, igd_plus=0.0050, spacing=0.0062, generation=150.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 151: hypervolume=0.8668, igd=0.0058, gd=0.0066, gd_plus=0.0046, igd_plus=0.0050, spacing=0.0069, generation=151.0000, generation_time=0.0288
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(77), np.str_('simulated_binary_crossover_batch'): np.int64(12)}
# Gen 152: hypervolume=0.8672, igd=0.0055, gd=0.0067, gd_plus=0.0046, igd_plus=0.0049, spacing=0.0063, generation=152.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(68), np.str_('simulated_binary_crossover_batch'): np.int64(14)}
# ...
# Gen 149: hypervolume=0.8702, igd=0.0042, gd=0.0048, gd_plus=0.0028, igd_plus=0.0031, spacing=0.0065, generation=149.0000, generation_time=0.0141
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(75), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 150: hypervolume=0.8697, igd=0.0045, gd=0.0050, gd_plus=0.0030, igd_plus=0.0034, spacing=0.0069, generation=150.0000, generation_time=0.0237
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(19)}
# Gen 151: hypervolume=0.8699, igd=0.0046, gd=0.0051, gd_plus=0.0029, igd_plus=0.0034, spacing=0.0073, generation=151.0000, generation_time=0.0125
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 152: hypervolume=0.8702, igd=0.0045, gd=0.0052, gd_plus=0.0029, igd_plus=0.0033, spacing=0.0068, generation=152.0000, generation_time=0.0140
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(72), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 153: hypervolume=0.8702, igd=0.0045, gd=0.0053, gd_plus=0.0030, igd_plus=0.0032, spacing=0.0065, generation=153.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(16)}
# Gen 154: hypervolume=0.8702, igd=0.0047, gd=0.0053, gd_plus=0.0030, igd_plus=0.0033, spacing=0.0063, generation=154.0000, generation_time=0.0263
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 155: hypervolume=0.8703, igd=0.0048, gd=0.0056, gd_plus=0.0032, igd_plus=0.0034, spacing=0.0057, generation=155.0000, generation_time=0.0146
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(76), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 156: hypervolume=0.8705, igd=0.0046, gd=0.0056, gd_plus=0.0032, igd_plus=0.0032, spacing=0.0056, generation=156.0000, generation_time=0.0160
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(12), np.str_('parent'): np.int64(75), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 157: hypervolume=0.8703, igd=0.0047, gd=0.0056, gd_plus=0.0032, igd_plus=0.0033, spacing=0.0059, generation=157.0000, generation_time=0.0132
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 158: hypervolume=0.8704, igd=0.0046, gd=0.0052, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0063, generation=158.0000, generation_time=0.0242
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 159: hypervolume=0.8701, igd=0.0046, gd=0.0052, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0071, generation=159.0000, generation_time=0.0130
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(20), np.str_('parent'): np.int64(68), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 160: hypervolume=0.8704, igd=0.0045, gd=0.0052, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0057, generation=160.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 161: hypervolume=0.8704, igd=0.0044, gd=0.0049, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0056, generation=161.0000, generation_time=0.0122
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(76), np.str_('uniform_crossover_batch'): np.int64(9)}
# Gen 162: hypervolume=0.8699, igd=0.0046, gd=0.0049, gd_plus=0.0028, igd_plus=0.0034, spacing=0.0059, generation=162.0000, generation_time=0.0125
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 163: hypervolume=0.8703, igd=0.0043, gd=0.0048, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0058, generation=163.0000, generation_time=0.0137
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(10)}
# Gen 164: hypervolume=0.8702, igd=0.0043, gd=0.0050, gd_plus=0.0030, igd_plus=0.0033, spacing=0.0061, generation=164.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(75), np.str_('uniform_crossover_batch'): np.int64(10)}
# Gen 165: hypervolume=0.8704, igd=0.0044, gd=0.0050, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0063, generation=165.0000, generation_time=0.0142
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(72), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 166: hypervolume=0.8702, igd=0.0042, gd=0.0048, gd_plus=0.0029, igd_plus=0.0031, spacing=0.0060, generation=166.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(65), np.str_('uniform_crossover_batch'): np.int64(19)}
# Gen 167: hypervolume=0.8702, igd=0.0044, gd=0.0046, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0058, generation=167.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(72), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 168: hypervolume=0.8704, igd=0.0043, gd=0.0047, gd_plus=0.0028, igd_plus=0.0031, spacing=0.0055, generation=168.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 169: hypervolume=0.8704, igd=0.0045, gd=0.0049, gd_plus=0.0029, igd_plus=0.0032, spacing=0.0063, generation=169.0000, generation_time=0.0145
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(18), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 170: hypervolume=0.8704, igd=0.0047, gd=0.0053, gd_plus=0.0030, igd_plus=0.0033, spacing=0.0067, generation=170.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(71), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 171: hypervolume=0.8705, igd=0.0047, gd=0.0054, gd_plus=0.0031, igd_plus=0.0033, spacing=0.0065, generation=171.0000, generation_time=0.0156
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(68), np.str_('uniform_crossover_batch'): np.int64(17)}
# Gen 172: hypervolume=0.8701, igd=0.0050, gd=0.0053, gd_plus=0.0029, igd_plus=0.0035, spacing=0.0070, generation=172.0000, generation_time=0.0148
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(76), np.str_('uniform_crossover_batch'): np.int64(8)}
# Gen 173: hypervolume=0.8700, igd=0.0052, gd=0.0050, gd_plus=0.0029, igd_plus=0.0036, spacing=0.0064, generation=173.0000, generation_time=0.0201
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 174: hypervolume=0.8698, igd=0.0050, gd=0.0051, gd_plus=0.0030, igd_plus=0.0036, spacing=0.0077, generation=174.0000, generation_time=0.0168
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(11), np.str_('parent'): np.int64(71), np.str_('uniform_crossover_batch'): np.int64(18)}
# Gen 175: hypervolume=0.8703, igd=0.0044, gd=0.0049, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0070, generation=175.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 176: hypervolume=0.8702, igd=0.0045, gd=0.0049, gd_plus=0.0027, igd_plus=0.0033, spacing=0.0062, generation=176.0000, generation_time=0.0221
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(10), np.str_('parent'): np.int64(76), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 177: hypervolume=0.8703, igd=0.0043, gd=0.0048, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0064, generation=177.0000, generation_time=0.0206
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(76), np.str_('uniform_crossover_batch'): np.int64(8)}
# Gen 178: hypervolume=0.8706, igd=0.0041, gd=0.0048, gd_plus=0.0030, igd_plus=0.0031, spacing=0.0053, generation=178.0000, generation_time=0.0275
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(9), np.str_('parent'): np.int64(79), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 179: hypervolume=0.8701, igd=0.0047, gd=0.0048, gd_plus=0.0030, igd_plus=0.0035, spacing=0.0076, generation=179.0000, generation_time=0.0143
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(69), np.str_('uniform_crossover_batch'): np.int64(18)}
# Gen 180: hypervolume=0.8700, igd=0.0047, gd=0.0049, gd_plus=0.0031, igd_plus=0.0036, spacing=0.0070, generation=180.0000, generation_time=0.0154
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(17)}
# Gen 181: hypervolume=0.8699, igd=0.0047, gd=0.0051, gd_plus=0.0030, igd_plus=0.0035, spacing=0.0064, generation=181.0000, generation_time=0.0289
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(69), np.str_('uniform_crossover_batch'): np.int64(18)}
# Gen 182: hypervolume=0.8700, igd=0.0046, gd=0.0049, gd_plus=0.0029, igd_plus=0.0033, spacing=0.0068, generation=182.0000, generation_time=0.0301
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(16)}
# Gen 183: hypervolume=0.8703, igd=0.0044, gd=0.0048, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0067, generation=183.0000, generation_time=0.0182
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(16)}
# Gen 184: hypervolume=0.8703, igd=0.0044, gd=0.0048, gd_plus=0.0027, igd_plus=0.0031, spacing=0.0063, generation=184.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 185: hypervolume=0.8704, igd=0.0044, gd=0.0046, gd_plus=0.0025, igd_plus=0.0031, spacing=0.0073, generation=185.0000, generation_time=0.0139
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(8), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(19)}
# Gen 186: hypervolume=0.8702, igd=0.0047, gd=0.0045, gd_plus=0.0025, igd_plus=0.0033, spacing=0.0078, generation=186.0000, generation_time=0.0135
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(69), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 187: hypervolume=0.8702, igd=0.0047, gd=0.0045, gd_plus=0.0026, igd_plus=0.0033, spacing=0.0070, generation=187.0000, generation_time=0.0249
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(68), np.str_('uniform_crossover_batch'): np.int64(18)}
# Gen 188: hypervolume=0.8701, igd=0.0046, gd=0.0043, gd_plus=0.0025, igd_plus=0.0032, spacing=0.0072, generation=188.0000, generation_time=0.0128
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(71), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 189: hypervolume=0.8704, igd=0.0047, gd=0.0046, gd_plus=0.0026, igd_plus=0.0033, spacing=0.0071, generation=189.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 190: hypervolume=0.8704, igd=0.0047, gd=0.0048, gd_plus=0.0027, igd_plus=0.0033, spacing=0.0077, generation=190.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(75), np.str_('uniform_crossover_batch'): np.int64(12)}
# Gen 191: hypervolume=0.8706, igd=0.0045, gd=0.0048, gd_plus=0.0027, igd_plus=0.0032, spacing=0.0065, generation=191.0000, generation_time=0.0127
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(17), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 192: hypervolume=0.8704, igd=0.0046, gd=0.0049, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0069, generation=192.0000, generation_time=0.0176
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(16), np.str_('parent'): np.int64(71), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 193: hypervolume=0.8704, igd=0.0046, gd=0.0047, gd_plus=0.0028, igd_plus=0.0032, spacing=0.0073, generation=193.0000, generation_time=0.0276
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(16)}
# Gen 194: hypervolume=0.8704, igd=0.0044, gd=0.0047, gd_plus=0.0028, igd_plus=0.0031, spacing=0.0070, generation=194.0000, generation_time=0.0224
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(69), np.str_('uniform_crossover_batch'): np.int64(17)}
# Gen 195: hypervolume=0.8702, igd=0.0045, gd=0.0053, gd_plus=0.0028, igd_plus=0.0033, spacing=0.0069, generation=195.0000, generation_time=0.0131
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(70), np.str_('uniform_crossover_batch'): np.int64(17)}
# Gen 196: hypervolume=0.8706, igd=0.0042, gd=0.0052, gd_plus=0.0027, igd_plus=0.0030, spacing=0.0059, generation=196.0000, generation_time=0.0133
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(74), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 197: hypervolume=0.8708, igd=0.0041, gd=0.0051, gd_plus=0.0027, igd_plus=0.0029, spacing=0.0057, generation=197.0000, generation_time=0.0126
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(13), np.str_('parent'): np.int64(73), np.str_('uniform_crossover_batch'): np.int64(14)}
# Gen 198: hypervolume=0.8709, igd=0.0042, gd=0.0053, gd_plus=0.0027, igd_plus=0.0028, spacing=0.0055, generation=198.0000, generation_time=0.0150
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(15), np.str_('parent'): np.int64(72), np.str_('uniform_crossover_batch'): np.int64(13)}
# Gen 199: hypervolume=0.8707, igd=0.0041, gd=0.0052, gd_plus=0.0028, igd_plus=0.0029, spacing=0.0055, generation=199.0000, generation_time=0.0183
# Survival counts by operator: {np.str_('blend_crossover_batch'): np.int64(14), np.str_('parent'): np.int64(65), np.str_('uniform_crossover_batch'): np.int64(21)}
# Gen 200: hypervolume=0.8708, igd=0.0041, gd=0.0051, gd_plus=0.0027, igd_plus=0.0029, spacing=0.0063, generation=200.0000, generation_time=0.0124
# Metrics for blx-ux saved to 'zdt1 2 blx-ux cross poly 100pop 200gen experiment2 PVOS-2C.xlsx'
